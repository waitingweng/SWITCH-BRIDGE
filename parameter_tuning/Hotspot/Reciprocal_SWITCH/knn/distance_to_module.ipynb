# %%
import scanpy as sc
import anndata as ad
import pandas as pd

# %%
sc.settings.verbosity = 3

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Reciprocal_SWIM/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Reciprocal_SWIM/Cell
# '/home/jovyan/work/parameter_tuning/Reciprocal_SWIM/Cell'

# %%
# import the PCC data
distance_4S = pd.read_csv("distance_4S.csv", index_col=0)
distance_I = pd.read_csv("distance_I.csv", index_col=0)
distance_III = pd.read_csv("distance_III.csv", index_col=0)
distance_IV = pd.read_csv("distance_IV.csv", index_col=0)
# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_4S
# Out:
#               TSPAN6       DPM1      SCYL3   C1orf112        FGR      FUCA2  \
# Symbol
# TSPAN6      0.000000  12.077164  12.114509  10.335746  11.408591  17.414794
# DPM1       12.077164   0.000000  13.671350   9.175476  12.439945  17.244211
# SCYL3      12.114509  13.671350   0.000000  14.081407  13.851651  18.443334
# C1orf112   10.335746   9.175476  14.081407   0.000000  13.429232  13.830080
# FGR        11.408591  12.439945  13.851651  13.429232   0.000000  19.323973
# ...              ...        ...        ...        ...        ...        ...
# LINC01481  11.699586   9.524999  12.324737   9.420976  12.384918  14.043924
# CYB561D2   12.643715  13.760717  16.361050  10.703740  13.617459  14.692915
# CCDC7      12.121853  11.217014  11.015836   9.151178  13.046306  13.085533
# MATR3      17.349253  14.287347  18.235229  16.660671  13.475624  21.051365
# RGS5        6.100851   9.580191   9.967081   9.317383  11.539570  15.836531
#
# ...

# %%
distance_4S = ad.AnnData(X=distance_4S)
distance_I = ad.AnnData(X=distance_I)
distance_III = ad.AnnData(X=distance_III)
distance_IV = ad.AnnData(X=distance_IV)
# distance_NA = ad.AnnData(X=distance_NA)

# %%
distance_4S.name = "distance_4S"
distance_I.name = "distance_I"
distance_III.name = "distance_III"
distance_IV.name = "distance_IV"
# distance_NA.name = "distance_NA"

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_leiden, leiden_to_module, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Reciprocal_SWIM/knn/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Reciprocal_SWIM/knn/Cell
# '/home/jovyan/work/parameter_tuning/Reciprocal_SWIM/knn/Cell'

# %% [markdown]
# 4S

# %%
resolution_values = [1,2,3,4,5,10,15,20,25]  # for n_neighbors=30: 20~260 clusters
# n_Neighbors doesn't affect the number of clusters at all, so don't need to use a large value

for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_4S, data_name="distance_4S", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_4S_{resolution_parameter}.svg")
    module_4S = leiden_to_module(distance_4S)
    module_to_json(module_dict=module_4S, file_path=f"module_4S_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:54)
# IGRAPH U-W- 12390 239115 --
# + attr: weight (e)
# running Leiden clustering
# /home/jovyan/work/FUNCTIONS/methods.py:383: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(data, resolution=resolution)
#     finished: found 22 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)
# Number of modules: 22
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:34)
# IGRAPH U-W- 12390 239115 --
# ...

# %% [markdown]
# I

# %%
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_I, data_name="distance_I", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_I_{resolution_parameter}.svg")
    module_I = leiden_to_module(distance_I)
    module_to_json(module_dict=module_I, file_path=f"module_I_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:36)
# IGRAPH U-W- 12515 241106 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:06)
# Number of modules: 20
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:25)
# IGRAPH U-W- 12515 241106 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 37 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)
# Number of modules: 37
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
# ...

# %% [markdown]
# III

# %%
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_III, data_name="distance_III", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_III_{resolution_parameter}.svg")
    module_III = leiden_to_module(distance_III)
    module_to_json(module_dict=module_III, file_path=f"module_III_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:33)
# IGRAPH U-W- 12707 239207 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 22 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:10)
# Number of modules: 22
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:28)
# IGRAPH U-W- 12707 239207 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 37 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:08)
# Number of modules: 37
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
# ...

# %% [markdown]
# IV

# %%
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_IV, data_name="distance_IV", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_IV_{resolution_parameter}.svg")
    module_IV = leiden_to_module(distance_IV)
    module_to_json(module_dict=module_IV, file_path=f"module_IV_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:26)
# IGRAPH U-W- 12677 240694 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 23 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:15)
# Number of modules: 23
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:32)
# IGRAPH U-W- 12677 240694 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 39 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:10)
# Number of modules: 39
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
# ...
