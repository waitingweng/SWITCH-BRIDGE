# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Linear_SWIM/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Linear_SWIM/Cell
# '/home/jovyan/work/parameter_tuning/Linear_SWIM/Cell'

# %%
# import the distance data
distance_4S = pd.read_csv("distance_4S.csv", index_col=0)
distance_I = pd.read_csv("distance_I.csv", index_col=0)
distance_III = pd.read_csv("distance_III.csv", index_col=0)
distance_IV = pd.read_csv("distance_IV.csv", index_col=0)
# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_4S
# Out:
#              TSPAN6      DPM1     SCYL3  C1orf112       FGR     FUCA2  \
# Symbol
# TSPAN6     0.000000  0.773897  0.703237  0.680294  0.641601  0.932403
# DPM1       0.773897  0.000000  0.766109  0.590894  0.824524  0.948819
# SCYL3      0.703237  0.766109  0.000000  0.729685  0.839800  0.855578
# C1orf112   0.680294  0.590894  0.729685  0.000000  0.784112  0.677189
# FGR        0.641601  0.824524  0.839800  0.784112  0.000000  0.949113
# ...             ...       ...       ...       ...       ...       ...
# LINC01481  0.670417  0.549146  0.799766  0.672784  0.875168  0.719538
# CYB561D2   0.677001  0.831691  0.862807  0.651520  0.760975  0.747418
# CCDC7      0.717391  0.800076  0.639342  0.627736  0.916372  0.538260
# MATR3      0.949935  0.800544  1.055671  0.938310  0.686201  0.985063
# RGS5       0.278521  0.604077  0.662947  0.482961  0.724755  0.826673
#
#                GCLC      NFYA     STPG1    NIPAL3  ...  LINC01176  \
# ...

# %%
# Set the name of the DataFrame
distance_4S.name = "distance_4S"
distance_I.name = "distance_I"
distance_III.name = "distance_III"
distance_IV.name = "distance_IV"
# distance_NA.name = "distance_NA"

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_nlog, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Linear_SWIM/knd_nlog/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Linear_SWIM/knd_nlog/Cell
# '/home/jovyan/work/parameter_tuning/Linear_SWIM/knd_nlog/Cell'

# %% [markdown]
# Cell: resolution = 0.4

# %%
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 15~180 modules

for resolution_parameter in resolution_values:
    module_4S = distance_to_module_nlog(distance_coordinate=distance_4S, fig_path1=f"./figures/degree_distribution_4S_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_4S_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_4S, file_path=f"module_4S_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 20
# Cluster assignments: [0, 0, 1, 0, 3, 2, 0, 2, 3, 3, 0, 2, 0, 0, 1, 0, 1, 2, 2, 1]
# Number of modules: 15
# IOStream.flush timed out
# IOStream.flush timed out
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 33
# Cluster assignments: [1, 5, 1, 0, 4, 2, 0, 2, 4, 4, 0, 2, 0, 0, 1, 0, 1, 5, 4, 2]
# Number of modules: 25
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 49
# Cluster assignments: [1, 3, 1, 0, 5, 2, 0, 2, 7, 5, 0, 2, 0, 0, 2, 0, 21, 3, 5, 2]
# Number of modules: 33
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 63
# Cluster assignments: [1, 3, 6, 0, 5, 2, 0, 3, 8, 8, 0, 2, 2, 2, 6, 0, 22, 11, 7, 6]
# ...

# %%
for resolution_parameter in resolution_values:
    module_I = distance_to_module_nlog(distance_coordinate=distance_I, fig_path1=f"./figures/degree_distribution_I_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_I_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_I, file_path=f"module_I_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 33
# Cluster assignments: [8, 1, 0, 0, 3, 0, 0, 0, 1, 1, 0, 1, 0, 0, 0, 0, 6, 0, 1, 4]
# Number of modules: 22
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 45
# Cluster assignments: [16, 2, 0, 2, 5, 0, 0, 0, 1, 2, 0, 1, 0, 0, 0, 3, 13, 0, 1, 7]
# Number of modules: 35
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 69
# Cluster assignments: [14, 1, 0, 1, 5, 2, 1, 0, 4, 4, 0, 2, 0, 0, 0, 3, 20, 1, 2, 10]
# Number of modules: 51
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 97
# Cluster assignments: [14, 6, 3, 1, 5, 2, 1, 0, 4, 4, 0, 2, 0, 0, 0, 3, 22, 1, 2, 10]
# Number of modules: 68
# ...

# %%
for resolution_parameter in resolution_values:
    module_III = distance_to_module_nlog(distance_coordinate=distance_III, fig_path1=f"./figures/degree_distribution_III_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_III_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_III, file_path=f"module_III_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# IOStream.flush timed out
# Number of clusters: 26
# Cluster assignments: [0, 3, 0, 0, 2, 1, 1, 1, 1, 1, 2, 0, 0, 0, 1, 3, 5, 2, 0, 0]
# Number of modules: 21
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 39
# Cluster assignments: [0, 6, 0, 1, 2, 1, 1, 3, 3, 3, 2, 0, 0, 0, 1, 4, 6, 2, 0, 0]
# Number of modules: 28
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 58
# Cluster assignments: [3, 8, 0, 1, 6, 5, 1, 3, 3, 3, 25, 0, 0, 0, 1, 4, 20, 2, 0, 0]
# Number of modules: 42
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 80
# Cluster assignments: [3, 9, 0, 5, 6, 7, 1, 3, 3, 3, 18, 0, 0, 1, 1, 2, 47, 6, 0, 0]
# Number of modules: 54
# ...

# %%
for resolution_parameter in resolution_values:
    module_IV = distance_to_module_nlog(distance_coordinate=distance_IV, fig_path1=f"./figures/degree_distribution_IV_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_IV_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_IV, file_path=f"module_IV_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 26
# Cluster assignments: [1, 2, 0, 0, 4, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 1, 0, 3, 0, 1]
# Number of modules: 17
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 34
# Cluster assignments: [1, 2, 0, 0, 5, 0, 0, 0, 4, 0, 0, 0, 0, 0, 0, 1, 0, 3, 0, 1]
# Number of modules: 28
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 48
# Cluster assignments: [2, 2, 0, 0, 6, 0, 0, 0, 7, 0, 0, 4, 0, 0, 3, 1, 0, 13, 2, 1]
# Number of modules: 33
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 61
# Cluster assignments: [2, 2, 0, 0, 6, 4, 0, 0, 7, 0, 0, 3, 0, 0, 4, 1, 0, 14, 2, 1]
# Number of modules: 48
# ...
