# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Nlog_SWIM/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Nlog_SWIM/Cell
# '/home/jovyan/work/parameter_tuning/Nlog_SWIM/Cell'

# %%
# import the distance data
distance_4S = pd.read_csv("distance_4S.csv", index_col=0)
distance_I = pd.read_csv("distance_I.csv", index_col=0)
distance_III = pd.read_csv("distance_III.csv", index_col=0)
distance_IV = pd.read_csv("distance_IV.csv", index_col=0)
# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_4S
# Out:
#              TSPAN6      DPM1     SCYL3  C1orf112       FGR     FUCA2  \
# Symbol
# TSPAN6     0.000000  4.049566  4.054379  3.653362  3.859807  5.439859
# DPM1       4.049566  0.000000  4.561088  3.120767  4.202342  5.287102
# SCYL3      4.054379  4.561088  0.000000  4.834309  4.760293  6.154686
# C1orf112   3.653362  3.120767  4.834309  0.000000  4.487691  4.265392
# FGR        3.859807  4.202342  4.760293  4.487691  0.000000  6.077643
# ...             ...       ...       ...       ...       ...       ...
# LINC01481  3.741959  3.353489  4.216637  3.127303  4.200063  4.371713
# CYB561D2   4.342285  4.329942  5.651799  3.575942  4.539573  4.666147
# CCDC7      3.900542  3.703925  3.840611  2.892865  4.348429  3.864123
# MATR3      6.136034  5.009328  6.455629  5.538098  4.467200  6.800812
# RGS5       2.182849  3.115051  3.378663  3.156659  3.930648  4.958267
#
#                GCLC      NFYA     STPG1    NIPAL3  ...  LINC01176  \
# ...

# %%
# Set the name of the DataFrame
distance_4S.name = "distance_4S"
distance_I.name = "distance_I"
distance_III.name = "distance_III"
distance_IV.name = "distance_IV"
# distance_NA.name = "distance_NA"

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_nlog, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Nlog_SWIM/knd_nlog/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Nlog_SWIM/knd_nlog/Cell
# '/home/jovyan/work/parameter_tuning/Nlog_SWIM/knd_nlog/Cell'

# %% [markdown]
# Cell: resolution = 0.35

# %%
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 30%: 30~195 modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 35%: 20~150 modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 15~120 modules

for resolution_parameter in resolution_values:
    module_4S = distance_to_module_nlog(distance_coordinate=distance_4S, fig_path1=f"./figures/degree_distribution_4S_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_4S_{resolution_parameter}.svg", threshold_percentile=30, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_4S, file_path=f"module_4S_{resolution_parameter}.json")
# Out:
# threshold_percentile = 30%: threshold_distance = 133.86802442674394
# Number of connected components: 3
# Number of clusters: 51
# Cluster assignments: [0, 0, 1, 0, 4, 2, 0, 5, 8, 2, 0, 5, 0, 0, 1, 0, 29, 2, 2, 2]
# Number of modules: 29
# threshold_percentile = 30%: threshold_distance = 133.86802442674394
# Number of connected components: 3
# Number of clusters: 69
# Cluster assignments: [2, 0, 2, 0, 4, 1, 0, 5, 10, 10, 0, 5, 0, 0, 2, 0, 31, 1, 1, 3]
# Number of modules: 42
# threshold_percentile = 30%: threshold_distance = 133.86802442674394
# Number of connected components: 3
# Number of clusters: 93
# Cluster assignments: [2, 0, 3, 0, 5, 4, 0, 4, 12, 12, 0, 4, 1, 1, 2, 0, 22, 10, 1, 3]
# Number of modules: 49
# threshold_percentile = 30%: threshold_distance = 133.86802442674394
# Number of connected components: 3
# Number of clusters: 121
# Cluster assignments: [2, 8, 3, 0, 5, 4, 0, 7, 13, 13, 1, 4, 1, 1, 11, 1, 21, 9, 4, 11]
# Number of modules: 66
# ...

# %%
for resolution_parameter in resolution_values:
    module_I = distance_to_module_nlog(distance_coordinate=distance_I, fig_path1=f"./figures/degree_distribution_I_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_I_{resolution_parameter}.svg", threshold_percentile=30, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_I, file_path=f"module_I_{resolution_parameter}.json")
# Out:
# threshold_percentile = 30%: threshold_distance = 123.72104183753777
# Number of connected components: 6
# Number of clusters: 78
# Cluster assignments: [9, 1, 1, 0, 3, 0, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 23, 1, 1, 3]
# Number of modules: 46
# threshold_percentile = 30%: threshold_distance = 123.72104183753777
# Number of connected components: 6
# Number of clusters: 115
# Cluster assignments: [16, 10, 2, 5, 4, 0, 2, 2, 1, 2, 0, 1, 0, 0, 0, 3, 28, 2, 1, 4]
# Number of modules: 61
# threshold_percentile = 30%: threshold_distance = 123.72104183753777
# Number of connected components: 6
# Number of clusters: 157
# Cluster assignments: [30, 8, 3, 2, 4, 0, 2, 3, 1, 5, 0, 1, 0, 0, 0, 3, 44, 2, 7, 13]
# Number of modules: 79
# threshold_percentile = 30%: threshold_distance = 123.72104183753777
# Number of connected components: 6
# Number of clusters: 215
# Cluster assignments: [39, 12, 2, 1, 3, 0, 1, 2, 4, 7, 0, 2, 0, 0, 0, 2, 63, 4, 9, 16]
# Number of modules: 107
# ...

# %%
for resolution_parameter in resolution_values:
    module_III = distance_to_module_nlog(distance_coordinate=distance_III, fig_path1=f"./figures/degree_distribution_III_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_III_{resolution_parameter}.svg", threshold_percentile=30, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_III, file_path=f"module_III_{resolution_parameter}.json")
# Out:
# threshold_percentile = 30%: threshold_distance = 114.55875038129618
# Number of connected components: 5
# Number of clusters: 72
# Cluster assignments: [3, 11, 0, 0, 9, 4, 4, 3, 3, 0, 2, 0, 0, 0, 4, 1, 11, 2, 0, 0]
# Number of modules: 47
# threshold_percentile = 30%: threshold_distance = 114.55875038129618
# Number of connected components: 5
# Number of clusters: 106
# Cluster assignments: [4, 14, 0, 5, 11, 2, 2, 4, 4, 4, 3, 0, 0, 0, 2, 1, 18, 3, 0, 0]
# Number of modules: 64
# threshold_percentile = 30%: threshold_distance = 114.55875038129618
# Number of connected components: 5

# %%
for resolution_parameter in resolution_values:
    module_IV = distance_to_module_nlog(distance_coordinate=distance_IV, fig_path1=f"./figures/degree_distribution_IV_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_IV_{resolution_parameter}.svg", threshold_percentile=30, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_IV, file_path=f"module_IV_{resolution_parameter}.json")
# Out:
# Number of clusters: 343
# Cluster assignments: [10, 12, 0, 0, 6, 7, 1, 0, 57, 0, 2, 9, 2, 0, 1, 3, 0, 22, 10, 5]
# Number of modules: 177
# threshold_percentile = 30%: threshold_distance = 122.73884745764407
# Number of connected components: 3
# Number of clusters: 439
# Cluster assignments: [239, 14, 0, 0, 7, 6, 2, 0, 163, 0, 1, 10, 1, 0, 6, 3, 0, 31, 8, 22]
# Number of modules: 201
