# %%
import hotspot
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplscience
import pickle

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /home/jovyan/work/parameter_tuning/Hotspot
# /home/jovyan/work/parameter_tuning/Hotspot/Cell
# /home/jovyan/work/parameter_tuning/Hotspot/Cell

# %%
adata = sc.read_h5ad("../../../results/Cell/discrete_cancer_stages.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 115774 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# 4S

# %%
adata_4S = adata[adata.obs.discrete_cancer_stage == "4S"]
adata_4S
# Out:
# View of AnnData object with n_obs × n_vars = 9111 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
hs = hotspot.Hotspot(
    adata_4S,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
hs_results = hs.compute_autocorrelations()
hs_results.head(15)
# Out:
# 100%|██████████| 12939/12939 [00:19<00:00, 663.30it/s]
#                  C           Z  Pval  FDR
# Gene
# ZNF211    0.874462  357.899118   0.0  0.0
# ZNF550    0.867319  357.847221   0.0  0.0
# NUS1      0.878360  357.131397   0.0  0.0
# ZSWIM3    0.849440  355.332156   0.0  0.0
# CDKN2AIP  0.863789  354.770498   0.0  0.0
# RNF113A   0.852449  354.236765   0.0  0.0
# KLF10     0.834133  353.914760   0.0  0.0
# ZBTB49    0.860923  352.079359   0.0  0.0
# ZNF420    0.872022  351.997838   0.0  0.0
# GPAT3     0.795504  351.545875   0.0  0.0
# ZNF830    0.878133  351.494858   0.0  0.0
# ZBTB2     0.806170  350.725601   0.0  0.0
# ZNF155    0.858137  350.657884   0.0  0.0
# FASTKD3   0.841565  350.357995   0.0  0.0
# RNF6      0.847716  350.224054   0.0  0.0

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=16)
# Out:
# Computing pair-wise local correlation on 12939 features...
# ...
# 100%|██████████| 83702391/83702391 [3:28:08<00:00, 6702.50it/s]

# %%
# Save the Hotspot object to a file
with open("hotspot_object_4S.pkl", "wb") as f:
    pickle.dump(hs, f)

# %% [markdown]
# I

# %%
adata_I = adata[adata.obs.discrete_cancer_stage == "I"]
adata_I
# Out:
# View of AnnData object with n_obs × n_vars = 31101 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
hs = hotspot.Hotspot(
    adata_I,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
hs_results = hs.compute_autocorrelations()
# Out:
# ...
# 100%|██████████| 12939/12939 [00:59<00:00, 216.69it/s]

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=16)
# Out:
# Computing pair-wise local correlation on 12939 features...
# ...
#  27%|██▋       | 22785491/83702391 [3:33:04<10:14:24, 1652.45it/s]

# %%
# Save the Hotspot object to a file
with open("hotspot_object_I.pkl", "wb") as f:
    pickle.dump(hs, f)

# %% [markdown]
# III

# %%
adata_III = adata[adata.obs.discrete_cancer_stage == "III"]
adata_III
# Out:
# View of AnnData object with n_obs × n_vars = 25385 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
hs = hotspot.Hotspot(
    adata_III,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)

# %%
hs_results = hs.compute_autocorrelations()
# Out:
# 100% 12939/12939 [02:16<00:00, 95.08it/s]

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=16)
# Out:
# Computing pair-wise local correlation on 12939 features...
# 100% 12939/12939 [00:27<00:00, 471.65it/s]
#  31% 25586072/83702391 [4:24:55<9:49:16, 1643.75it/s] IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  32% 27144677/83702391 [4:41:01<9:18:37, 1687.40it/s] IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  85% 71452528/83702391 [12:18:52<2:07:40, 1599.03it/s]IOPub message rate exceeded.
# ...

# %%
# Save the Hotspot object to a file
with open("hotspot_object_III.pkl", "wb") as f:
    pickle.dump(hs, f)

# %% [markdown]
# IV

# %%
adata_IV = adata[adata.obs.discrete_cancer_stage == "IV"]
adata_IV
# Out:
# View of AnnData object with n_obs × n_vars = 50177 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
hs = hotspot.Hotspot(
    adata_IV,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)

# %%
hs_results = hs.compute_autocorrelations()
# Out:
# 100% 12939/12939 [03:25<00:00, 63.03it/s]

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=16)
# Out:
# Computing pair-wise local correlation on 12939 features...
# 100% 12939/12939 [00:51<00:00, 249.25it/s]
#   1% 698900/83702391 [18:21<35:43:59, 645.24it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#   2% 1927532/83702391 [50:32<35:24:23, 641.56it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#   9% 7281203/83702391 [3:10:53<34:15:54, 619.52it/s]IOPub message rate exceeded.
# ...

# %%
# Save the Hotspot object to a file
with open("hotspot_object_IV.pkl", "wb") as f:
    pickle.dump(hs, f)
