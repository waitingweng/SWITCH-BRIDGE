# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/hdWGCNA/Cell
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/hdWGCNA/Cell
# '/home/jovyan/work/parameter_tuning/hdWGCNA/Cell'

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import hdWGCNA_to_module, module_to_json

# %% [markdown]
# deepSplit=2.5

# %%
deepSplit_values = [0,0.5,1,1.5,2,2.5,3,3.5,4]
for deepSplit in deepSplit_values:
    module_4S = hdWGCNA_to_module(stage="4S", path=f"module_4S_{deepSplit}.csv")
    module_to_json(module_dict=module_4S, file_path=f"module_4S_{deepSplit}.json")
# Out:
# 33
# 42
# 45
# 55
# 67
# 129
# 145
# 172
# 188

# %%
for deepSplit in deepSplit_values:
    module_I = hdWGCNA_to_module(stage="I", path=f"module_I_{deepSplit}.csv")
    module_to_json(module_dict=module_I, file_path=f"module_I_{deepSplit}.json")
# Out:
# 33
# 41
# 49
# 62
# 78
# 131
# 151
# 184
# 204

# %%
for deepSplit in deepSplit_values:
    module_III = hdWGCNA_to_module(stage="III", path=f"module_III_{deepSplit}.csv")
    module_to_json(module_dict=module_III, file_path=f"module_III_{deepSplit}.json")
# Out:
# 14
# 20
# 30
# 34
# 45
# 62
# 69
# 79
# 96

# %%
for deepSplit in deepSplit_values:
    module_IV = hdWGCNA_to_module(stage="IV", path=f"module_IV_{deepSplit}.csv")
    module_to_json(module_dict=module_IV, file_path=f"module_IV_{deepSplit}.json")
# Out:
# 37
# 43
# 52
# 66
# 85
# 128
# 153
# 172
# 193
