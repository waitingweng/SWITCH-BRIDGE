# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = sc.read_h5ad("discrete_cancer_stages.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 115774 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'discrete_cancer_stage'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'mean', 'std'
#     uns: 'INSS_stage_colors', '_scvi_manager_uuid', '_scvi_uuid', 'discrete_cancer_stage_colors', 'hvg', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'log1p', 'neighbors', 'paga', 'sample_ID_colors', 'scrublet', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     layers: 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
adata.X
# Out:
# array([[ 0. ,  0. ,  0. , ...,  0. ,  0. ,  7. ],
#        [ 0. ,  0. ,  0. , ...,  0. ,  0. ,  3.5],
#        [ 0. ,  0. ,  1. , ...,  0. ,  0. ,  4. ],
#        ...,
#        [ 0. ,  0. ,  0. , ...,  0. ,  0. ,  0.5],
#        [ 0. ,  4. ,  0. , ...,  0. ,  0. , 11. ],
#        [ 0. ,  0. ,  0. , ...,  0. ,  0. , 16. ]])

# %%
adata.layers['scvi_normalized']
# Out:
# array([[0.13660967, 0.15102433, 0.08426438, ..., 0.0131269 , 0.01406979,
#         6.4436555 ],
#        [0.10688095, 0.11575101, 0.06493848, ..., 0.01036287, 0.01495432,
#         7.553628  ],
#        [0.13362993, 0.15768649, 0.07316774, ..., 0.01351997, 0.01357406,
#         7.179622  ],
#        ...,
#        [0.1542854 , 0.4503489 , 0.06481571, ..., 0.01379568, 0.02050788,
#         4.8485856 ],
#        [0.0855314 , 0.7350836 , 0.05020642, ..., 0.01165168, 0.01825207,
#         6.0115347 ],
#        [0.09809586, 0.4400981 , 0.0554247 , ..., 0.01060313, 0.02386962,
#         8.708725  ]], dtype=float32)

# %%
# somehow scVI normalizes to 1e5
# Sum each row
row_sums = np.sum(adata.layers['scvi_normalized'], axis=1)

# Print the result
print("Row sums:", row_sums)
# Out:
# Row sums: [10000.    10000.    10000.    ... 10000.    10000.001 10000.   ]

# %%
adata.layers['scvi_log']
# Out:
# array([[0.12804987, 0.14065227, 0.08090176, ..., 0.01304149, 0.01397173,
#         2.0073621 ],
#        [0.1015461 , 0.10952772, 0.06291703, ..., 0.01030955, 0.01484361,
#         2.1463556 ],
#        [0.12542482, 0.14642361, 0.07061478, ..., 0.01342939, 0.01348276,
#         2.101646  ],
#        ...,
#        [0.14348145, 0.37180415, 0.06280174, ..., 0.01370138, 0.02030042,
#         1.7661998 ],
#        [0.08206964, 0.55105555, 0.04898673, ..., 0.01158432, 0.0180875 ,
#         1.9475566 ],
#        [0.09357765, 0.36471125, 0.05394324, ..., 0.01054731, 0.0235892 ,
#         2.273025  ]], dtype=float32)

# %%
adata.layers['scvi_scale']
# Out:
# array([[-0.46020573, -1.181261  ,  0.6703537 , ..., -0.48453858,
#          0.35390112,  0.5257946 ],
#        [-0.73325384, -1.4258136 , -0.09961344, ..., -0.618265  ,
#          0.45353538,  0.6564509 ],
#        [-0.4872496 , -1.1359143 ,  0.2299445 , ..., -0.46555126,
#          0.29802382,  0.61442304],
#        ...,
#        [-0.3012259 ,  0.6349517 , -0.10454928, ..., -0.45223722,
#          1.0771141 ,  0.2990978 ],
#        [-0.933905  ,  2.0433705 , -0.696001  , ..., -0.55586565,
#          0.82423145,  0.46957636],
#        [-0.8153467 ,  0.57922125, -0.48380163, ..., -0.6066268 ,
#          1.452939  ,  0.7755224 ]], dtype=float32)

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['4S'], reference='I', method="wilcoxon")

# %%
deg_4S_I = sc.get.rank_genes_groups_df(adata, group='4S')
deg_4S_I
# Out:
#          names      scores  logfoldchanges  pvals  pvals_adj
# 0      C5orf15  122.069374        0.987562    0.0        0.0
# 1        KCTD5  121.783592        1.083719    0.0        0.0
# 2      ATP6V1H  119.688843        0.772117    0.0        0.0
# 3       CHMP1B  116.934647        1.129777    0.0        0.0
# 4       NAP1L3  116.731514        1.156047    0.0        0.0
# ...        ...         ...             ...    ...        ...
# 12934     JUND -114.298233       -2.801515    0.0        0.0
# 12935     AVEN -115.296486       -1.543200    0.0        0.0
# 12936   SPTAN1 -115.965340       -1.196288    0.0        0.0
# 12937   DOPEY2 -116.143005       -1.135941    0.0        0.0
# 12938      CIC -117.197258       -0.959119    0.0        0.0
#
# [12939 rows x 5 columns]

# %%
deg_4S_I.to_csv("deg_4S_I.csv")

# %%
# deg[(deg['pvals_adj'] < 0.05) & (deg['logfoldchanges'] > 1)]
# Out:
#         names      scores  logfoldchanges  pvals  pvals_adj
# 1       KCTD5  121.783592        1.083719    0.0        0.0
# 3      CHMP1B  116.934647        1.129777    0.0        0.0
# 4      NAP1L3  116.731514        1.156047    0.0        0.0
# 5       PINX1  116.271049        2.170991    0.0        0.0
# 9        SDHB  115.093163        1.077428    0.0        0.0
# ...       ...         ...             ...    ...        ...
# 1467     NGFR   74.763283        1.076592    0.0        0.0
# 1534     RRAD   73.454720        1.117189    0.0        0.0
# 1595  C4orf36   72.042442        1.275950    0.0        0.0
# 2525      NPY   56.656776        1.105951    0.0        0.0
# 2806      OXT   51.663799        1.095322    0.0        0.0
#
# [201 rows x 5 columns]

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['4S'], reference='III', method="wilcoxon")
deg_4S_III = sc.get.rank_genes_groups_df(adata, group='4S')
deg_4S_III.to_csv("deg_4S_III.csv")
deg_4S_III
# Out:
#             names      scores  logfoldchanges  pvals  pvals_adj
# 0            DTX3  137.555679        1.470230    0.0        0.0
# 1      ZNF436-AS1  135.922058        2.326407    0.0        0.0
# 2        TBC1D10A  135.382050        1.576502    0.0        0.0
# 3           EPB42  135.299957        3.302273    0.0        0.0
# 4          DNAJB2  135.166275        1.849717    0.0        0.0
# ...           ...         ...             ...    ...        ...
# 12934        COA4 -128.957367       -1.135811    0.0        0.0
# 12935        CHML -129.279495       -2.428279    0.0        0.0
# 12936        SSR3 -129.497025       -1.346092    0.0        0.0
# 12937      CTHRC1 -131.908371       -3.475317    0.0        0.0
# 12938        NME2 -132.081512       -2.404622    0.0        0.0
#
# [12939 rows x 5 columns]

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['4S'], reference='IV', method="wilcoxon")
deg_4S_IV = sc.get.rank_genes_groups_df(adata, group='4S')
deg_4S_IV.to_csv("deg_4S_IV.csv")
deg_4S_IV
# Out:
#          names      scores  logfoldchanges  pvals  pvals_adj
# 0      TMEM242  141.337982        1.328492    0.0        0.0
# 1       TMEM59  140.924545        1.686794    0.0        0.0
# 2      MRPS18B  140.199890        1.486559    0.0        0.0
# 3        ANXA7  140.151749        1.839312    0.0        0.0
# 4          AUH  139.889755        1.571975    0.0        0.0
# ...        ...         ...             ...    ...        ...
# 12934     SBK1 -127.321747       -1.173684    0.0        0.0
# 12935    VTI1B -127.836693       -0.767237    0.0        0.0
# 12936  TMSB15A -129.355789       -1.655145    0.0        0.0
# 12937  SLC27A5 -130.494598       -1.282072    0.0        0.0
# 12938     GPX4 -132.395325       -0.903380    0.0        0.0
#
# [12939 rows x 5 columns]

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['I'], reference='III', method="wilcoxon")
deg_I_III = sc.get.rank_genes_groups_df(adata, group='I')
deg_I_III.to_csv("deg_I_III.csv")
deg_I_III
# Out:
#           names      scores  logfoldchanges  pvals  pvals_adj
# 0          TFEB  183.714386        2.515746    0.0        0.0
# 1         TLCD1  183.145950        2.273715    0.0        0.0
# 2         TPPP3  181.988068        2.071662    0.0        0.0
# 3        CCDC69  181.775894        1.836062    0.0        0.0
# 4          RHOC  181.371872        2.252828    0.0        0.0
# ...         ...         ...             ...    ...        ...
# 12934    CTHRC1 -172.168320       -2.663377    0.0        0.0
# 12935  SERPINF1 -172.878006       -3.576099    0.0        0.0
# 12936   SLC38A5 -174.725266       -2.273977    0.0        0.0
# 12937     DIMT1 -175.072021       -1.643463    0.0        0.0
# 12938     PTRH2 -175.287582       -1.608740    0.0        0.0
#
# [12939 rows x 5 columns]

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['I'], reference='IV', method="wilcoxon")
deg_I_IV = sc.get.rank_genes_groups_df(adata, group='I')
deg_I_IV.to_csv("deg_I_IV.csv")
deg_I_IV

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="discrete_cancer_stage", layer='scvi_log', groups=['III'], reference='IV', method="wilcoxon")
deg_III_IV = sc.get.rank_genes_groups_df(adata, group='III')
deg_III_IV.to_csv("deg_III_IV.csv")
deg_III_IV
