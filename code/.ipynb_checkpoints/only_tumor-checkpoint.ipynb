# %%
import scanpy as sc

# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
adata = sc.read_h5ad("annotated.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 203503 × 12850
#     obs: 'sample_source', 'sample_ID'

# %%
adata.obs
# Out:
#                        sample_source sample_ID
# Cell_barcode
# T44_AAACCTGAGAGGTTGC.1         tumor       T44
# T44_AAACCTGAGAGTGAGA.1         tumor       T44
# T44_AAACCTGAGGCATGTG.1         tumor       T44
# T44_AAACCTGAGTGTACCT.1         tumor       T44
# T44_AAACCTGCAATGCCAT.1         tumor       T44
# ...                              ...       ...
# T40_TTTGTCAGTGTCCTCT.1         tumor       T40
# T40_TTTGTCATCACTTATC.1         tumor       T40
# T40_TTTGTCATCAGGCCCA.1         tumor       T40
# T40_TTTGTCATCTGCAGTA.1         tumor       T40
# T40_TTTGTCATCTGGAGCC.1         tumor       T40
#
# [203503 rows x 2 columns]

# %%
adata = adata[adata.obs.sample_source == "tumor"]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 157932 × 12850
#     obs: 'sample_source', 'sample_ID'

# %%
adata.obs.sample_source
# Out:
# Cell_barcode
# T44_AAACCTGAGAGGTTGC.1    tumor
# T44_AAACCTGAGAGTGAGA.1    tumor
# T44_AAACCTGAGGCATGTG.1    tumor
# T44_AAACCTGAGTGTACCT.1    tumor
# T44_AAACCTGCAATGCCAT.1    tumor
#                           ...
# T40_TTTGTCAGTGTCCTCT.1    tumor
# T40_TTTGTCATCACTTATC.1    tumor
# T40_TTTGTCATCAGGCCCA.1    tumor
# T40_TTTGTCATCTGCAGTA.1    tumor
# T40_TTTGTCATCTGGAGCC.1    tumor
# Name: sample_source, Length: 157932, dtype: category
# Categories (1, object): ['tumor']

# %%
adata.write("counts.h5ad")
