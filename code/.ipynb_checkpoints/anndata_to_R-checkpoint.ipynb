# %%
import anndata2ri
import scanpy as sc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1495940/3645816622.py in <module>
# ----> 1 import anndata2ri
#       2 import scanpy as sc
#
# ~/.local/lib/python3.7/site-packages/anndata2ri/__init__.py in <module>
#      35
#      36 if not within_flit():
# ---> 37     from rpy2.rinterface import Sexp
#      38
#      39     from .conv import converter, activate, deactivate
#
# ~/.local/lib/python3.7/site-packages/rpy2/rinterface.py in <module>
#       4 import math
#       5 import typing
# ----> 6 from rpy2.rinterface_lib import openrlib
#       7 import rpy2.rinterface_lib._rinterface_capi as _rinterface
#       8 import rpy2.rinterface_lib.embedded as embedded
#
# ~/.local/lib/python3.7/site-packages/rpy2/rinterface_lib/openrlib.py in <module>
#      21
#      22
# ---> 23 rlib = _dlopen_rlib(R_HOME)
#      24
#      25
#
# ...

# %%
adata = sc.read_h5ad("/hdd/edward/the-project/code/discrete_cancer_stages_annotation.ipynb")
adata

# %%
Rdata = anndata2ri.py2ri(adata)
Rdata
