# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("/hdd/edward/the-project/results/clipped.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 197850 × 12850
#     obs: 'sample_source', 'patient_ID', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p'

# %%
adata.var["mean"]
# Out:
# Symbol
# TSPAN6       0.227099
# DPM1         0.413678
# SCYL3        0.071123
# C1orf112     0.051671
# FGR          0.033989
#                ...
# LINC01481    0.129602
# CYB561D2     0.179300
# CCDC7        0.028734
# RGS5         1.290282
# MATR3        0.018097
# Name: mean, Length: 12850, dtype: float64

# %%
adata.var["std"]
# Out:
# Symbol
# TSPAN6       0.668673
# DPM1         0.849643
# SCYL3        0.364809
# C1orf112     0.309032
# FGR          0.284124
#                ...
# LINC01481    0.442130
# CYB561D2     0.540158
# CCDC7        0.225052
# RGS5         1.724169
# MATR3        0.166300
# Name: std, Length: 12850, dtype: float64

# %%
bdata = sc.pp.scale(adata, copy=True)
bdata
# Out:
# AnnData object with n_obs × n_vars = 197850 × 12850
#     obs: 'sample_source', 'patient_ID', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'log1p'

# %%
bdata.var["mean"]
# Out:
# Symbol
# TSPAN6      -4.163890e-09
# DPM1         1.321453e-08
# SCYL3       -7.406463e-05
# C1orf112    -3.915071e-04
# FGR         -2.854555e-03
#                  ...
# LINC01481    3.297988e-09
# CYB561D2    -6.702585e-09
# CCDC7       -3.284820e-03
# RGS5        -1.414726e-08
# MATR3       -6.247435e-03
# Name: mean, Length: 12850, dtype: float64

# %%
bdata.var["std"]
# Out:
# Symbol
# TSPAN6       1.000000
# DPM1         1.000000
# SCYL3        0.999212
# C1orf112     0.995738
# FGR          0.967777
#                ...
# LINC01481    1.000000
# CYB561D2     1.000000
# CCDC7        0.960641
# RGS5         1.000000
# MATR3        0.925096
# Name: std, Length: 12850, dtype: float64
