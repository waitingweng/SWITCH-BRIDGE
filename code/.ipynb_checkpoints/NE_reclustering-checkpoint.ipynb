# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
import scanpy as sc
import scanpy.external as sce
import numpy as np
import gc

# %%
adata = sc.read_h5ad("cell_type_classified_counts.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 152182 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet'

# %%
ndata = adata[adata.obs.cell_type == "NE"]
ndata
# Out:
# View of AnnData object with n_obs × n_vars = 115774 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet'

# %%
# annotate the group of mitochondrial genes as 'mt' for QC
ndata.var['mt'] = ndata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(ndata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
ndata
# Out:
# /tmp/ipykernel_823/3637284604.py:2: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   ndata.var['mt'] = ndata.var_names.str.startswith('MT-')
# AnnData object with n_obs × n_vars = 115774 × 12939
#     obs: 'sample_ID', 'Gender', 'INSS_stage', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'cell_type'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'scrublet'

# %%
ndata.write("NE_counts.h5ad")
