# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
import scanpy as sc
import scanpy.external as sce
import pandas as pd

# %%
ndata = sc.read_h5ad("NE_log_data.h5ad")
ndata
