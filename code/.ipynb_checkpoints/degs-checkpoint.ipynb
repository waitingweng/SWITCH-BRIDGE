# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
import pandas as pd
import numpy as np

# %%
deg_4S_I = pd.read_csv("deg_4S_I.csv", index_col=0)
deg_4S_III = pd.read_csv("deg_4S_III.csv", index_col=0)
deg_4S_IV = pd.read_csv("deg_4S_IV.csv", index_col=0)
deg_I_III = pd.read_csv("deg_I_III.csv", index_col=0)
deg_I_IV = pd.read_csv("deg_I_IV.csv", index_col=0)
deg_III_IV = pd.read_csv("deg_III_IV.csv", index_col=0)
deg_4S_I
# Out:
#          names      scores  logfoldchanges  pvals  pvals_adj
# 0      C5orf15  122.069374        0.987562    0.0        0.0
# 1        KCTD5  121.783590        1.083719    0.0        0.0
# 2      ATP6V1H  119.688840        0.772117    0.0        0.0
# 3       CHMP1B  116.934650        1.129777    0.0        0.0
# 4       NAP1L3  116.731514        1.156047    0.0        0.0
# ...        ...         ...             ...    ...        ...
# 12934     JUND -114.298230       -2.801515    0.0        0.0
# 12935     AVEN -115.296486       -1.543200    0.0        0.0
# 12936   SPTAN1 -115.965340       -1.196288    0.0        0.0
# 12937   DOPEY2 -116.143005       -1.135941    0.0        0.0
# 12938      CIC -117.197260       -0.959119    0.0        0.0
#
# [12939 rows x 5 columns]

# %% [markdown]
# log2FC > 1

# %%
deg_I_4S = deg_4S_I[(abs(deg_4S_I['logfoldchanges']) > 1) & (deg_4S_I['pvals_adj'] < 0.05)]['names']
deg_I_4S.to_csv('deg_I_4S.txt', header=False, index=False)
deg_I_4S
# Out:
# 1         KCTD5
# 3        CHMP1B
# 4        NAP1L3
# 5         PINX1
# 9          SDHB
#           ...
# 12932     FOCAD
# 12934      JUND
# 12935      AVEN
# 12936    SPTAN1
# 12937    DOPEY2
# Name: names, Length: 638, dtype: object

# %%
deg_III_4S = deg_4S_III[abs((deg_4S_III['logfoldchanges']) > 1) & (deg_4S_III['pvals_adj'] < 0.05)]['names']
deg_III_4S.to_csv('deg_III_4S.txt', header=False, index=False)
deg_III_4S
# Out:
# 0             DTX3
# 1       ZNF436-AS1
# 2         TBC1D10A
# 3            EPB42
# 4           DNAJB2
#            ...
# 5265          DHDH
# 5578           HBB
# 5695     TNFRSF10D
# 5931          HBA1
# 6794          MT1E
# Name: names, Length: 1600, dtype: object

# %%
deg_IV_4S = deg_4S_IV[abs((deg_4S_IV['logfoldchanges']) > 1) & (deg_4S_IV['pvals_adj'] < 0.05)]['names']
deg_IV_4S.to_csv('deg_IV_4S.txt', header=False, index=False)
deg_IV_4S
# Out:
# 0       TMEM242
# 1        TMEM59
# 2       MRPS18B
# 3         ANXA7
# 4           AUH
#          ...
# 3715      MUC12
# 4121       PRPH
# 4245        FAS
# 4443      KRT19
# 4490        OXT
# Name: names, Length: 1078, dtype: object

# %%
deg_III_I = deg_I_III[abs((deg_I_III['logfoldchanges']) > 1) & (deg_I_III['pvals_adj'] < 0.05)]['names']
deg_III_I.to_csv('deg_III_I.txt', header=False, index=False)
deg_III_I
# Out:
# 0         TFEB
# 1        TLCD1
# 2        TPPP3
# 3       CCDC69
# 4         RHOC
#          ...
# 7041       AMT
# 7368    S100A8
# 7386    SLC7A8
# 8617      SCO2
# 9496     RPS17
# Name: names, Length: 1211, dtype: object

# %%
deg_IV_I = deg_I_IV[abs((deg_I_IV['logfoldchanges']) > 1) & (deg_I_IV['pvals_adj'] < 0.05)]['names']
deg_IV_I.to_csv('deg_IV_I.txt', header=False, index=False)
deg_IV_I
# Out:
# 0         STEAP3
# 1         BCAP29
# 2          MPV17
# 3         TMEM18
# 4           IRF2
#           ...
# 5368       AKAP7
# 5514     TNFSF12
# 5751    SCGB1B2P
# 6007       RGS22
# 7340        LYL1
# Name: names, Length: 1210, dtype: object

# %%
deg_IV_III = deg_III_IV[abs((deg_III_IV['logfoldchanges']) > 1) & (deg_III_IV['pvals_adj'] < 0.05)]['names']
deg_IV_III.to_csv('deg_IV_III.txt', header=False, index=False)
deg_IV_III
# Out:
# 1       HSP90AB1
# 2          WDR75
# 3           TPM2
# 4           RPS7
# 5        SLC10A4
#           ...
# 5690      SOWAHA
# 6077       HERC5
# 7135       LRRC7
# 7436       IFIT3
# 7534        MSR1
# Name: names, Length: 406, dtype: object

# %% [markdown]
# log2FC > 2

# %%
deg_I_4S = deg_4S_I[(abs(deg_4S_I['logfoldchanges']) > 2) & (deg_4S_I['pvals_adj'] < 0.05)]['names']
deg_I_4S.to_csv('deg_I_4S_2.txt', header=False, index=False)
deg_I_4S
# Out:
# 5            PINX1
# 33           ABCF2
# 75           ALDOA
# 79            RGS2
# 104       ARHGAP25
# 129          HSPA6
# 224         HSPA1B
# 249          HSPB1
# 295            BIK
# 354         DNAJB1
# 479         HSPA1A
# 1188         RPS17
# 11245      S100A10
# 11761     HIST1H1B
# 11922         PRH1
# 12591    MTRNR2L12
# 12831      MFSD14C
# 12848         CD81
# 12927        VEGFB
# 12934         JUND
# Name: names, dtype: object

# %%
deg_III_4S = deg_4S_III[abs((deg_4S_III['logfoldchanges']) > 2) & (deg_4S_III['pvals_adj'] < 0.05)]['names']
deg_III_4S.to_csv('deg_III_4S_2.txt', header=False, index=False)
deg_III_4S
# Out:
# 1       ZNF436-AS1
# 3            EPB42
# 5         ADAMTSL4
# 9           MAPRE3
# 15           HSPB1
#            ...
# 1861          IER5
# 2138         KRT19
# 2292         RCAN2
# 2327      SERPINH1
# 2818          GNG8
# Name: names, Length: 199, dtype: object

# %%
deg_IV_4S = deg_4S_IV[abs((deg_4S_IV['logfoldchanges']) > 2) & (deg_4S_IV['pvals_adj'] < 0.05)]['names']
deg_IV_4S.to_csv('deg_IV_4S_2.txt', header=False, index=False)
deg_IV_4S
# Out:
# 6          HMGCL
# 20        TMBIM1
# 26       PIK3IP1
# 29           CLU
# 35          QPCT
#           ...
# 1144    ARHGAP25
# 1206    SERPINH1
# 1520    NDUFA4L2
# 1688      PLAGL1
# 1908        TLE6
# Name: names, Length: 81, dtype: object

# %%
deg_III_I = deg_I_III[abs((deg_I_III['logfoldchanges']) > 2) & (deg_I_III['pvals_adj'] < 0.05)]['names']
deg_III_I.to_csv('deg_III_I_2.txt', header=False, index=False)
deg_III_I
# Out:
# 0            TFEB
# 1           TLCD1
# 2           TPPP3
# 4            RHOC
# 6        C9orf106
#           ...
# 2292    LINC01481
# 2460        PTH1R
# 2806      S100A10
# 4253      POLR2J3
# 5423         IGF2
# Name: names, Length: 93, dtype: object

# %%
deg_IV_I = deg_I_IV[abs((deg_I_IV['logfoldchanges']) > 2) & (deg_I_IV['pvals_adj'] < 0.05)]['names']
deg_IV_I.to_csv('deg_IV_I_2.txt', header=False, index=False)
deg_IV_I
# Out:
# 0          STEAP3
# 1          BCAP29
# 5          SPATA6
# 6           PSMB8
# 8           INSM1
#           ...
# 1116    MTRNR2L12
# 1940         PRPH
# 2051        NLRP3
# 2077      S100A10
# 2301      GALNTL6
# Name: names, Length: 82, dtype: object

# %%
deg_IV_III = deg_III_IV[abs((deg_III_IV['logfoldchanges']) > 2) & (deg_III_IV['pvals_adj'] < 0.05)]['names']
deg_IV_III.to_csv('deg_IV_III_2.txt', header=False, index=False)
deg_IV_III
# Out:
# 3           TPM2
# 10        CTHRC1
# 21          HPDL
# 45           HGF
# 81          TAP2
# 103       FAM49A
# 111     SERPINF1
# 217          TES
# 236       TDRD12
# 251       ATP10D
# 348        IFI44
# 644        TGFBI
# 666          MX1
# 830        IFI16
# 1050       IFIT2
# 1118        MYCN
# 1305       DDX60
# 1482       IFIT1
# 1663       DDX58
# 3556       HERC6
# 7436       IFIT3
# Name: names, dtype: object

# %%
with open("deg_2.txt", 'w') as f:
    for i in set(deg_I_4S) | set(deg_III_4S) | set(deg_IV_4S) | set(deg_III_I) | set(deg_IV_I) | set(deg_IV_III):
        f.write(i + '\n')

# %% [markdown]
# log2FC > 2.5

# %%
deg_I_4S = deg_4S_I[(abs(deg_4S_I['logfoldchanges']) > 2.5) & (deg_4S_I['pvals_adj'] < 0.05)]['names']
deg_I_4S.to_csv('deg_I_4S_2.5.txt', header=False, index=False)
deg_I_4S
# Out:
# 75        ALDOA
# 224      HSPA1B
# 1188      RPS17
# 12934      JUND
# Name: names, dtype: object

# %%
deg_III_4S = deg_4S_III[abs((deg_4S_III['logfoldchanges']) > 2.5) & (deg_4S_III['pvals_adj'] < 0.05)]['names']
deg_III_4S.to_csv('deg_III_4S_2.5.txt', header=False, index=False)
deg_III_4S
# Out:
# 3          EPB42
# 5       ADAMTSL4
# 15         HSPB1
# 19         AZIN2
# 27         PTPRH
#           ...
# 1061        COG5
# 1271       ANXA2
# 1294       RPS17
# 1298        IGF2
# 1640       AKAP7
# Name: names, Length: 83, dtype: object

# %%
deg_IV_4S = deg_4S_IV[abs((deg_4S_IV['logfoldchanges']) > 2.5) & (deg_4S_IV['pvals_adj'] < 0.05)]['names']
deg_IV_4S.to_csv('deg_IV_4S_2.5.txt', header=False, index=False)
deg_IV_4S
# Out:
# 20      TMBIM1
# 29         CLU
# 35        QPCT
# 52         CD9
# 68        DNER
# 79       CASP8
# 80      FAXDC2
# 82       PMP22
# 93        COG5
# 180       RHOC
# 186      TRPV2
# 187        DBH
# 242     STEAP3
# 269      ALDOC
# 273      ANXA2
# 278      RAMP3
# 362     AMIGO2
# 443     HSPA1A
# 537      NTRK1
# 577      HSPA6
# 590      MXRA8
# 726      HSPB1
# 833     HSPA1B
# 1110      RGS5
# 1116      BAG3
# Name: names, dtype: object

# %%
deg_III_I = deg_I_III[abs((deg_I_III['logfoldchanges']) > 2.5) & (deg_I_III['pvals_adj'] < 0.05)]['names']
deg_III_I.to_csv('deg_III_I_2.5.txt', header=False, index=False)
deg_III_I
# Out:
# 0           TFEB
# 16          CD36
# 27          MAP7
# 39          DRD2
# 41       PPP1R1A
# 47          RGS5
# 49        FAXDC2
# 54         EPB42
# 71       FAM95B1
# 102        TRPV2
# 117       S100A6
# 178        RCAN3
# 183        RAMP3
# 229     NDUFA4L2
# 337        ANXA2
# 397         POMC
# 900        MUC12
# 1567       NLRP3
# 2806     S100A10
# Name: names, dtype: object

# %%
deg_IV_I = deg_I_IV[abs((deg_I_IV['logfoldchanges']) > 2.5) & (deg_I_IV['pvals_adj'] < 0.05)]['names']
deg_IV_I.to_csv('deg_IV_I_2.5.txt', header=False, index=False)
deg_IV_I
# Out:
# 0         STEAP3
# 8          INSM1
# 10           CD9
# 28      FAM114A1
# 34       PPP1R3B
# 85         ANXA2
# 88         TRPV2
# 114      FAM95B1
# 159        RAMP3
# 2077     S100A10
# Name: names, dtype: object

# %%
deg_IV_III = deg_III_IV[abs((deg_III_IV['logfoldchanges']) > 2.5) & (deg_III_IV['pvals_adj'] < 0.05)]['names']
deg_IV_III.to_csv('deg_IV_III_2.5.txt', header=False, index=False)
deg_IV_III
# Out:
# 10        CTHRC1
# 45           HGF
# 103       FAM49A
# 111     SERPINF1
# 236       TDRD12
# 348        IFI44
# 1482       IFIT1
# Name: names, dtype: object

# %%
with open("deg_2.5.txt", 'w') as f:
    for i in set(deg_I_4S) | set(deg_III_4S) | set(deg_IV_4S) | set(deg_III_I) | set(deg_IV_I) | set(deg_IV_III):
        f.write(i + '\n')
