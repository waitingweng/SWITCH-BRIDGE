# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS')
from methods import module_to_json

# %%
# Save data to a file
KEGG_dict = dict()
with open("KEGG_2021_Human.txt", "r") as file:
    for line in file:
        data = line.strip().split('\t')
        KEGG_dict[data[0]] = data[2:]
        print(f"function: {data[0]}")
        print(f"genes: {data[2:]}")
# Out:
# function: ABC transporters
# genes: ['ABCA2', 'ABCC4', 'ABCG8', 'ABCA3', 'ABCC5', 'ABCC2', 'ABCA1', 'ABCC3', 'ABCA6', 'ABCC8', 'ABCA7', 'ABCC9', 'ABCA4', 'ABCC6', 'ABCA5', 'TAP2', 'ABCA8', 'TAP1', 'ABCA9', 'ABCA10', 'ABCB10', 'ABCA12', 'ABCB11', 'ABCC10', 'ABCG1', 'ABCG4', 'ABCC1', 'ABCG5', 'ABCG2', 'CFTR', 'ABCB4', 'ABCB1', 'ABCD3', 'ABCD4', 'ABCB7', 'ABCB8', 'ABCB5', 'ABCB6', 'ABCB9', 'ABCA13', 'ABCC11', 'ABCC12', 'DEFB1', 'ABCD1', 'ABCD2']
# function: AGE-RAGE signaling pathway in diabetic complications
# ...

# %%
KEGG_dict
# Out:
# {'ABC transporters': ['ABCA2',
#   'ABCC4',
#   'ABCG8',
#   'ABCA3',
#   'ABCC5',
#   'ABCC2',
#   'ABCA1',
#   'ABCC3',
#   'ABCA6',
#   'ABCC8',
#   'ABCA7',
#   'ABCC9',
#   'ABCA4',
#   'ABCC6',
#   'ABCA5',
#   'TAP2',
#   'ABCA8',
#   'TAP1',
#   'ABCA9',
#   'ABCA10',
#   'ABCB10',
#   'ABCA12',
#   'ABCB11',
#   'ABCC10',
#   'ABCG1',
#   'ABCG4',
#   'ABCC1',
#   'ABCG5',
#   'ABCG2',
#   'CFTR',
#   'ABCB4',
#   'ABCB1',
#   'ABCD3',
#   'ABCD4',
#   'ABCB7',
#   'ABCB8',
#   'ABCB5',
#   'ABCB6',
#   'ABCB9',
#   'ABCA13',
#   'ABCC11',
#   'ABCC12',
#   'DEFB1',
#   'ABCD1',
#   'ABCD2'],
#  'AGE-RAGE signaling pathway in diabetic complications': ['TGFB1',
#   'TGFB3',
#   'TGFB2',
#   'VCAM1',
#   'AGT',
#   'MAPK13',
#   'MAPK14',
#   'COL1A2',
#   'MAPK11',
#   'COL1A1',
#   'MAPK12',
#   'MAPK10',
#   'AGTR1',
#   'BAX',
#   'PLCD1',
#   'PLCD4',
#   'PLCD3',
#   'RELA',
#   'SERPINE1',
#   'TNF',
#   'FOXO1',
#   'NRAS',
#   'CCND1',
#   'AKT3',
#   'AKT1',
# ...

# %%
module_to_json(module_dict=KEGG_dict, file_path="KEGG_2021_Human.json")
