# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS')
from methods import module_to_json

# %%
# Save data to a file
WikiPathway_dict = dict()
with open("WikiPathway_2023_Human.txt", "r") as file:
    for line in file:
        data = line.strip().split('\t')
        WikiPathway_dict[data[0]] = data[2:]
        print(f"function: {data[0]}")
        print(f"genes: {data[2:]}")
# Out:
# function: Glutathione Metabolism WP100
# genes: ['GPX1', 'GGT5', 'IDH1', 'GPX3', 'G6PD', 'GPX2', 'GSTM2', 'GSR', 'GSTM1', 'GPX4', 'GSS', 'GSTT2', 'OPLAH', 'GCLC', 'GSTA5', 'ANPEP', 'GSTA1', 'GCLM', 'GGT1']
# function: Alanine And Aspartate Metabolism WP106
# genes: ['ASS1', 'PC', 'GOT2', 'GOT1', 'GAD2', 'GAD1', 'ASL', 'GPT', 'ASPA', 'ABAT', 'AGXT', 'DARS1']
# function: Translation Factors WP107
# genes: ['EIF5B', 'EIF5A', 'EIF1AY', 'EIF1AX', 'EIF2AK2', 'EIF2AK1', 'EIF2AK3', 'EEF1A2', 'EEF1A1', 'EEF1D', 'EEF1G', 'ETF1', 'PABPC1', 'EIF4B', 'EIF4H', 'EIF4E', 'EIF2B5', 'EIF3A', 'EIF2B4', 'EIF2B3', 'CLUH', 'EEF2', 'EIF2S3', 'EIF2S2', 'EIF1', 'EIF2S1', 'EIF5', 'EIF6', 'EIF3J', 'EIF3H', 'EIF4G1', 'EIF3I', 'EIF3F', 'EIF3G', 'EIF3D', 'EIF3E', 'EIF3B', 'EIF4G3', 'EIF3C', 'EIF4A2', 'EIF4A1', 'EIF4EBP1', 'GSPT2', 'EEF1B2', 'EEF2K', 'EIF4EBP2', 'EIF4EBP3', 'EIF2B2', 'EIF2B1', 'PAIP1']
# function: Electron Transport Chain OXPHOS System In Mitochondria WP111
# ...

# %%
WikiPathway_dict
# Out:
# {'Glutathione Metabolism WP100': ['GPX1',
#   'GGT5',
#   'IDH1',
#   'GPX3',
#   'G6PD',
#   'GPX2',
#   'GSTM2',
#   'GSR',
#   'GSTM1',
#   'GPX4',
#   'GSS',
#   'GSTT2',
#   'OPLAH',
#   'GCLC',
#   'GSTA5',
#   'ANPEP',
#   'GSTA1',
#   'GCLM',
#   'GGT1'],
#  'Alanine And Aspartate Metabolism WP106': ['ASS1',
#   'PC',
#   'GOT2',
#   'GOT1',
#   'GAD2',
#   'GAD1',
#   'ASL',
#   'GPT',
#   'ASPA',
#   'ABAT',
#   'AGXT',
#   'DARS1'],
#  'Translation Factors WP107': ['EIF5B',
#   'EIF5A',
#   'EIF1AY',
#   'EIF1AX',
#   'EIF2AK2',
#   'EIF2AK1',
#   'EIF2AK3',
#   'EEF1A2',
#   'EEF1A1',
#   'EEF1D',
#   'EEF1G',
#   'ETF1',
#   'PABPC1',
#   'EIF4B',
#   'EIF4H',
#   'EIF4E',
#   'EIF2B5',
#   'EIF3A',
#   'EIF2B4',
#   'EIF2B3',
#   'CLUH',
#   'EEF2',
#   'EIF2S3',
#   'EIF2S2',
#   'EIF1',
#   'EIF2S1',
#   'EIF5',
#   'EIF6',
#   'EIF3J',
#   'EIF3H',
#   'EIF4G1',
#   'EIF3I',
#   'EIF3F',
#   'EIF3G',
#   'EIF3D',
#   'EIF3E',
#   'EIF3B',
#   'EIF4G3',
#   'EIF3C',
# ...

# %%
module_to_json(module_dict=WikiPathway_dict, file_path="WikiPathway_2023_Human.json")
