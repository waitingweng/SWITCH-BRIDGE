# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS')
from methods import module_to_json

# %%
# Save data to a file
BioPlex_dict = dict()
with open("BioPlex_2017.txt", "r") as file:
    for line in file:
        data = line.strip().split('\t')
        BioPlex_dict[data[0]] = data[2:]
        print(f"function: {data[0]}")
        print(f"genes: {data[2:]}")
# Out:
# function: ATXN2
# genes: ['APOBEC3D', 'RBFOX2', 'CELA2B', 'DDX6', 'NUFIP2', 'FAM98A', 'FGL1', 'CELF5', 'CARD8', 'ELAVL2', 'CCNDBP1', 'NXF2', 'P4HA2', 'ESRP1', 'LPXN', 'CLASRP', 'NME2P1', 'ASB3', 'BCAT1']
# function: ARSA
# genes: ['DNASE2B', 'KLK5', 'ZBTB43', 'PTPRK', 'PLAUR', 'SUMF1', 'MESDC2', 'GALNS', 'SCGB1D1', 'TMEM25', 'DPEP2', 'SUSD4', 'INSL5']
# function: MED20
# genes: ['MED1', 'LMO2', 'CDK19', 'CCNC', 'GDF9', 'MED19', 'MED7', 'MED18', 'TCL1B', 'CDK8', 'MED21', 'BIRC5', 'TKT']
# function: TCEAL1
# genes: ['USP7', 'EYA3', 'USP4', 'STAT3', 'UROS', 'PTPN11', 'HAUS7', 'C14ORF179', 'C9ORF40', 'SCNM1', 'TDP2', 'SASS6', 'DTL', 'HOXB9', 'KDM3A', 'CDCA2', 'TRUB1', 'FAF1', 'USP11', 'WDR4', 'UHRF1', 'POGK', 'PHF7', 'CHEK1', 'UBE2Q1', 'ZNF703', 'ZKSCAN4', 'TRIM25', 'ZUFSP']
# function: PRPF19
# ...

# %%
BioPlex_dict
# Out:
# {'ATXN2': ['APOBEC3D',
#   'RBFOX2',
#   'CELA2B',
#   'DDX6',
#   'NUFIP2',
#   'FAM98A',
#   'FGL1',
#   'CELF5',
#   'CARD8',
#   'ELAVL2',
#   'CCNDBP1',
#   'NXF2',
#   'P4HA2',
#   'ESRP1',
#   'LPXN',
#   'CLASRP',
#   'NME2P1',
#   'ASB3',
#   'BCAT1'],
#  'ARSA': ['DNASE2B',
#   'KLK5',
#   'ZBTB43',
#   'PTPRK',
#   'PLAUR',
#   'SUMF1',
#   'MESDC2',
#   'GALNS',
#   'SCGB1D1',
#   'TMEM25',
#   'DPEP2',
#   'SUSD4',
#   'INSL5'],
#  'MED20': ['MED1',
#   'LMO2',
#   'CDK19',
#   'CCNC',
#   'GDF9',
#   'MED19',
#   'MED7',
#   'MED18',
#   'TCL1B',
#   'CDK8',
#   'MED21',
#   'BIRC5',
#   'TKT'],
#  'TCEAL1': ['USP7',
#   'EYA3',
#   'USP4',
#   'STAT3',
#   'UROS',
#   'PTPN11',
#   'HAUS7',
#   'C14ORF179',
#   'C9ORF40',
#   'SCNM1',
#   'TDP2',
#   'SASS6',
#   'DTL',
#   'HOXB9',
#   'KDM3A',
#   'CDCA2',
#   'TRUB1',
#   'FAF1',
#   'USP11',
#   'WDR4',
#   'UHRF1',
#   'POGK',
#   'PHF7',
#   'CHEK1',
#   'UBE2Q1',
#   'ZNF703',
#   'ZKSCAN4',
#   'TRIM25',
# ...

# %%
module_to_json(module_dict=BioPlex_dict, file_path="BioPlex_2017.json")
