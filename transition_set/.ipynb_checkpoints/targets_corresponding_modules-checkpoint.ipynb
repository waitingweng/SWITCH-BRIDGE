# %%
import sys
sys.path.append('../FUNCTIONS')
from methods import module_to_dict
from transitional_set import targets_to_modules

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /home/jovyan/work/transition_set
# /home/jovyan/work/transition_set/Cell
# /home/jovyan/work/transition_set/Cell

# %%
target_genes = module_to_dict(file="./Hotspot/target_genes.json")
target_genes
# Out:
# {'targets_I_4S': ['PINX1',
#   'SDHB',
#   'BCKDHA',
#   'ABCF2',
#   'VAMP7',
#   'SCAMP3',
#   'RNF25',
#   'FAM71D',
#   'ALDOA',
#   'IL10RB',
#   'PRICKLE4',
#   'SNHG9',
#   'AGGF1',
#   'RHBDD2',
#   'LMAN2L',
#   'SIT1',
#   'AC010894.3',
#   'GPX3',
#   'ZC3H11A',
#   'C6orf48',
#   'HIST2H2BE',
#   'SOX15',
#   'DMTN',
#   'EGLN2',
#   'B3GAT2',
#   'AK1',
#   'ZNF320',
#   'GABPB1',
#   'RPS17',
#   'LINC01481',
#   'SLC7A8',
#   'DMD',
#   'ZNF737',
#   'GRID2',
#   'TRIM8',
#   'ZNF486',
#   'RNF215',
#   'POMK',
#   'PRH1',
#   'MYO1B',
#   'SLC30A1',
#   'ZNF460',
#   'TEAD1',
#   'ZNF708',
#   'FARP1',
#   'ZNF484',
#   'ZNF407',
#   'PIK3C2A',
#   'PRKDC',
#   'BIRC6',
#   'FRY',
#   'SIK3',
#   'PCDHA10',
#   'MFN1',
#   'NBEAL2',
#   'ZNF208',
#   'ZNF704',
#   'IGF2R',
#   'HDAC4',
#   'ZNF880',
#   'PPP1R14B',
#   'ZNF780A',
#   'VPS13B',
#   'DMXL2',
#   'VPS13C',
#   'TAF10',
#   'EML5',
#   'STON2',
#   'CELSR3',
#   'MMP24',
#   'SHC2',
#   'MACF1',
# ...

# %%
module_4S = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_4S_50.json")
module_I = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_I_50.json")
module_III = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_III_50.json")
module_IV = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_IV_50.json")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_I_4S", first_module=module_4S, second_module=module_I, first_module_stage="4S", title="Hotspot 4S_I")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_III_4S", first_module=module_4S, second_module=module_III, first_module_stage='4S', title="Hotspot 4S_III")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_IV_4S", first_module=module_4S, second_module=module_IV, first_module_stage='4S', title="Hotspot 4S_IV")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_III_I", first_module=module_I, second_module=module_III, first_module_stage='I', title="Hotspot I_III")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_IV_I", first_module=module_I, second_module=module_IV, first_module_stage='I', title="Hotspot I_IV")

# %%
targets_to_modules(target_genes=target_genes, targets="targets_IV_III", first_module=module_III, second_module=module_IV, first_module_stage='III', title="Hotspot III_IV")
