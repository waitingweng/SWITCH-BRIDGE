# %%
import sys
sys.path.append('../FUNCTIONS')
from methods import module_to_dict
from transitional_set import module_relation_bipartite

# %%
# !pwd
# %cd Cell/Hotspot
# !pwd
# Out:
# /home/jovyan/work/transition_set
# /home/jovyan/work/transition_set/Cell/Hotspot
# /home/jovyan/work/transition_set/Cell/Hotspot

# %%
module_4S = module_to_dict("../../../parameter_tuning/Hotspot/Cell/module_4S_50.json")
module_I = module_to_dict("../../../parameter_tuning/Hotspot/Cell/module_I_50.json")
module_III = module_to_dict("../../../parameter_tuning/Hotspot/Cell/module_III_50.json")
module_IV = module_to_dict("../../../parameter_tuning/Hotspot/Cell/module_IV_50.json")

# %%
print(len(module_4S))
print(len(module_I))
print(len(module_III))
print(len(module_IV))
# Out:
# 103
# 112
# 113
# 102

# %% [markdown]
# write function

# %%
module_relation_bipartite(q_value=0.001, first_module=module_4S, second_module=module_I, first_module_stage="4S", second_module_stage="I", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_4S, second_module=module_III, first_module_stage="4S", second_module_stage="III", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_4S, second_module=module_IV, first_module_stage="4S", second_module_stage="IV", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_I, second_module=module_III, first_module_stage="I", second_module_stage="III", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_I, second_module=module_IV, first_module_stage="I", second_module_stage="IV", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_III, second_module=module_IV, first_module_stage="III", second_module_stage="IV", save=True)
