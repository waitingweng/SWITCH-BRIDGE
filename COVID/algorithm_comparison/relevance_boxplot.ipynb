# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from algorithm_comparison import file_to_float

# %%
# !pwd
# %cd /home/jovyan/work/COVID/algorithm_comparison/Cell
# !pwd
# Out:
# /home/jovyan/work/COVID/algorithm_comparison
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell

# %% [markdown]
# KEGG

# %%
binary_knd_binary_KEGG_relevance = file_to_float(path="./binary_knd_binary_KEGG_relevance.txt")
reciprocal_knd_binary_KEGG_relevance = file_to_float(path="./reciprocal_knd_binary_KEGG_relevance.txt")
nlog_knd_linear_KEGG_relevance = file_to_float(path="./nlog_knd_linear_KEGG_relevance.txt")
reciprocal_knd_linear_KEGG_relevance = file_to_float(path="./reciprocal_knd_linear_KEGG_relevance.txt")
nlog_knd_nlog_KEGG_relevance = file_to_float(path="./nlog_knd_nlog_KEGG_relevance.txt")
reciprocal_knd_nlog_KEGG_relevance = file_to_float(path="./reciprocal_knd_nlog_KEGG_relevance.txt")
nlog_knd_reciprocal_KEGG_relevance = file_to_float(path="./nlog_knd_reciprocal_KEGG_relevance.txt")
reciprocal_knd_reciprocal_KEGG_relevance = file_to_float(path="./reciprocal_knd_reciprocal_KEGG_relevance.txt")
binary_knn_KEGG_relevance = file_to_float(path="./binary_knn_KEGG_relevance.txt")
reciprocal_knn_KEGG_relevance = file_to_float(path="./reciprocal_knn_KEGG_relevance.txt")
hdWGCNA_KEGG_relevance = file_to_float(path="./hdWGCNA_KEGG_relevance.txt")
Hotspot_KEGG_relevance = file_to_float(path="./Hotspot_KEGG_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = binary_knd_binary_KEGG_relevance
data2 = reciprocal_knd_binary_KEGG_relevance
data3 = nlog_knd_linear_KEGG_relevance
data4 = reciprocal_knd_linear_KEGG_relevance
data5 = nlog_knd_nlog_KEGG_relevance
data6 = reciprocal_knd_nlog_KEGG_relevance
data7 = nlog_knd_reciprocal_KEGG_relevance
data8 = reciprocal_knd_reciprocal_KEGG_relevance
data9 = binary_knn_KEGG_relevance
data10 = reciprocal_knn_KEGG_relevance
data11 = hdWGCNA_KEGG_relevance
data12 = Hotspot_KEGG_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('KEGG Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

plt.savefig("./figures/KEGG_pathway_relevance_comparison_partial.svg")
# Show the plot
plt.show()

# %%
pcc_knd_binary_KEGG_relevance = file_to_float(path="./pcc_knd_binary_KEGG_relevance.txt")
binary_knd_binary_KEGG_relevance = file_to_float(path="./binary_knd_binary_KEGG_relevance.txt")
linear_knd_binary_KEGG_relevance = file_to_float(path="./linear_knd_binary_KEGG_relevance.txt")
nlog_knd_binary_KEGG_relevance = file_to_float(path="./nlog_knd_binary_KEGG_relevance.txt")
reciprocal_knd_binary_KEGG_relevance = file_to_float(path="./reciprocal_knd_binary_KEGG_relevance.txt")

# %%
pcc_knd_linear_KEGG_relevance = file_to_float(path="./pcc_knd_linear_KEGG_relevance.txt")
binary_knd_linear_KEGG_relevance = file_to_float(path="./binary_knd_linear_KEGG_relevance.txt")
linear_knd_linear_KEGG_relevance = file_to_float(path="./linear_knd_linear_KEGG_relevance.txt")
nlog_knd_linear_KEGG_relevance = file_to_float(path="./nlog_knd_linear_KEGG_relevance.txt")
reciprocal_knd_linear_KEGG_relevance = file_to_float(path="./reciprocal_knd_linear_KEGG_relevance.txt")

# %%
pcc_knd_nlog_KEGG_relevance = file_to_float(path="./pcc_knd_nlog_KEGG_relevance.txt")
binary_knd_nlog_KEGG_relevance = file_to_float(path="./binary_knd_nlog_KEGG_relevance.txt")
linear_knd_nlog_KEGG_relevance = file_to_float(path="./linear_knd_nlog_KEGG_relevance.txt")
nlog_knd_nlog_KEGG_relevance = file_to_float(path="./nlog_knd_nlog_KEGG_relevance.txt")
reciprocal_knd_nlog_KEGG_relevance = file_to_float(path="./reciprocal_knd_nlog_KEGG_relevance.txt")

# %%
pcc_knd_reciprocal_KEGG_relevance = file_to_float(path="./pcc_knd_reciprocal_KEGG_relevance.txt")
binary_knd_reciprocal_KEGG_relevance = file_to_float(path="./binary_knd_reciprocal_KEGG_relevance.txt")
linear_knd_reciprocal_KEGG_relevance = file_to_float(path="./linear_knd_reciprocal_KEGG_relevance.txt")
nlog_knd_reciprocal_KEGG_relevance = file_to_float(path="./nlog_knd_reciprocal_KEGG_relevance.txt")
reciprocal_knd_reciprocal_KEGG_relevance = file_to_float(path="./reciprocal_knd_reciprocal_KEGG_relevance.txt")

# %%
pcc_knn_KEGG_relevance = file_to_float(path="./pcc_knn_KEGG_relevance.txt")
binary_knn_KEGG_relevance = file_to_float(path="./binary_knn_KEGG_relevance.txt")
linear_knn_KEGG_relevance = file_to_float(path="./linear_knn_KEGG_relevance.txt")
nlog_knn_KEGG_relevance = file_to_float(path="./nlog_knn_KEGG_relevance.txt")
reciprocal_knn_KEGG_relevance = file_to_float(path="./reciprocal_knn_KEGG_relevance.txt")

# %%
pcc_leiden_KEGG_relevance = file_to_float(path="./pcc_leiden_KEGG_relevance.txt")

# %%
hdWGCNA_KEGG_relevance = file_to_float(path="./hdWGCNA_KEGG_relevance.txt")

# %%
# TOM_Leiden_KEGG_relevance = file_to_float(path="./TOM_Leiden_KEGG_relevance.txt")

# %%
Hotspot_KEGG_relevance = file_to_float(path="./Hotspot_KEGG_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_KEGG_relevance, binary_knd_binary_KEGG_relevance, linear_knd_binary_KEGG_relevance, nlog_knd_binary_KEGG_relevance, reciprocal_knd_binary_KEGG_relevance]
data2 = [pcc_knd_linear_KEGG_relevance, binary_knd_linear_KEGG_relevance, linear_knd_linear_KEGG_relevance, nlog_knd_linear_KEGG_relevance, reciprocal_knd_linear_KEGG_relevance]
data3 = [pcc_knd_nlog_KEGG_relevance, binary_knd_nlog_KEGG_relevance, linear_knd_nlog_KEGG_relevance, nlog_knd_nlog_KEGG_relevance, reciprocal_knd_nlog_KEGG_relevance]
data4 = [pcc_knd_reciprocal_KEGG_relevance, binary_knd_reciprocal_KEGG_relevance, linear_knd_reciprocal_KEGG_relevance, nlog_knd_reciprocal_KEGG_relevance, reciprocal_knd_reciprocal_KEGG_relevance]
data5 = [pcc_knn_KEGG_relevance, binary_knn_KEGG_relevance, linear_knn_KEGG_relevance, nlog_knn_KEGG_relevance, reciprocal_knn_KEGG_relevance]
data6 = pcc_leiden_KEGG_relevance
data7 = hdWGCNA_KEGG_relevance
data8 = Hotspot_KEGG_relevance
#data9 = Hotspot_KEGG_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
# custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden']
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
# ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6]) # Set the positions of major ticks
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6]) # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('KEGG Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'pcc', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/KEGG_pathway_relevance_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# Reactome

# %%
binary_knd_binary_Reactome_relevance = file_to_float(path="./binary_knd_binary_Reactome_relevance.txt")
reciprocal_knd_binary_Reactome_relevance = file_to_float(path="./reciprocal_knd_binary_Reactome_relevance.txt")
nlog_knd_linear_Reactome_relevance = file_to_float(path="./nlog_knd_linear_Reactome_relevance.txt")
reciprocal_knd_linear_Reactome_relevance = file_to_float(path="./reciprocal_knd_linear_Reactome_relevance.txt")
nlog_knd_nlog_Reactome_relevance = file_to_float(path="./nlog_knd_nlog_Reactome_relevance.txt")
reciprocal_knd_nlog_Reactome_relevance = file_to_float(path="./reciprocal_knd_nlog_Reactome_relevance.txt")
nlog_knd_reciprocal_Reactome_relevance = file_to_float(path="./nlog_knd_reciprocal_Reactome_relevance.txt")
reciprocal_knd_reciprocal_Reactome_relevance = file_to_float(path="./reciprocal_knd_reciprocal_Reactome_relevance.txt")
binary_knn_Reactome_relevance = file_to_float(path="./binary_knn_Reactome_relevance.txt")
reciprocal_knn_Reactome_relevance = file_to_float(path="./reciprocal_knn_Reactome_relevance.txt")
hdWGCNA_Reactome_relevance = file_to_float(path="./hdWGCNA_Reactome_relevance.txt")
Hotspot_Reactome_relevance = file_to_float(path="./Hotspot_Reactome_relevance.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 binary_knd_binary_Reactome_relevance = file_to_float(path="./binary_knd_binary_Reactome_relevance.txt")
#       2 reciprocal_knd_binary_Reactome_relevance = file_to_float(path="./reciprocal_knd_binary_Reactome_relevance.txt")
#       3 nlog_knd_linear_Reactome_relevance = file_to_float(path="./nlog_knd_linear_Reactome_relevance.txt")
#
# File ~/work/FUNCTIONS/algorithm_comparison.py:100, in file_to_float(path)
#      98 def file_to_float(path):
#      99     l = list()
# --> 100     with open(path, "r") as file:
#     101         for i in file:
#     102             l.append(float(i.strip()))
#
# FileNotFoundError: [Errno 2] No such file or directory: './binary_knd_binary_Reactome_relevance.txt'

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = binary_knd_binary_Reactome_relevance
data2 = reciprocal_knd_binary_Reactome_relevance
data3 = nlog_knd_linear_Reactome_relevance
data4 = reciprocal_knd_linear_Reactome_relevance
data5 = nlog_knd_nlog_Reactome_relevance
data6 = reciprocal_knd_nlog_Reactome_relevance
data7 = nlog_knd_reciprocal_Reactome_relevance
data8 = reciprocal_knd_reciprocal_Reactome_relevance
data9 = binary_knn_Reactome_relevance
data10 = reciprocal_knn_Reactome_relevance
data11 = hdWGCNA_Reactome_relevance
data12 = Hotspot_Reactome_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Reactome Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

plt.savefig("./figures/Reactome_pathway_relevance_comparison_partial.svg")
# Show the plot
plt.show()

# %%
pcc_knd_binary_Reactome_relevance = file_to_float(path="./pcc_knd_binary_Reactome_relevance.txt")
binary_knd_binary_Reactome_relevance = file_to_float(path="./binary_knd_binary_Reactome_relevance.txt")
linear_knd_binary_Reactome_relevance = file_to_float(path="./linear_knd_binary_Reactome_relevance.txt")
nlog_knd_binary_Reactome_relevance = file_to_float(path="./nlog_knd_binary_Reactome_relevance.txt")
reciprocal_knd_binary_Reactome_relevance = file_to_float(path="./reciprocal_knd_binary_Reactome_relevance.txt")

# %%
pcc_knd_linear_Reactome_relevance = file_to_float(path="./pcc_knd_linear_Reactome_relevance.txt")
binary_knd_linear_Reactome_relevance = file_to_float(path="./binary_knd_linear_Reactome_relevance.txt")
linear_knd_linear_Reactome_relevance = file_to_float(path="./linear_knd_linear_Reactome_relevance.txt")
nlog_knd_linear_Reactome_relevance = file_to_float(path="./nlog_knd_linear_Reactome_relevance.txt")
reciprocal_knd_linear_Reactome_relevance = file_to_float(path="./reciprocal_knd_linear_Reactome_relevance.txt")

# %%
pcc_knd_nlog_Reactome_relevance = file_to_float(path="./pcc_knd_nlog_Reactome_relevance.txt")
binary_knd_nlog_Reactome_relevance = file_to_float(path="./binary_knd_nlog_Reactome_relevance.txt")
linear_knd_nlog_Reactome_relevance = file_to_float(path="./linear_knd_nlog_Reactome_relevance.txt")
nlog_knd_nlog_Reactome_relevance = file_to_float(path="./nlog_knd_nlog_Reactome_relevance.txt")
reciprocal_knd_nlog_Reactome_relevance = file_to_float(path="./reciprocal_knd_nlog_Reactome_relevance.txt")

# %%
pcc_knd_reciprocal_Reactome_relevance = file_to_float(path="./pcc_knd_reciprocal_Reactome_relevance.txt")
binary_knd_reciprocal_Reactome_relevance = file_to_float(path="./binary_knd_reciprocal_Reactome_relevance.txt")
linear_knd_reciprocal_Reactome_relevance = file_to_float(path="./linear_knd_reciprocal_Reactome_relevance.txt")
nlog_knd_reciprocal_Reactome_relevance = file_to_float(path="./nlog_knd_reciprocal_Reactome_relevance.txt")
reciprocal_knd_reciprocal_Reactome_relevance = file_to_float(path="./reciprocal_knd_reciprocal_Reactome_relevance.txt")

# %%
pcc_knn_Reactome_relevance = file_to_float(path="./pcc_knn_Reactome_relevance.txt")
binary_knn_Reactome_relevance = file_to_float(path="./binary_knn_Reactome_relevance.txt")
linear_knn_Reactome_relevance = file_to_float(path="./linear_knn_Reactome_relevance.txt")
nlog_knn_Reactome_relevance = file_to_float(path="./nlog_knn_Reactome_relevance.txt")
reciprocal_knn_Reactome_relevance = file_to_float(path="./reciprocal_knn_Reactome_relevance.txt")

# %%
pcc_Reactome_relevance = file_to_float(path="./pcc_Reactome_relevance.txt")

# %%
hdWGCNA_Reactome_relevance = file_to_float(path="./hdWGCNA_Reactome_relevance.txt")

# %%
# TOM_Leiden_Reactome_relevance = file_to_float(path="./TOM_Leiden_Reactome_relevance.txt")

# %%
Hotspot_Reactome_relevance = file_to_float(path="./Hotspot_Reactome_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_Reactome_relevance, binary_knd_binary_Reactome_relevance, linear_knd_binary_Reactome_relevance, nlog_knd_binary_Reactome_relevance, reciprocal_knd_binary_Reactome_relevance]
data2 = [pcc_knd_linear_Reactome_relevance, binary_knd_linear_Reactome_relevance, linear_knd_linear_Reactome_relevance, nlog_knd_linear_Reactome_relevance, reciprocal_knd_linear_Reactome_relevance]
data3 = [pcc_knd_nlog_Reactome_relevance, binary_knd_nlog_Reactome_relevance, linear_knd_nlog_Reactome_relevance, nlog_knd_nlog_Reactome_relevance, reciprocal_knd_nlog_Reactome_relevance]
data4 = [pcc_knd_reciprocal_Reactome_relevance, binary_knd_reciprocal_Reactome_relevance, linear_knd_reciprocal_Reactome_relevance, nlog_knd_reciprocal_Reactome_relevance, reciprocal_knd_reciprocal_Reactome_relevance]
data5 = [pcc_knn_Reactome_relevance, binary_knn_Reactome_relevance, linear_knn_Reactome_relevance, nlog_knn_Reactome_relevance, reciprocal_knn_Reactome_relevance]
data6 = pcc_Reactome_relevance
data7 = hdWGCNA_Reactome_relevance
data8 = Hotspot_Reactome_relevance
# data9 = Hotspot_Reactome_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Reactome Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'pcc', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/Reactome_pathway_relevance_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# BioPlex

# %%
binary_knd_binary_BioPlex_relevance = file_to_float(path="./binary_knd_binary_BioPlex_relevance.txt")
reciprocal_knd_binary_BioPlex_relevance = file_to_float(path="./reciprocal_knd_binary_BioPlex_relevance.txt")
nlog_knd_linear_BioPlex_relevance = file_to_float(path="./nlog_knd_linear_BioPlex_relevance.txt")
reciprocal_knd_linear_BioPlex_relevance = file_to_float(path="./reciprocal_knd_linear_BioPlex_relevance.txt")
nlog_knd_nlog_BioPlex_relevance = file_to_float(path="./nlog_knd_nlog_BioPlex_relevance.txt")
reciprocal_knd_nlog_BioPlex_relevance = file_to_float(path="./reciprocal_knd_nlog_BioPlex_relevance.txt")
nlog_knd_reciprocal_BioPlex_relevance = file_to_float(path="./nlog_knd_reciprocal_BioPlex_relevance.txt")
reciprocal_knd_reciprocal_BioPlex_relevance = file_to_float(path="./reciprocal_knd_reciprocal_BioPlex_relevance.txt")
binary_knn_BioPlex_relevance = file_to_float(path="./binary_knn_BioPlex_relevance.txt")
reciprocal_knn_BioPlex_relevance = file_to_float(path="./reciprocal_knn_BioPlex_relevance.txt")
hdWGCNA_BioPlex_relevance = file_to_float(path="./hdWGCNA_BioPlex_relevance.txt")
Hotspot_BioPlex_relevance = file_to_float(path="./Hotspot_BioPlex_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = binary_knd_binary_BioPlex_relevance
data2 = reciprocal_knd_binary_BioPlex_relevance
data3 = nlog_knd_linear_BioPlex_relevance
data4 = reciprocal_knd_linear_BioPlex_relevance
data5 = nlog_knd_nlog_BioPlex_relevance
data6 = reciprocal_knd_nlog_BioPlex_relevance
data7 = nlog_knd_reciprocal_BioPlex_relevance
data8 = reciprocal_knd_reciprocal_BioPlex_relevance
data9 = binary_knn_BioPlex_relevance
data10 = reciprocal_knn_BioPlex_relevance
data11 = hdWGCNA_BioPlex_relevance
data12 = Hotspot_BioPlex_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('BioPlex Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

plt.savefig("./figures/BioPlex_pathway_relevance_comparison_partial.svg")
# Show the plot
plt.show()

# %%
pcc_knd_binary_BioPlex_relevance = file_to_float(path="./pcc_knd_binary_BioPlex_relevance.txt")
binary_knd_binary_BioPlex_relevance = file_to_float(path="./binary_knd_binary_BioPlex_relevance.txt")
linear_knd_binary_BioPlex_relevance = file_to_float(path="./linear_knd_binary_BioPlex_relevance.txt")
nlog_knd_binary_BioPlex_relevance = file_to_float(path="./nlog_knd_binary_BioPlex_relevance.txt")
reciprocal_knd_binary_BioPlex_relevance = file_to_float(path="./reciprocal_knd_binary_BioPlex_relevance.txt")

# %%
pcc_knd_linear_BioPlex_relevance = file_to_float(path="./pcc_knd_linear_BioPlex_relevance.txt")
binary_knd_linear_BioPlex_relevance = file_to_float(path="./binary_knd_linear_BioPlex_relevance.txt")
linear_knd_linear_BioPlex_relevance = file_to_float(path="./linear_knd_linear_BioPlex_relevance.txt")
nlog_knd_linear_BioPlex_relevance = file_to_float(path="./nlog_knd_linear_BioPlex_relevance.txt")
reciprocal_knd_linear_BioPlex_relevance = file_to_float(path="./reciprocal_knd_linear_BioPlex_relevance.txt")

# %%
pcc_knd_nlog_BioPlex_relevance = file_to_float(path="./pcc_knd_nlog_BioPlex_relevance.txt")
binary_knd_nlog_BioPlex_relevance = file_to_float(path="./binary_knd_nlog_BioPlex_relevance.txt")
linear_knd_nlog_BioPlex_relevance = file_to_float(path="./linear_knd_nlog_BioPlex_relevance.txt")
nlog_knd_nlog_BioPlex_relevance = file_to_float(path="./nlog_knd_nlog_BioPlex_relevance.txt")
reciprocal_knd_nlog_BioPlex_relevance = file_to_float(path="./reciprocal_knd_nlog_BioPlex_relevance.txt")

# %%
pcc_knd_reciprocal_BioPlex_relevance = file_to_float(path="./pcc_knd_reciprocal_BioPlex_relevance.txt")
binary_knd_reciprocal_BioPlex_relevance = file_to_float(path="./binary_knd_reciprocal_BioPlex_relevance.txt")
linear_knd_reciprocal_BioPlex_relevance = file_to_float(path="./linear_knd_reciprocal_BioPlex_relevance.txt")
nlog_knd_reciprocal_BioPlex_relevance = file_to_float(path="./nlog_knd_reciprocal_BioPlex_relevance.txt")
reciprocal_knd_reciprocal_BioPlex_relevance = file_to_float(path="./reciprocal_knd_reciprocal_BioPlex_relevance.txt")

# %%
pcc_knn_BioPlex_relevance = file_to_float(path="./pcc_knn_BioPlex_relevance.txt")
binary_knn_BioPlex_relevance = file_to_float(path="./binary_knn_BioPlex_relevance.txt")
linear_knn_BioPlex_relevance = file_to_float(path="./linear_knn_BioPlex_relevance.txt")
nlog_knn_BioPlex_relevance = file_to_float(path="./nlog_knn_BioPlex_relevance.txt")
reciprocal_knn_BioPlex_relevance = file_to_float(path="./reciprocal_knn_BioPlex_relevance.txt")

# %%
pcc_BioPlex_relevance = file_to_float(path="./pcc_BioPlex_relevance.txt")

# %%
hdWGCNA_BioPlex_relevance = file_to_float(path="./hdWGCNA_BioPlex_relevance.txt")

# %%
# TOM_Leiden_BioPlex_relevance = file_to_float(path="./TOM_Leiden_BioPlex_relevance.txt")

# %%
Hotspot_BioPlex_relevance = file_to_float(path="./Hotspot_BioPlex_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_BioPlex_relevance, binary_knd_binary_BioPlex_relevance, linear_knd_binary_BioPlex_relevance, nlog_knd_binary_BioPlex_relevance, reciprocal_knd_binary_BioPlex_relevance]
data2 = [pcc_knd_linear_BioPlex_relevance, binary_knd_linear_BioPlex_relevance, linear_knd_linear_BioPlex_relevance, nlog_knd_linear_BioPlex_relevance, reciprocal_knd_linear_BioPlex_relevance]
data3 = [pcc_knd_nlog_BioPlex_relevance, binary_knd_nlog_BioPlex_relevance, linear_knd_nlog_BioPlex_relevance, nlog_knd_nlog_BioPlex_relevance, reciprocal_knd_nlog_BioPlex_relevance]
data4 = [pcc_knd_reciprocal_BioPlex_relevance, binary_knd_reciprocal_BioPlex_relevance, linear_knd_reciprocal_BioPlex_relevance, nlog_knd_reciprocal_BioPlex_relevance, reciprocal_knd_reciprocal_BioPlex_relevance]
data5 = [pcc_knn_BioPlex_relevance, binary_knn_BioPlex_relevance, linear_knn_BioPlex_relevance, nlog_knn_BioPlex_relevance, reciprocal_knn_BioPlex_relevance]
data6 = pcc_BioPlex_relevance
data7 = hdWGCNA_BioPlex_relevance
data8 = Hotspot_BioPlex_relevance
# data9 = Hotspot_BioPlex_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('BioPlex Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'pcc', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/BioPlex_pathway_relevance_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# WikiPathway

# %%
binary_knd_binary_WikiPathway_relevance = file_to_float(path="./binary_knd_binary_WikiPathway_relevance.txt")
reciprocal_knd_binary_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_binary_WikiPathway_relevance.txt")
nlog_knd_linear_WikiPathway_relevance = file_to_float(path="./nlog_knd_linear_WikiPathway_relevance.txt")
reciprocal_knd_linear_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_linear_WikiPathway_relevance.txt")
nlog_knd_nlog_WikiPathway_relevance = file_to_float(path="./nlog_knd_nlog_WikiPathway_relevance.txt")
reciprocal_knd_nlog_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_nlog_WikiPathway_relevance.txt")
nlog_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./nlog_knd_reciprocal_WikiPathway_relevance.txt")
reciprocal_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_reciprocal_WikiPathway_relevance.txt")
binary_knn_WikiPathway_relevance = file_to_float(path="./binary_knn_WikiPathway_relevance.txt")
reciprocal_knn_WikiPathway_relevance = file_to_float(path="./reciprocal_knn_WikiPathway_relevance.txt")
hdWGCNA_WikiPathway_relevance = file_to_float(path="./hdWGCNA_WikiPathway_relevance.txt")
Hotspot_WikiPathway_relevance = file_to_float(path="./Hotspot_WikiPathway_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = binary_knd_binary_WikiPathway_relevance
data2 = reciprocal_knd_binary_WikiPathway_relevance
data3 = nlog_knd_linear_WikiPathway_relevance
data4 = reciprocal_knd_linear_WikiPathway_relevance
data5 = nlog_knd_nlog_WikiPathway_relevance
data6 = reciprocal_knd_nlog_WikiPathway_relevance
data7 = nlog_knd_reciprocal_WikiPathway_relevance
data8 = reciprocal_knd_reciprocal_WikiPathway_relevance
data9 = binary_knn_WikiPathway_relevance
data10 = reciprocal_knn_WikiPathway_relevance
data11 = hdWGCNA_WikiPathway_relevance
data12 = Hotspot_WikiPathway_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('WikiPathway Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

plt.savefig("./figures/WikiPathway_pathway_relevance_comparison_partial.svg")
# Show the plot
plt.show()

# %%
pcc_knd_binary_WikiPathway_relevance = file_to_float(path="./pcc_knd_binary_WikiPathway_relevance.txt")
binary_knd_binary_WikiPathway_relevance = file_to_float(path="./binary_knd_binary_WikiPathway_relevance.txt")
linear_knd_binary_WikiPathway_relevance = file_to_float(path="./linear_knd_binary_WikiPathway_relevance.txt")
nlog_knd_binary_WikiPathway_relevance = file_to_float(path="./nlog_knd_binary_WikiPathway_relevance.txt")
reciprocal_knd_binary_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_binary_WikiPathway_relevance.txt")

# %%
pcc_knd_linear_WikiPathway_relevance = file_to_float(path="./pcc_knd_linear_WikiPathway_relevance.txt")
binary_knd_linear_WikiPathway_relevance = file_to_float(path="./binary_knd_linear_WikiPathway_relevance.txt")
linear_knd_linear_WikiPathway_relevance = file_to_float(path="./linear_knd_linear_WikiPathway_relevance.txt")
nlog_knd_linear_WikiPathway_relevance = file_to_float(path="./nlog_knd_linear_WikiPathway_relevance.txt")
reciprocal_knd_linear_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_linear_WikiPathway_relevance.txt")

# %%
pcc_knd_nlog_WikiPathway_relevance = file_to_float(path="./pcc_knd_nlog_WikiPathway_relevance.txt")
binary_knd_nlog_WikiPathway_relevance = file_to_float(path="./binary_knd_nlog_WikiPathway_relevance.txt")
linear_knd_nlog_WikiPathway_relevance = file_to_float(path="./linear_knd_nlog_WikiPathway_relevance.txt")
nlog_knd_nlog_WikiPathway_relevance = file_to_float(path="./nlog_knd_nlog_WikiPathway_relevance.txt")
reciprocal_knd_nlog_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_nlog_WikiPathway_relevance.txt")

# %%
pcc_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./pcc_knd_reciprocal_WikiPathway_relevance.txt")
binary_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./binary_knd_reciprocal_WikiPathway_relevance.txt")
linear_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./linear_knd_reciprocal_WikiPathway_relevance.txt")
nlog_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./nlog_knd_reciprocal_WikiPathway_relevance.txt")
reciprocal_knd_reciprocal_WikiPathway_relevance = file_to_float(path="./reciprocal_knd_reciprocal_WikiPathway_relevance.txt")

# %%
pcc_knn_WikiPathway_relevance = file_to_float(path="./pcc_knn_WikiPathway_relevance.txt")
binary_knn_WikiPathway_relevance = file_to_float(path="./binary_knn_WikiPathway_relevance.txt")
linear_knn_WikiPathway_relevance = file_to_float(path="./linear_knn_WikiPathway_relevance.txt")
nlog_knn_WikiPathway_relevance = file_to_float(path="./nlog_knn_WikiPathway_relevance.txt")
reciprocal_knn_WikiPathway_relevance = file_to_float(path="./reciprocal_knn_WikiPathway_relevance.txt")

# %%
pcc_WikiPathway_relevance = file_to_float(path="./pcc_WikiPathway_relevance.txt")

# %%
hdWGCNA_WikiPathway_relevance = file_to_float(path="./hdWGCNA_WikiPathway_relevance.txt")

# %%
# TOM_Leiden_WikiPathway_relevance = file_to_float(path="./TOM_Leiden_WikiPathway_relevance.txt")

# %%
Hotspot_WikiPathway_relevance = file_to_float(path="./Hotspot_WikiPathway_relevance.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_WikiPathway_relevance, binary_knd_binary_WikiPathway_relevance, linear_knd_binary_WikiPathway_relevance, nlog_knd_binary_WikiPathway_relevance, reciprocal_knd_binary_WikiPathway_relevance]
data2 = [pcc_knd_linear_WikiPathway_relevance, binary_knd_linear_WikiPathway_relevance, linear_knd_linear_WikiPathway_relevance, nlog_knd_linear_WikiPathway_relevance, reciprocal_knd_linear_WikiPathway_relevance]
data3 = [pcc_knd_nlog_WikiPathway_relevance, binary_knd_nlog_WikiPathway_relevance, linear_knd_nlog_WikiPathway_relevance, nlog_knd_nlog_WikiPathway_relevance, reciprocal_knd_nlog_WikiPathway_relevance]
data4 = [pcc_knd_reciprocal_WikiPathway_relevance, binary_knd_reciprocal_WikiPathway_relevance, linear_knd_reciprocal_WikiPathway_relevance, nlog_knd_reciprocal_WikiPathway_relevance, reciprocal_knd_reciprocal_WikiPathway_relevance]
data5 = [pcc_knn_WikiPathway_relevance, binary_knn_WikiPathway_relevance, linear_knn_WikiPathway_relevance, nlog_knn_WikiPathway_relevance, reciprocal_knn_WikiPathway_relevance]
data6 = pcc_WikiPathway_relevance
data7 = hdWGCNA_WikiPathway_relevance
data8 = Hotspot_WikiPathway_relevance
# data9 = Hotspot_WikiPathway_relevance

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('WikiPathway Relevance', fontsize=18)
ax.set_title('Relevance Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'pcc', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/WikiPathway_pathway_relevance_comparison.svg")
# Show the plot
plt.show()
