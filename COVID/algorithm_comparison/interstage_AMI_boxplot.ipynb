# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS/')
from methods import module_to_dict

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /hdd/edward/the-project/algorithm_comparison
# /hdd/edward/the-project/algorithm_comparison/Cell
# /hdd/edward/the-project/algorithm_comparison/Cell

# %%
PCC_SWIM_knd_binary_AMI = list(module_to_dict(file="PCC_SWIM_knd_binary_interstage_AMI.json").values())
Binary_SWIM_knd_binary_AMI = list(module_to_dict(file="Binary_SWIM_knd_binary_interstage_AMI.json").values())
Linear_SWIM_knd_binary_AMI = list(module_to_dict(file="Linear_SWIM_knd_binary_interstage_AMI.json").values())
Nlog_SWIM_knd_binary_AMI = list(module_to_dict(file="Nlog_SWIM_knd_binary_interstage_AMI.json").values())
Reciprocal_SWIM_knd_binary_AMI = list(module_to_dict(file="Reciprocal_SWIM_knd_binary_interstage_AMI.json").values())

# %%
PCC_SWIM_knd_linear_AMI = list(module_to_dict(file="PCC_SWIM_knd_linear_interstage_AMI.json").values())
Binary_SWIM_knd_linear_AMI = list(module_to_dict(file="Binary_SWIM_knd_linear_interstage_AMI.json").values())
Linear_SWIM_knd_linear_AMI = list(module_to_dict(file="Linear_SWIM_knd_linear_interstage_AMI.json").values())
Nlog_SWIM_knd_linear_AMI = list(module_to_dict(file="Nlog_SWIM_knd_linear_interstage_AMI.json").values())
Reciprocal_SWIM_knd_linear_AMI = list(module_to_dict(file="Reciprocal_SWIM_knd_linear_interstage_AMI.json").values())

# %%
PCC_SWIM_knd_nlog_AMI = list(module_to_dict(file="PCC_SWIM_knd_nlog_interstage_AMI.json").values())
Binary_SWIM_knd_nlog_AMI = list(module_to_dict(file="Binary_SWIM_knd_nlog_interstage_AMI.json").values())
Linear_SWIM_knd_nlog_AMI = list(module_to_dict(file="Linear_SWIM_knd_nlog_interstage_AMI.json").values())
Nlog_SWIM_knd_nlog_AMI = list(module_to_dict(file="Nlog_SWIM_knd_nlog_interstage_AMI.json").values())
Reciprocal_SWIM_knd_nlog_AMI = list(module_to_dict(file="Reciprocal_SWIM_knd_nlog_interstage_AMI.json").values())

# %%
PCC_SWIM_knd_reciprocal_AMI = list(module_to_dict(file="PCC_SWIM_knd_reciprocal_interstage_AMI.json").values())
Binary_SWIM_knd_reciprocal_AMI = list(module_to_dict(file="Binary_SWIM_knd_reciprocal_interstage_AMI.json").values())
Linear_SWIM_knd_reciprocal_AMI = list(module_to_dict(file="Linear_SWIM_knd_reciprocal_interstage_AMI.json").values())
Nlog_SWIM_knd_reciprocal_AMI = list(module_to_dict(file="Nlog_SWIM_knd_reciprocal_interstage_AMI.json").values())
Reciprocal_SWIM_knd_reciprocal_AMI = list(module_to_dict(file="Reciprocal_SWIM_knd_reciprocal_interstage_AMI.json").values())

# %%
PCC_SWIM_knn_AMI = list(module_to_dict(file="PCC_SWIM_knn_interstage_AMI.json").values())
Binary_SWIM_knn_AMI = list(module_to_dict(file="Binary_SWIM_knn_interstage_AMI.json").values())
Linear_SWIM_knn_AMI = list(module_to_dict(file="Linear_SWIM_knn_interstage_AMI.json").values())
Nlog_SWIM_knn_AMI = list(module_to_dict(file="Nlog_SWIM_knn_interstage_AMI.json").values())
Reciprocal_SWIM_knn_AMI = list(module_to_dict(file="Reciprocal_SWIM_knn_interstage_AMI.json").values())

# %%
PCC_Leiden_AMI = list(module_to_dict(file="PCC_Leiden_interstage_AMI.json").values())

# %%
hdWGCNA_AMI = list(module_to_dict(file="hdWGCNA_interstage_AMI.json").values())

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_AMI, Binary_SWIM_knd_binary_AMI, Linear_SWIM_knd_binary_AMI, Nlog_SWIM_knd_binary_AMI, Reciprocal_SWIM_knd_binary_AMI]
data2 = [PCC_SWIM_knd_linear_AMI, Binary_SWIM_knd_linear_AMI, Linear_SWIM_knd_linear_AMI, Nlog_SWIM_knd_linear_AMI, Reciprocal_SWIM_knd_linear_AMI]
data3 = [PCC_SWIM_knd_nlog_AMI, Binary_SWIM_knd_nlog_AMI, Linear_SWIM_knd_nlog_AMI, Nlog_SWIM_knd_nlog_AMI, Reciprocal_SWIM_knd_nlog_AMI]
data4 = [PCC_SWIM_knd_reciprocal_AMI, Binary_SWIM_knd_reciprocal_AMI, Linear_SWIM_knd_reciprocal_AMI, Nlog_SWIM_knd_reciprocal_AMI, Reciprocal_SWIM_knd_reciprocal_AMI]
data5 = [PCC_SWIM_knn_AMI, Binary_SWIM_knn_AMI, Linear_SWIM_knn_AMI, Nlog_SWIM_knn_AMI, Reciprocal_SWIM_knn_AMI]
data6 = PCC_Leiden_AMI
data7 = hdWGCNA_AMI

# Create a figure and axis object
fig, ax = plt.subplots()

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.1, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
# Draw the second box plot
bp7 = ax.boxplot(data7, widths=0.1, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Adjusted Mutual Information', fontsize=18)
ax.set_title('Interstage AMI Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/interstage_AMI_comparison.svg")
# Show the plot
plt.show()
