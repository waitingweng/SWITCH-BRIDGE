# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS/')
from algorithm_comparison import file_to_float

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /hdd/edward/the-project/algorithm_comparison
# /hdd/edward/the-project/algorithm_comparison/Cell
# /hdd/edward/the-project/algorithm_comparison/Cell

# %%
PCC_SWIM_knd_binary_module_ratio = file_to_float(path="PCC_SWIM_knd_binary_module_ratio.txt")
Binary_SWIM_knd_binary_module_ratio = file_to_float(path="Binary_SWIM_knd_binary_module_ratio.txt")
Linear_SWIM_knd_binary_module_ratio = file_to_float(path="Linear_SWIM_knd_binary_module_ratio.txt")
Nlog_SWIM_knd_binary_module_ratio = file_to_float(path="Nlog_SWIM_knd_binary_module_ratio.txt")
Reciprocal_SWIM_knd_binary_module_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_module_ratio.txt")

# %%
PCC_SWIM_knd_linear_module_ratio = file_to_float(path="PCC_SWIM_knd_linear_module_ratio.txt")
Binary_SWIM_knd_linear_module_ratio = file_to_float(path="Binary_SWIM_knd_linear_module_ratio.txt")
Linear_SWIM_knd_linear_module_ratio = file_to_float(path="Linear_SWIM_knd_linear_module_ratio.txt")
Nlog_SWIM_knd_linear_module_ratio = file_to_float(path="Nlog_SWIM_knd_linear_module_ratio.txt")
Reciprocal_SWIM_knd_linear_module_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_module_ratio.txt")

# %%
PCC_SWIM_knd_nlog_module_ratio = file_to_float(path="PCC_SWIM_knd_nlog_module_ratio.txt")
Binary_SWIM_knd_nlog_module_ratio = file_to_float(path="Binary_SWIM_knd_nlog_module_ratio.txt")
Linear_SWIM_knd_nlog_module_ratio = file_to_float(path="Linear_SWIM_knd_nlog_module_ratio.txt")
Nlog_SWIM_knd_nlog_module_ratio = file_to_float(path="Nlog_SWIM_knd_nlog_module_ratio.txt")
Reciprocal_SWIM_knd_nlog_module_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_module_ratio.txt")

# %%
PCC_SWIM_knd_reciprocal_module_ratio = file_to_float(path="PCC_SWIM_knd_reciprocal_module_ratio.txt")
Binary_SWIM_knd_reciprocal_module_ratio = file_to_float(path="Binary_SWIM_knd_reciprocal_module_ratio.txt")
Linear_SWIM_knd_reciprocal_module_ratio = file_to_float(path="Linear_SWIM_knd_reciprocal_module_ratio.txt")
Nlog_SWIM_knd_reciprocal_module_ratio = file_to_float(path="Nlog_SWIM_knd_reciprocal_module_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_module_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_module_ratio.txt")

# %%
PCC_SWIM_knn_module_ratio = file_to_float(path="PCC_SWIM_knn_module_ratio.txt")
Binary_SWIM_knn_module_ratio = file_to_float(path="Binary_SWIM_knn_module_ratio.txt")
Linear_SWIM_knn_module_ratio = file_to_float(path="Linear_SWIM_knn_module_ratio.txt")
Nlog_SWIM_knn_module_ratio = file_to_float(path="Nlog_SWIM_knn_module_ratio.txt")
Reciprocal_SWIM_knn_module_ratio = file_to_float(path="Reciprocal_SWIM_knn_module_ratio.txt")

# %%
PCC_Leiden_module_ratio = file_to_float(path="PCC_Leiden_module_ratio.txt")

# %%
hdWGCNA_module_ratio = file_to_float(path="hdWGCNA_module_ratio.txt")

# %%
# TOM_Leiden_module_ratio = file_to_float(path="TOM_Leiden_module_ratio.txt")

# %%
Hotspot_module_ratio = file_to_float(path="Hotspot_module_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_module_ratio, Binary_SWIM_knd_binary_module_ratio, Linear_SWIM_knd_binary_module_ratio, Nlog_SWIM_knd_binary_module_ratio, Reciprocal_SWIM_knd_binary_module_ratio]
data2 = [PCC_SWIM_knd_linear_module_ratio, Binary_SWIM_knd_linear_module_ratio, Linear_SWIM_knd_linear_module_ratio, Nlog_SWIM_knd_linear_module_ratio, Reciprocal_SWIM_knd_linear_module_ratio]
data3 = [PCC_SWIM_knd_nlog_module_ratio, Binary_SWIM_knd_nlog_module_ratio, Linear_SWIM_knd_nlog_module_ratio, Nlog_SWIM_knd_nlog_module_ratio, Reciprocal_SWIM_knd_nlog_module_ratio]
data4 = [PCC_SWIM_knd_reciprocal_module_ratio, Binary_SWIM_knd_reciprocal_module_ratio, Linear_SWIM_knd_reciprocal_module_ratio, Nlog_SWIM_knd_reciprocal_module_ratio, Reciprocal_SWIM_knd_reciprocal_module_ratio]
data5 = [PCC_SWIM_knn_module_ratio, Binary_SWIM_knn_module_ratio, Linear_SWIM_knn_module_ratio, Nlog_SWIM_knn_module_ratio, Reciprocal_SWIM_knn_module_ratio]
data6 = PCC_Leiden_module_ratio
data7 = hdWGCNA_module_ratio
data8 = Hotspot_module_ratio
# data9 = Hotspot_module_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Module Ratio', fontsize=18)
ax.set_title('Module Ratio Comparison', fontsize=20)

# Add legend for categories
plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/module_ratio_comparison.svg")
# Show the plot
plt.show()
