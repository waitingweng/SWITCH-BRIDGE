# %%
import sys
sys.path.append('../FUNCTIONS/')
from methods import module_to_dict
from transitional_set import module_relation_bipartite, degree_MDI, module_to_degree_MDI, module_to_error, module_to_variation

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /hdd/edward/the-project/algorithm_comparison
# /hdd/edward/the-project/algorithm_comparison/Cell
# /hdd/edward/the-project/algorithm_comparison/Cell

# %% [markdown]
# visualize errors

# %% [markdown]
# PCC-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_IV_0.6.json")

PCC_SWIM_knd_binary_errors = module_to_error(path="PCC_SWIM_knd_binary_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_binary_errors
# Out:
# [0.0,
#  15.905236567186924,
#  19.649005382820377,
#  21.90000730882752,
#  24.495668124108988,
#  32.42344748295384,
#  33.552226069271406,
#  30.709754512062705,
#  30.331551750635736,
#  30.988903917570774,
#  31.84353066624191,
#  29.033931794478825]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_IV_0.35.json")

PCC_SWIM_knd_linear_errors = module_to_error(path="PCC_SWIM_knd_linear_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_linear_errors
# Out:
# [0.0,
#  27.315854937360463,
#  36.94440571274764,
#  57.87233962473835,
#  63.530627672647505,
#  73.42783942214888,
#  78.30439575973818,
#  84.57704008116983,
#  86.46032112367845,
#  87.84310789899435,
#  90.20953977197786,
#  87.89858079843168]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_IV_0.35.json")

PCC_SWIM_knd_nlog_errors = module_to_error(path="PCC_SWIM_knd_nlog_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_nlog_errors
# Out:
# [0.0,
#  27.785590996175088,
#  36.412287985458484,
#  58.54409924950393,
#  66.64583880683726,
#  75.0644484468789,
#  75.78229578235629,
#  80.71362906432608,
#  81.82792600626382,
#  81.7364184697046,
#  83.04416304109829,
#  81.08112979113544]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

PCC_SWIM_knd_reciprocal_errors = module_to_error(path="PCC_SWIM_knd_reciprocal_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_reciprocal_errors
# Out:
# [0.0,
#  28.404310277376403,
#  35.193835380490775,
#  47.62949351233267,
#  52.460546235642326,
#  59.399075551387256,
#  63.81572532223431,
#  70.77930512635298,
#  72.45356126689342,
#  72.49940208750373,
#  71.17344689587496,
#  71.57688128764839]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_IV_10.json")

PCC_SWIM_knn_errors = module_to_error(path="PCC_SWIM_knn_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knn_errors
# Out:
# [0.0,
#  30.091212839765415,
#  37.59742937558012,
#  42.12639800426109,
#  41.63038019189962,
#  40.84690897602929,
#  45.69237412636301,
#  45.59144780606439,
#  48.35725875902302,
#  48.081754061901854,
#  46.07884022403372,
#  48.106118211104004]

# %% [markdown]
# Binary-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_IV_0.7.json")

Binary_SWIM_knd_binary_errors = module_to_error(path="Binary_SWIM_knd_binary_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_binary_errors
# Out:
# [0.0,
#  8.53589163343304,
#  4.512855917376192,
#  7.9169329975222045,
#  11.725101578831524,
#  14.74796575533201,
#  15.429721138870343,
#  17.564918419652003,
#  15.95616480841306,
#  17.527290906793052,
#  19.35390260194085,
#  20.116308681429487]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_IV_0.3.json")

Binary_SWIM_knd_linear_errors = module_to_error(path="Binary_SWIM_knd_linear_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_linear_errors
# Out:
# [0.0,
#  16.427278507226397,
#  24.567757835483704,
#  33.33153393283909,
#  34.72253338619937,
#  40.54985043219628,
#  42.7606708914402,
#  44.07147946429038,
#  44.35078047829652,
#  42.45768395443574,
#  43.41065580004317,
#  44.06964279230828]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_IV_0.3.json")

Binary_SWIM_knd_nlog_errors = module_to_error(path="Binary_SWIM_knd_nlog_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_nlog_errors
# Out:
# [0.0,
#  23.83782977665402,
#  37.716790666520055,
#  47.2669516115869,
#  46.81675058217196,
#  46.95821478139265,
#  46.611292758884034,
#  45.88612223007886,
#  45.764911059933915,
#  49.48428277757037,
#  49.178248377366664,
#  49.02353287044258]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

Binary_SWIM_knd_reciprocal_errors = module_to_error(path="Binary_SWIM_knd_reciprocal_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_reciprocal_errors
# Out:
# [0.0,
#  20.324463473995294,
#  27.549135164422758,
#  38.60210739551016,
#  42.329017642810555,
#  47.09050387747291,
#  47.92182316002706,
#  50.37224774603814,
#  50.49778130193558,
#  50.554041926488125,
#  50.598643929062064,
#  52.037313749304765]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_IV_10.json")

Binary_SWIM_knn_errors = module_to_error(path="Binary_SWIM_knn_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knn_errors
# Out:
# [0.0,
#  14.328794886969764,
#  26.668437292756806,
#  26.493529127708165,
#  27.736155507548226,
#  31.00471745882355,
#  29.78714020727615,
#  28.411776302038316,
#  31.106216349905292,
#  30.832030066087945,
#  31.407642786915563,
#  33.35862756643829]

# %% [markdown]
# Linear-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_IV_0.7.json")

Linear_SWIM_knd_binary_errors = module_to_error(path="Linear_SWIM_knd_binary_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_binary_errors
# Out:
# [0.0,
#  14.514881426177999,
#  17.14780406930159,
#  24.252152343163786,
#  24.93104981979902,
#  30.164679961205003,
#  29.057833075419556,
#  28.753890694153515,
#  28.95232610937063,
#  26.941612745196277,
#  28.740981092705454,
#  28.880879953573352]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_IV_0.35.json")

Linear_SWIM_knd_linear_errors = module_to_error(path="Linear_SWIM_knd_linear_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_linear_errors
# Out:
# [0.0,
#  21.37284523737513,
#  26.662956170401838,
#  34.68918029341233,
#  38.54279438260143,
#  42.683634811900745,
#  42.972120288202845,
#  42.17889926569725,
#  41.83640995983487,
#  45.27751736984541,
#  46.05986562563121,
#  47.02094458311531]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_IV_0.4.json")

Linear_SWIM_knd_nlog_errors = module_to_error(path="Linear_SWIM_knd_nlog_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_nlog_errors
# Out:
# [0.0,
#  22.130649221138086,
#  30.493098028963914,
#  38.09676450258005,
#  38.166513032889206,
#  38.07568709747967,
#  37.913251844287366,
#  42.4196732318614,
#  42.63309722556405,
#  43.826838663255636,
#  45.18704183897498,
#  44.37521749659201]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_4S_0.5.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_I_0.5.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_III_0.5.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_IV_0.5.json")

Linear_SWIM_knd_reciprocal_errors = module_to_error(path="Linear_SWIM_knd_reciprocal_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_reciprocal_errors
# Out:
# [0.0,
#  12.803708754365335,
#  21.895545269674713,
#  29.404251546581307,
#  32.426922569764784,
#  35.022518592436036,
#  35.755305094361375,
#  35.07552502494336,
#  35.07196971718088,
#  37.202418101373745,
#  38.60184645033127,
#  38.37364883459538]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_IV_10.json")

Linear_SWIM_knn_errors = module_to_error(path="Linear_SWIM_knn_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knn_errors
# Out:
# [0.0,
#  24.085946718071668,
#  28.05749043642826,
#  44.72895730231729,
#  45.911820069104074,
#  48.76474155815672,
#  56.218563281132674,
#  57.403762368523694,
#  56.85617926105945,
#  54.40745101993339,
#  57.42092636317626,
#  59.61418024900845]

# %% [markdown]
# Nlog_SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_IV_0.7.json")

Nlog_SWIM_knd_binary_errors = module_to_error(path="Nlog_SWIM_knd_binary_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_binary_errors
# Out:
# [0.0,
#  17.424625964801102,
#  13.469290167167854,
#  18.2513171715634,
#  20.6729156592868,
#  21.500497534998733,
#  22.132476233927076,
#  24.06893605399958,
#  24.122105771614553,
#  26.451325773114732,
#  25.78603977994876,
#  25.926507928375127]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_IV_0.4.json")

Nlog_SWIM_knd_linear_errors = module_to_error(path="Nlog_SWIM_knd_linear_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_linear_errors
# Out:
# [0.0,
#  6.876422733647627,
#  8.417117659476094,
#  12.439345381809783,
#  13.725598611078963,
#  17.630277433719627,
#  18.616360812508816,
#  21.206159672142235,
#  20.965538282834487,
#  22.73412444692636,
#  23.27494334934813,
#  23.446773827300497]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_IV_0.35.json")

Nlog_SWIM_knd_nlog_errors = module_to_error(path="Nlog_SWIM_knd_nlog_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_nlog_errors
# Out:
# [0.0,
#  13.227277419268756,
#  13.643257287988138,
#  14.555986681381738,
#  13.55756117957577,
#  15.127739302178327,
#  17.04536273733503,
#  16.54734665069882,
#  16.77892894153421,
#  18.572678625910754,
#  20.01030383689773,
#  23.11432247075442]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_IV_0.7.json")

Nlog_SWIM_knd_reciprocal_errors = module_to_error(path="Nlog_SWIM_knd_reciprocal_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_reciprocal_errors
# Out:
# [0.0,
#  11.10174974355832,
#  13.283121313798315,
#  19.264997064752237,
#  18.015977686643538,
#  17.780098592663293,
#  16.822605670577747,
#  20.66080684626382,
#  21.77394589951889,
#  20.784873428946863,
#  21.82607319812077,
#  23.62734129416303]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_IV_10.json")

Nlog_SWIM_knn_errors = module_to_error(path="Nlog_SWIM_knn_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knn_errors
# Out:
# [0.0,
#  16.97904553445303,
#  27.972815231969197,
#  33.999925999955494,
#  33.926587221529964,
#  35.113774582975196,
#  38.191254531553355,
#  37.975960386341185,
#  39.74680843851675,
#  43.455680766393556,
#  42.69789844761977,
#  44.26523509526895]

# %% [markdown]
# Reciprocal-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_4S_0.8.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_I_0.8.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_III_0.8.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_IV_0.8.json")

Reciprocal_SWIM_knd_binary_errors = module_to_error(path="Reciprocal_SWIM_knd_binary_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_binary_errors
# Out:
# [0.0,
#  8.884533972819536,
#  12.07942914625204,
#  17.503351577078583,
#  16.41965060421574,
#  16.198579280812407,
#  17.965293846119867,
#  19.99699082249343,
#  20.50359062008825,
#  22.322438994800937,
#  22.247022783668417,
#  22.426389743231894]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_IV_0.4.json")

Reciprocal_SWIM_knd_linear_errors = module_to_error(path="Reciprocal_SWIM_knd_linear_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_linear_errors
# Out:
# [0.0,
#  19.89117154131694,
#  20.173572242703504,
#  19.761139983910894,
#  23.721260159100325,
#  29.94886422944186,
#  29.707911876598033,
#  33.913736865160104,
#  33.37765440057387,
#  33.61939650892115,
#  34.399724388093304,
#  34.08402477927585]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_IV_0.6.json")

Reciprocal_SWIM_knd_nlog_errors = module_to_error(path="Reciprocal_SWIM_knd_nlog_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_nlog_errors
# Out:
# [0.0,
#  6.202427226538203,
#  10.380120352229422,
#  13.773199493895323,
#  17.369486688033152,
#  16.94072518049909,
#  17.763107314544158,
#  19.179607416279183,
#  18.842733155917678,
#  19.506234786878665,
#  20.316186969338556,
#  21.80766710007775]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_IV_0.6.json")

Reciprocal_SWIM_knd_reciprocal_errors = module_to_error(path="Reciprocal_SWIM_knd_reciprocal_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_reciprocal_errors
# Out:
# [0.0,
#  8.650409425289624,
#  10.210672536830241,
#  13.503999648570002,
#  15.75337856214317,
#  17.20534726710256,
#  19.967509382639367,
#  21.702971349054277,
#  21.96769296142542,
#  21.401654992692745,
#  22.233284443914158,
#  24.058177196627977]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_IV_10.json")

Reciprocal_SWIM_knn_errors = module_to_error(path="Reciprocal_SWIM_knn_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knn_errors
# Out:
# [0.0,
#  12.53675694767475,
#  10.577761502283582,
#  16.460963105910974,
#  15.797055516627978,
#  20.977444600447246,
#  20.97647762374746,
#  19.720156323543037,
#  20.51149874433924,
#  20.127860703245318,
#  19.955907773648214,
#  18.762272987089396]

# %% [markdown]
# PCC_Leiden

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_IV_0.35.json")

PCC_Leiden_errors = module_to_error(path="PCC_Leiden_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_Leiden_errors
# Out:
# [0.0,
#  25.404760047897128,
#  32.087486148005574,
#  46.13347037290003,
#  48.86871809834297,
#  50.05311561604823,
#  51.288309978598456,
#  54.7921727616095,
#  56.48081199583793,
#  57.60981512750681,
#  59.63476113956481,
#  60.72045575041739]

# %% [markdown]
# hdWGCNA

# %%
module_4S = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_4S_2.5.json")
module_I = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_I_2.5.json")
module_III = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_III_2.5.json")
module_IV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_IV_2.5.json")

hdWGCNA_errors = module_to_error(path="hdWGCNA_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
hdWGCNA_errors
# Out:
# [0.0,
#  3.145085449322581,
#  4.735493591332787,
#  3.542593007866722,
#  5.687442886837423,
#  6.407755248660953,
#  6.368383393102352,
#  8.758398487151895,
#  9.129001755595816,
#  10.328810929031034,
#  10.365489372628778,
#  9.140887561593269]

# %% [markdown]
# Hotspot

# %%
module_4S = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_4S_50.json")
module_I = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_I_50.json")
module_III = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_III_50.json")
module_IV = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_IV_50.json")

Hotspot_errors = module_to_error(path="Hotspot_errors.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Hotspot_errors
# Out:
# [0.0,
#  17.220284720585123,
#  22.764402571789013,
#  40.12872768598468,
#  43.661177001147294,
#  48.49272039351741,
#  49.137164152238526,
#  47.617772867636084,
#  48.69567484268761,
#  47.873665982970444,
#  47.60614344809736,
#  44.51228029115036]

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_binary_errors, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_binary_errors, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_binary_errors, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_binary_errors, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_binary_errors, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_errors, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_errors, marker='o', linestyle='-')
line8, = ax.plot(x, Hotspot_errors, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Error', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid

# # Place the legend outside the plot
# ax.legend([line1, line2, line3, line4, line5, line6, line7],
#           ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'],
#           fontsize=13,
#           loc='upper left',         # Location of the legend
#           bbox_to_anchor=(1.05, 1)) # Coordinates of the legend relative to the plot

plt.savefig("./figures/degree_MDI_instability_knd_binary.svg")
plt.show()

# %%
# Create a separate figure for the legend only
fig_legend = plt.figure(figsize=(4, 2))  # You can adjust the size of the legend figure

# Create the legend for the existing lines
legend = fig_legend.legend([line1, line2, line3, line4, line5, line6, line7, line8],
                           ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot'],
                           fontsize=13,
                           loc='center')

# Remove axes from the legend figure
fig_legend.gca().axis('off')

# Save the legend as a separate image
plt.savefig('./figures/degree_MDI_instability_legend.svg', bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_linear_errors, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_linear_errors, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_linear_errors, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_linear_errors, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_linear_errors, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_errors, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_errors, marker='o', linestyle='-')
line8, = ax.plot(x, Hotspot_errors, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Error', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_nlog_errors, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_nlog_errors, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_nlog_errors, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_nlog_errors, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_nlog_errors, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_errors, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_errors, marker='o', linestyle='-')
line8, = ax.plot(x, Hotspot_errors, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Error', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_reciprocal_errors, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_reciprocal_errors, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_reciprocal_errors, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_reciprocal_errors, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_reciprocal_errors, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_errors, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_errors, marker='o', linestyle='-')
line8, = ax.plot(x, Hotspot_errors, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Error', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knn_errors, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knn_errors, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knn_errors, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knn_errors, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knn_errors, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_errors, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_errors, marker='o', linestyle='-')
line8, = ax.plot(x, Hotspot_errors, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Error', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %% [markdown]
# visualize variations

# %% [markdown]
# PCC-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_IV_0.6.json")

PCC_SWIM_knd_binary_variations = module_to_variation(path="PCC_SWIM_knd_binary_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_binary_variations
# Out:
# [0.0,
#  12.611920177001217,
#  12.228982822935162,
#  12.76076657740651,
#  7.131268895121235,
#  6.903712364745532,
#  3.9622956910071743,
#  6.543901910555108,
#  6.2851149857476,
#  7.925511386588882,
#  2.352146041933521,
#  4.698653622210578]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_IV_0.35.json")

PCC_SWIM_knd_linear_variations = module_to_variation(path="PCC_SWIM_knd_linear_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_linear_variations
# Out:
# [0.0,
#  42.10046948470875,
#  6.164885982218976,
#  20.859662898558575,
#  9.457845050584067,
#  15.907561476759472,
#  6.777659797011637,
#  12.336379702338077,
#  4.471246002710601,
#  8.893619731129318,
#  2.9208010867708256,
#  4.965019003580682]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_IV_0.35.json")

PCC_SWIM_knd_nlog_variations = module_to_variation(path="PCC_SWIM_knd_nlog_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_nlog_variations
# Out:
# [0.0,
#  33.826403644563314,
#  12.179089331524715,
#  20.60802575123509,
#  9.755166191072428,
#  20.136009780598943,
#  6.462189456829069,
#  7.1477207477354,
#  4.919188862168343,
#  3.562759162455541,
#  4.446428544027736,
#  5.033008920196256]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

PCC_SWIM_knd_reciprocal_variations = module_to_variation(path="PCC_SWIM_knd_reciprocal_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knd_reciprocal_variations
# Out:
# [0.0,
#  30.045819339552608,
#  12.234695541913633,
#  23.3176598949271,
#  6.639457680062101,
#  11.174313978918743,
#  4.208131567755915,
#  14.524645209327183,
#  7.268451482346988,
#  3.1242526285563827,
#  1.8880041916811843,
#  2.2166080548686757]

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_IV_10.json")

PCC_SWIM_knn_variations = module_to_variation(path="PCC_SWIM_knn_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_SWIM_knn_variations
# Out:
# [0.0,
#  12.206513617527058,
#  10.36121907946912,
#  22.927752261192936,
#  14.399335814598903,
#  12.162074759034896,
#  3.7701158966072814,
#  8.160835481342218,
#  6.315366021101158,
#  5.7997016525007234,
#  4.490333253838802,
#  4.795050605115775]

# %% [markdown]
# Binary-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_IV_0.7.json")

Binary_SWIM_knd_binary_variations = module_to_variation(path="Binary_SWIM_knd_binary_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_binary_variations
# Out:
# [0.0,
#  20.4634336173334,
#  6.561454665675945,
#  6.565594891813255,
#  3.3513551327123263,
#  6.976212179372535,
#  2.7167649068394075,
#  3.971152353883146,
#  2.6865015754461283,
#  3.7151306650793297,
#  1.691842117120734,
#  2.697338192929528]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_IV_0.3.json")

Binary_SWIM_knd_linear_variations = module_to_variation(path="Binary_SWIM_knd_linear_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_linear_variations
# Out:
# [0.0,
#  26.293823350254087,
#  7.502640900218708,
#  14.306343907719285,
#  9.087887265346785,
#  12.726195974426686,
#  3.048596049820146,
#  5.435233935000039,
#  5.185710536714377,
#  6.21547394165396,
#  1.4971230867045195,
#  1.3040205475957218]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_IV_0.3.json")

Binary_SWIM_knd_nlog_variations = module_to_variation(path="Binary_SWIM_knd_nlog_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_nlog_variations
# Out:
# [0.0,
#  22.70530451850756,
#  10.242427141878832,
#  26.853733432639892,
#  7.0324344512791725,
#  9.82777877733632,
#  2.470926120782566,
#  3.0438568735167566,
#  2.5804645038442473,
#  3.7188301146056566,
#  2.980561148595071,
#  4.448546328316726]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

Binary_SWIM_knd_reciprocal_variations = module_to_variation(path="Binary_SWIM_knd_reciprocal_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knd_reciprocal_variations
# Out:
# [0.0,
#  23.867400199470715,
#  9.921487277750257,
#  19.626792887847774,
#  5.969695667266768,
#  10.747134760723622,
#  2.8623809004855696,
#  5.529208067760817,
#  2.938198979621171,
#  5.019701230452076,
#  2.7563321704074335,
#  4.095791356030466]

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_IV_10.json")

Binary_SWIM_knn_variations = module_to_variation(path="Binary_SWIM_knn_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Binary_SWIM_knn_variations
# Out:
# [0.0,
#  9.800978733420225,
#  8.653728121526077,
#  18.834664949931046,
#  9.789163467491973,
#  12.996827163465861,
#  5.958112679093143,
#  6.990689704868589,
#  3.7905281634564707,
#  5.754801468409694,
#  3.316014530900271,
#  6.518386186214119]

# %% [markdown]
# Linear-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_IV_0.7.json")

Linear_SWIM_knd_binary_variations = module_to_variation(path="Linear_SWIM_knd_binary_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_binary_variations
# Out:
# [0.0,
#  14.366207444307669,
#  11.034819116977484,
#  2.7810114533078174,
#  5.4865963368439425,
#  5.374786639478675,
#  2.075765164161245,
#  4.381829090485659,
#  1.593094974252264,
#  3.5683973996231364,
#  1.4498784284472153,
#  3.717798219232586]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_IV_0.35.json")

Linear_SWIM_knd_linear_variations = module_to_variation(path="Linear_SWIM_knd_linear_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_linear_variations
# Out:
# [0.0,
#  23.20679151333291,
#  8.720834664264645,
#  15.039301273250633,
#  6.33944032404823,
#  11.312326123600846,
#  3.433532691541762,
#  6.394138135710754,
#  2.379795019296215,
#  2.7208997468640495,
#  3.2142766260903906,
#  3.2932228238605727]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_IV_0.4.json")

Linear_SWIM_knd_nlog_variations = module_to_variation(path="Linear_SWIM_knd_nlog_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_nlog_variations
# Out:
# [0.0,
#  24.914277713535796,
#  7.808227205851663,
#  12.808748041484128,
#  7.014192493651461,
#  4.206923441432579,
#  3.8004855060555087,
#  5.904711494705581,
#  3.0046161913951344,
#  2.5789636095036874,
#  2.459489113698556,
#  4.335276196927261]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_4S_0.5.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_I_0.5.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_III_0.5.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_IV_0.5.json")

Linear_SWIM_knd_reciprocal_variations = module_to_variation(path="Linear_SWIM_knd_reciprocal_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knd_reciprocal_variations
# Out:
# [0.0,
#  29.427422092689984,
#  5.147190308397639,
#  14.125712944633614,
#  5.125002204513658,
#  8.758609692051088,
#  2.8721334866511046,
#  5.3587947026117035,
#  4.095087359115205,
#  3.0629796341811537,
#  1.5591952469031245,
#  2.4688215751974645]

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_IV_10.json")

Linear_SWIM_knn_variations = module_to_variation(path="Linear_SWIM_knn_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Linear_SWIM_knn_variations
# Out:
# [0.0,
#  12.419143213611155,
#  11.014300567733404,
#  18.77382640635596,
#  10.164770873163262,
#  15.08999579064665,
#  7.692846105826017,
#  6.307189466622981,
#  9.335477589344288,
#  7.378661293690228,
#  3.364245190748453,
#  4.034933880744412]

# %% [markdown]
# Nlog

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_IV_0.7.json")

Nlog_SWIM_knd_binary_variations = module_to_variation(path="Nlog_SWIM_knd_binary_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_binary_variations
# Out:
# [0.0,
#  11.920998334303942,
#  6.425663379339054,
#  5.14590803270393,
#  3.854731033506244,
#  3.657694865539798,
#  1.5998506111103814,
#  7.887912684392974,
#  1.0325915678947477,
#  3.8552971195330583,
#  1.375240627817124,
#  2.9148739533719636]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_IV_0.4.json")

Nlog_SWIM_knd_linear_variations = module_to_variation(path="Nlog_SWIM_knd_linear_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_linear_variations
# Out:
# [0.0,
#  14.196333378598206,
#  4.139646847970947,
#  2.5427951322076545,
#  2.8626495900201108,
#  5.621270873155705,
#  3.081716561720634,
#  7.450708608884685,
#  2.3912665690816137,
#  1.1804284601926156,
#  1.800424395688049,
#  2.0031100300666704]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_IV_0.35.json")

Nlog_SWIM_knd_nlog_variations = module_to_variation(path="Nlog_SWIM_knd_nlog_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_nlog_variations
# Out:
# [0.0,
#  14.327755435915357,
#  6.93077805024558,
#  3.9188782889660114,
#  1.962681962599886,
#  3.4638539541262645,
#  3.4776995439363327,
#  5.3626389545903885,
#  2.3942519001903615,
#  4.000867101542104,
#  2.591077255107506,
#  2.5151262221687025]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_IV_0.7.json")

Nlog_SWIM_knd_reciprocal_variations = module_to_variation(path="Nlog_SWIM_knd_reciprocal_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knd_reciprocal_variations
# Out:
# [0.0,
#  20.116499817980504,
#  2.6786156320404158,
#  7.877296846656725,
#  2.82531372356443,
#  5.333698961953578,
#  2.9056352789872646,
#  1.6918942262659171,
#  2.6160585216666963,
#  3.9093170620299076,
#  1.775878855499347,
#  2.751159616165444]

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_IV_10.json")

Nlog_SWIM_knn_variations = module_to_variation(path="Nlog_SWIM_knn_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Nlog_SWIM_knn_variations
# Out:
# [0.0,
#  11.265849155482089,
#  7.710059975033531,
#  17.305526950593233,
#  6.5605259749122755,
#  8.618191885095866,
#  5.617895977859478,
#  6.579213748924496,
#  6.155119277255204,
#  3.632066238766921,
#  3.640462933467952,
#  4.098723084508466]

# %% [markdown]
# Reciprocal-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_4S_0.8.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_I_0.8.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_III_0.8.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_IV_0.8.json")

Reciprocal_SWIM_knd_binary_variations = module_to_variation(path="Reciprocal_SWIM_knd_binary_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_binary_variations
# Out:
# [0.0,
#  7.3456824506307505,
#  2.74888281647417,
#  6.354809095807163,
#  1.8922844529495817,
#  6.790759668857206,
#  1.6985674250551348,
#  2.63069525354676,
#  0.46396340277628767,
#  3.9690204603460426,
#  1.782044299282239,
#  2.8640158786608345]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_IV_0.4.json")

Reciprocal_SWIM_knd_linear_variations = module_to_variation(path="Reciprocal_SWIM_knd_linear_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_linear_variations
# Out:
# [0.0,
#  28.681098712857814,
#  8.285344945698059,
#  5.292535184321006,
#  3.2503447134420775,
#  10.114991993336217,
#  2.021265733509858,
#  6.774757102801868,
#  3.4522582281091125,
#  2.5348098745833316,
#  2.333804249916088,
#  1.0797645951933434]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_IV_0.6.json")

Reciprocal_SWIM_knd_nlog_variations = module_to_variation(path="Reciprocal_SWIM_knd_nlog_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_nlog_variations
# Out:
# [0.0,
#  16.3343212327861,
#  1.8191152592250157,
#  8.72279988160981,
#  3.738885601603195,
#  3.771777223635085,
#  2.103697994723427,
#  5.481670266006639,
#  2.4962978677752337,
#  1.990788579205177,
#  1.7944810582385866,
#  3.059422188081909]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_IV_0.6.json")

Reciprocal_SWIM_knd_reciprocal_variations = module_to_variation(path="Reciprocal_SWIM_knd_reciprocal_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knd_reciprocal_variations
# Out:
# [0.0,
#  12.826210436041007,
#  3.7998924541924253,
#  7.827843174526188,
#  4.773278806832283,
#  4.1694434493912915,
#  3.395899703802809,
#  3.3526293836649583,
#  2.444150126679979,
#  1.239534344965407,
#  2.9030853042577434,
#  1.3698187676996727]

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_IV_10.json")

Reciprocal_SWIM_knn_variations = module_to_variation(path="Reciprocal_SWIM_knn_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
Reciprocal_SWIM_knn_variations
# Out:
# [0.0,
#  6.373700573246545,
#  10.24370932442266,
#  9.024690806120477,
#  7.738999592787254,
#  5.338811514320947,
#  5.160307987044092,
#  9.178396252541921,
#  1.6802194072189323,
#  4.77903504675275,
#  2.0343602512592143,
#  3.282182722743523]

# %% [markdown]
# PCC_Leiden

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_IV_0.35.json")

PCC_Leiden_variations = module_to_variation(path="PCC_Leiden_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
PCC_Leiden_variations
# Out:
# [0.0,
#  24.988196910478322,
#  10.75085098282161,
#  16.753046668676447,
#  7.032199527252482,
#  9.136733728410844,
#  1.7878070805032114,
#  6.1384388569778165,
#  0.9715103529655008,
#  2.8919519680066443,
#  2.33305900188563,
#  3.128188143858366]

# %% [markdown]
# hdWGCNA

# %%
module_4S = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_4S_2.5.json")
module_I = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_I_2.5.json")
module_III = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_III_2.5.json")
module_IV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_IV_2.5.json")

hdWGCNA_variations = module_to_variation(path="hdWGCNA_variations.txt", module_4S=module_4S, module_I=module_I, module_III=module_III, module_IV=module_IV)
hdWGCNA_variations
# Out:
# [0.0,
#  2.184491032641684,
#  0.3903009222838886,
#  4.318516330792041,
#  1.1256458230620732,
#  2.39738040016886,
#  2.2702221002203054,
#  0.9273766752357674,
#  0.6893921562274918,
#  3.076829183029524,
#  1.8051755799979765,
#  0.5622447879767887]

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_binary_variations, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_binary_variations, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_binary_variations, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_binary_variations, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_binary_variations, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_variations, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_variations, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Variation', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# Place the legend outside the plot
ax.legend([line1, line2, line3, line4, line5, line6, line7],
          ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'],
          fontsize=13,
          loc='upper left',         # Location of the legend
          bbox_to_anchor=(1.05, 1)) # Coordinates of the legend relative to the plot

plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_linear_variations, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_linear_variations, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_linear_variations, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_linear_variations, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_linear_variations, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_variations, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_variations, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Variation', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_nlog_variations, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_nlog_variations, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_nlog_variations, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_nlog_variations, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_nlog_variations, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_variations, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_variations, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Variation', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knd_reciprocal_variations, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knd_reciprocal_variations, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knd_reciprocal_variations, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knd_reciprocal_variations, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knd_reciprocal_variations, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_variations, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_variations, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Variation', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import math
q_values = [0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001, 0.000005, 0.000001, 0.0000005, 0.0000001]
x = [-math.log10(i) for i in q_values]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plotting
line1, = ax.plot(x, PCC_SWIM_knn_variations, marker='o', linestyle='-')
line2, = ax.plot(x, Binary_SWIM_knn_variations, marker='o', linestyle='-')
line3, = ax.plot(x, Linear_SWIM_knn_variations, marker='o', linestyle='-')
line4, = ax.plot(x, Nlog_SWIM_knn_variations, marker='o', linestyle='-')
line5, = ax.plot(x, Reciprocal_SWIM_knn_variations, marker='o', linestyle='-')
line6, = ax.plot(x, PCC_Leiden_variations, marker='o', linestyle='-')
line7, = ax.plot(x, hdWGCNA_variations, marker='o', linestyle='-')

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_xscale('linear')  # Set x-axis scale to logarithmic
ax.set_xlabel('-log(q-value)', fontsize=18)
ax.set_ylabel('Degree MDI Variation', fontsize=18)
ax.set_title('Degree MDI Instability', fontsize=20)

ax.grid(True)  # Add grid
# ax.legend([line1, line2, line3, line4, line5, line6, line7], ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA'], fontsize=13)
plt.show()  # Display the plot
