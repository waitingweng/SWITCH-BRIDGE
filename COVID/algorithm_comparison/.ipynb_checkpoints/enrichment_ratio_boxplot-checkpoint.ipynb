# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from algorithm_comparison import file_to_float

# %%
# !pwd
# %cd /home/jovyan/work/COVID/algorithm_comparison/Cell
# !pwd
# Out:
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell

# %% [markdown]
# KEGG

# %%
pcc_knd_binary_enrichment_ratio = file_to_float(path="./pcc_knd_binary_KEGG_enrichment_ratio.txt")
binary_knd_binary_enrichment_ratio = file_to_float(path="./binary_knd_binary_KEGG_enrichment_ratio.txt")
linear_knd_binary_enrichment_ratio = file_to_float(path="./linear_knd_binary_KEGG_enrichment_ratio.txt")
nlog_knd_binary_enrichment_ratio = file_to_float(path="./nlog_knd_binary_KEGG_enrichment_ratio.txt")
reciprocal_knd_binary_enrichment_ratio = file_to_float(path="./reciprocal_knd_binary_KEGG_enrichment_ratio.txt")

# %%
pcc_knd_linear_enrichment_ratio = file_to_float(path="./pcc_knd_linear_KEGG_enrichment_ratio.txt")
binary_knd_linear_enrichment_ratio = file_to_float(path="./binary_knd_linear_KEGG_enrichment_ratio.txt")
linear_knd_linear_enrichment_ratio = file_to_float(path="./linear_knd_linear_KEGG_enrichment_ratio.txt")
nlog_knd_linear_enrichment_ratio = file_to_float(path="./nlog_knd_linear_KEGG_enrichment_ratio.txt")
reciprocal_knd_linear_enrichment_ratio = file_to_float(path="./reciprocal_knd_linear_KEGG_enrichment_ratio.txt")

# %%
pcc_knd_nlog_enrichment_ratio = file_to_float(path="./pcc_knd_nlog_KEGG_enrichment_ratio.txt")
binary_knd_nlog_enrichment_ratio = file_to_float(path="./binary_knd_nlog_KEGG_enrichment_ratio.txt")
linear_knd_nlog_enrichment_ratio = file_to_float(path="./linear_knd_nlog_KEGG_enrichment_ratio.txt")
nlog_knd_nlog_enrichment_ratio = file_to_float(path="./nlog_knd_nlog_KEGG_enrichment_ratio.txt")
reciprocal_knd_nlog_enrichment_ratio = file_to_float(path="./reciprocal_knd_nlog_KEGG_enrichment_ratio.txt")

# %%
pcc_knd_reciprocal_enrichment_ratio = file_to_float(path="./pcc_knd_reciprocal_KEGG_enrichment_ratio.txt")
binary_knd_reciprocal_enrichment_ratio = file_to_float(path="./binary_knd_reciprocal_KEGG_enrichment_ratio.txt")
linear_knd_reciprocal_enrichment_ratio = file_to_float(path="./linear_knd_reciprocal_KEGG_enrichment_ratio.txt")
nlog_knd_reciprocal_enrichment_ratio = file_to_float(path="./nlog_knd_reciprocal_KEGG_enrichment_ratio.txt")
reciprocal_knd_reciprocal_enrichment_ratio = file_to_float(path="./reciprocal_knd_reciprocal_KEGG_enrichment_ratio.txt")

# %%
pcc_knn_enrichment_ratio = file_to_float(path="./pcc_knn_KEGG_enrichment_ratio.txt")
binary_knn_enrichment_ratio = file_to_float(path="./binary_knn_KEGG_enrichment_ratio.txt")
linear_knn_enrichment_ratio = file_to_float(path="./linear_knn_KEGG_enrichment_ratio.txt")
nlog_knn_enrichment_ratio = file_to_float(path="./nlog_knn_KEGG_enrichment_ratio.txt")
reciprocal_knn_enrichment_ratio = file_to_float(path="./reciprocal_knn_KEGG_enrichment_ratio.txt")

# %%
PCC_Leiden_enrichment_ratio = file_to_float(path="./pcc_leiden_KEGG_enrichment_ratio.txt")

# %%
hdWGCNA_enrichment_ratio = file_to_float(path="./hdWGCNA_KEGG_enrichment_ratio.txt")

# %%
# TOM_Leiden_enrichment_ratio = file_to_float(path="./TOM_Leiden_KEGG_enrichment_ratio.txt")

# %%
Hotspot_enrichment_ratio = file_to_float(path="./Hotspot_KEGG_enrichment_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_enrichment_ratio, binary_knd_binary_enrichment_ratio, linear_knd_binary_enrichment_ratio, nlog_knd_binary_enrichment_ratio, reciprocal_knd_binary_enrichment_ratio]
data2 = [pcc_knd_linear_enrichment_ratio, binary_knd_linear_enrichment_ratio, linear_knd_linear_enrichment_ratio, nlog_knd_linear_enrichment_ratio, reciprocal_knd_linear_enrichment_ratio]
data3 = [pcc_knd_nlog_enrichment_ratio, binary_knd_nlog_enrichment_ratio, linear_knd_nlog_enrichment_ratio, nlog_knd_nlog_enrichment_ratio, reciprocal_knd_nlog_enrichment_ratio]
data4 = [pcc_knd_reciprocal_enrichment_ratio, binary_knd_reciprocal_enrichment_ratio, linear_knd_reciprocal_enrichment_ratio, nlog_knd_reciprocal_enrichment_ratio, reciprocal_knd_reciprocal_enrichment_ratio]
data5 = [pcc_knn_enrichment_ratio, binary_knn_enrichment_ratio, linear_knn_enrichment_ratio, nlog_knn_enrichment_ratio, reciprocal_knn_enrichment_ratio]
data6 = PCC_Leiden_enrichment_ratio

data7 = hdWGCNA_enrichment_ratio
data8 = Hotspot_enrichment_ratio

# data9 = 

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
# custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden']
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
# ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6])
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('KEGG Enrichment Ratio', fontsize=18)
ax.set_title('Pathway Enrichment Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/KEGG_pathway_enrichment_ratio_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# Reactome

# %%
pcc_knd_binary_enrichment_ratio = file_to_float(path="./pcc_knd_binary_Reactome_enrichment_ratio.txt")
binary_knd_binary_enrichment_ratio = file_to_float(path="./binary_knd_binary_Reactome_enrichment_ratio.txt")
linear_knd_binary_enrichment_ratio = file_to_float(path="./linear_knd_binary_Reactome_enrichment_ratio.txt")
nlog_knd_binary_enrichment_ratio = file_to_float(path="./nlog_knd_binary_Reactome_enrichment_ratio.txt")
reciprocal_knd_binary_enrichment_ratio = file_to_float(path="./reciprocal_knd_binary_Reactome_enrichment_ratio.txt")

# %%
pcc_knd_linear_enrichment_ratio = file_to_float(path="./pcc_knd_linear_Reactome_enrichment_ratio.txt")
binary_knd_linear_enrichment_ratio = file_to_float(path="./binary_knd_linear_Reactome_enrichment_ratio.txt")
linear_knd_linear_enrichment_ratio = file_to_float(path="./linear_knd_linear_Reactome_enrichment_ratio.txt")
nlog_knd_linear_enrichment_ratio = file_to_float(path="./nlog_knd_linear_Reactome_enrichment_ratio.txt")
reciprocal_knd_linear_enrichment_ratio = file_to_float(path="./reciprocal_knd_linear_Reactome_enrichment_ratio.txt")

# %%
pcc_knd_nlog_enrichment_ratio = file_to_float(path="./pcc_knd_nlog_Reactome_enrichment_ratio.txt")
binary_knd_nlog_enrichment_ratio = file_to_float(path="./binary_knd_nlog_Reactome_enrichment_ratio.txt")
linear_knd_nlog_enrichment_ratio = file_to_float(path="./linear_knd_nlog_Reactome_enrichment_ratio.txt")
nlog_knd_nlog_enrichment_ratio = file_to_float(path="./nlog_knd_nlog_Reactome_enrichment_ratio.txt")
reciprocal_knd_nlog_enrichment_ratio = file_to_float(path="./reciprocal_knd_nlog_Reactome_enrichment_ratio.txt")

# %%
pcc_knd_reciprocal_enrichment_ratio = file_to_float(path="./pcc_knd_reciprocal_Reactome_enrichment_ratio.txt")
binary_knd_reciprocal_enrichment_ratio = file_to_float(path="./binary_knd_reciprocal_Reactome_enrichment_ratio.txt")
linear_knd_reciprocal_enrichment_ratio = file_to_float(path="./linear_knd_reciprocal_Reactome_enrichment_ratio.txt")
nlog_knd_reciprocal_enrichment_ratio = file_to_float(path="./nlog_knd_reciprocal_Reactome_enrichment_ratio.txt")
reciprocal_knd_reciprocal_enrichment_ratio = file_to_float(path="./reciprocal_knd_reciprocal_Reactome_enrichment_ratio.txt")

# %%
pcc_knn_enrichment_ratio = file_to_float(path="./pcc_knn_Reactome_enrichment_ratio.txt")
binary_knn_enrichment_ratio = file_to_float(path="./binary_knn_Reactome_enrichment_ratio.txt")
linear_knn_enrichment_ratio = file_to_float(path="./linear_knn_Reactome_enrichment_ratio.txt")
nlog_knn_enrichment_ratio = file_to_float(path="./nlog_knn_Reactome_enrichment_ratio.txt")
reciprocal_knn_enrichment_ratio = file_to_float(path="./reciprocal_knn_Reactome_enrichment_ratio.txt")

# %%
PCC_Leiden_enrichment_ratio = file_to_float(path="./pcc_leiden_Reactome_enrichment_ratio.txt")

# %%
hdWGCNA_enrichment_ratio = file_to_float(path="./hdWGCNA_Reactome_enrichment_ratio.txt")

# %%
# TOM_Leiden_enrichment_ratio = file_to_float(path="./TOM_Leiden_Reactome_enrichment_ratio.txt")

# %%
Hotspot_enrichment_ratio = file_to_float(path="./Hotspot_Reactome_enrichment_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_enrichment_ratio, binary_knd_binary_enrichment_ratio, linear_knd_binary_enrichment_ratio, nlog_knd_binary_enrichment_ratio, reciprocal_knd_binary_enrichment_ratio]
data2 = [pcc_knd_linear_enrichment_ratio, binary_knd_linear_enrichment_ratio, linear_knd_linear_enrichment_ratio, nlog_knd_linear_enrichment_ratio, reciprocal_knd_linear_enrichment_ratio]
data3 = [pcc_knd_nlog_enrichment_ratio, binary_knd_nlog_enrichment_ratio, linear_knd_nlog_enrichment_ratio, nlog_knd_nlog_enrichment_ratio, reciprocal_knd_nlog_enrichment_ratio]
data4 = [pcc_knd_reciprocal_enrichment_ratio, binary_knd_reciprocal_enrichment_ratio, linear_knd_reciprocal_enrichment_ratio, nlog_knd_reciprocal_enrichment_ratio, reciprocal_knd_reciprocal_enrichment_ratio]
data5 = [pcc_knn_enrichment_ratio, binary_knn_enrichment_ratio, linear_knn_enrichment_ratio, nlog_knn_enrichment_ratio, reciprocal_knn_enrichment_ratio]
data6 = PCC_Leiden_enrichment_ratio

data7 = hdWGCNA_enrichment_ratio
data8 = Hotspot_enrichment_ratio
# data9 = 

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})

bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})

# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
# custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden']
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']

# ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6]) 
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Reactome Enrichment Ratio', fontsize=18)
ax.set_title('Pathway Enrichment Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/Reactome_pathway_enrichment_ratio_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# BioPlex

# %%
pcc_knd_linear_enrichment_ratio = file_to_float(path="./pcc_knd_linear_BioPlex_enrichment_ratio.txt")
binary_knd_linear_enrichment_ratio = file_to_float(path="./binary_knd_linear_BioPlex_enrichment_ratio.txt")
linear_knd_linear_enrichment_ratio = file_to_float(path="./linear_knd_linear_BioPlex_enrichment_ratio.txt")
nlog_knd_linear_enrichment_ratio = file_to_float(path="./nlog_knd_linear_BioPlex_enrichment_ratio.txt")
reciprocal_knd_linear_enrichment_ratio = file_to_float(path="./reciprocal_knd_linear_BioPlex_enrichment_ratio.txt")

# %%
pcc_knd_nlog_enrichment_ratio = file_to_float(path="./pcc_knd_nlog_BioPlex_enrichment_ratio.txt")
binary_knd_nlog_enrichment_ratio = file_to_float(path="./binary_knd_nlog_BioPlex_enrichment_ratio.txt")
linear_knd_nlog_enrichment_ratio = file_to_float(path="./linear_knd_nlog_BioPlex_enrichment_ratio.txt")
nlog_knd_nlog_enrichment_ratio = file_to_float(path="./nlog_knd_nlog_BioPlex_enrichment_ratio.txt")
reciprocal_knd_nlog_enrichment_ratio = file_to_float(path="./reciprocal_knd_nlog_BioPlex_enrichment_ratio.txt")

# %%
pcc_knd_reciprocal_enrichment_ratio = file_to_float(path="./pcc_knd_reciprocal_BioPlex_enrichment_ratio.txt")
binary_knd_reciprocal_enrichment_ratio = file_to_float(path="./binary_knd_reciprocal_BioPlex_enrichment_ratio.txt")
linear_knd_reciprocal_enrichment_ratio = file_to_float(path="./linear_knd_reciprocal_BioPlex_enrichment_ratio.txt")
nlog_knd_reciprocal_enrichment_ratio = file_to_float(path="./nlog_knd_reciprocal_BioPlex_enrichment_ratio.txt")
reciprocal_knd_reciprocal_enrichment_ratio = file_to_float(path="./reciprocal_knd_reciprocal_BioPlex_enrichment_ratio.txt")

# %%
pcc_knn_enrichment_ratio = file_to_float(path="./pcc_knn_BioPlex_enrichment_ratio.txt")
binary_knn_enrichment_ratio = file_to_float(path="./binary_knn_BioPlex_enrichment_ratio.txt")
linear_knn_enrichment_ratio = file_to_float(path="./linear_knn_BioPlex_enrichment_ratio.txt")
nlog_knn_enrichment_ratio = file_to_float(path="./nlog_knn_BioPlex_enrichment_ratio.txt")
reciprocal_knn_enrichment_ratio = file_to_float(path="./reciprocal_knn_BioPlex_enrichment_ratio.txt")

# %%
PCC_Leiden_enrichment_ratio = file_to_float(path="./pcc_leiden_BioPlex_enrichment_ratio.txt")

# %%
hdWGCNA_enrichment_ratio = file_to_float(path="./hdWGCNA_BioPlex_enrichment_ratio.txt")

# %%
# TOM_Leiden_enrichment_ratio = file_to_float(path="./TOM_Leiden_BioPlex_enrichment_ratio.txt")

# %%
Hotspot_enrichment_ratio = file_to_float(path="./Hotspot_BioPlex_enrichment_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_enrichment_ratio, binary_knd_binary_enrichment_ratio, linear_knd_binary_enrichment_ratio, nlog_knd_binary_enrichment_ratio, reciprocal_knd_binary_enrichment_ratio]
data2 = [pcc_knd_linear_enrichment_ratio, binary_knd_linear_enrichment_ratio, linear_knd_linear_enrichment_ratio, nlog_knd_linear_enrichment_ratio, reciprocal_knd_linear_enrichment_ratio]
data3 = [pcc_knd_nlog_enrichment_ratio, binary_knd_nlog_enrichment_ratio, linear_knd_nlog_enrichment_ratio, nlog_knd_nlog_enrichment_ratio, reciprocal_knd_nlog_enrichment_ratio]
data4 = [pcc_knd_reciprocal_enrichment_ratio, binary_knd_reciprocal_enrichment_ratio, linear_knd_reciprocal_enrichment_ratio, nlog_knd_reciprocal_enrichment_ratio, reciprocal_knd_reciprocal_enrichment_ratio]
data5 = [pcc_knn_enrichment_ratio, binary_knn_enrichment_ratio, linear_knn_enrichment_ratio, nlog_knn_enrichment_ratio, reciprocal_knn_enrichment_ratio]
data6 = PCC_Leiden_enrichment_ratio

data7 = hdWGCNA_enrichment_ratio
data8 = Hotspot_enrichment_ratio
# data9 = 

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})

bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})

# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
# custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden']
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
# ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6])  # Set the positions of major ticks
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('BioPlex Enrichment Ratio', fontsize=18)
ax.set_title('Pathway Enrichment Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/BioPlex_pathway_enrichment_ratio_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# WikiPathway

# %%
pcc_knd_linear_enrichment_ratio = file_to_float(path="./pcc_knd_linear_WikiPathway_enrichment_ratio.txt")
binary_knd_linear_enrichment_ratio = file_to_float(path="./binary_knd_linear_WikiPathway_enrichment_ratio.txt")
linear_knd_linear_enrichment_ratio = file_to_float(path="./linear_knd_linear_WikiPathway_enrichment_ratio.txt")
nlog_knd_linear_enrichment_ratio = file_to_float(path="./nlog_knd_linear_WikiPathway_enrichment_ratio.txt")
reciprocal_knd_linear_enrichment_ratio = file_to_float(path="./reciprocal_knd_linear_WikiPathway_enrichment_ratio.txt")

# %%
pcc_knd_nlog_enrichment_ratio = file_to_float(path="./pcc_knd_nlog_WikiPathway_enrichment_ratio.txt")
binary_knd_nlog_enrichment_ratio = file_to_float(path="./binary_knd_nlog_WikiPathway_enrichment_ratio.txt")
linear_knd_nlog_enrichment_ratio = file_to_float(path="./linear_knd_nlog_WikiPathway_enrichment_ratio.txt")
nlog_knd_nlog_enrichment_ratio = file_to_float(path="./nlog_knd_nlog_WikiPathway_enrichment_ratio.txt")
reciprocal_knd_nlog_enrichment_ratio = file_to_float(path="./reciprocal_knd_nlog_WikiPathway_enrichment_ratio.txt")

# %%
pcc_knd_reciprocal_enrichment_ratio = file_to_float(path="./pcc_knd_reciprocal_WikiPathway_enrichment_ratio.txt")
binary_knd_reciprocal_enrichment_ratio = file_to_float(path="./binary_knd_reciprocal_WikiPathway_enrichment_ratio.txt")
linear_knd_reciprocal_enrichment_ratio = file_to_float(path="./linear_knd_reciprocal_WikiPathway_enrichment_ratio.txt")
nlog_knd_reciprocal_enrichment_ratio = file_to_float(path="./nlog_knd_reciprocal_WikiPathway_enrichment_ratio.txt")
reciprocal_knd_reciprocal_enrichment_ratio = file_to_float(path="./reciprocal_knd_reciprocal_WikiPathway_enrichment_ratio.txt")

# %%
pcc_knn_enrichment_ratio = file_to_float(path="./pcc_knn_WikiPathway_enrichment_ratio.txt")
binary_knn_enrichment_ratio = file_to_float(path="./binary_knn_WikiPathway_enrichment_ratio.txt")
linear_knn_enrichment_ratio = file_to_float(path="./linear_knn_WikiPathway_enrichment_ratio.txt")
nlog_knn_enrichment_ratio = file_to_float(path="./nlog_knn_WikiPathway_enrichment_ratio.txt")
reciprocal_knn_enrichment_ratio = file_to_float(path="./reciprocal_knn_WikiPathway_enrichment_ratio.txt")

# %%
PCC_Leiden_enrichment_ratio = file_to_float(path="./pcc_leiden_WikiPathway_enrichment_ratio.txt")

# %%
hdWGCNA_enrichment_ratio = file_to_float(path="./hdWGCNA_WikiPathway_enrichment_ratio.txt")

# %%
# TOM_Leiden_enrichment_ratio = file_to_float(path="./TOM_Leiden_WikiPathway_enrichment_ratio.txt")

# %%
Hotspot_enrichment_ratio = file_to_float(path="./Hotspot_WikiPathway_enrichment_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [pcc_knd_binary_enrichment_ratio, binary_knd_binary_enrichment_ratio, linear_knd_binary_enrichment_ratio, nlog_knd_binary_enrichment_ratio, reciprocal_knd_binary_enrichment_ratio]
data2 = [pcc_knd_linear_enrichment_ratio, binary_knd_linear_enrichment_ratio, linear_knd_linear_enrichment_ratio, nlog_knd_linear_enrichment_ratio, reciprocal_knd_linear_enrichment_ratio]
data3 = [pcc_knd_nlog_enrichment_ratio, binary_knd_nlog_enrichment_ratio, linear_knd_nlog_enrichment_ratio, nlog_knd_nlog_enrichment_ratio, reciprocal_knd_nlog_enrichment_ratio]
data4 = [pcc_knd_reciprocal_enrichment_ratio, binary_knd_reciprocal_enrichment_ratio, linear_knd_reciprocal_enrichment_ratio, nlog_knd_reciprocal_enrichment_ratio, reciprocal_knd_reciprocal_enrichment_ratio]
data5 = [pcc_knn_enrichment_ratio, binary_knn_enrichment_ratio, linear_knn_enrichment_ratio, nlog_knn_enrichment_ratio, reciprocal_knn_enrichment_ratio]
data6 = PCC_Leiden_enrichment_ratio

data7 = hdWGCNA_enrichment_ratio
data8 = Hotspot_enrichment_ratio
# data9 = 

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis

# custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden']
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
# ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6])  # Set the positions of major ticks
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('WikiPathway Enrichment Ratio', fontsize=18)
ax.set_title('Pathway Enrichment Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/WikiPathway_pathway_enrichment_ratio_comparison.svg")
# Show the plot
plt.show()
