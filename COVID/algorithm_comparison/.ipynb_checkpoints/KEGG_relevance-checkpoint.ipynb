# %%
pip install leidenalg
# Out:
# Requirement already satisfied: leidenalg in /opt/conda/lib/python3.11/site-packages (0.10.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from leidenalg) (0.10.6)
# Requirement already satisfied: texttable>=1.6.2 in /opt/conda/lib/python3.11/site-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.6.7)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gseapy
# Out:
# Collecting gseapy
#   Downloading gseapy-1.1.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /opt/conda/lib/python3.11/site-packages (from gseapy) (1.24.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from gseapy) (1.11.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from gseapy) (2.0.3)
# Requirement already satisfied: matplotlib>=2.2 in /opt/conda/lib/python3.11/site-packages (from gseapy) (3.7.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from gseapy) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->gseapy) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->gseapy) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->gseapy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->gseapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->gseapy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->gseapy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.16.0)
# Downloading gseapy-1.1.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.8/590.8 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: gseapy
# Successfully installed gseapy-1.1.8
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import json
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import module_to_dict
from algorithm_comparison import relevance, list_to_txt

# %%
# !pwd
# %cd /home/jovyan/work/COVID/algorithm_comparison/Cell
# !pwd
# Out:
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell

# %%
# Load background genes
with open("/home/jovyan/work/COVID/algorithm_comparison/Cell/background.txt", "r") as f:
    background_set = set(line.strip() for line in f)
print(len(background_set))
# Out:
# 26571

# %% [markdown]
# KEGG

# %%
# Opening JSON file
with open("/home/jovyan/work/pathway_relevance/KEGG_2021_Human.json", 'r') as json_file:
    KEGG_2021_Human = json.load(json_file)
KEGG_2021_Human
# Out:
# {'ABC transporters': ['ABCA2',
#   'ABCC4',
#   'ABCG8',
#   'ABCA3',
#   'ABCC5',
#   'ABCC2',
#   'ABCA1',
#   'ABCC3',
#   'ABCA6',
#   'ABCC8',
#   'ABCA7',
#   'ABCC9',
#   'ABCA4',
#   'ABCC6',
#   'ABCA5',
#   'TAP2',
#   'ABCA8',
#   'TAP1',
#   'ABCA9',
#   'ABCA10',
#   'ABCB10',
#   'ABCA12',
#   'ABCB11',
#   'ABCC10',
#   'ABCG1',
#   'ABCG4',
#   'ABCC1',
#   'ABCG5',
#   'ABCG2',
#   'CFTR',
#   'ABCB4',
#   'ABCB1',
#   'ABCD3',
#   'ABCD4',
#   'ABCB7',
#   'ABCB8',
#   'ABCB5',
#   'ABCB6',
#   'ABCB9',
#   'ABCA13',
#   'ABCC11',
#   'ABCC12',
#   'DEFB1',
#   'ABCD1',
#   'ABCD2'],
#  'AGE-RAGE signaling pathway in diabetic complications': ['TGFB1',
#   'TGFB3',
#   'TGFB2',
#   'VCAM1',
#   'AGT',
#   'MAPK13',
#   'MAPK14',
#   'COL1A2',
#   'MAPK11',
#   'COL1A1',
#   'MAPK12',
#   'MAPK10',
#   'AGTR1',
#   'BAX',
#   'PLCD1',
#   'PLCD4',
#   'PLCD3',
#   'RELA',
#   'SERPINE1',
#   'TNF',
#   'FOXO1',
#   'NRAS',
#   'CCND1',
#   'AKT3',
#   'AKT1',
#   'PLCE1',
#   'AKT2',
#   'EGR1',
#   'SMAD3',
#   'STAT5B',
#   'SMAD2',
#   'SMAD4',
#   'PRKCD',
#   'PRKCE',
#   'CYBB',
#   'PRKCB',
#   'PRKCA',
#   'SELE',
#   'NFKB1',
#   'DIAPH1',
#   'PRKCZ',
#   'PIK3R1',
#   'NOX4',
#   'NOX1',
#   'AGER',
#   'ICAM1',
#   'PIM1',
#   'PLCG1',
#   'PLCG2',
#   'STAT5A',
#   'EDN1',
#   'JUN',
#   'MMP2',
#   'VEGFC',
#   'FN1',
#   'VEGFD',
#   'NFATC1',
#   'TGFBR1',
#   'TGFBR2',
#   'VEGFA',
#   'VEGFB',
#   'IL1A',
#   'IL1B',
#   'COL3A1',
#   'IL6',
#   'PIK3CB',
#   'PIK3CA',
#   'CDK4',
#   'BCL2',
#   'CXCL8',
#   'PIK3R3',
#   'PIK3R2',
#   'CASP3',
#   'NOS3',
#   'STAT1',
#   'STAT3',
#   'F3',
#   'CDC42',
#   'COL4A1',
#   'PLCB4',
#   'COL4A3',
#   'COL4A2',
#   'COL4A5',
#   'COL4A4',
#   'COL4A6',
#   'KRAS',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'CDKN1B',
#   'PIK3CD',
#   'MAPK9',
#   'THBD',
#   'MAPK8',
#   'MAPK3',
#   'CCL2',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'JAK2'],
#  'AMPK signaling pathway': ['RAB2A',
#   'PPP2R1A',
#   'TSC2',
#   'TSC1',
#   'PRKAB1',
#   'PRKAB2',
#   'SCD',
#   'LEP',
#   'ULK1',
#   'PRKAA2',
#   'CRTC2',
#   'FOXO3',
#   'PRKAA1',
#   'FOXO1',
#   'CREB3L1',
#   'CREB3L4',
#   'CCND1',
#   'AKT3',
#   'CREB3L2',
#   'CREB3L3',
#   'AKT1',
#   'AKT2',
#   'MAP3K7',
#   'PPARGC1A',
#   'SREBF1',
#   'INSR',
#   'IGF1',
#   'EEF2',
#   'CREB3',
#   'CCNA2',
#   'CCNA1',
#   'CREB1',
#   'PIK3R1',
#   'RHEB',
#   'FASN',
#   'CREB5',
#   'PFKFB1',
#   'CFTR',
#   'PFKFB3',
#   'PFKFB2',
#   'PFKFB4',
#   'IRS1',
#   'IRS2',
#   'EIF4EBP1',
#   'SLC2A4',
#   'IRS4',
#   'IGF1R',
#   'STK11',
#   'EEF2K',
#   'LIPE',
#   'LEPR',
#   'STRADA',
#   'STRADB',
#   'PPP2R5C',
#   'PPP2R5B',
#   'PPP2R5E',
#   'PPP2R5D',
#   'G6PC1',
#   'SIRT1',
#   'G6PC2',
#   'PPP2R5A',
#   'G6PC3',
#   'PIK3CB',
#   'PIK3CA',
#   'AKT1S1',
#   'FBP1',
#   'FBP2',
#   'CAB39L',
#   'PIK3R3',
#   'ADIPOR1',
#   'PIK3R2',
#   'ADIPOR2',
#   'ELAVL1',
#   'ACACB',
#   'ADRA1A',
#   'ACACA',
#   'HNF4A',
#   'CD36',
#   'PCK2',
#   'PCK1',
#   'ADIPOQ',
#   'CPT1B',
#   'CPT1A',
#   'PDPK1',
#   'SCD5',
#   'PPP2R3A',
#   'PPP2R3C',
#   'PPP2R3B',
#   'CPT1C',
#   'MTOR',
#   'RAB11B',
#   'PPP2CA',
#   'TBC1D1',
#   'PFKM',
#   'PFKL',
#   'RAB10',
#   'PPP2R2D',
#   'RPS6KB2',
#   'PPP2R2C',
#   'RPS6KB1',
#   'RAB14',
#   'PPARG',
#   'PFKP',
#   'CAB39',
#   'PRKAG2',
#   'PRKAG3',
#   'HMGCR',
#   'PIK3CD',
#   'PPP2R2B',
#   'PPP2R2A',
#   'PRKAG1',
#   'INS',
#   'CAMKK2',
#   'GYS1',
#   'PPP2CB',
#   'GYS2',
#   'RPTOR',
#   'PPP2R1B',
#   'RAB8A',
#   'MLYCD'],
#  'Acute myeloid leukemia': ['DUSP6',
#   'BAD',
#   'JUP',
#   'ZBTB16',
#   'RUNX1',
#   'BRAF',
#   'IL3',
#   'PML',
#   'PIK3CB',
#   'PIK3CA',
#   'RARA',
#   'SOS2',
#   'RAF1',
#   'SOS1',
#   'LEF1',
#   'RELA',
#   'CSF2',
#   'BCL2A1',
#   'MPO',
#   'PIK3R3',
#   'ARAF',
#   'PIK3R2',
#   'NRAS',
#   'CCND1',
#   'AKT3',
#   'MYC',
#   'AKT1',
#   'AKT2',
#   'RUNX1T1',
#   'STAT5B',
#   'MAP2K2',
#   'TCF7L2',
#   'TCF7L1',
#   'CHUK',
#   'MAP2K1',
#   'STAT3',
#   'MTOR',
#   'NFKB1',
#   'CCNA2',
#   'PER2',
#   'CCNA1',
#   'KIT',
#   'PIK3R1',
#   'RPS6KB2',
#   'RPS6KB1',
#   'TCF7',
#   'GRB2',
#   'KRAS',
#   'PPARD',
#   'CEBPA',
#   'CSF1R',
#   'SPI1',
#   'CEBPE',
#   'FLT3',
#   'EIF4EBP1',
#   'PIK3CD',
#   'ITGAM',
#   'IKBKB',
#   'FCGR1A',
#   'MAPK3',
#   'PIM2',
#   'PIM1',
#   'HRAS',
#   'MAPK1',
#   'CD14',
#   'IKBKG',
#   'STAT5A'],
#  'Adherens junction': ['PTPN1',
#   'RHOA',
#   'ACTN4',
#   'ACTN1',
#   'LMO7',
#   'BAIAP2',
#   'TGFBR1',
#   'TGFBR2',
#   'AFDN',
#   'PTPRF',
#   'FER',
#   'PTPRB',
#   'PTPN6',
#   'LEF1',
#   'CTNND1',
#   'PTPRM',
#   'IQGAP1',
#   'EGFR',
#   'PTPRJ',
#   'ACTB',
#   'CDH1',
#   'ERBB2',
#   'WASF1',
#   'ACP1',
#   'MAP3K7',
#   'WASF2',
#   'WASF3',
#   'SMAD3',
#   'YES1',
#   'CREBBP',
#   'FARP2',
#   'INSR',
#   'TCF7L2',
#   'SMAD4',
#   'TCF7L1',
#   'CSNK2A2',
#   'CSNK2A1',
#   'CSNK2A3',
#   'SORBS1',
#   'PARD3',
#   'CDC42',
#   'TJP1',
#   'CSNK2B',
#   'FGFR1',
#   'NECTIN1',
#   'SNAI2',
#   'TCF7',
#   'MET',
#   'SNAI1',
#   'SSX2IP',
#   'NECTIN4',
#   'NECTIN3',
#   'NECTIN2',
#   'VCL',
#   'SRC',
#   'CTNNB1',
#   'ACTG1',
#   'WAS',
#   'WASL',
#   'NLK',
#   'IGF1R',
#   'EP300',
#   'CTNNA2',
#   'MAPK3',
#   'RAC3',
#   'CTNNA1',
#   'MAPK1',
#   'RAC1',
#   'CTNNA3',
#   'FYN',
#   'RAC2'],
#  'Adipocytokine signaling pathway': ['ACSL3',
#   'ACSL1',
#   'ACSL6',
#   'PTPN11',
#   'ACSL5',
#   'ACSL4',
#   'G6PC1',
#   'PRKAB1',
#   'G6PC2',
#   'PRKAB2',
#   'TNFRSF1A',
#   'TNFRSF1B',
#   'NFKBIB',
#   'NFKBIA',
#   'G6PC3',
#   'MAPK10',
#   'LEP',
#   'AGRP',
#   'NFKBIE',
#   'RELA',
#   'PRKAA2',
#   'TRADD',
#   'TNF',
#   'ADIPOR1',
#   'ADIPOR2',
#   'PRKAA1',
#   'ACACB',
#   'SOCS3',
#   'RXRA',
#   'RXRB',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'CD36',
#   'PCK2',
#   'PPARGC1A',
#   'RXRG',
#   'PCK1',
#   'ADIPOQ',
#   'CPT1B',
#   'CPT1A',
#   'PPARA',
#   'CHUK',
#   'STAT3',
#   'TRAF2',
#   'CPT1C',
#   'MTOR',
#   'NFKB1',
#   'POMC',
#   'ACSBG2',
#   'ACSBG1',
#   'PRKCQ',
#   'IRS1',
#   'IRS2',
#   'SLC2A1',
#   'PRKAG2',
#   'PRKAG3',
#   'SLC2A4',
#   'IRS4',
#   'PRKAG1',
#   'CAMKK2',
#   'IKBKB',
#   'STK11',
#   'MAPK9',
#   'MAPK8',
#   'NPY',
#   'LEPR',
#   'IKBKG',
#   'JAK2'],
#  'Adrenergic signaling in cardiomyocytes': ['TPM4',
#   'CACNA2D2',
#   'TPM3',
#   'CACNA2D1',
#   'TPM2',
#   'CACNA2D4',
#   'CACNA2D3',
#   'ATP1B4',
#   'PPP2R1A',
#   'ATP1B3',
#   'ATP1B2',
#   'AGT',
#   'ATP1B1',
#   'MAPK13',
#   'PPP1CA',
#   'MAPK14',
#   'PPP1CB',
#   'MAPK11',
#   'MAPK12',
#   'MYL2',
#   'MYL3',
#   'MYL4',
#   'AGTR2',
#   'AGTR1',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'ATF2',
#   'ADCY1',
#   'CALML6',
#   'ATF6B',
#   'ADCY5',
#   'ADCY4',
#   'ATP1A4',
#   'CALML3',
#   'ADCY3',
#   'ATP1A3',
#   'CALML4',
#   'ADCY2',
#   'ATP1A2',
#   'CALML5',
#   'ADCY9',
#   'ATP1A1',
#   'ADCY8',
#   'ADCY7',
#   'SLC9A1',
#   'ADCY6',
#   'PPP1CC',
#   'CREB3L1',
#   'CREB3L4',
#   'AKT3',
#   'CREB3L2',
#   'SCN7A',
#   'CREB3L3',
#   'AKT1',
#   'TPM1',
#   'AKT2',
#   'TNNC1',
#   'PRKCA',
#   'KCNE1B',
#   'CACNB2',
#   'CREB3',
#   'CACNB3',
#   'CACNB4',
#   'CREB1',
#   'PPP1R1A',
#   'TNNT2',
#   'GNAQ',
#   'GNAS',
#   'ATF4',
#   'CREB5',
#   'CACNB1',
#   'KCNE1',
#   'CACNA1C',
#   'CREM',
#   'CACNA1D',
#   'CACNA1F',
#   'PRKACG',
#   'CACNA1S',
#   'PRKACB',
#   'PRKACA',
#   'SCN1B',
#   'PPP2R5C',
#   'PPP2R5B',
#   'PPP2R5E',
#   'PPP2R5D',
#   'PPP2R5A',
#   'FXYD2',
#   'BCL2',
#   'RAPGEF3',
#   'SCN4B',
#   'MYH6',
#   'MYH7',
#   'RAPGEF4',
#   'PIK3R5',
#   'ADRB1',
#   'ADRB2',
#   'ADRA1D',
#   'ADRA1B',
#   'ADRA1A',
#   'PIK3R6',
#   'PPP2R3A',
#   'ATP2B4',
#   'ATP2B3',
#   'PPP2R3C',
#   'ATP2B2',
#   'PPP2R3B',
#   'ATP2B1',
#   'PPP2CA',
#   'PLCB4',
#   'PPP2R2D',
#   'KCNQ1',
#   'PPP2R2C',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'RYR2',
#   'CAMK2D',
#   'CAMK2A',
#   'CAMK2B',
#   'ATP2A3',
#   'ATP2A2',
#   'PPP2R2B',
#   'ATP2A1',
#   'PPP2R2A',
#   'ACTC1',
#   'GNAI1',
#   'SLC8A1',
#   'GNAI2',
#   'SLC8A2',
#   'GNAI3',
#   'PIK3CG',
#   'SLC8A3',
#   'CACNG7',
#   'PLN',
#   'PPP2CB',
#   'RPS6KA5',
#   'CACNG8',
#   'PPP2R1B',
#   'MAPK3',
#   'SCN5A',
#   'TNNI3',
#   'CACNG1',
#   'MAPK1',
#   'CACNG2',
#   'CACNG3',
#   'CAMK2G',
#   'CACNG4',
#   'CACNG5',
#   'CACNG6'],
#  'African trypanosomiasis': ['PRKCG',
#   'IL10',
#   'HBA1',
#   'IGH',
#   'PRKCB',
#   'HBA2',
#   'IL18',
#   'PRKCA',
#   'SELE',
#   'VCAM1',
#   'IL1B',
#   'MYD88',
#   'PLCB4',
#   'IL6',
#   'APOA1',
#   'FAS',
#   'GNAQ',
#   'IFNG',
#   'F2RL1',
#   'TLR9',
#   'THOP1',
#   'PLCB2',
#   'PLCB3',
#   'IDO1',
#   'IDO2',
#   'PLCB1',
#   'HBB',
#   'LAMA4',
#   'HPR',
#   'TNF',
#   'FASLG',
#   'ICAM1',
#   'KNG1',
#   'NPPA',
#   'IL12B',
#   'IL12A',
#   'APOL1'],
#  'Alanine, aspartate and glutamate metabolism': ['CAD',
#   'GFPT1',
#   'GOT2',
#   'ADSL',
#   'GOT1',
#   'GAD2',
#   'GAD1',
#   'GFPT2',
#   'GPT2',
#   'ASNS',
#   'ASRGL1',
#   'ALDH5A1',
#   'GLUD1',
#   'ALDH4A1',
#   'ASS1',
#   'GLUD2',
#   'FOLH1',
#   'CPS1',
#   'ADSS1',
#   'ADSS2',
#   'AGXT2',
#   'ASPA',
#   'NIT2',
#   'NAT8L',
#   'AGXT',
#   'GOT1L1',
#   'GLS2',
#   'GPT',
#   'GLS',
#   'ABAT',
#   'DDO',
#   'IL4I1',
#   'PPAT',
#   'ASL',
#   'GLUL',
#   'RIMKLB',
#   'RIMKLA'],
#  'Alcoholism': ['H2AZ2',
#   'H2BC8',
#   'H2AZ1',
#   'H2BC9',
#   'H2BC6',
#   'H2BC7',
#   'H2BC4',
#   'H2BC5',
#   'H2BC3',
#   'H2BC1',
#   'GRIN2D',
#   'GRIN2C',
#   'PDYN',
#   'GRIN1',
#   'PPP1CA',
#   'PPP1CB',
#   'GRIN3A',
#   'GRIN3B',
#   'HAT1',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'RAF1',
#   'ATF2',
#   'CALML6',
#   'ATF6B',
#   'ADCY5',
#   'H2AB2',
#   'CALML3',
#   'H2AB3',
#   'CALML4',
#   'ARAF',
#   'CALML5',
#   'H2AB1',
#   'MACROH2A2',
#   'MACROH2A1',
#   'GNG2',
#   'PPP1CC',
#   'CREB3L1',
#   'NRAS',
#   'GNG4',
#   'GNG3',
#   'CREB3L4',
#   'GNG5',
#   'CREB3L2',
#   'GNG8',
#   'CREB3L3',
#   'GNG7',
#   'H2BU1',
#   'H4C9',
#   'H4C8',
#   'H2AC7',
#   'H2AC8',
#   'MAP2K1',
#   'H2AC6',
#   'H2AC4',
#   'H2AC1',
#   'H2BE1',
#   'CREB3',
#   'CREB1',
#   'GNB1',
#   'PPP1R1B',
#   'H2AC20',
#   'H4C15',
#   'GNB3',
#   'H2AC21',
#   'H4C14',
#   'GNB2',
#   'H4C13',
#   'PKIA',
#   'GNB5',
#   'H4C12',
#   'GNAS',
#   'GNB4',
#   'H4C11',
#   'GRB2',
#   'ATF4',
#   'CREB5',
#   'HDAC11',
#   'HDAC10',
#   'H2AC16',
#   'H2AC17',
#   'SLC6A3',
#   'H2AC18',
#   'H2AC19',
#   'H2AC12',
#   'H2AC13',
#   'PRKACG',
#   'GNG11',
#   'GRIN2B',
#   'H2AC14',
#   'GNG10',
#   'GRIN2A',
#   'H2AC15',
#   'H2AC11',
#   'H4C1',
#   'H4C3',
#   'H4C2',
#   'H2BW2',
#   'H4C5',
#   'PRKACB',
#   'H4C4',
#   'H4C7',
#   'H2BW1',
#   'H4C6',
#   'PRKACA',
#   'BDNF',
#   'BRAF',
#   'GNG13',
#   'H2BC17',
#   'GNG12',
#   'H2BC18',
#   'H2BC13',
#   'H2BC14',
#   'H2BC15',
#   'H2AJ',
#   'TH',
#   'ADORA2B',
#   'H2BC10',
#   'H2BC11',
#   'ADORA2A',
#   'GNAO1',
#   'H2BC12',
#   'CAMK4',
#   'SOS2',
#   'H2AW',
#   'SOS1',
#   'H3-3A',
#   'SHC3',
#   'SHC4',
#   'SHC1',
#   'MAOB',
#   'SHC2',
#   'MAOA',
#   'GNGT2',
#   'GNGT1',
#   'H3C2',
#   'H3C1',
#   'DRD1',
#   'H3C4',
#   'DRD2',
#   'H3C3',
#   'H3C6',
#   'SLC18A1',
#   'SLC18A2',
#   'H3-3B',
#   'H3C8',
#   'H3C7',
#   'NTRK2',
#   'H4-16',
#   'H3-4',
#   'H3-5',
#   'FOSB',
#   'CRH',
#   'KRAS',
#   'SLC29A2',
#   'SLC29A1',
#   'SLC29A3',
#   'HDAC5',
#   'H2AX',
#   'HDAC6',
#   'HDAC3',
#   'DDC',
#   'HDAC4',
#   'HDAC1',
#   'HDAC2',
#   'HDAC9',
#   'CAMKK1',
#   'GNAI1',
#   'CAMKK2',
#   'GNAI2',
#   'HDAC7',
#   'GNAI3',
#   'HDAC8',
#   'H3C14',
#   'H2BC21',
#   'H3C15',
#   'H3C12',
#   'H3C13',
#   'NPY',
#   'H3C10',
#   'MAPK3',
#   'H3C11',
#   'HRAS',
#   'MAPK1',
#   'H2BS1'],
#  'Aldosterone synthesis and secretion': ['HSD3B1',
#   'HSD3B2',
#   'ATP1B4',
#   'ATP1B3',
#   'ATP1B2',
#   'AGT',
#   'ATP1B1',
#   'AGTR1',
#   'ORAI1',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'ATF2',
#   'ATF1',
#   'ADCY1',
#   'CALML6',
#   'ATF6B',
#   'ADCY5',
#   'ADCY4',
#   'ATP1A4',
#   'CALML3',
#   'ADCY3',
#   'ATP1A3',
#   'CALML4',
#   'ADCY2',
#   'ATP1A2',
#   'CALML5',
#   'ADCY9',
#   'ATP1A1',
#   'ADCY8',
#   'ADCY7',
#   'ADCY6',
#   'CREB3L1',
#   'CREB3L4',
#   'CREB3L2',
#   'CREB3L3',
#   'LDLR',
#   'PRKCG',
#   'PRKCE',
#   'PRKCB',
#   'PRKCA',
#   'CREB3',
#   'NR4A2',
#   'CREB1',
#   'GNAQ',
#   'STAR',
#   'PRKD1',
#   'GNAS',
#   'PRKD3',
#   'PRKD2',
#   'ATF4',
#   'CREB5',
#   'CACNA1C',
#   'CACNA1D',
#   'CACNA1G',
#   'CACNA1F',
#   'CACNA1I',
#   'NR4A1',
#   'CACNA1H',
#   'PRKACG',
#   'LIPE',
#   'CYP11A1',
#   'NPPA',
#   'CACNA1S',
#   'PDE2A',
#   'PRKACB',
#   'PRKACA',
#   'KCNJ5',
#   'CYP11B2',
#   'CAMK4',
#   'CAMK1',
#   'KCNK3',
#   'DAGLA',
#   'DAGLB',
#   'KCNK9',
#   'NPR1',
#   'ITPR2',
#   'ITPR3',
#   'ITPR1',
#   'MC2R',
#   'CAMK1D',
#   'ATP2B4',
#   'ATP2B3',
#   'ATP2B2',
#   'ATP2B1',
#   'POMC',
#   'PLCB4',
#   'CYP21A2',
#   'PLCB2',
#   'CAMK1G',
#   'PLCB3',
#   'PLCB1',
#   'CAMK2D',
#   'CAMK2A',
#   'CAMK2B',
#   'GNA11',
#   'CAMK2G',
#   'SCARB1'],
#  'Aldosterone-regulated sodium reabsorption': ['INSR',
#   'PRKCG',
#   'PDPK1',
#   'ATP1B4',
#   'IGF1',
#   'PRKCB',
#   'ATP1B3',
#   'PRKCA',
#   'ATP1B2',
#   'ATP1B1',
#   'SCNN1G',
#   'PIK3CB',
#   'PIK3R1',
#   'FXYD4',
#   'PIK3CA',
#   'FXYD2',
#   'SCNN1B',
#   'KRAS',
#   'SGK1',
#   'IRS1',
#   'NEDD4L',
#   'SCNN1A',
#   'ATP1A4',
#   'ATP1A3',
#   'PIK3CD',
#   'PIK3R3',
#   'ATP1A2',
#   'PIK3R2',
#   'ATP1A1',
#   'INS',
#   'NR3C2',
#   'HSD11B2',
#   'SLC9A3R2',
#   'MAPK3',
#   'MAPK1',
#   'SFN',
#   'KCNJ1'],
#  'Allograft rejection': ['HLA-DRB5',
#   'IL10',
#   'GZMB',
#   'HLA-C',
#   'IGH',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'HLA-E',
#   'HLA-F',
#   'IL2',
#   'IL5',
#   'IL4',
#   'FAS',
#   'IFNG',
#   'HLA-DQB1',
#   'HLA-DRA',
#   'CD28',
#   'HLA-DPB1',
#   'CD40LG',
#   'HLA-DRB4',
#   'HLA-DRB3',
#   'HLA-DRB1',
#   'CD86',
#   'CD40',
#   'CD80',
#   'PRF1',
#   'TNF',
#   'FASLG',
#   'HLA-DMB',
#   'HLA-DPA1',
#   'IL12B',
#   'IL12A',
#   'HLA-DOB',
#   'HLA-DMA',
#   'HLA-DQA2',
#   'HLA-DOA',
#   'HLA-DQA1'],
#  'Alzheimer disease': ['BAD',
#   'TPTEP2-CSNK1E',
#   'DKK1',
#   'GRIN2D',
#   'ATG14',
#   'DKK2',
#   'GRIN2C',
#   'ATG13',
#   'DKK4',
#   'PSMC6',
#   'APC',
#   'MAPK10',
#   'PSMC4',
#   'PSMC5',
#   'PSMC2',
#   'PSMC3',
#   'UQCRC2',
#   'PSMC1',
#   'UQCRC1',
#   'ULK2',
#   'ULK1',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'APP',
#   'CALML6',
#   'LRP1',
#   'TUBAL3',
#   'LRP6',
#   'UQCR10',
#   'CALML3',
#   'LRP5',
#   'CALML4',
#   'FZD10',
#   'ARAF',
#   'CALML5',
#   'UQCR11',
#   'PSMD9',
#   'FRAT1',
#   'FRAT2',
#   'PSMD7',
#   'PSMD8',
#   'PSMD6',
#   'AKT3',
#   'PSMD3',
#   'PSMD4',
#   'AKT1',
#   'APBB1',
#   'NRBF2',
#   'PSMD1',
#   'AKT2',
#   'PSMD2',
#   'NCSTN',
#   'SNCA',
#   'FZD2',
#   'COX8A',
#   'FZD1',
#   'INSR',
#   'FZD4',
#   'WNT10B',
#   'COX8C',
#   'FZD3',
#   'WNT10A',
#   'XBP1',
#   'FZD6',
#   'FZD5',
#   'FZD8',
#   'FZD7',
#   'FZD9',
#   'CSNK1E',
#   'COX7A2L',
#   'BACE1',
#   'BACE2',
#   'PIK3R1',
#   'CSNK2B',
#   'ATG2B',
#   'NOX4',
#   'ATG2A',
#   'ATF6',
#   'NOX1',
#   'ATF4',
#   'PPP3R1',
#   'GRIN2B',
#   'PPP3R2',
#   'GRIN2A',
#   'COX3',
#   'APOE',
#   'COX2',
#   'COX1',
#   'PSENEN',
#   'CSNK1A1',
#   'TUBB',
#   'WNT9A',
#   'BRAF',
#   'WNT9B',
#   'ATP5F1D',
#   'TUBB2A',
#   'ATP5F1E',
#   'COX6C',
#   'IL1A',
#   'IL1B',
#   'TUBB2B',
#   'MAPT',
#   'COX7C',
#   'COX7B',
#   'IDE',
#   'WNT8B',
#   'WNT8A',
#   'PPP3CA',
#   'PPP3CB',
#   'PPP3CC',
#   'CASP12',
#   'ATG101',
#   'FADD',
#   'ATP5PF',
#   'APC2',
#   'ATP5PD',
#   'CSNK2A2',
#   'CSNK2A1',
#   'MME',
#   'ATP5PB',
#   'CSNK2A3',
#   'WNT7A',
#   'ND4L',
#   'WNT7B',
#   'ADAM10',
#   'TUBB4B',
#   'COX6B1',
#   'TUBB4A',
#   'COX6B2',
#   'PSMA6',
#   'PSMA7',
#   'PLCB4',
#   'PSMA4',
#   'ADAM17',
#   'PSMA5',
#   'PSMA2',
#   'PSMA3',
#   'NDUFAB1',
#   'NDUFA4L2',
#   'PSMA1',
#   'ATP5PO',
#   'CDK5R1',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'RYR3',
#   'COX5A',
#   'NDUFA12',
#   'NDUFA13',
#   'CTNNB1',
#   'NDUFA10',
#   'NDUFA11',
#   'TUBA1A',
#   'COX5B',
#   'PSMA8',
#   'PTGS2',
#   'PSMB7',
#   'ATP5F1A',
#   'IKBKB',
#   'ATP5F1B',
#   'PSMB5',
#   'TUBA1C',
#   'ATP5F1C',
#   'PSMB6',
#   'TUBA1B',
#   'PSMB3',
#   'PSMB4',
#   'PSMB1',
#   'PSMB2',
#   'HRAS',
#   'BID',
#   'WNT5A',
#   'WNT5B',
#   'SDHD',
#   'COX7B2',
#   'SDHB',
#   'SDHC',
#   'GRIN1',
#   'ERN1',
#   'SDHA',
#   'TUBA4A',
#   'TUBA8',
#   'FAS',
#   'UQCRQ',
#   'SLC25A31',
#   'PPIF',
#   'PPID',
#   'RAF1',
#   'CHRM3',
#   'RELA',
#   'CHRM1',
#   'NDUFB11',
#   'CSF1',
#   'CHRM5',
#   'CHRNA7',
#   'NDUFB10',
#   'TUBB1',
#   'TNF',
#   'COX6A2',
#   'TUBA3C',
#   'NDUFC2-KCTD14',
#   'COX6A1',
#   'KIF5A',
#   'NRAS',
#   'TUBB8',
#   'TUBA3E',
#   'TUBA3D',
#   'TUBB6',
#   'KIF5C',
#   'TUBB3',
#   'KIF5B',
#   'CAPN1',
#   'CAPN2',
#   'NDUFV3',
#   'NDUFV2',
#   'MAP3K5',
#   'NDUFV1',
#   'MAP2K2',
#   'WNT3A',
#   'MAP2K1',
#   'CYBB',
#   'TRAF2',
#   'NFKB1',
#   'EIF2S1',
#   'SEM1',
#   'GNAQ',
#   'ND2',
#   'ND1',
#   'ND4',
#   'ND3',
#   'ND6',
#   'ND5',
#   'WNT2B',
#   'ATP8',
#   'IRS1',
#   'IRS2',
#   'UQCRB',
#   'ATP6',
#   'LPL',
#   'ATP5MC3',
#   'CACNA1C',
#   'PSEN1',
#   'CACNA1D',
#   'IRS4',
#   'PSEN2',
#   'AGER',
#   'COX7A1',
#   'CACNA1F',
#   'COX7A2',
#   'GPR83',
#   'ATP5MC1',
#   'ATP5MC2',
#   'UQCRH',
#   'CACNA1S',
#   'CYC1',
#   'MAP2K7',
#   'APAF1',
#   'EIF2AK2',
#   'AXIN2',
#   'AXIN1',
#   'EIF2AK3',
#   'WIPI1',
#   'NDUFC2',
#   'WIPI2',
#   'NDUFC1',
#   'TNFRSF1A',
#   'WNT16',
#   'IL6',
#   'NDUFS8',
#   'PIK3CB',
#   'CDK5',
#   'NDUFS7',
#   'PIK3CA',
#   'NDUFS6',
#   'NDUFS5',
#   'NDUFS4',
#   'NDUFS3',
#   'CYCS',
#   'NDUFS2',
#   'NDUFS1',
#   'PIK3C3',
#   'CYTB',
#   'MCU',
#   'PSMD11',
#   'RTN3',
#   'RTN4',
#   'GSK3B',
#   'NDUFB9',
#   'PSMD13',
#   'SLC25A4',
#   'NDUFB8',
#   'PSMD12',
#   'NDUFB7',
#   'NDUFB6',
#   'PSMD14',
#   'COX4I2',
#   'NDUFB5',
#   'NDUFB4',
#   'ITPR2',
#   'NDUFB3',
#   'ITPR3',
#   'NDUFB2',
#   'PIK3R4',
#   'NDUFB1',
#   'PIK3R3',
#   'PIK3R2',
#   'KLC2',
#   'KLC1',
#   'ITPR1',
#   'APH1B',
#   'WNT6',
#   'APH1A',
#   'CASP8',
#   'KLC4',
#   'WNT11',
#   'CASP9',
#   'KLC3',
#   'CASP7',
#   'DVL1',
#   'DVL2',
#   'DVL3',
#   'UQCRFS1',
#   'CASP3',
#   'COX4I1',
#   'NAE1',
#   'WNT1',
#   'WNT2',
#   'WNT3',
#   'WNT4',
#   'NDUFA9',
#   'NDUFA8',
#   'NDUFA7',
#   'NDUFA6',
#   'CHUK',
#   'NDUFA5',
#   'ADRM1',
#   'NDUFA4',
#   'NDUFA3',
#   'NDUFA2',
#   'NDUFA1',
#   'MTOR',
#   'UQCRHL',
#   'CSNK1A1L',
#   'DDIT3',
#   'VDAC3',
#   'VDAC2',
#   'KRAS',
#   'VDAC1',
#   'SLC25A6',
#   'SLC25A5',
#   'GAPDH',
#   'BECN1',
#   'BECN2',
#   'ATP2A3',
#   'RB1CC1',
#   'ATP2A2',
#   'PIK3CD',
#   'ATP2A1',
#   'AMBRA1',
#   'INS',
#   'HSD17B10',
#   'MAPK9',
#   'GRM5',
#   'MAPK8',
#   'MAPK3',
#   'MAPK1',
#   'NOS1',
#   'NOS2'],
#  'Amino sugar and nucleotide sugar metabolism': ['CHIA',
#   'GFPT1',
#   'PMM2',
#   'PMM1',
#   'GFPT2',
#   'RENBP',
#   'GCK',
#   'GALK1',
#   'CHIT1',
#   'GNPDA1',
#   'NAGK',
#   'UGDH',
#   'GALE',
#   'GNPDA2',
#   'FCSK',
#   'HKDC1',
#   'CYB5RL',
#   'GNE',
#   'GPI',
#   'GALT',
#   'CMAS',
#   'HEXA',
#   'MPI',
#   'HEXB',
#   'UXS1',
#   'NPL',
#   'UAP1',
#   'HK1',
#   'HK3',
#   'HK2',
#   'CYB5R3',
#   'NANP',
#   'CYB5R2',
#   'CYB5R4',
#   'NANS',
#   'UAP1L1',
#   'UGP2',
#   'AMDHD2',
#   'GMDS',
#   'GMPPA',
#   'FPGT',
#   'GMPPB',
#   'GNPNAT1',
#   'PGM3',
#   'GFUS',
#   'CYB5R1',
#   'PGM2',
#   'PGM1'],
#  'Aminoacyl-tRNA biosynthesis': ['HARS2',
#   'RARS1',
#   'HARS1',
#   'RARS2',
#   'QARS1',
#   'SARS1',
#   'GARS1',
#   'SARS2',
#   'PARS2',
#   'TARS3',
#   'TARS1',
#   'TARS2',
#   'AARS2',
#   'YARS1',
#   'KARS1',
#   'TRNS2',
#   'TRNS1',
#   'YARS2',
#   'IARS1',
#   'IARS2',
#   'AARS1',
#   'MARS1',
#   'TRNW',
#   'TRNV',
#   'TRNT',
#   'GATB',
#   'TRNR',
#   'MARS2',
#   'TRNQ',
#   'GATC',
#   'QRSL1',
#   'WARS1',
#   'DARS2',
#   'WARS2',
#   'DARS1',
#   'TRNY',
#   'TRNL1',
#   'TRNL2',
#   'EPRS1',
#   'LARS2',
#   'LARS1',
#   'CARS2',
#   'FARSB',
#   'FARSA',
#   'CARS1',
#   'MTFMT',
#   'FARS2',
#   'SEPSECS',
#   'TRNH',
#   'TRNG',
#   'TRNF',
#   'TRNE',
#   'NARS2',
#   'TRND',
#   'NARS1',
#   'TRNC',
#   'TRNA',
#   'TRNP',
#   'TRNN',
#   'TRNM',
#   'PSTK',
#   'TRNK',
#   'VARS1',
#   'EARS2',
#   'TRNI',
#   'VARS2'],
#  'Amoebiasis': ['TGFB1',
#   'TGFB3',
#   'TGFB2',
#   'ACTN4',
#   'IL1R1',
#   'IL1R2',
#   'ACTN1',
#   'IGH',
#   'COL1A2',
#   'COL1A1',
#   'RELA',
#   'ADCY1',
#   'CSF2',
#   'TNF',
#   'MUC2',
#   'PRKCG',
#   'PRKCB',
#   'PRKCA',
#   'NFKB1',
#   'PTK2',
#   'GNAL',
#   'PIK3R1',
#   'GNAQ',
#   'GNAS',
#   'RAB5A',
#   'RAB5B',
#   'VCL',
#   'CD1E',
#   'CD1D',
#   'CD1C',
#   'CD1B',
#   'CD1A',
#   'PRKACG',
#   'C9',
#   'PRDX1',
#   'IL12B',
#   'IL12A',
#   'CD14',
#   'PRKACB',
#   'PRKACA',
#   'IL10',
#   'LAMB4',
#   'LAMB3',
#   'FN1',
#   'LAMB2',
#   'LAMB1',
#   'TLR2',
#   'IL1B',
#   'COL3A1',
#   'IL6',
#   'PIK3CB',
#   'PIK3CA',
#   'IFNG',
#   'RAB7A',
#   'TLR4',
#   'RAB7B',
#   'CXCL8',
#   'RAB5C',
#   'LAMC1',
#   'C8A',
#   'CXCL2',
#   'LAMC3',
#   'PIK3R3',
#   'CXCL1',
#   'LAMC2',
#   'PIK3R2',
#   'C8B',
#   'CXCL3',
#   'HSPB1',
#   'C8G',
#   'CASP3',
#   'CTSG',
#   'SERPINB4',
#   'SERPINB3',
#   'ARG1',
#   'ARG2',
#   'SERPINB9',
#   'SERPINB6',
#   'COL4A1',
#   'PLCB4',
#   'COL4A3',
#   'COL4A2',
#   'COL4A5',
#   'COL4A4',
#   'COL4A6',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'ITGB2',
#   'SERPINB13',
#   'LAMA3',
#   'LAMA2',
#   'LAMA5',
#   'LAMA4',
#   'SERPINB10',
#   'LAMA1',
#   'PIK3CD',
#   'ITGAM',
#   'GNA14',
#   'GNA15',
#   'GNA11',
#   'NOS2'],
#  'Amphetamine addiction': ['JUN',
#   'GRIN2D',
#   'SIRT1',
#   'GRIN2C',
#   'PDYN',
#   'GRIN1',
#   'PPP1CA',
#   'PPP1CB',
#   'GRIN3A',
#   'GRIN3B',
#   'TH',
#   'CAMK4',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'STX1A',
#   'ATF2',
#   'CALML6',
#   'ATF6B',
#   'MAOB',
#   'MAOA',
#   'ADCY5',
#   'CALML3',
#   'CALML4',
#   'CALML5',
#   'PPP1CC',
#   'PPP3CA',
#   'CREB3L1',
#   'PPP3CB',
#   'PPP3CC',
#   'CREB3L4',
#   'CREB3L2',
#   'CREB3L3',
#   'DRD1',
#   'SLC18A1',
#   'SLC18A2',
#   'PRKCG',
#   'FOS',
#   'PRKCB',
#   'PRKCA',
#   'CREB3',
#   'ARC',
#   'CREB1',
#   'PPP1R1B',
#   'FOSB',
#   'GNAS',
#   'ATF4',
#   'CREB5',
#   'GRIA2',
#   'CAMK2D',
#   'GRIA3',
#   'DDC',
#   'GRIA1',
#   'HDAC1',
#   'HDAC2',
#   'CAMK2A',
#   'CAMK2B',
#   'CACNA1C',
#   'CACNA1D',
#   'SLC6A3',
#   'PPP3R1',
#   'PRKACG',
#   'GRIN2B',
#   'PPP3R2',
#   'GRIN2A',
#   'CAMK2G',
#   'PRKACB',
#   'GRIA4',
#   'PRKACA'],
#  'Amyotrophic lateral sclerosis': ['BAD',
#   'NUP214',
#   'NUP210',
#   'GRIN2D',
#   'ATG14',
#   'GRIN2C',
#   'ATG13',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'MAPK12',
#   'NUP93',
#   'PSMC6',
#   'CCS',
#   'NUP210L',
#   'NUP98',
#   'PSMC4',
#   'PSMC5',
#   'PSMC2',
#   'PSMC3',
#   'UQCRC2',
#   'BAX',
#   'PSMC1',
#   'UQCRC1',
#   'ULK2',
#   'ULK1',
#   'PFN2',
#   'PFN1',
#   'PFN4',
#   'TP53',
#   'OPTN',
#   'PFN3',
#   'NUP205',
#   'TUBAL3',
#   'UQCR10',
#   'UQCR11',
#   'NXF1',
#   'PSMD9',
#   'ACTB',
#   'NXF2',
#   'NXF3',
#   'PSMD7',
#   'PSMD8',
#   'PSMD6',
#   'NUP85',
#   'PSMD3',
#   'PSMD4',
#   'NRBF2',
#   'PSMD1',
#   'PSMD2',
#   'NUP88',
#   'NXF5',
#   'DNAH14',
#   'SIGMAR1',
#   'COX8A',
#   'DNAH12',
#   'GABARAPL2',
#   'COX8C',
#   'DAXX',
#   'DNAH11',
#   'GABARAPL1',
#   'XBP1',
#   'DNAH17',
#   'RAB39B',
#   'COX7A2L',
#   'SETX',
#   'ATG2B',
#   'ATG2A',
#   'HNRNPA1L2',
#   'ATF6',
#   'DNAH10',
#   'ATF4',
#   'GABARAP',
#   'POM121',
#   'C9ORF72',
#   'WDR41',
#   'DNALI1',
#   'GLE1',
#   'PPP3R1',
#   'GRIN2B',
#   'PPP3R2',
#   'GRIN2A',
#   'TBK1',
#   'POM121C',
#   'NUP62',
#   'COX3',
#   'COX2',
#   'COX1',
#   'SEC13',
#   'NDC1',
#   'TUBB',
#   'ATP5F1D',
#   'TUBB2A',
#   'ATP5F1E',
#   'COX6C',
#   'TOMM40L',
#   'TUBB2B',
#   'HAP1',
#   'ACTR10',
#   'COX7C',
#   'COX7B',
#   'ACTR1A',
#   'PPP3CA',
#   'PPP3CB',
#   'ACTR1B',
#   'PPP3CC',
#   'ATXN2',
#   'CASP12',
#   'ATG101',
#   'RANBP2',
#   'ATP5PF',
#   'ATP5PD',
#   'ATP5PB',
#   'ND4L',
#   'TUBB4B',
#   'COX6B1',
#   'TUBB4A',
#   'COX6B2',
#   'FIG4',
#   'PSMA6',
#   'PSMA7',
#   'PSMA4',
#   'PSMA5',
#   'HNRNPA2B1',
#   'PSMA2',
#   'PSMA3',
#   'NDUFAB1',
#   'NDUFA4L2',
#   'PSMA1',
#   'ATP5PO',
#   'COX5A',
#   'TOMM40',
#   'NDUFA12',
#   'NDUFA13',
#   'NDUFA10',
#   'NDUFA11',
#   'DERL1',
#   'NUP188',
#   'TUBA1A',
#   'COX5B',
#   'PSMA8',
#   'PSMB7',
#   'ATP5F1A',
#   'ATP5F1B',
#   'PSMB5',
#   'TUBA1C',
#   'ATP5F1C',
#   'PSMB6',
#   'TUBA1B',
#   'PSMB3',
#   'PSMB4',
#   'PSMB1',
#   'PSMB2',
#   'ANXA7',
#   'NEFL',
#   'NEFM',
#   'RAB8A',
#   'RAC1',
#   'NEFH',
#   'BID',
#   'ALYREF',
#   'SDHD',
#   'COX7B2',
#   'SDHB',
#   'SDHC',
#   'GRIN1',
#   'ERN1',
#   'SDHA',
#   'TUBA4A',
#   'TUBA8',
#   'ATXN2L',
#   'PINK1',
#   'UQCRQ',
#   'SRSF3',
#   'SQSTM1',
#   'SRSF7',
#   'TARDBP',
#   'RAB1A',
#   'PRKN',
#   'NDUFB11',
#   'NDUFB10',
#   'SLC1A2',
#   'TUBB1',
#   'TNF',
#   'COX6A2',
#   'TUBA3C',
#   'NUP160',
#   'NDUFC2-KCTD14',
#   'TANK',
#   'COX6A1',
#   'KIF5A',
#   'TUBB8',
#   'TUBA3E',
#   'TUBA3D',
#   'TUBB6',
#   'KIF5C',
#   'TUBB3',
#   'KIF5B',
#   'NDUFV3',
#   'RAE1',
#   'NDUFV2',
#   'MAP3K5',
#   'NDUFV1',
#   'MAP2K3',
#   'CHCHD10',
#   'NUP153',
#   'NUP155',
#   'TRAF2',
#   'EIF2S1',
#   'SEM1',
#   'BCL2L1',
#   'CHMP2B',
#   'DNAL1',
#   'ND2',
#   'ND1',
#   'DNAL4',
#   'ND4',
#   'RAB5A',
#   'ND3',
#   'ND6',
#   'ND5',
#   'NXF2B',
#   'GRIA2',
#   'GRIA1',
#   'VCP',
#   'ATP8',
#   'UQCRB',
#   'ATP6',
#   'ACTG1',
#   'ATP5MC3',
#   'COX7A1',
#   'COX7A2',
#   'ATP5MC1',
#   'ATP5MC2',
#   'UQCRH',
#   'TPR',
#   'CYC1',
#   'MAP2K6',
#   'GPX1',
#   'FUS',
#   'GPX3',
#   'GPX2',
#   'GPX5',
#   'APAF1',
#   'HSPA5',
#   'GPX7',
#   'GPX6',
#   'NCBP1',
#   'EIF2AK3',
#   'GPX8',
#   'NRG1',
#   'WIPI1',
#   'NDUFC2',
#   'NRG2',
#   'WIPI2',
#   'NDUFC1',
#   'NRG3',
#   'NUP133',
#   'TNFRSF1A',
#   'TNFRSF1B',
#   'NUP50',
#   'NDUFS8',
#   'NRG4',
#   'NDUFS7',
#   'NUP54',
#   'NDUFS6',
#   'NDUFS5',
#   'NDUFS4',
#   'BCL2',
#   'NDUFS3',
#   'NUP58',
#   'CYCS',
#   'NDUFS2',
#   'NDUFS1',
#   'PIK3C3',
#   'SMCR8',
#   'CYTB',
#   'MCU',
#   'PSMD11',
#   'DNAH5',
#   'DNAH2',
#   'NDUFB9',
#   'PSMD13',
#   'SEH1L',
#   'DNAH3',
#   'NDUFB8',
#   'PSMD12',
#   'DNAH8',
#   'NDUFB7',
#   'DNAH9',
#   'NDUFB6',
#   'PSMD14',
#   'COX4I2',
#   'DNAH6',
#   'NDUFB5',
#   'DNAH7',
#   'NDUFB4',
#   'NDUFB3',
#   'ITPR3',
#   'NDUFB2',
#   'PIK3R4',
#   'NDUFB1',
#   'KLC2',
#   'KLC1',
#   'KLC4',
#   'CASP9',
#   'KLC3',
#   'ERBB4',
#   'NUP43',
#   'UQCRFS1',
#   'CASP3',
#   'COX4I1',
#   'CASP1',
#   'DNAI1',
#   'PRPH',
#   'DNAI2',
#   'NDUFA9',
#   'NDUFA8',
#   'NDUFA7',
#   'NDUFA6',
#   'NDUFA5',
#   'ADRM1',
#   'NDUFA4',
#   'NDUFA3',
#   'NDUFA2',
#   'NDUFA1',
#   'ANXA11',
#   'MTOR',
#   'SOD1',
#   'UQCRHL',
#   'CAT',
#   'VAPB',
#   'ALS2',
#   'NUP35',
#   'ANG',
#   'DDIT3',
#   'MATR3',
#   'VDAC1',
#   'DNAH1',
#   'NUP37',
#   'POM121L2',
#   'BECN1',
#   'BECN2',
#   'DCTN6',
#   'HDAC6',
#   'NUP107',
#   'NXT1',
#   'NXT2',
#   'DCTN3',
#   'DCTN2',
#   'DCTN5',
#   'DCTN4',
#   'RB1CC1',
#   'DCTN1',
#   'AMBRA1',
#   'UBQLN2',
#   'UBQLN1',
#   'NOS1',
#   'NOS2',
#   'HNRNPA3',
#   'SPG11',
#   'UBQLN4',
#   'HNRNPA1',
#   'UBQLN3'],
#  'Antigen processing and presentation': ['CTSB',
#   'CD74',
#   'HSP90AA1',
#   'HSPA6',
#   'KLRC3',
#   'HSPA1L',
#   'HSPA5',
#   'KLRC4',
#   'HSPA8',
#   'HSPA2',
#   'TAP2',
#   'HSPA4',
#   'TAP1',
#   'TAPBP',
#   'CD4',
#   'RFX5',
#   'IFNG',
#   'HLA-DQB1',
#   'HLA-DRA',
#   'HSPA1A',
#   'KLRD1',
#   'CALR',
#   'HSPA1B',
#   'KIR2DL1',
#   'TNF',
#   'KIR2DL2',
#   'KIR2DL3',
#   'KIR2DL4',
#   'CTSS',
#   'CTSL',
#   'B2M',
#   'HLA-DOB',
#   'KIR2DL5A',
#   'CIITA',
#   'HLA-DQA2',
#   'HLA-DOA',
#   'HLA-DQA1',
#   'PDIA3',
#   'HLA-DRB5',
#   'KIR2DS1',
#   'KIR2DS2',
#   'NFYB',
#   'KIR2DS3',
#   'NFYC',
#   'KIR2DS4',
#   'KIR2DS5',
#   'HLA-C',
#   'CD8B2',
#   'KIR3DL1',
#   'RFXANK',
#   'HLA-A',
#   'KIR3DL2',
#   'HLA-B',
#   'KIR3DL3',
#   'HLA-G',
#   'HLA-E',
#   'HLA-F',
#   'CREB1',
#   'CD8B',
#   'CD8A',
#   'RFXAP',
#   'CANX',
#   'LGMN',
#   'PSME2',
#   'HLA-DPB1',
#   'PSME3',
#   'PSME1',
#   'HLA-DRB4',
#   'HLA-DRB3',
#   'HLA-DRB1',
#   'HSP90AB1',
#   'IFI30',
#   'HLA-DMB',
#   'HLA-DPA1',
#   'KLRC1',
#   'KLRC2',
#   'NFYA',
#   'HLA-DMA'],
#  'Apelin signaling pathway': ['BORCS8-MEF2B',
#   'RPS6',
#   'PRKAB1',
#   'PRKAB2',
#   'APLN',
#   'MYL2',
#   'MYL3',
#   'MYL4',
#   'AGTR1',
#   'APLNR',
#   'TFAM',
#   'CALM2',
#   'CALM3',
#   'ADCY10',
#   'CALM1',
#   'RAF1',
#   'PRKAA2',
#   'ADCY1',
#   'CALML6',
#   'SERPINE1',
#   'ADCY5',
#   'ADCY4',
#   'CALML3',
#   'UCP1',
#   'ADCY3',
#   'CALML4',
#   'ADCY2',
#   'CALML5',
#   'ADCY9',
#   'ADCY8',
#   'PRKAA1',
#   'ADCY7',
#   'SLC9A1',
#   'ADCY6',
#   'GNG2',
#   'NRAS',
#   'GNG4',
#   'GNG3',
#   'CCND1',
#   'GNG5',
#   'AKT3',
#   'CDH1',
#   'GNG8',
#   'GNG7',
#   'AKT1',
#   'AKT2',
#   'SPP1',
#   'CCN2',
#   'PPARGC1A',
#   'EGR1',
#   'SMAD3',
#   'SMAD2',
#   'GABARAPL2',
#   'JAG1',
#   'MAP2K2',
#   'GABARAPL1',
#   'SMAD4',
#   'MAP2K1',
#   'PRKCE',
#   'GNB1',
#   'GNB3',
#   'GNAQ',
#   'GNB2',
#   'GNB5',
#   'GNB4',
#   'NOTCH3',
#   'GABARAP',
#   'PLAT',
#   'MYLK',
#   'PRKACG',
#   'GNG11',
#   'LIPE',
#   'GNG10',
#   'PRKACB',
#   'PRKACA',
#   'SPHK2',
#   'SPHK1',
#   'GNG13',
#   'GNG12',
#   'TGFBR1',
#   'ACTA2',
#   'MRAS',
#   'PDE3B',
#   'CAMK4',
#   'PIK3C3',
#   'ITPR2',
#   'PIK3R5',
#   'ITPR3',
#   'PIK3R4',
#   'NRF1',
#   'ITPR1',
#   'PIK3R6',
#   'GNGT2',
#   'GNGT1',
#   'RRAS2',
#   'RRAS',
#   'MEF2B',
#   'MEF2A',
#   'MEF2D',
#   'MEF2C',
#   'NOS3',
#   'PLIN1',
#   'MTOR',
#   'KLF2',
#   'PLCB4',
#   'RPS6KB2',
#   'RPS6KB1',
#   'KRAS',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'BECN1',
#   'HDAC5',
#   'MYLK2',
#   'RYR2',
#   'BECN2',
#   'MYLK3',
#   'RYR3',
#   'HDAC4',
#   'RYR1',
#   'PRKAG2',
#   'PRKAG3',
#   'PRKAG1',
#   'GNAI1',
#   'SLC8A1',
#   'GNAI2',
#   'MYLK4',
#   'SLC8A2',
#   'GNAI3',
#   'PIK3CG',
#   'SLC8A3',
#   'GNA13',
#   'MAPK3',
#   'HRAS',
#   'MAPK1',
#   'NOS1',
#   'NOS2'],
#  'Apoptosis': ['ENDOG',
#   'BAD',
#   'ERN1',
#   'TUBA4A',
#   'TUBA8',
#   'MAPK10',
#   'FAS',
#   'BAX',
#   'TP53',
#   'RAF1',
#   'RELA',
#   'TUBAL3',
#   'TNF',
#   'TUBA3C',
#   'LMNA',
#   'ACTB',
#   'NRAS',
#   'BCL2L11',
#   'TUBA3E',
#   'TUBA3D',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'CAPN1',
#   'CAPN2',
#   'MAP3K5',
#   'NGFR',
#   'MAP2K2',
#   'DAXX',
#   'GADD45B',
#   'MAP2K1',
#   'GADD45A',
#   'GADD45G',
#   'TRAF1',
#   'TNFRSF10B',
#   'TNFRSF10A',
#   'TRAF2',
#   'NFKB1',
#   'EIF2S1',
#   'PIK3R1',
#   'BCL2L1',
#   'BIRC5',
#   'BIRC6',
#   'BIRC7',
#   'MAP3K14',
#   'BIRC2',
#   'ATF4',
#   'BIRC3',
#   'ACTG1',
#   'HTRA2',
#   'PRF1',
#   'FASLG',
#   'CSF2RB',
#   'TP53AIP1',
#   'PMAIP1',
#   'TNFSF10',
#   'CTSB',
#   'JUN',
#   'APAF1',
#   'CFLAR',
#   'EIF2AK3',
#   'PTPN13',
#   'IL3',
#   'TNFRSF1A',
#   'NFKBIA',
#   'PIK3CB',
#   'PIK3CA',
#   'IL3RA',
#   'ATM',
#   'BCL2',
#   'CYCS',
#   'HRK',
#   'DIABLO',
#   'BCL2A1',
#   'TRADD',
#   'CTSZ',
#   'ITPR2',
#   'LMNB1',
#   'ITPR3',
#   'PIK3R3',
#   'CTSW',
#   'PIK3R2',
#   'CTSV',
#   'CTSS',
#   'ITPR1',
#   'LMNB2',
#   'BBC3',
#   'SPTA1',
#   'CASP8',
#   'CASP9',
#   'CTSO',
#   'CASP12',
#   'CASP6',
#   'CASP7',
#   'CASP10',
#   'CTSL',
#   'CTSK',
#   'CASP2',
#   'CASP3',
#   'CTSH',
#   'FADD',
#   'RIPK1',
#   'BOK',
#   'CTSF',
#   'CTSD',
#   'MCL1',
#   'PIDD1',
#   'CTSC',
#   'DFFB',
#   'PARP4',
#   'DFFA',
#   'NTRK1',
#   'PARP2',
#   'CHUK',
#   'PARP3',
#   'GZMB',
#   'PDPK1',
#   'PARP1',
#   'FOS',
#   'SEPTIN4',
#   'NGF',
#   'DAB2IP',
#   'XIAP',
#   'DDIT3',
#   'KRAS',
#   'BECN1',
#   'BECN2',
#   'PIK3CD',
#   'TUBA1A',
#   'IKBKB',
#   'MAPK9',
#   'TUBA1C',
#   'MAPK8',
#   'TUBA1B',
#   'AIFM1',
#   'MAPK3',
#   'BAK1',
#   'HRAS',
#   'MAPK1',
#   'IKBKG',
#   'SPTAN1',
#   'BID'],
#  'Arachidonic acid metabolism': ['GPX1',
#   'GPX3',
#   'PLA2G2E',
#   'GPX2',
#   'PLA2G2F',
#   'GPX5',
#   'PLA2G2C',
#   'PTGES2',
#   'PLA2G2D',
#   'PTGES3',
#   'GPX7',
#   'PLA2G2A',
#   'GPX6',
#   'GPX8',
#   'CYP2C9',
#   'CYP2C8',
#   'CYP2U1',
#   'ALOX15',
#   'ALOX12',
#   'ALOX12B',
#   'HPGDS',
#   'ALOX5',
#   'PTGDS',
#   'CBR3',
#   'GGT5',
#   'PLA2G12A',
#   'CBR1',
#   'PLA2G12B',
#   'PTGIS',
#   'PLA2G4E',
#   'CYP4F2',
#   'PLA2G4F',
#   'CYP4F3',
#   'PLA2G4C',
#   'EPHX2',
#   'PLA2G4D',
#   'PLA2G4A',
#   'AKR1C3',
#   'PLA2G4B',
#   'CYP4F8',
#   'PLAAT3',
#   'ALOX15B',
#   'PRXL2B',
#   'PLA2G10',
#   'TBXAS1',
#   'JMJD7-PLA2G4B',
#   'CYP2E1',
#   'PTGES',
#   'PLA2G1B',
#   'PLA2G3',
#   'PLA2G5',
#   'PLA2G6',
#   'CYP2C19',
#   'PTGS1',
#   'LTC4S',
#   'PLB1',
#   'PTGS2',
#   'CYP2B6',
#   'LTA4H',
#   'GGT1',
#   'CYP2J2'],
#  'Arginine and proline metabolism': ['GAMT',
#   'AOC1',
#   'CKM',
#   'CKMT1B',
#   'CKMT1A',
#   'PYCR1',
#   'PYCR2',
#   'PYCR3',
#   'PRODH2',
#   'DAO',
#   'ALDH4A1',
#   'P4HA1',
#   'LAP3',
#   'P4HA2',
#   'P4HA3',
#   'ALDH18A1',
#   'GOT1L1',
#   'MAOB',
#   'AMD1',
#   'MAOA',
#   'ODC1',
#   'CNDP1',
#   'CNDP2',
#   'L3HYPDH',
#   'ARG1',
#   'GOT2',
#   'NOS3',
#   'SMOX',
#   'ARG2',
#   'GOT1',
#   'AGMAT',
#   'AZIN2',
#   'ALDH3A2',
#   'ALDH7A1',
#   'GATM',
#   'HOGA1',
#   'SMS',
#   'ALDH9A1',
#   'OAT',
#   'SAT1',
#   'SRM',
#   'SAT2',
#   'CKMT2',
#   'ALDH1B1',
#   'ALDH2',
#   'CARNS1',
#   'CKB',
#   'NOS1',
#   'NOS2',
#   'PRODH'],
#  'Arginine biosynthesis': ['GOT1L1',
#   'ABHD14A-ACY1',
#   'GLS2',
#   'ARG1',
#   'GOT2',
#   'NOS3',
#   'ARG2',
#   'GOT1',
#   'ACY1',
#   'GPT2',
#   'GPT',
#   'GLS',
#   'GLUD1',
#   'ASS1',
#   'GLUD2',
#   'CPS1',
#   'ASL',
#   'GLUL',
#   'NAGS',
#   'NOS1',
#   'NOS2',
#   'OTC'],
#  'Arrhythmogenic right ventricular cardiomyopathy': ['ITGA1',
#   'ITGA5',
#   'ACTN3',
#   'ITGA4',
#   'JUP',
#   'ACTN2',
#   'CACNA2D2',
#   'ITGA3',
#   'CACNA2D1',
#   'ITGA2',
#   'CACNA2D4',
#   'CACNA2D3',
#   'DES',
#   'ITGA10',
#   'ITGA11',
#   'ITGA9',
#   'DSG2',
#   'ITGA8',
#   'PKP2',
#   'ITGA7',
#   'ITGA6',
#   'DSC2',
#   'LEF1',
#   'ITGA2B',
#   'LMNA',
#   'ACTB',
#   'CDH2',
#   'DAG1',
#   'EMD',
#   'DSP',
#   'TCF7L2',
#   'TCF7L1',
#   'CACNB2',
#   'CACNB3',
#   'CACNB4',
#   'TCF7',
#   'CACNB1',
#   'RYR2',
#   'ITGB1',
#   'ITGB6',
#   'ITGB5',
#   'LAMA2',
#   'CTNNB1',
#   'ITGB4',
#   'ITGB3',
#   'ACTG1',
#   'CACNA1C',
#   'ATP2A3',
#   'ATP2A2',
#   'LAMA1',
#   'ATP2A1',
#   'CACNA1D',
#   'CACNA1F',
#   'SLC8A1',
#   'SLC8A2',
#   'SLC8A3',
#   'CACNG7',
#   'CACNG8',
#   'SGCG',
#   'SGCD',
#   'GJA1',
#   'SGCB',
#   'SGCA',
#   'CACNA1S',
#   'CTNNA2',
#   'CTNNA1',
#   'CACNG1',
#   'ITGB8',
#   'CACNG2',
#   'CTNNA3',
#   'DMD',
#   'ITGAV',
#   'ITGB7',
#   'CACNG3',
#   'CACNG4',
#   'CACNG5',
#   'CACNG6'],
#  'Ascorbate and aldarate metabolism': ['KL',
#   'MIOX',
#   'UGT2B11',
#   'UGT2B10',
#   'UGT2A1',
#   'UGT2B15',
#   'UGT1A1',
#   'UGT2B17',
#   'AKR1A1',
#   'ALDH3A2',
#   'ALDH7A1',
#   'UGDH',
#   'RGN',
#   'UGT2B4',
#   'ALDH9A1',
#   'UGT2B7',
#   'UGT1A10',
#   'UGT2B28',
#   'ALDH1B1',
#   'ALDH2',
#   'UGT1A6',
#   'UGT1A5',
#   'UGT1A4',
#   'UGT2A3',
#   'UGT1A3',
#   'UGT2A2',
#   'GUSB',
#   'UGT1A9',
#   'UGT1A8',
#   'UGT1A7'],
#  'Asthma': ['HLA-DRB5',
#   'IL10',
#   'IL13',
#   'IGH',
#   'PRG2',
#   'RNASE3',
#   'IL3',
#   'IL5',
#   'IL4',
#   'IL9',
#   'HLA-DQB1',
#   'HLA-DRA',
#   'HLA-DPB1',
#   'CD40LG',
#   'HLA-DRB4',
#   'HLA-DRB3',
#   'MS4A2',
#   'HLA-DRB1',
#   'CD40',
#   'CCL11',
#   'TNF',
#   'EPX',
#   'HLA-DMB',
#   'HLA-DPA1',
#   'FCER1A',
#   'FCER1G',
#   'HLA-DOB',
#   'HLA-DMA',
#   'HLA-DQA2',
#   'HLA-DOA',
#   'HLA-DQA1'],
#  'Autoimmune thyroid disease': ['IL10',
#   'IGH',
#   'IL2',
#   'IL5',
#   'IL4',
#   'TG',
#   'FAS',
#   'HLA-DQB1',
#   'HLA-DRA',
#   'CD28',
#   'CD86',
#   'CD40',
#   'CD80',
#   'CTLA4',
#   'HLA-DOB',
#   'HLA-DQA2',
#   'HLA-DOA',
#   'HLA-DQA1',
#   'IFNA13',
#   'IFNA14',
#   'HLA-DRB5',
#   'IFNA16',
#   'IFNA17',
#   'GZMB',
#   'HLA-C',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'HLA-E',
#   'HLA-F',
#   'TSHR',
#   'HLA-DPB1',
#   'CD40LG',
#   'HLA-DRB4',
#   'HLA-DRB3',
#   'IFNA10',
#   'HLA-DRB1',
#   'IFNA6',
#   'IFNA5',
#   'IFNA8',
#   'IFNA7',
#   'IFNA2',
#   'IFNA1',
#   'IFNA4',
#   'PRF1',
#   'FASLG',
#   'HLA-DMB',
#   'TPO',
#   'HLA-DPA1',
#   'CGA',
#   'HLA-DMA',
#   'IFNA21',
#   'TSHB'],
#  'Autophagy': ['ATG9A',
#   'UVRAG',
#   'SH3GLB1',
#   'BAD',
#   'ATG9B',
#   'ATG10',
#   'TSC2',
#   'TSC1',
#   'ATG14',
#   'ATG13',
#   'ATG12',
#   'ERN1',
#   'RRAGB',
#   'MAPK10',
#   'RRAGA',
#   'RRAGD',
#   'ATG16L2',
#   'RRAGC',
#   'ATG16L1',
#   'ULK2',
#   'ULK1',
#   'SQSTM1',
#   'RAF1',
#   'RAB1A',
#   'MTMR3',
#   'PRKAA2',
#   'MTMR4',
#   'STX17',
#   'ZFYVE1',
#   'PRKAA1',
#   'TANK',
#   'NRAS',
#   'PRAP1',
#   'LAMP2',
#   'LAMP1',
#   'AKT3',
#   'TP53INP2',
#   'AKT1',
#   'NRBF2',
#   'AKT2',
#   'MAP3K7',
#   'ATG3',
#   'GABARAPL2',
#   'MAP2K2',
#   'GABARAPL1',
#   'PRKCD',
#   'MAP2K1',
#   'RAB39B',
#   'EIF2S1',
#   'VAMP8',
#   'PIK3R1',
#   'RHEB',
#   'TRAF6',
#   'ATG2B',
#   'BCL2L1',
#   'ATG2A',
#   'PRKCQ',
#   'GABARAP',
#   'C9ORF72',
#   'IRS1',
#   'IRS2',
#   'IRS4',
#   'WDR41',
#   'HIF1A',
#   'IGF1R',
#   'PRKACG',
#   'STK11',
#   'TBK1',
#   'MLST8',
#   'ATG7',
#   'PRKACB',
#   'SUPT20H',
#   'ATG5',
#   'PRKACA',
#   'CTSB',
#   'RUBCN',
#   'CFLAR',
#   'EIF2AK4',
#   'EIF2AK3',
#   'WIPI1',
#   'WIPI2',
#   'RAB33B',
#   'MRAS',
#   'PIK3CB',
#   'PIK3CA',
#   'AKT1S1',
#   'ATG4D',
#   'ATG4C',
#   'BCL2',
#   'ATG4B',
#   'ATG4A',
#   'PIK3C3',
#   'SMCR8',
#   'RAB7A',
#   'RAB7B',
#   'PIK3R4',
#   'HMGB1',
#   'PIK3R3',
#   'PIK3R2',
#   'ITPR1',
#   'ATG101',
#   'CTSL',
#   'RRAS2',
#   'RRAS',
#   'SNAP29',
#   'CTSD',
#   'IGBP1',
#   'DAPK2',
#   'DAPK1',
#   'PDPK1',
#   'DAPK3',
#   'MTOR',
#   'PPP2CA',
#   'RPS6KB2',
#   'RPS6KB1',
#   'DDIT4',
#   'KRAS',
#   'VMP1',
#   'BECN1',
#   'BECN2',
#   'MTMR14',
#   'PTEN',
#   'RB1CC1',
#   'PIK3CD',
#   'AMBRA1',
#   'INS',
#   'CAMKK2',
#   'PPP2CB',
#   'RPTOR',
#   'MAPK9',
#   'MAPK8',
#   'MAPK3',
#   'BNIP3',
#   'RAB8A',
#   'HRAS',
#   'MAPK1',
#   'DEPTOR'],
#  'Axon guidance': ['EPHA6',
#   'SEMA4A',
#   'EPHA5',
#   'SEMA4B',
#   'EPHA8',
#   'RYK',
#   'EPHA7',
#   'PLXNC1',
#   'SEMA4F',
#   'SEMA4C',
#   'WNT5A',
#   'SEMA4D',
#   'WNT5B',
#   'SEMA4G',
#   'BUB1B-PAK6',
#   'L1CAM',
#   'MYL5',
#   'CXCL12',
#   'PLXNB3',
#   'PLXNB2',
#   'PLXNB1',
#   'EPHA2',
#   'MYL9',
#   'EPHA1',
#   'NGEF',
#   'EPHA4',
#   'EPHA3',
#   'RAF1',
#   'SEMA5B',
#   'ROCK1',
#   'SEMA5A',
#   'ROCK2',
#   'NTN1',
#   'EFNA5',
#   'MYL12B',
#   'NTN3',
#   'PARD6G',
#   'NTN4',
#   'EFNB3',
#   'PARD6A',
#   'ABLIM1',
#   'DPYSL2',
#   'EFNB2',
#   'NRAS',
#   'ABLIM2',
#   'PAK2',
#   'ABLIM3',
#   'PAK1',
#   'PARD6B',
#   'DPYSL5',
#   'EFNB1',
#   'CFL2',
#   'CFL1',
#   'SLIT2',
#   'SLIT1',
#   'SLIT3',
#   'PAK4',
#   'PAK3',
#   'PAK6',
#   'PAK5',
#   'ARHGEF12',
#   'NTNG2',
#   'SEMA6C',
#   'SEMA6D',
#   'SEMA6A',
#   'TRPC6',
#   'FZD3',
#   'NTNG1',
#   'SEMA6B',
#   'TRPC4',
#   'TRPC5',
#   'TRPC3',
#   'PARD3',
#   'PRKCA',
#   'GDF7',
#   'SSH3',
#   'SSH1',
#   'PTK2',
#   'SSH2',
#   'EFNA2',
#   'EFNA1',
#   'MYL12A',
#   'EFNA4',
#   'PRKCZ',
#   'EFNA3',
#   'PIK3R1',
#   'SMO',
#   'PPP3R1',
#   'PPP3R2',
#   'RGS3',
#   'PLXNA3',
#   'PLXNA2',
#   'PLCG1',
#   'PLXNA1',
#   'ABL1',
#   'PLCG2',
#   'SRGAP3',
#   'SEMA7A',
#   'SRGAP2',
#   'SRGAP1',
#   'LRRC4C',
#   'PLXNA4',
#   'RHOA',
#   'LIMK1',
#   'LIMK2',
#   'NFATC4',
#   'NFATC3',
#   'PTCH1',
#   'PTPN11',
#   'NFATC2',
#   'RHOD',
#   'BMP7',
#   'RGMA',
#   'ENAH',
#   'RASA1',
#   'FES',
#   'PIK3CB',
#   'CDK5',
#   'PIK3CA',
#   'BMPR1B',
#   'BMPR2',
#   'GSK3B',
#   'ILK',
#   'LRRC4',
#   'PIK3R3',
#   'PIK3R2',
#   'PPP3CA',
#   'PPP3CB',
#   'PPP3CC',
#   'SHH',
#   'BOC',
#   'RRAS',
#   'TRPC1',
#   'WNT4',
#   'DCC',
#   'UNC5B',
#   'UNC5C',
#   'PDPK1',
#   'UNC5A',
#   'UNC5D',
#   'CDC42',
#   'MET',
#   'KRAS',
#   'NRP1',
#   'ROBO3',
#   'CAMK2D',
#   'EPHB6',
#   'ITGB1',
#   'SEMA3A',
#   'SRC',
#   'SEMA3D',
#   'SEMA3E',
#   'CAMK2A',
#   'SEMA3B',
#   'CAMK2B',
#   'SEMA3C',
#   'PIK3CD',
#   'SEMA3F',
#   'SEMA3G',
#   'GNAI1',
#   'GNAI2',
#   'RND1',
#   'ROBO1',
#   'GNAI3',
#   'ROBO2',
#   'CXCR4',
#   'LRIG2',
#   'MAPK3',
#   'RAC3',
#   'EPHB1',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'FYN',
#   'RAC2',
#   'CAMK2G',
#   'EPHB3',
#   'NEO1',
#   'EPHB2',
#   'NCK1',
#   'EPHB4',
#   'NCK2'],
#  'B cell receptor signaling pathway': ['LYN',
#   'JUN',
#   'CD72',
#   'IGH',
#   'LILRB1',
#   'NFATC3',
#   'LILRB2',
#   'NFATC2',
#   'LILRB3',
#   'NFATC1',
#   'LILRB4',
#   'LILRB5',
#   'VAV1',
#   'VAV2',
#   'VAV3',
#   'NFKBIB',
#   'NFKBIA',
#   'FCGR2B',
#   'PIK3CB',
#   'PIK3CA',
#   'SOS2',
#   'NFKBIE',
#   'PTPN6',
#   'CD22',
#   'RAF1',
#   'SOS1',
#   'RELA',
#   'GSK3B',
#   'IFITM1',
#   'CD81',
#   'PIK3R3',
#   'INPPL1',
#   'PIK3R2',
#   'PPP3CA',
#   'NRAS',
#   'PPP3CB',
#   'PPP3CC',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'BLNK',
#   'CARD11',
#   'MAP2K2',
#   'CR2',
#   'CHUK',
#   'MAP2K1',
#   'SYK',
#   'FOS',
#   'PRKCB',
#   'NFKB1',
#   'PIK3R1',
#   'BTK',
#   'GRB2',
#   'KRAS',
#   'PIK3AP1',
#   'BCL10',
#   'LILRA1',
#   'PIK3CD',
#   'LILRA2',
#   'LILRA3',
#   'RASGRP3',
#   'LILRA4',
#   'DAPP1',
#   'LILRA5',
#   'LILRA6',
#   'MALT1',
#   'CD79B',
#   'IKBKB',
#   'INPP5D',
#   'PPP3R1',
#   'CD79A',
#   'PPP3R2',
#   'CD19',
#   'MAPK3',
#   'RAC3',
#   'HRAS',
#   'MAPK1',
#   'RAC1',
#   'PLCG2',
#   'RAC2',
#   'IKBKG'],
#  'Bacterial invasion of epithelial cells': ['ACTR3',
#   'RHOA',
#   'ACTR2',
#   'ITGA5',
#   'CAV3',
#   'CAV2',
#   'CAV1',
#   'FN1',
#   'GAB1',
#   'RHOG',
#   'DNM1',
#   'DNM2',
#   'DNM3',
#   'PIK3CB',
#   'PIK3CA',
#   'ELMO1',
#   'ELMO2',
#   'ELMO3',
#   'DOCK1',
#   'BCAR1',
#   'MAD2L2',
#   'ARPC1A',
#   'SHC3',
#   'SHC4',
#   'SHC1',
#   'SHC2',
#   'ILK',
#   'ARPC1B',
#   'CLTC',
#   'ARPC5L',
#   'CLTB',
#   'CLTA',
#   'PIK3R3',
#   'PIK3R2',
#   'SEPTIN12',
#   'SEPTIN11',
#   'CD2AP',
#   'CRKL',
#   'ACTB',
#   'CDH1',
#   'CLTCL1',
#   'WASF1',
#   'WASF2',
#   'SEPTIN2',
#   'SEPTIN3',
#   'SEPTIN1',
#   'SEPTIN6',
#   'ARPC5',
#   'SEPTIN8',
#   'CDC42',
#   'PTK2',
#   'SEPTIN9',
#   'ARHGAP10',
#   'ARPC3',
#   'PIK3R1',
#   'ARPC4',
#   'CTTN',
#   'ARPC2',
#   'HCLS1',
#   'CRK',
#   'MET',
#   'VCL',
#   'ITGB1',
#   'SRC',
#   'PXN',
#   'ARHGEF26',
#   'CTNNB1',
#   'ACTG1',
#   'PIK3CD',
#   'WASL',
#   'ACTR3B',
#   'ACTR3C',
#   'CBL',
#   'CTNNA2',
#   'CTNNA1',
#   'RAC1',
#   'CTNNA3'],
#  'Basal cell carcinoma': ['PTCH2',
#   'WNT5A',
#   'WNT5B',
#   'AXIN2',
#   'AXIN1',
#   'PTCH1',
#   'WNT9A',
#   'WNT9B',
#   'KIF7',
#   'WNT16',
#   'BMP4',
#   'APC',
#   'BMP2',
#   'BAX',
#   'TP53',
#   'LEF1',
#   'GSK3B',
#   'WNT8B',
#   'FZD10',
#   'WNT8A',
#   'WNT6',
#   'WNT11',
#   'SHH',
#   'DVL1',
#   'DVL2',
#   'DVL3',
#   'WNT1',
#   'WNT2',
#   'WNT3',
#   'WNT4',
#   'FZD2',
#   'FZD1',
#   'FZD4',
#   'TCF7L2',
#   'WNT10B',
#   'APC2',
#   'FZD3',
#   'TCF7L1',
#   'WNT10A',
#   'FZD6',
#   'WNT3A',
#   'FZD5',
#   'GADD45B',
#   'FZD8',
#   'GADD45A',
#   'FZD7',
#   'GADD45G',
#   'WNT7A',
#   'FZD9',
#   'WNT7B',
#   'DDB2',
#   'SMO',
#   'TCF7',
#   'WNT2B',
#   'CDKN1A',
#   'CTNNB1',
#   'HHIP',
#   'GLI2',
#   'GLI1',
#   'GLI3',
#   'SUFU',
#   'POLK',
#   'BAK1'],
#  'Basal transcription factors': ['GTF2H2C_2',
#   'TBP',
#   'GTF2A1L',
#   'TAF15',
#   'TAF13',
#   'TAF11',
#   'TAF12',
#   'GTF2H1',
#   'TAF10',
#   'GTF2H2',
#   'GTF2F1',
#   'GTF2H3',
#   'GTF2F2',
#   'GTF2H4',
#   'GTF2H5',
#   'TAF1',
#   'TAF6L',
#   'CDK7',
#   'ERCC2',
#   'ERCC3',
#   'TAF4B',
#   'TAF9',
#   'TBPL1',
#   'TAF8',
#   'TBPL2',
#   'TAF7',
#   'GTF2IRD1',
#   'TAF6',
#   'GTF2H2C',
#   'TAF5',
#   'MNAT1',
#   'TAF4',
#   'TAF3',
#   'TAF2',
#   'GTF2A1',
#   'GTF2I',
#   'GTF2A2',
#   'CCNH',
#   'GTF2B',
#   'GTF2E1',
#   'GTF2E2',
#   'TAF1L',
#   'TAF5L',
#   'TAF7L',
#   'TAF9B'],
#  'Base excision repair': ['MBD4',
#   'PARP4',
#   'PARP2',
#   'LIG1',
#   'PARP3',
#   'PARP1',
#   'XRCC1',
#   'LIG3',
#   'SMUG1',
#   'NEIL3',
#   'POLE2',
#   'APEX2',
#   'POLE3',
#   'APEX1',
#   'POLE4',
#   'NEIL2',
#   'NEIL1',
#   'PCNA',
#   'FEN1',
#   'MPG',
#   'OGG1',
#   'HMGB1',
#   'UNG',
#   'POLD4',
#   'POLB',
#   'POLE',
#   'NTHL1',
#   'POLD1',
#   'POLD2',
#   'POLD3',
#   'TDG',
#   'POLL',
#   'MUTYH'],
#  'Bile secretion': ['ABCC4',
#   'ABCG8',
#   'ABCC2',
#   'ABCC3',
#   'SLC10A1',
#   'UGT2A1',
#   'SLC10A2',
#   'ATP1B4',
#   'SLC51A',
#   'SLCO1B7',
#   'ATP1B3',
#   'SLC51B',
#   'ATP1B2',
#   'ATP1B1',
#   'SLC9A3',
#   'FXYD2',
#   'ABCG5',
#   'SLC22A8',
#   'ABCG2',
#   'UGT1A10',
#   'ABCB4',
#   'ABCB1',
#   'SCT',
#   'ADCY1',
#   'AQP9',
#   'ADCY5',
#   'ADCY4',
#   'AQP8',
#   'ATP1A4',
#   'ADCY3',
#   'ATP1A3',
#   'SLC5A1',
#   'ADCY2',
#   'ATP1A2',
#   'CYP3A4',
#   'ADCY9',
#   'ATP1A1',
#   'CYP7A1',
#   'ADCY8',
#   'AQP4',
#   'ADCY7',
#   'AQP1',
#   'SLC9A1',
#   'ADCY6',
#   'SLCO1B1',
#   'SULT2A1',
#   'CA2',
#   'RXRA',
#   'SLCO1B3',
#   'UGT2A3',
#   'UGT2A2',
#   'LDLR',
#   'UGT2B11',
#   'UGT2B10',
#   'EPHX1',
#   'UGT2B15',
#   'UGT1A1',
#   'UGT2B17',
#   'NR1H4',
#   'NR0B2',
#   'SCTR',
#   'BAAT',
#   'NCEH1',
#   'ABCB11',
#   'SLCO1A2',
#   'GNAS',
#   'UGT2B4',
#   'CFTR',
#   'SLC27A5',
#   'UGT2B7',
#   'SLC22A7',
#   'SLC22A1',
#   'UGT2B28',
#   'SLC2A1',
#   'HMGCR',
#   'SLC4A2',
#   'SLC4A4',
#   'SLC4A5',
#   'PRKACG',
#   'UGT1A6',
#   'KCNN2',
#   'UGT1A5',
#   'UGT1A4',
#   'UGT1A3',
#   'PRKACB',
#   'UGT1A9',
#   'SCARB1',
#   'UGT1A8',
#   'PRKACA',
#   'UGT1A7'],
#  'Biosynthesis of unsaturated fatty acids': ['ELOVL1',
#   'ELOVL2',
#   'ELOVL5',
#   'ELOVL6',
#   'ELOVL3',
#   'SCD5',
#   'ELOVL4',
#   'ELOVL7',
#   'BAAT',
#   'SCD',
#   'ACOX3',
#   'ACOX1',
#   'TECR',
#   'ACOT2',
#   'ACOT1',
#   'ACOT7',
#   'ACOT4',
#   'HACD2',
#   'HACD1',
#   'HSD17B4',
#   'HACD4',
#   'HSD17B12',
#   'HACD3',
#   'SCP2',
#   'ACAA1',
#   'FADS2',
#   'FADS1'],
#  'Bladder cancer': ['EGF',
#   'MAP2K2',
#   'CDKN2A',
#   'DAPK2',
#   'MMP1',
#   'DAPK1',
#   'MAP2K1',
#   'MMP2',
#   'DAPK3',
#   'BRAF',
#   'MMP9',
#   'UPK3A',
#   'VEGFA',
#   'CDK4',
#   'KRAS',
#   'HBEGF',
#   'FGFR3',
#   'TP53',
#   'MDM2',
#   'RAF1',
#   'CXCL8',
#   'TYMP',
#   'RB1',
#   'SRC',
#   'CDKN1A',
#   'THBS1',
#   'ARAF',
#   'EGFR',
#   'RPS6KA5',
#   'NRAS',
#   'RASSF1',
#   'CCND1',
#   'CDH1',
#   'ERBB2',
#   'E2F1',
#   'MYC',
#   'E2F2',
#   'MAPK3',
#   'E2F3',
#   'HRAS',
#   'MAPK1'],
#  'Breast cancer': ['EGF',
#   'WNT5A',
#   'WNT5B',
#   'APC',
#   'BAX',
#   'TP53',
#   'RAF1',
#   'LEF1',
#   'RB1',
#   'LRP6',
#   'LRP5',
#   'FZD10',
#   'ARAF',
#   'DLL1',
#   'EGFR',
#   'DLL3',
#   'DLL4',
#   'FRAT1',
#   'NRAS',
#   'FRAT2',
#   'CCND1',
#   'AKT3',
#   'E2F1',
#   'MYC',
#   'AKT1',
#   'E2F2',
#   'FGF21',
#   'AKT2',
#   'E2F3',
#   'FGF20',
#   'HES1',
#   'FGF23',
#   'FGF22',
#   'HES5',
#   'FZD2',
#   'FZD1',
#   'FZD4',
#   'JAG1',
#   'MAP2K2',
#   'WNT10B',
#   'FZD3',
#   'JAG2',
#   'WNT10A',
#   'FZD6',
#   'WNT3A',
#   'FZD5',
#   'GADD45B',
#   'MAP2K1',
#   'FZD8',
#   'GADD45A',
#   'FZD7',
#   'GADD45G',
#   'FZD9',
#   'IGF1',
#   'ESR1',
#   'ESR2',
#   'NFKB2',
#   'FGF18',
#   'FGF17',
#   'FGF16',
#   'PIK3R1',
#   'FGF19',
#   'FGF10',
#   'FGFR1',
#   'TCF7',
#   'GRB2',
#   'PGR',
#   'NOTCH3',
#   'NOTCH4',
#   'NOTCH1',
#   'WNT2B',
#   'NOTCH2',
#   'FGF1',
#   'FGF2',
#   'FGF3',
#   'FGF4',
#   'IGF1R',
#   'FGF5',
#   'FGF6',
#   'FGF7',
#   'FGF8',
#   'FGF9',
#   'TNFSF11',
#   'NCOA3',
#   'CSNK1A1',
#   'JUN',
#   'NCOA1',
#   'AXIN2',
#   'AXIN1',
#   'WNT9A',
#   'BRAF',
#   'WNT9B',
#   'WNT16',
#   'SP1',
#   'CDK6',
#   'PIK3CB',
#   'PIK3CA',
#   'CDK4',
#   'SOS2',
#   'SOS1',
#   'GSK3B',
#   'SHC3',
#   'SHC4',
#   'SHC1',
#   'SHC2',
#   'WNT8B',
#   'BRCA1',
#   'PIK3R3',
#   'BRCA2',
#   'PIK3R2',
#   'WNT8A',
#   'WNT6',
#   'WNT11',
#   'DVL1',
#   'ERBB2',
#   'DVL2',
#   'DVL3',
#   'WNT1',
#   'WNT2',
#   'WNT3',
#   'WNT4',
#   'TCF7L2',
#   'APC2',
#   'TCF7L1',
#   'FOS',
#   'WNT7A',
#   'WNT7B',
#   'MTOR',
#   'HEYL',
#   'DDB2',
#   'CSNK1A1L',
#   'KIT',
#   'RPS6KB2',
#   'RPS6KB1',
#   'KRAS',
#   'CDKN1A',
#   'FLT4',
#   'CTNNB1',
#   'PTEN',
#   'PIK3CD',
#   'HEY2',
#   'HEY1',
#   'MAPK3',
#   'POLK',
#   'BAK1',
#   'HRAS',
#   'MAPK1'],
#  'Butanoate metabolism': ['HMGCS2',
#   'HMGCS1',
#   'GAD2',
#   'GAD1',
#   'ALDH5A1',
#   'BDH2',
#   'BDH1',
#   'HADHA',
#   'L2HGDH',
#   'HMGCLL1',
#   'ACSM4',
#   'ACSM3',
#   'ACSM1',
#   'ACAT1',
#   'ACSM2A',
#   'ACSM2B',
#   'EHHADH',
#   'ACSM6',
#   'ACSM5',
#   'ECHS1',
#   'ABAT',
#   'ACAT2',
#   'HMGCL',
#   'AACS',
#   'OXCT1',
#   'OXCT2',
#   'HADH',
#   'ACADS'],
#  'C-type lectin receptor signaling pathway': ['MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'MAPK12',
#   'CLEC4D',
#   'CLEC4E',
#   'MAPK10',
#   'IL23A',
#   'CD209',
#   'MAPKAPK2',
#   'CLEC4M',
#   'CALM2',
#   'CALM3',
#   'CALM1',
#   'RAF1',
#   'RELA',
#   'CALML6',
#   'CALML3',
#   'CALML4',
#   'TNF',
#   'CALML5',
#   'CBLB',
#   'RELB',
#   'NRAS',
#   'PYCARD',
#   'PAK1',
#   'AKT3',
#   'AKT1',
#   'NLRP3',
#   'AKT2',
#   'ARHGEF12',
#   'EGR2',
#   'EGR3',
#   'PRKCD',
#   'PLK3',
#   'NFKB1',
#   'NFKB2',
#   'PIK3R1',
#   'CLEC6A',
#   'MAP3K14',
#   'MDM2',
#   'BCL10',
#   'PPP3R1',
#   'PPP3R2',
#   'IL12B',
#   'IL12A',
#   'PLCG2',
#   'RHOA',
#   'IL10',
#   'JUN',
#   'CCL22',
#   'KSR1',
#   'CARD9',
#   'NFATC4',
#   'NFATC3',
#   'PTPN11',
#   'NFATC2',
#   'NFATC1',
#   'IL2',
#   'IL1B',
#   'IRF1',
#   'NFKBIA',
#   'CYLD',
#   'MRAS',
#   'IL6',
#   'PIK3CB',
#   'PIK3CA',
#   'BCL3',
#   'IRF9',
#   'ITPR2',
#   'ITPR3',
#   'PIK3R3',
#   'PIK3R2',
#   'ITPR1',
#   'PPP3CA',
#   'PPP3CB',
#   'CASP8',
#   'PPP3CC',
#   'CLEC7A',
#   'RRAS2',
#   'RRAS',
#   'CASP1',
#   'FCER1G',
#   'STAT1',
#   'CHUK',
#   'STAT2',
#   'SYK',
#   'KRAS',
#   'IL17D',
#   'SRC',
#   'LSP1',
#   'PIK3CD',
#   'MALT1',
#   'PTGS2',
#   'IKBKB',
#   'MAPK9',
#   'CLEC1B',
#   'MAPK8',
#   'MAPK3',
#   'HRAS',
#   'MAPK1',
#   'IKBKG',
#   'CCL17',
#   'IKBKE'],
#  'Caffeine metabolism': ['CYP2A7', 'CYP2A6', 'NAT2', 'CYP1A2', 'XDH', 'NAT1'],
#  'Calcium signaling pathway': ['TRHR',
#   'EGF',
#   'GRIN2D',
#   'GRIN2C',
#   'HTR5A',
#   'ORAI3',
#   'AGTR1',
#   'ORAI2',
#   'PLCD1',
#   'ORAI1',
#   'CALM2',
#   'PLCD4',
#   'CALM3',
#   'CALM1',
#   'PLCD3',
#   'ADCY1',
#   'CALML6',
#   'ADCY4',
#   'CALML3',
#   'ADCY3',
#   'CALML4',
#   'MST1R',
#   'ADCY2',
#   'CALML5',
#   'ADCY9',
#   'ADCY8',
#   'ADCY7',
#   'PLCE1',
#   'KDR',
#   'NTSR1',
#   'PRKCG',
#   'TNNC1',
#   'TNNC2',
#   'AVPR1A',
#   'PHKA2',
#   'PRKCB',
#   'AVPR1B',
#   'PHKA1',
#   'PRKCA',
#   'CCKBR',
#   'PTGFR',
#   'OXTR',
#   'PDE1C',
#   'PDE1B',
#   'PDE1A',
#   'PDGFC',
#   'PDGFB',
#   'PDGFA',
#   'GRPR',
#   'HTR6',
#   'MYLK',
#   'HTR4',
#   'PPP3R1',
#   'PRKACG',
#   'HTR7',
#   'PPP3R2',
#   'GRIN2A',
#   'PDGFD',
#   'PLCG1',
#   'PLCG2',
#   'PRKACB',
#   'PRKACA',
#   'MST1',
#   'SPHK2',
#   'SPHK1',
#   'TACR3',
#   'VEGFC',
#   'VEGFD',
#   'TACR1',
#   'TACR2',
#   'VEGFA',
#   'VEGFB',
#   'ITPKC',
#   'ITPKA',
#   'ITPKB',
#   'CAMK4',
#   'HRC',
#   'CAMK1',
#   'RET',
#   'ADRB1',
#   'ADRB2',
#   'ADRB3',
#   'PPP3CA',
#   'PPP3CB',
#   'PPP3CC',
#   'CCKAR',
#   'CD38',
#   'PLCB4',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1',
#   'RYR2',
#   'RYR3',
#   'RYR1',
#   'PTGER1',
#   'PTAFR',
#   'PTGER3',
#   'SLC8A1',
#   'SLC8A2',
#   'SLC8A3',
#   'CXCR4',
#   'PDGFRB',
#   'PDGFRA',
#   'IGH',
#   'GRIN1',
#   'STIM1',
#   'STIM2',
#   'LTB4R2',
#   'SLC25A31',
#   'PPIF',
#   'CHRM3',
#   'CHRM1',
#   'CHRM2',
#   'CHRM5',
#   'CHRNA7',
#   'EGFR',
#   'CYSLTR2',
#   'CYSLTR1',
#   'FGF21',
#   'FGF20',
#   'FGF23',
#   'FGF22',
#   'F2R',
#   'HGF',
#   'PHKB',
#   'FGF18',
#   'GNAL',
#   'FGF17',
#   'FGF16',
#   'GDNF',
#   'FGF19',
#   'GNAQ',
#   'FGF10',
#   'FGFR1',
#   'GNAS',
#   'CASQ1',
#   'CASQ2',
#   'FGFR4',
#   'FGFR3',
#   'FGFR2',
#   'CACNA1A',
#   'CACNA1C',
#   'CACNA1B',
#   'CACNA1E',
#   'CACNA1D',
#   'FGF1',
#   'CACNA1G',
#   'FGF2',
#   'CACNA1F',
#   'FGF3',
#   'CACNA1I',
#   'FGF4',
#   'CACNA1H',
#   'FGF5',
#   'FGF6',
#   'FGF7',
#   'FGF8',
#   'FGF9',
#   'CACNA1S',
#   'TRDN',
#   'TPCN1',
#   'TPCN2',
#   'ADORA2B',
#   'ADORA2A',
#   'MCU',
#   'SLC25A4',
#   'HTR2C',
#   'ITPR2',
#   'ITPR3',
#   'HTR2A',
#   'ADRA1D',
#   'HTR2B',
#   'ADRA1B',
#   'ADRA1A',
#   'ITPR1',
#   'HRH2',
#   'HRH1',
#   'ERBB4',
#   'TBXA2R',
#   'BDKRB1',
#   'ERBB2',
#   'ERBB3',
#   'PLCZ1',
#   'BDKRB2',
#   'DRD1',
#   'DRD5',
#   'NTRK2',
#   'LHCGR',
#   'NTRK3',
#   'CAMK1D',
#   'NTRK1',
#   'NOS3',
#   'ATP2B4',
#   'ATP2B3',
#   'ATP2B2',
#   'ATP2B1',
#   'MCOLN2',
#   'MCOLN3',
#   'NGF',
#   'MCOLN1',
#   'P2RX7',
#   'P2RX6',
#   'P2RX5',
#   'P2RX4',
#   'P2RX3',
#   'P2RX2',
#   'ASPH',
#   'P2RX1',
#   'VDAC3',
#   'MET',
#   'VDAC2',
#   'VDAC1',
#   'SLC25A6',
#   'CAMK1G',
#   'SLC25A5',
#   'MYLK2',
#   'CAMK2D',
#   'MYLK3',
#   'FLT1',
#   'FLT4',
#   'CAMK2A',
#   'CAMK2B',
#   'ATP2A3',
#   'ATP2A2',
#   'ATP2A1',
#   'MYLK4',
#   'GRM1',
#   'GNA14',
#   'PLN',
#   'EDNRA',
#   'GNA15',
#   'EDNRB',
#   'GRM5',
#   'PHKG2',
#   'GNA11',
#   'PHKG1',
#   'PTK2B',
#   'NOS1',
#   'NOS2',
#   'CAMK2G'],
#  'Carbohydrate digestion and absorption': ['MGAM',
#   'AMY1A',
#   'AMY1B',
#   'AMY1C',
#   'ATP1B4',
#   'PRKCB',
#   'ATP1B3',
#   'ATP1B2',
#   'G6PC1',
#   'ATP1B1',
#   'G6PC2',
#   'G6PC3',
#   'PLCB4',
#   'PIK3CB',
#   'PIK3R1',
#   'MGAM2',
#   'PIK3CA',
#   'FXYD2',
#   'HKDC1',
#   'PLCB2',
#   'LCT',
#   'PLCB3',
#   'PLCB1',
#   'AMY2A',
#   'AMY2B',
#   'SLC2A2',
#   'ATP1A4',
#   'ATP1A3',
#   'PIK3CD',
#   'PIK3R3',
#   'SLC5A1',
#   'ATP1A2',
#   'CACNA1D',
#   'PIK3R2',
#   'SLC2A5',
#   'ATP1A1',
#   'HK1',
#   'HK3',
#   'HK2',
#   'GNAT3',
#   'SI',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'TAS1R3',
#   'TAS1R2',
#   'SLC37A4'],
#  'Cardiac muscle contraction': ['TRDN',
#   'TPM4',
#   'CACNA2D2',
#   'TPM3',
#   'CACNA2D1',
#   'TPM2',
#   'CACNA2D4',
#   'CACNA2D3',
#   'ATP1B4',
#   'ATP1B3',
#   'ATP1B2',
#   'COX7B2',
#   'ATP1B1',
#   'COX6C',
#   'SLC9A6',
#   'SLC9A7',
#   'MYL2',
#   'MYL3',
#   'UQCRQ',
#   'FXYD2',
#   'MYL4',
#   'UQCRC2',
#   'HRC',
#   'UQCRC1',
#   'CYTB',
#   'MYH6',
#   'MYH7',
#   'COX7C',
#   'COX7B',
#   'COX4I2',
#   'UQCR10',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'UQCR11',
#   'ATP1A1',
#   'COX6A2',
#   'SLC9A1',
#   'COX6A1',
#   'TPM1',
#   'UQCRFS1',
#   'COX4I1',
#   'COX8A',
#   'COX8C',
#   'TNNC1',
#   'COX7A2L',
#   'COX6B1',
#   'COX6B2',
#   'UQCRHL',
#   'CACNB2',
#   'CACNB3',
#   'CACNB4',
#   'TNNT2',
#   'ASPH',
#   'CASQ2',
#   'CACNB1',
#   'RYR2',
#   'COX5A',
#   'UQCRB',
#   'CACNA1C',
#   'ATP2A3',
#   'ATP2A2',
#   'ATP2A1',
#   'CACNA1D',
#   'ACTC1',
#   'COX7A1',
#   'CACNA1F',
#   'COX5B',
#   'COX7A2',
#   'SLC8A1',
#   'SLC8A2',
#   'SLC8A3',
#   'UQCRH',
#   'CACNG7',
#   'CACNG8',
#   'CACNA1S',
#   'COX3',
#   'TNNI3',
#   'CACNG1',
#   'COX2',
#   'CACNG2',
# ...
#   'CCR8',
#   'CCR5',
#   'CCR4',
#   'CCR3',
#   'CDKN2A',
#   'CDKN2B',
#   'SYK',
#   'RANBP1',
#   'STAT3',
#   'GTF2H1',
#   'GTF2H2',
#   'GTF2H3',
#   'H4-16',
#   'GTF2H4',
#   'DDB1',
#   'CCNE2',
#   'CCNE1',
#   'ATP6V0D2',
#   'CDKN1B',
#   'CDKN1A',
#   'EP300',
#   'HRAS',
#   'RAC1',
#   'H2BS1',
#   'IKBKG',
#   'JAK3',
#   'JAK1',
#   'GSN',
#   'H2BC8',
#   'H2BC9',
#   'USP7',
#   'H2BC6',
#   'H2BC7',
#   'H2BC4',
#   'H2BC5',
#   'H2BC3',
#   'H2BC1',
#   'MAPKAPK2',
#   'IL6ST',
#   'RELA',
#   'RBPJL',
#   'ATF6B',
#   'GTF2B',
#   'UBE3A',
#   'GTF2E1',
#   'GTF2E2',
#   'NRAS',
#   'CCND3',
#   'CCND2',
#   'CCND1',
#   'H2BU1',
#   'TRAF1',
#   'TRAF3',
#   'TRAF2',
#   'H2BE1',
#   'NFKB1',
#   'NFKB2',
#   'CREB3',
#   'CCNA2',
#   'DLG1',
#   'CCNA1',
#   'CREB1',
#   'TRAF5',
#   'H4C15',
#   'H4C14',
#   'H4C13',
#   'H4C12',
#   'H4C11',
#   'MAD1L1',
#   'CREB5',
#   'MDM2',
#   'PXN',
#   'PMAIP1',
#   'H2BW2',
#   'H2BW1',
#   'EIF2AK2',
#   'H2BC17',
#   'H2BC18',
#   'H2BC13',
#   'H2BC14',
#   'NFKBIA',
#   'H2BC15',
#   'RBL1',
#   'RBL2',
#   'CDK6',
#   'PIK3CB',
#   'H2BC10',
#   'PIK3CA',
#   'CDK4',
#   'H2BC11',
#   'RASA2',
#   'H2BC12',
#   'IRF3',
#   'CDK2',
#   'CDK1',
#   'IRF9',
#   'IRF7',
#   'GTF2A1',
#   'GTF2A2',
#   'YWHAG',
#   'DDX3X',
#   'YWHAE',
#   'YWHAB',
#   'TRADD',
#   'UBR4',
#   'PIK3R3',
#   'CHD4',
#   'PIK3R2',
#   'CASP8',
#   'SCIN',
#   'YWHAQ',
#   'CASP3',
#   'YWHAH',
#   'TBP',
#   'YWHAZ',
#   'CDC42',
#   'PKM',
#   'LTBR',
#   'DNAJA3',
#   'VDAC3',
#   'KRAS',
#   'HDAC5',
#   'VAC14',
#   'HDAC6',
#   'HDAC3',
#   'SRC',
#   'HDAC4',
#   'HDAC1',
#   'HDAC2',
#   'SRF',
#   'PIK3CD',
#   'HDAC9',
#   'HDAC7',
#   'HDAC8',
#   'POLB',
#   'H2BC21',
#   'MAPK3',
#   'BAK1',
#   'MAPK1'],
#  'Viral myocarditis': ['CAV1',
#   'IGH',
#   'HLA-DQB1',
#   'HLA-DRA',
#   'CD28',
#   'CYCS',
#   'MYH6',
#   'MYH7',
#   'CD86',
#   'CD40',
#   'CD80',
#   'ACTB',
#   'CASP8',
#   'CASP9',
#   'CCND1',
#   'CASP3',
#   'DAG1',
#   'HLA-DOB',
#   'HLA-DQA2',
#   'HLA-DOA',
#   'HLA-DQA1',
#   'CXADR',
#   'HLA-DRB5',
#   'HLA-C',
#   'HLA-A',
#   'HLA-B',
#   'HLA-G',
#   'HLA-E',
#   'HLA-F',
#   'EIF4G1',
#   'HLA-DPB1',
#   'CD40LG',
#   'HLA-DRB4',
#   'HLA-DRB3',
#   'EIF4G3',
#   'EIF4G2',
#   'HLA-DRB1',
#   'ITGB2',
#   'LAMA2',
#   'ACTG1',
#   'PRF1',
#   'LAMA1',
#   'ITGAL',
#   'ICAM1',
#   'SGCG',
#   'HLA-DMB',
#   'SGCD',
#   'SGCB',
#   'SGCA',
#   'ABL2',
#   'HLA-DPA1',
#   'RAC3',
#   'RAC1',
#   'ABL1',
#   'DMD',
#   'FYN',
#   'RAC2',
#   'BID',
#   'HLA-DMA',
#   'CD55'],
#  'Viral protein interaction with cytokine and cytokine receptor': ['CXCL10',
#   'CXCL11',
#   'CXCL12',
#   'CXCL13',
#   'IL6ST',
#   'PF4',
#   'CSF1',
#   'TNF',
#   'IL2RG',
#   'CXCL14',
#   'XCR1',
#   'TNFSF14',
#   'PPBP',
#   'TNFRSF10D',
#   'TNFRSF10C',
#   'TNFRSF10B',
#   'TNFRSF10A',
#   'IL22RA1',
#   'CSF1R',
#   'CCL4L1',
#   'CCL4L2',
#   'IL20RB',
#   'IL18RAP',
#   'IL20RA',
#   'TNFSF10',
#   'IL6R',
#   'CCR10',
#   'CCL26',
#   'CCR2',
#   'CCL25',
#   'CCR1',
#   'CCL24',
#   'CCL23',
#   'IL10',
#   'CCL22',
#   'CCL21',
#   'CCL20',
#   'IL10RB',
#   'XCL1',
#   'IL10RA',
#   'IL19',
#   'IL18',
#   'TNFRSF1A',
#   'IL2',
#   'TNFRSF1B',
#   'IL6',
#   'XCL2',
#   'CCL28',
#   'CCL27',
#   'IL18R1',
#   'CXCL8',
#   'CCL3L1',
#   'CXCL9',
#   'CCL3L3',
#   'CXCL2',
#   'CXCL1',
#   'CX3CL1',
#   'CXCL3',
#   'CXCL6',
#   'CXCL5',
#   'CCR9',
#   'CCR8',
#   'CCR7',
#   'CCR6',
#   'CCR5',
#   'TNFRSF14',
#   'CCR4',
#   'CCR3',
#   'PF4V1',
#   'IL34',
#   'IL37',
#   'LTBR',
#   'IL2RA',
#   'IL2RB',
#   'ACKR4',
#   'LTA',
#   'ACKR3',
#   'CCL15',
#   'CCL14',
#   'CCL13',
#   'IL20',
#   'CCL11',
#   'IL24',
#   'CX3CR1',
#   'CXCR5',
#   'CCL8',
#   'CXCR2',
#   'CCL7',
#   'CXCR1',
#   'CXCR4',
#   'CCL5',
#   'CXCR3',
#   'CCL4',
#   'CCL3',
#   'CCL2',
#   'CCL1',
#   'CCL19',
#   'CCL18',
#   'CCL17',
#   'CCL16'],
#  'Vitamin B6 metabolism': ['PHOSPHO2',
#   'PDXK',
#   'PSAT1',
#   'AOX1',
#   'PNPO',
#   'PDXP'],
#  'Vitamin digestion and absorption': ['CUBN',
#   'SLC46A1',
#   'CBLIF',
#   'SLC52A3',
#   'SLC23A1',
#   'APOA4',
#   'PLB1',
#   'SLC5A6',
#   'BTD',
#   'LMBRD1',
#   'AWAT2',
#   'FOLH1',
#   'TCN2',
#   'APOA1',
#   'RBP2',
#   'LRAT',
#   'MMACHC',
#   'ABCC1',
#   'SLC19A1',
#   'SCARB1',
#   'SLC19A2',
#   'APOB',
#   'PNLIP',
#   'SLC19A3'],
#  'Wnt signaling pathway': ['RNF43',
#   'TLE4',
#   'RYK',
#   'TLE3',
#   'TLE2',
#   'FBXW11',
#   'TLE1',
#   'CTNNBIP1',
#   'TPTEP2-CSNK1E',
#   'WNT5A',
#   'WNT5B',
#   'DKK1',
#   'DKK2',
#   'RBX1',
#   'TLE7',
#   'DKK4',
#   'TLE6',
#   'SFRP4',
#   'SFRP5',
#   'SFRP2',
#   'TBL1XR1',
#   'APC',
#   'MAPK10',
#   'BAMBI',
#   'ROR2',
#   'ROR1',
#   'TP53',
#   'LEF1',
#   'ROCK2',
#   'CTNND2',
#   'LRP6',
#   'LRP5',
#   'FZD10',
#   'NKD1',
#   'SFRP1',
#   'NKD2',
#   'RUVBL1',
#   'FRAT1',
#   'FRAT2',
#   'CCND3',
#   'CCND2',
#   'WIF1',
#   'CCND1',
#   'MYC',
#   'GPC4',
#   'SERPINF1',
#   'CCN4',
#   'TBL1X',
#   'TBL1Y',
#   'MAP3K7',
#   'BTRC',
#   'CER1',
#   'FZD2',
#   'SIAH1',
#   'SMAD3',
#   'CREBBP',
#   'FZD1',
#   'PRKCG',
#   'FZD4',
#   'WNT10B',
#   'FZD3',
#   'SMAD4',
#   'WNT10A',
#   'FZD6',
#   'WNT3A',
#   'FZD5',
#   'FZD8',
#   'FZD7',
#   'FZD9',
#   'CSNK1E',
#   'PRKCB',
#   'PRKCA',
#   'VANGL2',
#   'FOSL1',
#   'VANGL1',
#   'CSNK2B',
#   'TCF7',
#   'WNT2B',
#   'CTBP2',
#   'CTBP1',
#   'CUL1',
#   'PSEN1',
#   'NLK',
#   'PORCN',
#   'PPP3R1',
#   'PRKACG',
#   'PPP3R2',
#   'SOX17',
#   'PRKACB',
#   'SKP1',
#   'PRKACA',
#   'RHOA',
#   'CSNK1A1',
#   'MMP7',
#   'JUN',
#   'AXIN2',
#   'NFATC4',
#   'AXIN1',
#   'NFATC3',
#   'NFATC2',
#   'WNT9A',
#   'NFATC1',
#   'WNT9B',
#   'SENP2',
#   'WNT16',
#   'GSK3B',
#   'CHD8',
#   'WNT8B',
#   'CBY1',
#   'WNT8A',
#   'PPP3CA',
#   'WNT6',
#   'PPP3CB',
#   'PPP3CC',
#   'WNT11',
#   'DVL1',
#   'DVL2',
#   'DVL3',
#   'WNT1',
#   'WNT2',
#   'WNT3',
#   'WNT4',
#   'TCF7L2',
#   'APC2',
#   'TCF7L1',
#   'CSNK2A2',
#   'CSNK2A1',
#   'CSNK2A3',
#   'WNT7A',
#   'CACYBP',
#   'WNT7B',
#   'CSNK1A1L',
#   'PLCB4',
#   'DAAM2',
#   'NOTUM',
#   'DAAM1',
#   'PLCB2',
#   'LGR6',
#   'PLCB3',
#   'LGR5',
#   'PPARD',
#   'LGR4',
#   'PLCB1',
#   'CAMK2D',
#   'INVS',
#   'CAMK2A',
#   'CTNNB1',
#   'CAMK2B',
#   'PRICKLE3',
#   'PRICKLE4',
#   'CXXC4',
#   'PRICKLE1',
#   'PRICKLE2',
#   'MAPK9',
#   'ZNRF3',
#   'MAPK8',
#   'EP300',
#   'RAC3',
#   'RSPO3',
#   'RSPO4',
#   'RAC1',
#   'RSPO1',
#   'SOST',
#   'RAC2',
#   'RSPO2',
#   'CAMK2G'],
#  'Yersinia infection': ['IGH',
#   'TICAM1',
#   'MAPK13',
#   'MAPK14',
#   'MAPK11',
#   'MAPK12',
#   'CD4',
#   'MAPK10',
#   'ELMO1',
#   'ELMO2',
#   'SKAP2',
#   'RELA',
#   'ROCK1',
#   'ROCK2',
#   'ARPC5L',
#   'TNF',
#   'CRKL',
#   'ACTB',
#   'PYCARD',
#   'AKT3',
#   'AKT1',
#   'NLRP3',
#   'AKT2',
#   'MAP3K7',
#   'ARHGEF12',
#   'FYB1',
#   'MAP2K4',
#   'MAP2K2',
#   'MAP2K3',
#   'MAP2K1',
#   'CD8B2',
#   'ARPC5',
#   'TRAF2',
#   'NFKB1',
#   'PTK2',
#   'MYD88',
#   'ARPC3',
#   'PIK3R1',
#   'ARPC4',
#   'CD8B',
#   'CD8A',
#   'ARPC2',
#   'GNAQ',
#   'TRAF6',
#   'TAB2',
#   'TAB1',
#   'PXN',
#   'ARHGEF28',
#   'ACTG1',
#   'ACTR3B',
#   'ACTR3C',
#   'TBK1',
#   'PIP5K1A',
#   'PIP5K1B',
#   'PIP5K1C',
#   'PLCG1',
#   'MAP2K6',
#   'MAP2K7',
#   'ACTR3',
#   'RHOA',
#   'ACTR2',
#   'IL10',
#   'JUN',
#   'ITGA5',
#   'LIMK1',
#   'ITGA4',
#   'FN1',
#   'NFATC3',
#   'IRAK4',
#   'NFATC2',
#   'IL18',
#   'NFATC1',
#   'RHOG',
#   'BAIAP2',
#   'VAV1',
#   'VAV2',
#   'IL2',
#   'VAV3',
#   'IL1B',
#   'NFKBIA',
#   'FCGR2A',
#   'IL6',
#   'PIK3CB',
#   'PIK3CA',
#   'IRF3',
#   'LCP2',
#   'DOCK1',
#   'TLR4',
#   'ARHGEF7',
#   'BCAR1',
#   'LAT',
#   'ARPC1A',
#   'CXCL8',
#   'GSK3B',
#   'MEFV',
#   'ARHGEF1',
#   'ARPC1B',
#   'NLRC4',
#   'PIK3R3',
#   'PIK3R2',
#   'IRAK1',
#   'CASP1',
#   'WASF2',
#   'CHUK',
#   'FOS',
#   'CDC42',
#   'LCK',
#   'ZAP70',
#   'PKN1',
#   'CRK',
#   'PKN2',
#   'ARF6',
#   'ITGB1',
#   'SRC',
#   'WIPF1',
#   'WIPF2',
#   'WIPF3',
#   'WAS',
#   'PIK3CD',
#   'WASL',
#   'IKBKB',
#   'MAPK9',
#   'MAPK8',
#   'RPS6KA6',
#   'RPS6KA1',
#   'RPS6KA3',
#   'RPS6KA2',
#   'MAPK3',
#   'PTK2B',
#   'RAC3',
#   'CCL2',
#   'IFNB1',
#   'MAPK1',
#   'RAC1',
#   'RAC2',
#   'IKBKG',
#   'GIT2'],
#  'alpha-Linolenic acid metabolism': ['PLA2G12A',
#   'PLA2G12B',
#   'PLA2G2E',
#   'PLA2G2F',
#   'PLA2G2C',
#   'PLA2G4E',
#   'PLA2G2D',
#   'PLA2G4F',
#   'PLA2G2A',
#   'PLA2G4C',
#   'PLA2G4D',
#   'PLA2G4A',
#   'PLA2G4B',
#   'PLAAT3',
#   'ACOX3',
#   'ACOX1',
#   'PLA2G10',
#   'JMJD7-PLA2G4B',
#   'PLA2G1B',
#   'PLA2G3',
#   'PLA2G5',
#   'PLA2G6',
#   'PLB1',
#   'ACAA1',
#   'FADS2'],
#  'beta-Alanine metabolism': ['AOC2',
#   'AOC3',
#   'SMOX',
#   'GAD2',
#   'GAD1',
#   'UPB1',
#   'ALDH3A2',
#   'ALDH7A1',
#   'ALDH6A1',
#   'ACOX3',
#   'ACOX1',
#   'ALDH3A1',
#   'DPYD',
#   'HADHA',
#   'ALDH9A1',
#   'DPYS',
#   'EHHADH',
#   'GADL1',
#   'ECHS1',
#   'ABAT',
#   'CNDP1',
#   'CNDP2',
#   'ALDH1B1',
#   'ALDH2',
#   'ALDH3B2',
#   'ALDH3B1',
#   'CARNS1',
#   'MLYCD',
#   'HIBCH',
#   'ACADS'],
#  'cAMP signaling pathway': ['BAD',
#   'GRIN2D',
#   'GRIN2C',
#   'GRIN3A',
#   'SST',
#   'GRIN3B',
#   'MAPK10',
#   'ORAI1',
#   'CALM2',
#   'MYL9',
#   'CALM3',
#   'VIP',
#   'CALM1',
#   'HCN4',
#   'VIPR2',
#   'ADCY1',
#   'CALML6',
#   'ADCY5',
#   'ADCY4',
#   'CALML3',
#   'ADCY3',
#   'CALML4',
#   'ADCY2',
#   'CALML5',
#   'ADCY9',
#   'ADCY8',
#   'ADCY7',
#   'ADCY6',
#   'CREB3L1',
#   'CREB3L4',
#   'AKT3',
#   'CREB3L2',
#   'CREB3L3',
#   'AKT1',
#   'PLCE1',
#   'AKT2',
#   'CREBBP',
#   'PIK3R1',
#   'PPP1R1B',
#   'CFTR',
#   'OXTR',
#   'LHB',
#   'HHIP',
#   'ADCYAP1R1',
#   'HTR6',
#   'HTR4',
#   'PRKACG',
#   'GRIN2B',
#   'LIPE',
#   'GRIN2A',
#   'SOX9',
#   'FFAR2',
#   'PRKACB',
#   'CGA',
#   'PRKACA',
#   'EDN1',
#   'RHOA',
#   'EDN2',
#   'GABBR2',
#   'EDN3',
#   'GABBR1',
#   'JUN',
#   'FSHB',
#   'PTCH1',
#   'BRAF',
#   'NFATC1',
#   'VAV1',
#   'VAV2',
#   'VAV3',
#   'FXYD1',
#   'FSHR',
#   'FXYD2',
#   'CAMK4',
#   'RAPGEF3',
#   'RAPGEF4',
#   'GIPR',
#   'ADRB1',
#   'ADRB2',
#   'MC2R',
#   'RAP1A',
#   'RAP1B',
#   'RRAS2',
#   'RRAS',
#   'GPR119',
#   'PPARA',
#   'FOS',
#   'GHRL',
#   'RYR2',
#   'PTGER2',
#   'PTGER3',
#   'GLI1',
#   'GNAI1',
#   'GNAI2',
#   'GLI3',
#   'GNAI3',
#   'EP300',
#   'NPY',
#   'RAC3',
#   'RAC1',
#   'RAC2',
#   'NPY1R',
#   'ATP1B4',
#   'ATP1B3',
#   'GCG',
#   'ATP1B2',
#   'ATP1B1',
#   'GRIN1',
#   'PPP1CA',
#   'PPP1CB',
#   'ADCY10',
#   'RAF1',
#   'RELA',
#   'CHRM1',
#   'CHRM2',
#   'ROCK1',
#   'ROCK2',
#   'SUCNR1',
#   'ATP1A4',
#   'ATP1A3',
#   'ATP1A2',
#   'ATP1A1',
#   'SLC9A1',
#   'PPP1CC',
#   'PAK1',
#   'ADORA1',
#   'GHSR',
#   'MAP2K2',
#   'F2R',
#   'MAP2K1',
#   'NFKB1',
#   'CREB3',
#   'CREB1',
#   'CNGB3',
#   'GNAS',
#   'CNGB1',
#   'CREB5',
#   'GRIA2',
#   'GRIA3',
#   'GRIA1',
#   'CACNA1C',
#   'CACNA1D',
#   'CACNA1F',
#   'HCAR3',
#   'HCAR1',
#   'HCAR2',
#   'NPPA',
#   'CACNA1S',
#   'GRIA4',
#   'ABCC4',
#   'PPP1R12A',
#   'HTR1F',
#   'BDNF',
#   'HTR1D',
#   'HTR1E',
#   'ARAP3',
#   'HTR1B',
#   'SSTR1',
#   'HTR1A',
#   'SSTR2',
#   'SSTR5',
#   'AFDN',
#   'NFKBIA',
#   'ACOX3',
#   'PIK3CB',
#   'PIK3CA',
#   'ACOX1',
#   'ADORA2A',
#   'PDE3B',
#   'PDE3A',
#   'NPR1',
#   'GLP1R',
#   'PIK3R3',
#   'OXT',
#   'PIK3R2',
#   'PLD2',
#   'PLD1',
#   'CNGA2',
#   'PDE4C',
#   'CNGA3',
#   'PDE4B',
#   'CNGA4',
#   'DRD1',
#   'PDE4A',
#   'AMH',
#   'DRD2',
#   'DRD5',
#   'CNGA1',
#   'LHCGR',
#   'PDE4D',
#   'ATP2B4',
#   'ATP2B3',
#   'ATP2B2',
#   'ATP2B1',
#   'GIP',
#   'TIAM1',
#   'TSHR',
#   'ADCYAP1',
#   'POMC',
#   'PDE10A',
#   'HCN2',
#   'CAMK2D',
#   'CAMK2A',
#   'CAMK2B',
#   'ATP2A3',
#   'ATP2A2',
#   'PIK3CD',
#   'ATP2A1',
#   'PLN',
#   'EDNRA',
#   'MAPK9',
#   'MAPK8',
#   'MAPK3',
#   'TNNI3',
#   'MAPK1',
#   'CAMK2G',
#   'TSHB'],
#  'cGMP-PKG signaling pathway': ['GUCY1A2',
#   'GUCY1A1',
#   'BAD',
#   'BORCS8-MEF2B',
#   'ATP1B4',
#   'ATP1B3',
#   'IRAG1',
#   'ATP1B2',
#   'ATP1B1',
#   'PPP1CA',
#   'PPP1CB',
#   'SLC25A31',
#   'AGTR1',
#   'PPIF',
#   'GTF2IRD1',
#   'CALM2',
#   'MYL9',
#   'CALM3',
#   'CALM1',
#   'RAF1',
#   'ATF2',
#   'GTF2I',
#   'ROCK1',
#   'ADCY1',
#   'CALML6',
#   'ROCK2',
#   'ATF6B',
#   'ADCY5',
#   'ADCY4',
#   'ATP1A4',
#   'CALML3',
#   'ADCY3',
#   'ATP1A3',
#   'CALML4',
#   'ADCY2',
#   'ATP1A2',
#   'CALML5',
#   'ADCY9',
#   'ATP1A1',
#   'ADCY8',
#   'ADCY7',
#   'ADCY6',
#   'PPP1CC',
#   'CREB3L1',
#   'CREB3L4',
#   'AKT3',
#   'CREB3L2',
#   'CREB3L3',
#   'AKT1',
#   'ADORA3',
#   'AKT2',
#   'ADORA1',
#   'INSR',
#   'MAP2K2',
#   'TRPC6',
#   'MAP2K1',
#   'PRKCE',
#   'ADRA2C',
#   'ADRA2B',
#   'ADRA2A',
#   'VASP',
#   'CREB3',
#   'KCNU1',
#   'CREB1',
#   'KCNMA1',
#   'GNAQ',
#   'ATF4',
#   'CNGB1',
#   'CREB5',
#   'GUCY1B1',
#   'IRS1',
#   'IRS2',
#   'CACNA1C',
#   'CACNA1D',
#   'GATA4',
#   'IRS4',
#   'CACNA1F',
#   'MYLK',
#   'NPPC',
#   'PPP3R1',
#   'PPP3R2',
#   'KCNMB1',
#   'RGS2',
#   'KCNMB2',
#   'NPPA',
#   'KCNMB3',
#   'NPPB',
#   'CACNA1S',
#   'KCNMB4',
#   'PDE2A',
#   'RHOA',
#   'PPP1R12A',
#   'KCNJ8',
#   'NFATC4',
#   'NFATC3',
#   'NFATC2',
#   'NFATC1',
#   'FXYD2',
#   'PDE3B',
#   'PDE3A',
#   'MYH6',
#   'MYH7',
#   'SLC25A4',
#   'OPRD1',
#   'NPR1',
#   'NPR2',
#   'ITPR2',
#   'PIK3R5',
#   'ADRB1',
#   'ITPR3',
#   'ADRB2',
#   'ADRA1D',
#   'ADRB3',
#   'ADRA1B',
#   'ADRA1A',
#   'ITPR1',
#   'KNG1',
#   'PIK3R6',
#   'PPP3CA',
#   'PPP3CB',
#   'PPP3CC',
#   'BDKRB2',
#   'PRKG2',
#   'CNGA1',
#   'PRKG1',
#   'MEF2B',
#   'MEF2A',
#   'MEF2D',
#   'MEF2C',
#   'NOS3',
#   'ATP2B4',
#   'ATP2B3',
#   'ATP2B2',
#   'ATP2B1',
#   'PLCB4',
#   'VDAC3',
#   'VDAC2',
#   'PDE5A',
#   'VDAC1',
#   'PLCB2',
#   'SLC25A6',
#   'PLCB3',
#   'SLC25A5',
#   'PLCB1',
#   'MYLK2',
#   'MYLK3',
#   'SRF',
#   'ATP2A3',
#   'ATP2A2',
#   'ATP2A1',
#   'INS',
#   'GNAI1',
#   'SLC8A1',
#   'GNAI2',
#   'MYLK4',
#   'SLC8A2',
#   'GNAI3',
#   'PIK3CG',
#   'SLC8A3',
#   'PLN',
#   'EDNRA',
#   'EDNRB',
#   'GNA11',
#   'GNA12',
#   'GNA13',
#   'MAPK3',
#   'MAPK1'],
#  'mRNA surveillance pathway': ['CPSF6',
#   'CPSF7',
#   'CPSF2',
#   'CPSF1',
#   'CPSF4',
#   'ALYREF',
#   'CPSF3',
#   'PPP2R1A',
#   'UPF3B',
#   'UPF3A',
#   'PPP1CA',
#   'SRRM1',
#   'PPP1CB',
#   'DDX39B',
#   'WDR82',
#   'SSU72',
#   'TARDBP',
#   'RNMT',
#   'CASC3',
#   'PNN',
#   'MAGOH',
#   'NXF1',
#   'PPP1CC',
#   'NXF2',
#   'NXF3',
#   'CLP1',
#   'PABPN1',
#   'PABPC1L2A',
#   'SAP18',
#   'PABPC1L2B',
#   'NXF5',
#   'PYM1',
#   'RNPS1',
#   'NXF2B',
#   'CSTF3',
#   'MSI1',
#   'MSI2',
#   'PABPN1L',
#   'GSPT2',
#   'GSPT1',
#   'GLE1',
#   'PELO',
#   'PAPOLG',
#   'CSTF2',
#   'PAPOLB',
#   'CSTF1',
#   'PAPOLA',
#   'PABPC4L',
#   'UPF2',
#   'FUS',
#   'UPF1',
#   'NCBP2',
#   'PABPC5',
#   'NCBP1',
#   'PPP2R5C',
#   'PPP2R5B',
#   'PPP2R5E',
#   'PPP2R5D',
#   'PPP2R5A',
#   'WDR33',
#   'MAGOHB',
#   'DDX19A',
#   'DDX19B',
#   'NCBP2L',
#   'PABPC3',
#   'ETF1',
#   'PABPC4',
#   'PABPC1',
#   'DAZAP1',
#   'HBS1L',
#   'RBM8A',
#   'PCF11',
#   'SYMPK',
#   'BCL2L2-PABPN1',
#   'RNGTT',
#   'PPP2R3A',
#   'PPP2R3C',
#   'PPP2R3B',
#   'PPP2CA',
#   'NUDT21',
#   'PPP2R2D',
#   'CPSF4L',
#   'PPP2R2C',
#   'ACIN1',
#   'PABPC1L',
#   'EIF4A3',
#   'SMG5',
#   'NXT1',
#   'NXT2',
#   'SMG1',
#   'PPP2R2B',
#   'PPP2R2A',
#   'CSTF2T',
#   'SMG6',
#   'SMG7',
#   'PPP2CB',
#   'FIP1L1',
#   'PPP2R1B'],
#  'mTOR signaling pathway': ['ATP6V1E1',
#   'RPS6',
#   'WNT5A',
#   'WNT5B',
#   'TSC2',
#   'TSC1',
#   'RRAGB',
#   'RRAGA',
#   'RRAGD',
#   'RRAGC',
#   'ULK2',
#   'ULK1',
#   'RAF1',
#   'PRKAA2',
#   'NPRL2',
#   'NPRL3',
#   'LRP6',
#   'LRP5',
#   'FZD10',
#   'TNF',
#   'PRKAA1',
#   'NRAS',
#   'AKT3',
#   'AKT1',
#   'AKT2',
#   'GRB10',
#   'ATP6V1E2',
#   'FZD2',
#   'FZD1',
#   'INSR',
#   'PRKCG',
#   'FZD4',
#   'MAP2K2',
#   'WDR59',
#   'WNT10B',
#   'FZD3',
#   'WNT10A',
#   'FZD6',
#   'WNT3A',
#   'FZD5',
#   'MAP2K1',
#   'FZD8',
#   'FZD7',
#   'FZD9',
#   'IGF1',
#   'PRKCB',
#   'PRKCA',
#   'EIF4E1B',
#   'PIK3R1',
#   'RHEB',
#   'GRB2',
#   'ATP6V1B1',
#   'ATP6V1B2',
#   'ATP6V1A',
#   'ATP6V1D',
#   'WNT2B',
#   'IRS1',
#   'EIF4EBP1',
#   'IGF1R',
#   'STK11',
#   'SESN2',
#   'MLST8',
#   'SLC38A9',
#   'ATP6V1F',
#   'ATP6V1C1',
#   'ATP6V1C2',
#   'ATP6V1H',
#   'SKP2',
#   'TTI1',
#   'RHOA',
#   'SEC13',
#   'STRADA',
#   'STRADB',
#   'WNT9A',
#   'BRAF',
#   'WNT9B',
#   'TNFRSF1A',
#   'WNT16',
#   'SLC7A5',
#   'LPIN1',
#   'PIK3CB',
#   'PIK3CA',
#   'AKT1S1',
#   'LPIN2',
#   'SOS2',
#   'DEPDC5',
#   'EIF4E2',
#   'LPIN3',
#   'SGK1',
#   'SOS1',
#   'EIF4B',
#   'GSK3B',
#   'SEH1L',
#   'CAB39L',
#   'MAPKAP1',
#   'WNT8B',
#   'SLC3A2',
#   'PIK3R3',
#   'PIK3R2',
#   'WNT8A',
#   'WDR24',
#   'WNT6',
#   'WNT11',
#   'DVL1',
#   'DVL2',
#   'DVL3',
#   'RNF152',
#   'MIOS',
#   'WNT1',
#   'EIF4E',
#   'FNIP2',
#   'WNT2',
#   'WNT3',
#   'WNT4',
#   'FNIP1',
#   'ATP6V1G1',
#   'ATP6V1G2',
#   'ATP6V1G3',
#   'CHUK',
#   'PDPK1',
#   'WNT7A',
#   'WNT7B',
#   'CASTOR2',
#   'CASTOR1',
#   'MTOR',
#   'CLIP1',
#   'RPS6KB2',
#   'RPS6KB1',
#   'DDIT4',
#   'TBC1D7',
#   'LAMTOR1',
#   'LAMTOR3',
#   'KRAS',
#   'LAMTOR2',
#   'LAMTOR5',
#   'LAMTOR4',
#   'TELO2',
#   'PRR5',
#   'CAB39',
#   'PTEN',
#   'PIK3CD',
#   'INS',
#   'FLCN',
#   'IKBKB',
#   'RPTOR',
#   'RPS6KA6',
#   'RPS6KA1',
#   'RPS6KA3',
#   'RPS6KA2',
#   'MAPK3',
#   'HRAS',
#   'MAPK1',
#   'RICTOR',
#   'DEPTOR'],
#  'p53 signaling pathway': ['APAF1',
#   'SHISA5',
#   'TSC2',
#   'CDK6',
#   'TP53I3',
#   'RRM2B',
#   'CDK4',
#   'FAS',
#   'CCNG2',
#   'CCNG1',
#   'CDK2',
#   'ATM',
#   'BAX',
#   'BCL2',
#   'CDK1',
#   'CYCS',
#   'STEAP3',
#   'ATR',
#   'TP53',
#   'CD82',
#   'EI24',
#   'SERPINE1',
#   'GORAB',
#   'RCHY1',
#   'BBC3',
#   'CASP8',
#   'CASP9',
#   'CCND3',
#   'CCND2',
#   'CHEK1',
#   'CCND1',
#   'CHEK2',
#   'PERP',
#   'CASP3',
#   'GTSE1',
#   'PIDD1',
#   'RPRM',
#   'SIAH1',
#   'SERPINB5',
#   'RRM2',
#   'CDKN2A',
#   'GADD45B',
#   'GADD45A',
#   'IGFBP3',
#   'GADD45G',
#   'IGF1',
#   'TNFRSF10B',
#   'TNFRSF10A',
#   'DDB2',
#   'TP73',
#   'PPM1D',
#   'CCNE2',
#   'ADGRB1',
#   'CCNE1',
#   'BCL2L1',
#   'MDM4',
#   'SIVA1',
#   'MDM2',
#   'CDKN1A',
#   'PTEN',
#   'THBS1',
#   'SESN1',
#   'TP53AIP1',
#   'CCNB2',
#   'CCNB1',
#   'COP1',
#   'AIFM2',
#   'ZMAT3',
#   'SESN2',
#   'SESN3',
#   'PMAIP1',
#   'SFN',
#   'BID']}

# %%
# make sure the curated pathways only have genes in the background
for i in KEGG_2021_Human:
    KEGG_2021_Human[i] = list(set(KEGG_2021_Human[i]) & background_set)
KEGG_2021_Human
# Out:
# {'ABC transporters': ['ABCD1',
#   'ABCC6',
#   'ABCC9',
#   'ABCG8',
#   'ABCD2',
#   'ABCB5',
#   'ABCG2',
#   'ABCA6',
#   'ABCC11',
#   'ABCC1',
#   'ABCC5',
#   'ABCA13',
#   'ABCB9',
#   'ABCA4',
#   'TAP1',
#   'ABCB11',
#   'ABCC8',
#   'ABCB1',
#   'ABCB7',
#   'ABCA1',
#   'ABCA8',
#   'ABCA7',
#   'ABCA10',
#   'ABCB6',
#   'ABCA5',
#   'ABCC2',
#   'ABCD3',
#   'ABCB4',
#   'CFTR',
#   'ABCA3',
#   'ABCD4',
#   'ABCA9',
#   'ABCC3',
#   'ABCG1',
#   'DEFB1',
#   'TAP2',
#   'ABCC10',
#   'ABCB10',
#   'ABCG5',
#   'ABCA2',
#   'ABCC4',
#   'ABCB8',
#   'ABCA12'],
#  'AGE-RAGE signaling pathway in diabetic complications': ['ICAM1',
#   'PLCB4',
#   'MAPK8',
#   'PLCD4',
#   'TGFB1',
#   'EDN1',
#   'VEGFB',
#   'COL3A1',
#   'MAPK1',
#   'MAPK9',
#   'STAT5A',
#   'IL1A',
#   'MAPK13',
#   'CCL2',
#   'PIK3CD',
#   'PLCD1',
#   'TGFB2',
#   'SERPINE1',
#   'COL4A5',
#   'FOXO1',
#   'PIK3R3',
#   'AKT2',
#   'STAT3',
#   'COL1A2',
#   'RELA',
#   'EGR1',
#   'CDK4',
#   'CCND1',
#   'NFATC1',
#   'CASP3',
#   'TGFBR2',
#   'PRKCA',
#   'COL4A6',
#   'CYBB',
#   'TGFBR1',
#   'IL1B',
#   'COL4A3',
#   'PIM1',
#   'F3',
#   'BAX',
#   'THBD',
#   'NOX1',
#   'AGT',
#   'VEGFA',
#   'PIK3CA',
#   'NOX4',
#   'NFKB1',
#   'PLCB3',
#   'NRAS',
#   'SMAD4',
#   'MAPK12',
#   'VEGFC',
#   'KRAS',
#   'IL6',
#   'COL4A4',
#   'SMAD2',
#   'HRAS',
#   'PRKCZ',
#   'MMP2',
#   'PLCB2',
#   'PIK3R2',
#   'CDKN1B',
#   'STAT1',
#   'CXCL8',
#   'FN1',
#   'AKT3',
#   'VCAM1',
#   'STAT5B',
#   'SMAD3',
#   'CDC42',
#   'COL4A2',
#   'BCL2',
#   'MAPK11',
#   'COL4A1',
#   'VEGFD',
#   'DIAPH1',
#   'PIK3R1',
#   'JAK2',
#   'MAPK3',
#   'AGER',
#   'TNF',
#   'MAPK14',
#   'PRKCD',
#   'PLCB1',
#   'RAC1',
#   'PLCD3',
#   'MAPK10',
#   'PLCG1',
#   'PLCE1',
#   'TGFB3',
#   'JUN',
#   'COL1A1',
#   'PLCG2',
#   'PIK3CB',
#   'NOS3',
#   'PRKCE',
#   'PRKCB',
#   'AKT1'],
#  'AMPK signaling pathway': ['STRADA',
#   'PRKAB2',
#   'SIRT1',
#   'INSR',
#   'GYS1',
#   'TSC2',
#   'CPT1B',
#   'CD36',
#   'PPP2R5E',
#   'PFKFB3',
#   'PFKFB4',
#   'IRS1',
#   'CAB39',
#   'PPP2R2C',
#   'MAP3K7',
#   'PPP2R2B',
#   'CREB3L4',
#   'RAB14',
#   'CREB1',
#   'EEF2K',
#   'RAB11B',
#   'SREBF1',
#   'PIK3CD',
#   'G6PC2',
#   'LIPE',
#   'HNF4A',
#   'PPP2R2A',
#   'CRTC2',
#   'PPP2R5A',
#   'G6PC3',
#   'FBP1',
#   'FOXO1',
#   'PIK3R3',
#   'AKT2',
#   'PPP2R2D',
#   'CREB3',
#   'PPP2R3A',
#   'PFKM',
#   'PCK1',
#   'CCND1',
#   'LEPR',
#   'PRKAG1',
#   'PRKAG2',
#   'HMGCR',
#   'PPP2R5C',
#   'SLC2A4',
#   'PFKFB2',
#   'PPP2R1A',
#   'LEP',
#   'RAB8A',
#   'CFTR',
#   'PPP2CA',
#   'CCNA2',
#   'CREB3L1',
#   'IGF1R',
#   'ADIPOR2',
#   'CPT1C',
#   'RAB2A',
#   'AKT1',
#   'PFKFB1',
#   'CAMKK2',
#   'IRS2',
#   'PIK3CA',
#   'PFKP',
#   'MTOR',
#   'RPS6KB2',
#   'EEF2',
#   'FOXO3',
#   'PPARGC1A',
#   'SCD5',
#   'PRKAG3',
#   'PPP2R5B',
#   'PRKAA2',
#   'ACACA',
#   'PRKAA1',
#   'TSC1',
#   'GYS2',
#   'CREB3L3',
#   'STK11',
#   'PPP2R3B',
#   'PPP2R1B',
#   'ADIPOQ',
#   'PIK3R2',
#   'MLYCD',
#   'CCNA1',
#   'PPP2CB',
#   'RPTOR',
#   'CREB5',
#   'AKT3',
#   'FASN',
#   'PPP2R5D',
#   'CREB3L2',
#   'TBC1D1',
#   'PRKAB1',
#   'PPARG',
#   'ELAVL1',
#   'RPS6KB1',
#   'CAB39L',
#   'PFKL',
#   'SCD',
#   'ULK1',
#   'PIK3R1',
#   'IGF1',
#   'PPP2R3C',
#   'ADIPOR1',
#   'EIF4EBP1',
#   'CPT1A',
#   'AKT1S1',
#   'ACACB',
#   'PIK3CB',
#   'STRADB',
#   'PDPK1',
#   'PCK2',
#   'RAB10',
#   'RHEB',
#   'ADRA1A'],
#  'Acute myeloid leukemia': ['PIK3R3',
#   'PPARD',
#   'RELA',
#   'ARAF',
#   'PIK3CA',
#   'PER2',
#   'JUP',
#   'MPO',
#   'MTOR',
#   'RPS6KB1',
#   'NFKB1',
#   'FLT3',
#   'RPS6KB2',
#   'BAD',
#   'AKT2',
#   'CCND1',
#   'IL3',
#   'NRAS',
#   'CEBPE',
#   'PIK3R1',
#   'PIM2',
#   'MAPK3',
#   'RUNX1',
#   'BCL2A1',
#   'PML',
#   'MAP2K2',
#   'KRAS',
#   'CSF2',
#   'HRAS',
#   'EIF4EBP1',
#   'MAPK1',
#   'RARA',
#   'CEBPA',
#   'MAP2K1',
#   'SOS2',
#   'KIT',
#   'CD14',
#   'FCGR1A',
#   'CHUK',
#   'TCF7L2',
#   'SPI1',
#   'DUSP6',
#   'BRAF',
#   'ITGAM',
#   'STAT5A',
#   'GRB2',
#   'ZBTB16',
#   'CCNA2',
#   'MYC',
#   'RUNX1T1',
#   'PIK3CD',
#   'CSF1R',
#   'PIK3R2',
#   'CCNA1',
#   'RAF1',
#   'PIM1',
#   'PIK3CB',
#   'SOS1',
#   'IKBKB',
#   'IKBKG',
#   'TCF7',
#   'AKT3',
#   'TCF7L1',
#   'LEF1',
#   'STAT5B',
#   'AKT1',
#   'STAT3'],
#  'Adherens junction': ['ACP1',
#   'WASF3',
#   'CDC42',
#   'RHOA',
#   'INSR',
#   'FYN',
#   'AFDN',
#   'ACTB',
#   'FGFR1',
#   'CSNK2A1',
#   'RAC3',
#   'SORBS1',
#   'CDH1',
#   'VCL',
#   'TGFBR2',
#   'SMAD4',
#   'MAP3K7',
#   'CREBBP',
#   'MAPK3',
#   'SSX2IP',
#   'CTNNB1',
#   'CTNNA1',
#   'FER',
#   'CTNNA2',
#   'PTPRB',
#   'EP300',
#   'PARD3',
#   'EGFR',
#   'IQGAP1',
#   'PTPRJ',
#   'RAC1',
#   'WASF1',
#   'CSNK2A2',
#   'MET',
#   'NECTIN2',
#   'SRC',
#   'NECTIN3',
#   'YES1',
#   'LMO7',
#   'NECTIN1',
#   'SNAI2',
#   'PTPN6',
#   'TCF7L2',
#   'ACTN1',
#   'CSNK2B',
#   'NLK',
#   'RAC2',
#   'TGFBR1',
#   'ACTG1',
#   'TJP1',
#   'CTNNA3',
#   'ACTN4',
#   'PTPN1',
#   'PTPRF',
#   'IGF1R',
#   'BAIAP2',
#   'FARP2',
#   'MAPK1',
#   'ERBB2',
#   'PTPRM',
#   'WASL',
#   'CTNND1',
#   'SNAI1',
#   'WAS',
#   'TCF7',
#   'WASF2',
#   'TCF7L1',
#   'LEF1',
#   'NECTIN4',
#   'SMAD3'],
#  'Adipocytokine signaling pathway': ['PRKAB2',
#   'NFKBIE',
#   'TNFRSF1A',
#   'RXRG',
#   'NPY',
#   'PRKAB1',
#   'RELA',
#   'ACSBG2',
#   'IRS2',
#   'CAMKK2',
#   'CPT1B',
#   'ACSL3',
#   'AGRP',
#   'RXRA',
#   'MTOR',
#   'PRKCQ',
#   'NFKB1',
#   'CD36',
#   'MAPK8',
#   'AKT2',
#   'PCK1',
#   'IRS1',
#   'PPARGC1A',
#   'LEPR',
#   'PRKAG1',
#   'PRKAG2',
#   'JAK2',
#   'ACSBG1',
#   'PRKAG3',
#   'TNF',
#   'POMC',
#   'PRKAA2',
#   'TRADD',
#   'ADIPOR1',
#   'PRKAA1',
#   'ACSL4',
#   'ACSL5',
#   'SLC2A4',
#   'MAPK9',
#   'PTPN11',
#   'MAPK10',
#   'LEP',
#   'CHUK',
#   'STK11',
#   'CPT1A',
#   'TNFRSF1B',
#   'ACACB',
#   'ADIPOQ',
#   'G6PC2',
#   'TRAF2',
#   'SLC2A1',
#   'NFKBIB',
#   'PPARA',
#   'IKBKB',
#   'ACSL6',
#   'ADIPOR2',
#   'PCK2',
#   'SOCS3',
#   'CPT1C',
#   'IKBKG',
#   'AKT3',
#   'G6PC3',
#   'ACSL1',
#   'RXRB',
#   'AKT1',
#   'STAT3',
#   'NFKBIA'],
#  'Adrenergic signaling in cardiomyocytes': ['TNNC1',
#   'ADRB2',
#   'SCN1B',
#   'ATP1B2',
#   'ADCY5',
#   'PLCB4',
#   'PPP2R5E',
#   'CACNA2D3',
#   'PPP2R2C',
#   'ATF4',
#   'PIK3CG',
#   'CAMK2D',
#   'KCNE1',
#   'CACNB1',
#   'PPP2R2B',
#   'CREB3L4',
#   'RYR2',
#   'CACNA1C',
#   'CALML5',
#   'ADCY2',
#   'PPP1CA',
#   'MAPK1',
#   'ADCY4',
#   'CREB1',
#   'CACNA2D4',
#   'ATP2B1',
#   'SLC8A1',
#   'CAMK2A',
#   'MAPK13',
#   'ATP1A3',
#   'PRKACB',
#   'PPP2R2A',
#   'CALML3',
#   'CACNB2',
#   'PPP2R5A',
#   'CACNG2',
#   'ADCY3',
#   'AKT2',
#   'PPP2R2D',
#   'CREB3',
#   'CREM',
#   'TPM1',
#   'PPP2R3A',
#   'RPS6KA5',
#   'GNAS',
#   'PPP1R1A',
#   'PRKCA',
#   'PPP2R5C',
#   'MYH6',
#   'CALM3',
#   'ATP1B1',
#   'CACNA1D',
#   'PLN',
#   'ATP1B4',
#   'TPM2',
#   'TPM4',
#   'TNNT2',
#   'PPP2R1A',
#   'FXYD2',
#   'ATP1A2',
#   'ATP1A1',
#   'PPP2CA',
#   'ADCY9',
#   'ADCY6',
#   'CREB3L1',
#   'ADRB1',
#   'CACNA2D2',
#   'CACNG6',
#   'CAMK2B',
#   'CACNA1F',
#   'CALML4',
#   'ATP2A3',
#   'ADCY1',
#   'ADCY7',
#   'CALM1',
#   'AGT',
#   'ATP2A2',
#   'PIK3R5',
#   'CACNG3',
#   'PLCB3',
#   'CACNB4',
#   'PPP1CB',
#   'GNAI1',
#   'MAPK12',
#   'PPP2R5B',
#   'GNAI2',
#   'PRKACA',
#   'KCNQ1',
#   'CAMK2G',
#   'ATP2B4',
#   'CREB3L3',
#   'PPP2R3B',
#   'PPP2R1B',
#   'PLCB2',
#   'CALM2',
#   'SCN7A',
#   'MYL4',
#   'TPM3',
#   'CACNB3',
#   'PPP2CB',
#   'SCN4B',
#   'SLC8A2',
#   'CREB5',
#   'CALML6',
#   'ACTC1',
#   'AKT3',
#   'PPP2R5D',
#   'CACNG8',
#   'CREB3L2',
#   'CACNG4',
#   'RAPGEF3',
#   'SLC8A3',
#   'BCL2',
#   'MAPK11',
#   'ATF6B',
#   'MYL2',
#   'ATF2',
#   'ATP1A4',
#   'ADRA1B',
#   'TNNI3',
#   'MAPK3',
#   'KCNE1B',
#   'PPP2R3C',
#   'GNAQ',
#   'ATP2B3',
#   'GNAI3',
#   'MAPK14',
#   'CACNA2D1',
#   'PLCB1',
#   'PPP1CC',
#   'ATP2A1',
#   'SCN5A',
#   'ATP1B3',
#   'SLC9A1',
#   'RAPGEF4',
#   'PIK3R6',
#   'AKT1',
#   'ADRA1A',
#   'ATP2B2'],
#  'African trypanosomiasis': ['ICAM1',
#   'IDO1',
#   'PLCB4',
#   'PLCB3',
#   'TLR9',
#   'IFNG',
#   'HBA2',
#   'PRKCA',
#   'GNAQ',
#   'IL10',
#   'TNF',
#   'NPPA',
#   'IL6',
#   'HBB',
#   'LAMA4',
#   'PLCB1',
#   'THOP1',
#   'FASLG',
#   'FAS',
#   'HPR',
#   'IL18',
#   'PRKCG',
#   'IL12A',
#   'PLCB2',
#   'IL1B',
#   'APOL1',
#   'F2RL1',
#   'MYD88',
#   'IDO2',
#   'HBA1',
#   'APOA1',
#   'PRKCB',
#   'KNG1',
#   'VCAM1',
#   'IL12B'],
#  'Alanine, aspartate and glutamate metabolism': ['ASL',
#   'GPT',
#   'CAD',
#   'GFPT1',
#   'ALDH5A1',
#   'ALDH4A1',
#   'FOLH1',
#   'GAD2',
#   'RIMKLA',
#   'ABAT',
#   'ASNS',
#   'GLS',
#   'ADSL',
#   'GLUD1',
#   'RIMKLB',
#   'PPAT',
#   'GOT2',
#   'GOT1',
#   'GLUD2',
#   'ASPA',
#   'AGXT',
#   'GPT2',
#   'NIT2',
#   'GFPT2',
#   'ASRGL1',
#   'GAD1',
#   'CPS1',
#   'DDO',
#   'IL4I1',
#   'GLUL',
#   'GLS2',
#   'NAT8L',
#   'ASS1'],
#  'Alcoholism': ['CAMKK1',
#   'PDYN',
#   'SHC2',
#   'HDAC11',
#   'ADCY5',
#   'ATF4',
#   'HDAC1',
#   'CREB3L4',
#   'CALML5',
#   'PPP1CA',
#   'CRH',
#   'MAPK1',
#   'CREB1',
#   'SHC1',
#   'HDAC9',
#   'PRKACB',
#   'CALML3',
#   'SOS1',
#   'GNGT1',
#   'ADORA2B',
#   'HAT1',
#   'BDNF',
#   'CREB3',
#   'NPY',
#   'GNB5',
#   'GNB4',
#   'GNAS',
#   'GNG3',
#   'DDC',
#   'HDAC6',
#   'CALM3',
#   'SLC29A2',
#   'NTRK2',
#   'GNB2',
#   'PKIA',
#   'SHC3',
#   'CREB3L1',
#   'PPP1R1B',
#   'CALML4',
#   'MAOB',
#   'SLC29A3',
#   'CALM1',
#   'GRIN2C',
#   'GRIN2B',
#   'GNG5',
#   'ARAF',
#   'GNG7',
#   'CAMKK2',
#   'SLC18A2',
#   'HDAC7',
#   'NRAS',
#   'HDAC3',
#   'GNG12',
#   'PPP1CB',
#   'HDAC2',
#   'GNAI1',
#   'HDAC5',
#   'GNAI2',
#   'KRAS',
#   'PRKACA',
#   'HRAS',
#   'SLC29A1',
#   'GNG10',
#   'SOS2',
#   'CREB3L3',
#   'CALM2',
#   'GNB3',
#   'RAF1',
#   'GRIN1',
#   'CREB5',
#   'CALML6',
#   'GRIN2D',
#   'CAMK4',
#   'GNG11',
#   'GNB1',
#   'CREB3L2',
#   'SLC18A1',
#   'HDAC8',
#   'MAOA',
#   'SLC6A3',
#   'GRIN3A',
#   'ATF6B',
#   'ATF2',
#   'HDAC4',
#   'MAPK3',
#   'GNG8',
#   'GNG4',
#   'HDAC10',
#   'GNAI3',
#   'GRIN2A',
#   'ADORA2A',
#   'PPP1CC',
#   'SHC4',
#   'GNAO1',
#   'MAP2K1',
#   'BRAF',
#   'GRIN3B',
#   'GRB2',
#   'DRD2',
#   'GNGT2',
#   'FOSB',
#   'GNG2'],
#  'Aldosterone synthesis and secretion': ['CYP21A2',
#   'SCARB1',
#   'PDE2A',
#   'ATP1B2',
#   'DAGLA',
#   'ADCY5',
#   'PLCB4',
#   'CYP11A1',
#   'ATF4',
#   'KCNK3',
#   'CAMK2D',
#   'ITPR3',
#   'CREB3L4',
#   'PRKD3',
#   'CACNA1C',
#   'CALML5',
#   'ADCY2',
#   'CACNA1I',
#   'ADCY4',
#   'CREB1',
#   'ATP2B1',
#   'CAMK2A',
#   'HSD3B1',
#   'ATP1A3',
#   'LIPE',
#   'PRKACB',
#   'DAGLB',
#   'HSD3B2',
#   'CALML3',
#   'ADCY3',
#   'CREB3',
#   'STAR',
#   'ORAI1',
#   'KCNK9',
#   'GNAS',
#   'CACNA1H',
#   'MC2R',
#   'PRKCA',
#   'CALM3',
#   'ATP1B1',
#   'CACNA1D',
#   'ITPR1',
#   'PRKD2',
#   'ATP1B4',
#   'PRKCG',
#   'ATP1A2',
#   'ATP1A1',
#   'CAMK1',
#   'ADCY9',
#   'ADCY6',
#   'CREB3L1',
#   'CAMK2B',
#   'CACNA1F',
#   'CALML4',
#   'ADCY1',
#   'ADCY7',
#   'CALM1',
#   'AGT',
#   'KCNJ5',
#   'ITPR2',
#   'PLCB3',
#   'POMC',
#   'PRKACA',
#   'NPR1',
#   'NR4A2',
#   'PRKD1',
#   'ATP2B4',
#   'CAMK2G',
#   'CREB3L3',
#   'PLCB2',
#   'CALM2',
#   'CREB5',
#   'CALML6',
#   'CAMK4',
#   'CREB3L2',
#   'NR4A1',
#   'CACNA1G',
#   'CAMK1D',
#   'ATF6B',
#   'ATF2',
#   'ATP1A4',
#   'GNAQ',
#   'ATP2B3',
#   'NPPA',
#   'PLCB1',
#   'GNA11',
#   'ATF1',
#   'CAMK1G',
#   'ATP1B3',
#   'PRKCE',
#   'PRKCB',
#   'LDLR',
#   'ATP2B2'],
#  'Aldosterone-regulated sodium reabsorption': ['SGK1',
#   'SCNN1B',
#   'INSR',
#   'PIK3CA',
#   'ATP1B2',
#   'SLC9A3R2',
#   'IRS1',
#   'ATP1A4',
#   'PIK3R1',
#   'MAPK3',
#   'PRKCA',
#   'IGF1',
#   'KCNJ1',
#   'ATP1B1',
#   'KRAS',
#   'HSD11B2',
#   'SCNN1G',
#   'ATP1B4',
#   'MAPK1',
#   'NR3C2',
#   'FXYD2',
#   'PRKCG',
#   'ATP1A2',
#   'ATP1A1',
#   'NEDD4L',
#   'FXYD4',
#   'ATP1A3',
#   'SFN',
#   'PIK3CD',
#   'PIK3R2',
#   'PIK3CB',
#   'PDPK1',
#   'ATP1B3',
#   'PRKCB',
#   'SCNN1A',
#   'PIK3R3'],
#  'Allograft rejection': ['HLA-G',
#   'CD40',
#   'CD40LG',
#   'HLA-B',
#   'HLA-DRA',
#   'HLA-DRB1',
#   'HLA-DQB1',
#   'GZMB',
#   'HLA-DQA1',
#   'CD86',
#   'HLA-C',
#   'IFNG',
#   'HLA-DOB',
#   'HLA-DMA',
#   'HLA-DRB5',
#   'HLA-DQA2',
#   'IL4',
#   'IL2',
#   'IL10',
#   'TNF',
#   'IL5',
#   'FASLG',
#   'HLA-F',
#   'FAS',
#   'HLA-DPA1',
#   'IL12A',
#   'CD80',
#   'CD28',
#   'HLA-DPB1',
#   'HLA-DOA',
#   'HLA-A',
#   'PRF1',
#   'HLA-E',
#   'HLA-DMB',
#   'IL12B'],
#  'Alzheimer disease': ['ATG14',
#   'INSR',
#   'PSMC4',
#   'NDUFB6',
#   'EIF2AK3',
#   'PLCB4',
#   'FZD10',
#   'IRS1',
#   'ATF4',
#   'CACNA1C',
#   'CALML5',
#   'PSMB1',
#   'IL1A',
#   'NDUFA9',
#   'NDUFAB1',
#   'ATG2A',
#   'VDAC3',
#   'TUBA1A',
#   'TUBB4B',
#   'GAPDH',
#   'FZD1',
#   'ATP5PF',
#   'COX5A',
#   'NOS2',
#   'CALM3',
#   'WNT11',
#   'TUBB6',
#   'PSMD13',
#   'CYBB',
#   'CSNK2B',
#   'PSMD12',
#   'IL1B',
#   'COX5B',
#   'NDUFB9',
#   'NDUFA12',
#   'PPID',
#   'BACE2',
#   'ATP2A3',
#   'ULK2',
#   'CAPN1',
#   'PSMC6',
#   'KIF5B',
#   'GRIN2B',
#   'MAP3K5',
#   'SEM1',
#   'NDUFB10',
#   'WNT7B',
#   'AMBRA1',
#   'NDUFS4',
#   'PSMD11',
#   'NRAS',
#   'NDUFS6',
#   'TUBB4A',
#   'TUBB2A',
#   'NDUFB3',
#   'PSEN1',
#   'SLC25A5',
#   'WNT10B',
#   'PIK3R2',
#   'PSMD6',
#   'DKK2',
#   'IKBKB',
#   'NDUFC2-KCTD14',
#   'COX8A',
#   'COX4I2',
#   'NDUFA13',
#   'WNT3',
#   'SLC25A31',
#   'NDUFB11',
#   'NDUFA4L2',
#   'IDE',
#   'SLC25A6',
#   'GNAQ',
#   'TNF',
#   'DVL1',
#   'NDUFA5',
#   'UQCRFS1',
#   'WNT7A',
#   'MCU',
#   'ATP2A1',
#   'NDUFA10',
#   'WNT16',
#   'VDAC2',
#   'CDK5',
#   'AKT1',
#   'UQCRB',
#   'NDUFA1',
#   'TUBB',
#   'NDUFB2',
#   'COX7A2L',
#   'CYC1',
#   'ATP5F1A',
#   'ATP5F1C',
#   'FZD3',
#   'PIK3CD',
#   'NDUFS5',
#   'ATP5F1B',
#   'APC2',
#   'UQCR10',
#   'CASP9',
#   'KLC1',
#   'PIK3R3',
#   'PSMD9',
#   'ATG13',
#   'COX6B2',
#   'EIF2S1',
#   'ATG101',
#   'CASP3',
#   'WNT8B',
#   'PIK3C3',
#   'ATP5MC3',
#   'CACNA1D',
#   'PSMB4',
#   'CSNK2A2',
#   'FZD8',
#   'WNT4',
#   'PPP3CA',
#   'FRAT1',
#   'CHRNA7',
#   'PSMC1',
#   'GSK3B',
#   'TUBA8',
#   'CALML4',
#   'CASP7',
#   'CYCS',
#   'FZD9',
#   'PSMD3',
#   'ITPR2',
#   'KLC3',
#   'UQCRHL',
#   'WIPI2',
#   'HRAS',
#   'COX6B1',
#   'PSMA8',
#   'CSNK1A1L',
#   'WNT10A',
#   'PLCB2',
#   'NDUFA6',
#   'COX7A2',
#   'HSD17B10',
#   'LPL',
#   'AKT3',
#   'PSMC2',
#   'ATF6',
#   'PIK3R1',
#   'MAPK3',
#   'ATP5MC2',
#   'COX6A2',
#   'CAPN2',
#   'WNT9B',
#   'MAPK10',
#   'MAP2K1',
#   'PPP3CB',
#   'TUBB1',
#   'NDUFS8',
#   'BACE1',
#   'APBB1',
#   'ADAM17',
#   'NDUFA2',
#   'NRBF2',
#   'AXIN1',
#   'COX7C',
#   'PSMD4',
#   'UQCRC2',
#   'DKK4',
#   'ATP5F1D',
#   'ERN1',
#   'ITPR3',
#   'MAPK1',
#   'MAPK9',
#   'BID',
#   'EIF2AK2',
#   'KIF5A',
#   'NDUFV2',
#   'ADRM1',
#   'FADD',
#   'ATP5PO',
#   'FZD4',
#   'WNT3A',
#   'NDUFC2',
#   'AKT2',
#   'CHRM5',
#   'ATP5MC1',
#   'COX7A1',
#   'GPR83',
#   'FRAT2',
#   'PTGS2',
#   'WNT2B',
#   'DKK1',
#   'VDAC1',
#   'WNT1',
#   'MAP2K2',
#   'BECN1',
#   'PIK3R4',
#   'NCSTN',
#   'FAS',
#   'NDUFB4',
#   'RB1CC1',
#   'SDHB',
#   'UQCR11',
#   'NDUFA8',
#   'PSMA4',
#   'APP',
#   'CASP8',
#   'PSMB7',
#   'PSMB6',
#   'NOX1',
#   'KLC2',
#   'WNT6',
#   'ATP2A2',
#   'ATP5PB',
#   'GRIN2C',
#   'ARAF',
#   'IRS2',
#   'PIK3CA',
#   'LRP1',
#   'UQCRC1',
#   'COX6C',
#   'NFKB1',
#   'PSMC5',
#   'PLCB3',
#   'PPP3R2',
#   'NDUFV3',
#   'CDK5R1',
#   'NDUFB8',
#   'COX7B2',
#   'DDIT3',
#   'PSMD8',
#   'APAF1',
#   'KRAS',
#   'ADAM10',
#   'NDUFA3',
#   'NDUFC1',
#   'PSMB3',
#   'TRAF2',
#   'UQCRH',
#   'TUBA3D',
#   'MAP2K7',
#   'RTN3',
#   'KLC4',
#   'COX4I1',
#   'CALML6',
#   'GRIN2D',
#   'SNCA',
#   'TPTEP2-CSNK1E',
#   'TNFRSF1A',
#   'PPIF',
#   'WNT5B',
#   'PPP3R1',
#   'CSF1',
#   'NDUFS7',
#   'SLC25A4',
#   'ULK1',
#   'PSMD7',
#   'NDUFS2',
#   'APH1B',
#   'PLCB1',
#   'XBP1',
#   'SDHD',
#   'TUBB3',
#   'FZD6',
#   'LRP6',
#   'PSMA7',
#   'PSMA1',
#   'NOS1',
#   'NDUFA11',
#   'FZD7',
#   'MAPK8',
#   'FZD5',
#   'CTNNB1',
#   'NDUFB7',
#   'DVL3',
#   'APH1A',
#   'NDUFS1',
#   'WNT9A',
#   'RTN4',
#   'CALML3',
#   'NDUFB1',
#   'FZD2',
#   'MAPT',
#   'LRP5',
#   'RELA',
#   'APC',
#   'NDUFB5',
#   'ATP5F1E',
#   'ITPR1',
#   'PSMB2',
#   'APOE',
#   'TUBA1B',
#   'COX7B',
#   'ATG2B',
#   'RYR3',
#   'PSEN2',
#   'CACNA1F',
#   'PSMA6',
#   'PSMD2',
#   'GRM5',
#   'CALM1',
#   'TUBA4A',
#   'NOX4',
#   'TUBB8',
#   'MTOR',
#   'PSMA5',
#   'CSNK2A1',
#   'WNT5A',
#   'ATP5PD',
#   'DVL2',
#   'PSENEN',
#   'IL6',
#   'SDHC',
#   'PSMC3',
#   'PPP3CC',
#   'NDUFA4',
#   'CALM2',
#   'MME',
#   'RAF1',
#   'GRIN1',
#   'PSMB5',
#   'CHRM3',
#   'NDUFA7',
#   'KIF5C',
#   'PSMA2',
#   'NDUFV1',
#   'COX6A1',
#   'WIPI1',
#   'CSNK1A1',
#   'BAD',
#   'UQCRQ',
#   'TUBA1C',
#   'AXIN2',
#   'TUBAL3',
#   'AGER',
#   'GRIN2A',
#   'CSNK1E',
#   'PSMA3',
#   'CHUK',
#   'BRAF',
#   'SDHA',
#   'NAE1',
#   'PIK3CB',
#   'PSMD1',
#   'NDUFS3',
#   'TUBB2B',
#   'PSMD14'],
#  'Amino sugar and nucleotide sugar metabolism': ['NAGK',
#   'MPI',
#   'HK2',
#   'PGM2',
#   'NANP',
#   'GFPT1',
#   'UAP1L1',
#   'GNE',
#   'PMM2',
#   'PGM1',
#   'GMPPA',
#   'GALK1',
#   'GALT',
#   'GNPNAT1',
#   'HK1',
#   'UAP1',
#   'CYB5R4',
#   'GALE',
#   'AMDHD2',
#   'PGM3',
#   'HKDC1',
#   'CYB5R2',
#   'NANS',
#   'CMAS',
#   'NPL',
#   'CYB5R1',
#   'HEXB',
#   'CYB5RL',
#   'GFPT2',
#   'GMPPB',
#   'GCK',
#   'CYB5R3',
#   'HK3',
#   'CHIT1',
#   'GNPDA2',
#   'HEXA',
#   'PMM1',
#   'UXS1',
#   'UGP2',
#   'GPI',
#   'RENBP',
#   'GMDS',
#   'GNPDA1',
#   'UGDH',
#   'FPGT'],
#  'Aminoacyl-tRNA biosynthesis': ['LARS2',
#   'FARSB',
#   'TARS2',
#   'SEPSECS',
#   'FARS2',
#   'PSTK',
#   'NARS2',
#   'PARS2',
#   'MARS2',
#   'SARS2',
#   'VARS2',
#   'CARS2',
#   'DARS2',
#   'MTFMT',
#   'YARS2',
#   'HARS2',
#   'WARS2',
#   'GATB',
#   'RARS2',
#   'FARSA',
#   'EARS2',
#   'IARS2',
#   'GATC',
#   'QRSL1',
#   'AARS2'],
#  'Amoebiasis': ['LAMC3',
#   'PLCB4',
#   'TGFB1',
#   'TLR4',
#   'COL3A1',
#   'RAB7A',
#   'CD1D',
#   'TLR2',
#   'CXCL2',
#   'ACTN1',
#   'PIK3CD',
#   'PRKACB',
#   'TGFB2',
#   'ARG1',
#   'COL4A5',
#   'C8A',
#   'RAB7B',
#   'PIK3R3',
#   'COL1A2',
#   'RELA',
#   'GNAS',
#   'C8B',
#   'LAMC1',
#   'NOS2',
#   'VCL',
#   'IFNG',
#   'CASP3',
#   'CD1B',
#   'PRKCA',
#   'COL4A6',
#   'CD1E',
#   'ARG2',
#   'CD1C',
#   'PRKCG',
#   'SERPINB10',
#   'IL1B',
#   'COL4A3',
#   'ACTN4',
#   'PTK2',
#   'LAMA3',
#   'RAB5A',
#   'ADCY1',
#   'MUC2',
#   'CD14',
#   'PIK3CA',
#   'HSPB1',
#   'NFKB1',
#   'LAMC2',
#   'SERPINB4',
#   'PLCB3',
#   'SERPINB13',
#   'PRDX1',
#   'IL1R1',
#   'SERPINB3',
#   'CSF2',
#   'PRKACA',
#   'IL6',
#   'SERPINB6',
#   'COL4A4',
#   'CD1A',
#   'LAMA5',
#   'ITGAM',
#   'GNA14',
#   'PLCB2',
#   'PIK3R2',
#   'CXCL8',
#   'GNA15',
#   'FN1',
#   'C8G',
#   'RAB5B',
#   'LAMB1',
#   'IL12B',
#   'CTSG',
#   'COL4A2',
#   'CXCL3',
#   'COL4A1',
#   'ITGB2',
#   'PIK3R1',
#   'LAMB4',
#   'GNAQ',
#   'LAMB2',
#   'IL10',
#   'TNF',
#   'PLCB1',
#   'LAMA4',
#   'GNA11',
#   'IL1R2',
#   'GNAL',
#   'SERPINB9',
#   'RAB5C',
#   'IL12A',
#   'TGFB3',
#   'LAMA1',
#   'COL1A1',
#   'PIK3CB',
#   'LAMA2',
#   'CXCL1',
#   'PRKCB',
#   'C9',
#   'LAMB3'],
#  'Amphetamine addiction': ['GRIN2C',
#   'CREB3L2',
#   'ARC',
#   'CREB3',
#   'GRIN2B',
#   'SLC18A1',
#   'PDYN',
#   'SIRT1',
#   'PPP3R1',
#   'MAOA',
#   'FOS',
#   'ADCY5',
#   'SLC18A2',
#   'GNAS',
#   'SLC6A3',
#   'PPP3R2',
#   'GRIN3A',
#   'ATF6B',
#   'ATF2',
#   'PPP1CB',
#   'ATF4',
#   'DDC',
#   'CAMK2D',
#   'PRKCA',
#   'HDAC2',
#   'STX1A',
#   'GRIA3',
#   'HDAC1',
#   'CREB3L4',
#   'CALM3',
#   'CACNA1C',
#   'CALML5',
#   'GRIN2A',
#   'CACNA1D',
#   'PRKACA',
#   'PPP1CC',
#   'PPP1CA',
#   'CREB1',
#   'CAMK2G',
#   'PPP3CC',
#   'PPP3CB',
#   'CAMK2A',
#   'CREB3L3',
#   'PRKCG',
#   'GRIN3B',
#   'JUN',
#   'PPP3CA',
#   'CALM2',
#   'PRKACB',
#   'CREB3L1',
#   'PPP1R1B',
#   'GRIN1',
#   'GRIA1',
#   'CALML3',
#   'GRIA4',
#   'CAMK2B',
#   'FOSB',
#   'CREB5',
#   'CALML6',
#   'CALML4',
#   'GRIN2D',
#   'MAOB',
#   'CAMK4',
#   'PRKCB',
#   'CALM1'],
#  'Amyotrophic lateral sclerosis': ['UBQLN2',
#   'ATG14',
#   'PSMC4',
#   'RANBP2',
#   'NDUFB6',
#   'EIF2AK3',
#   'DCTN3',
#   'ATF4',
#   'HNRNPA1L2',
#   'GPX2',
#   'RAB1A',
#   'PSMB1',
#   'NDUFA9',
#   'NDUFAB1',
#   'TNFRSF1B',
#   'DNAL1',
#   'ATG2A',
#   'SLC1A2',
#   'NUP160',
#   'DCTN1',
#   'TUBA1A',
#   'TUBB4B',
#   'HSPA5',
#   'ATP5PF',
#   'COX5A',
#   'NOS2',
#   'HDAC6',
#   'ALYREF',
#   'CCS',
#   'ALS2',
#   'NUP85',
#   'TUBB6',
#   'PSMD13',
#   'PSMD12',
#   'COX5B',
#   'NDUFB9',
#   'NDUFA12',
#   'RAB5A',
#   'ULK2',
#   'PSMC6',
#   'KIF5B',
#   'GRIN2B',
#   'MAP3K5',
#   'SEM1',
#   'HNRNPA2B1',
#   'PRKN',
#   'NDUFB10',
#   'PFN4',
#   'CASP1',
#   'AMBRA1',
#   'NDUFS4',
#   'PSMD11',
#   'NUP35',
#   'DERL1',
#   'NDUFS6',
#   'SEC13',
#   'BCL2L1',
#   'TUBB4A',
#   'TUBB2A',
#   'NDUFB3',
#   'NEFL',
#   'PSMD6',
#   'NDUFC2-KCTD14',
#   'COX8A',
#   'COX4I2',
#   'NDUFA13',
#   'DNAH2',
#   'TOMM40',
#   'NDUFB11',
#   'SPG11',
#   'NDUFA4L2',
#   'TPR',
#   'TNF',
#   'DNAH7',
#   'NDUFA5',
#   'UQCRFS1',
#   'HAP1',
#   'MCU',
#   'NDUFA10',
#   'NCBP1',
#   'NUP107',
#   'DNAI1',
#   'UQCRB',
#   'NEFM',
#   'NDUFA1',
#   'TUBB',
#   'ATXN2',
#   'NDUFB2',
#   'DNAH10',
#   'SETX',
#   'COX7A2L',
#   'CYC1',
#   'ATP5F1A',
#   'ATP5F1C',
#   'MAPK13',
#   'NDUFS5',
#   'ATP5F1B',
#   'CHCHD10',
#   'UQCR10',
#   'DNAH12',
#   'CASP9',
#   'SRSF7',
#   'KLC1',
#   'PSMD9',
#   'CAT',
#   'ATG13',
#   'COX6B2',
#   'EIF2S1',
#   'DNAH14',
#   'ATG101',
#   'CASP3',
#   'SIGMAR1',
#   'PIK3C3',
#   'NUP214',
#   'ATP5MC3',
#   'PSMB4',
#   'DNAH8',
#   'GABARAPL2',
#   'RAB8A',
#   'MAP2K6',
#   'DCTN4',
#   'PPP3CA',
#   'BAX',
#   'PSMC1',
#   'GABARAPL1',
#   'NUP62',
#   'TUBA8',
#   'CYCS',
#   'PSMD3',
#   'NRG1',
#   'KLC3',
#   'UQCRHL',
#   'WIPI2',
#   'ACTR1B',
#   'COX6B1',
#   'PSMA8',
#   'TARDBP',
#   'MATR3',
#   'NRG4',
#   'SEH1L',
#   'NDUFA6',
#   'COX7A2',
#   'UBQLN1',
#   'PSMC2',
#   'NUP88',
#   'TBK1',
#   'MAPK11',
#   'ATF6',
#   'ATP5MC2',
#   'WDR41',
#   'COX6A2',
#   'PPP3CB',
#   'ERBB4',
#   'DAXX',
#   'TUBB1',
#   'NDUFS8',
#   'DNAH3',
#   'TP53',
#   'SOD1',
#   'ANXA11',
#   'POM121C',
#   'NDUFA2',
#   'NRBF2',
#   'SRSF3',
#   'ATXN2L',
#   'COX7C',
#   'PSMD4',
#   'UQCRC2',
#   'ATP5F1D',
#   'ERN1',
#   'ITPR3',
#   'VAPB',
#   'BID',
#   'HNRNPA3',
#   'KIF5A',
#   'NDUFV2',
#   'ADRM1',
#   'SQSTM1',
#   'NEFH',
#   'ATP5PO',
#   'UBQLN4',
#   'NUP210L',
#   'NDUFC2',
#   'ATP5MC1',
#   'COX7A1',
#   'GLE1',
#   'VDAC1',
#   'BECN1',
#   'PIK3R4',
#   'NDUFB4',
#   'RB1CC1',
#   'NXT2',
#   'SDHB',
#   'VCP',
#   'UQCR11',
#   'NDUFA8',
#   'PSMA4',
#   'DNAH9',
#   'PSMB7',
#   'PSMB6',
#   'KLC2',
#   'ATP5PB',
#   'GRIN2C',
#   'UQCRC1',
#   'COX6C',
#   'NXF3',
#   'PSMC5',
#   'ACTB',
#   'NDUFV3',
#   'PPP3R2',
#   'GPX3',
#   'DNAH6',
#   'NDUFB8',
#   'DNAI2',
#   'COX7B2',
#   'NXT1',
#   'DDIT3',
#   'PSMD8',
#   'APAF1',
#   'NXF1',
#   'MAPK12',
#   'NUP133',
#   'NUP98',
#   'NDUFA3',
#   'FUS',
#   'NDUFC1',
#   'NUP37',
#   'DNAH11',
#   'PSMB3',
#   'TRAF2',
#   'UQCRH',
#   'TUBA3D',
#   'KLC4',
#   'COX4I1',
#   'GRIN2D',
#   'DCTN6',
#   'TNFRSF1A',
#   'NUP188',
#   'PPP3R1',
#   'NDUFS7',
#   'ULK1',
#   'PSMD7',
#   'NUP50',
#   'NDUFS2',
#   'NUP43',
#   'NDC1',
#   'GPX8',
#   'XBP1',
#   'RAC1',
#   'HNRNPA1',
#   'SDHD',
#   'TUBB3',
#   'PSMA7',
#   'PSMA1',
#   'GRIA1',
#   'PFN2',
#   'RAB39B',
#   'ACTR10',
#   'ACTR1A',
#   'NUP54',
#   'ANXA7',
#   'NOS1',
#   'NDUFA11',
#   'RAE1',
#   'NDUFB7',
#   'PFN1',
#   'NDUFS1',
#   'DNALI1',
#   'PINK1',
#   'NUP153',
#   'MAP2K3',
#   'NDUFB1',
#   'DCTN5',
#   'NUP155',
#   'NDUFB5',
#   'ATP5F1E',
#   'PSMB2',
#   'DNAH1',
#   'GABARAP',
#   'CHMP2B',
#   'TUBA1B',
#   'COX7B',
#   'ATG2B',
#   'PSMA6',
#   'NUP210',
#   'PSMD2',
#   'FIG4',
#   'TANK',
#   'TUBA4A',
#   'TUBB8',
#   'MTOR',
#   'PSMA5',
#   'NUP93',
#   'ATP5PD',
#   'DCTN2',
#   'GPX7',
#   'SDHC',
#   'PSMC3',
#   'PPP3CC',
#   'NDUFA4',
#   'NRG2',
#   'NUP205',
#   'ANG',
#   'NUP58',
#   'GRIN1',
#   'PSMB5',
#   'POM121',
#   'KIF5C',
#   'NDUFA7',
#   'PSMA2',
#   'NDUFV1',
#   'PRPH',
#   'COX6A1',
#   'WIPI1',
#   'BAD',
#   'UQCRQ',
#   'TUBA1C',
#   'BCL2',
#   'DNAH5',
#   'TUBAL3',
#   'MAPK14',
#   'GRIN2A',
#   'PSMA3',
#   'OPTN',
#   'TOMM40L',
#   'DNAH17',
#   'ACTG1',
#   'SDHA',
#   'DNAL4',
#   'PSMD1',
#   'NDUFS3',
#   'TUBB2B',
#   'SMCR8',
#   'PSMD14'],
#  'Antigen processing and presentation': ['B2M',
#   'RFXANK',
#   'CTSS',
#   'CANX',
#   'RFXAP',
#   'HLA-G',
#   'HSP90AA1',
#   'HLA-B',
#   'TAPBP',
#   'HSPA5',
#   'HLA-DRA',
#   'HLA-DRB1',
#   'PDIA3',
#   'HLA-DQB1',
#   'CD4',
#   'KIR2DL4',
#   'KLRD1',
#   'HLA-DQA1',
#   'HSPA4',
#   'TAP1',
#   'PSME2',
#   'HLA-C',
#   'NFYC',
#   'CALR',
#   'IFNG',
#   'HLA-DMA',
#   'HLA-DOB',
#   'HLA-DRB5',
#   'HSP90AB1',
#   'HLA-DQA2',
#   'CTSL',
#   'NFYA',
#   'TNF',
#   'NFYB',
#   'KIR3DL2',
#   'IFI30',
#   'PSME3',
#   'CD8B',
#   'CTSB',
#   'HSPA2',
#   'CREB1',
#   'HLA-F',
#   'LGMN',
#   'CIITA',
#   'KLRC2',
#   'HLA-DPA1',
#   'KIR2DL1',
#   'HSPA6',
#   'CD74',
#   'KLRC1',
#   'HSPA1A',
#   'RFX5',
#   'TAP2',
#   'KLRC3',
#   'KIR3DL1',
#   'HLA-DPB1',
#   'KIR2DL3',
#   'HLA-DOA',
#   'HLA-A',
#   'HSPA1L',
#   'CD8A',
#   'PSME1',
#   'HLA-E',
#   'KLRC4',
#   'KIR3DL3',
#   'HSPA8',
#   'HSPA1B',
#   'CD8B2',
#   'HLA-DMB'],
#  'Apelin signaling pathway': ['MEF2C',
#   'PRKAB2',
#   'NOTCH3',
#   'NOS1',
#   'ADCY5',
#   'PLCB4',
#   'PIK3CG',
#   'ITPR3',
#   'RYR2',
#   'CALML5',
#   'ADCY2',
#   'MAPK1',
#   'TFAM',
#   'ADCY4',
#   'SLC8A1',
#   'LIPE',
#   'PRKACB',
#   'CALML3',
#   'GNGT1',
#   'SERPINE1',
#   'MEF2D',
#   'ADCY3',
#   'AKT2',
#   'GNB5',
#   'GNB4',
#   'RYR1',
#   'EGR1',
#   'CCND1',
#   'CDH1',
#   'GNG3',
#   'NOS2',
#   'PRKAG1',
#   'PRKAG2',
#   'PIK3C3',
#   'NRF1',
#   'CALM3',
#   'MAP2K2',
#   'ITPR1',
#   'BECN1',
#   'GABARAPL2',
#   'PIK3R4',
#   'GNB2',
#   'GABARAP',
#   'TGFBR1',
#   'ADCY9',
#   'ADCY6',
#   'MEF2B',
#   'PLAT',
#   'RYR3',
#   'GABARAPL1',
#   'CALML4',
#   'SPHK1',
#   'ADCY1',
#   'ADCY7',
#   'CALM1',
#   'SPP1',
#   'PIK3R5',
#   'GNA13',
#   'GNG5',
#   'GNG7',
#   'ITPR2',
#   'JAG1',
#   'MTOR',
#   'RPS6KB2',
#   'PLCB3',
#   'NRAS',
#   'PPARGC1A',
#   'SMAD4',
#   'GNG12',
#   'APLN',
#   'GNAI1',
#   'HDAC5',
#   'PRKAG3',
#   'PRKAA2',
#   'GNAI2',
#   'ACTA2',
#   'KRAS',
#   'PRKAA1',
#   'PRKACA',
#   'SMAD2',
#   'HRAS',
#   'GNG10',
#   'MYLK',
#   'RRAS',
#   'PLCB2',
#   'BORCS8-MEF2B',
#   'MYLK3',
#   'CALM2',
#   'GNB3',
#   'SPHK2',
#   'RAF1',
#   'MYL4',
#   'SLC8A2',
#   'CALML6',
#   'RRAS2',
#   'AKT3',
#   'CAMK4',
#   'GNG11',
#   'SMAD3',
#   'GNB1',
#   'PRKAB1',
#   'RPS6',
#   'MYLK2',
#   'SLC8A3',
#   'MYLK4',
#   'RPS6KB1',
#   'MRAS',
#   'MYL2',
#   'PDE3B',
#   'PLIN1',
#   'GNG8',
#   'HDAC4',
#   'GNG4',
#   'GNAQ',
#   'MAPK3',
#   'GNAI3',
#   'PLCB1',
#   'KLF2',
#   'ADCY10',
#   'MAP2K1',
#   'GNGT2',
#   'NOS3',
#   'UCP1',
#   'PRKCE',
#   'SLC9A1',
#   'GNG2',
#   'MEF2A',
#   'PIK3R6',
#   'AKT1'],
#  'Apoptosis': ['CTSS',
#   'PARP2',
#   'BBC3',
#   'FOS',
#   'EIF2AK3',
#   'MAPK8',
#   'ATF4',
#   'ERN1',
#   'ITPR3',
#   'BIRC6',
#   'BIRC3',
#   'PIDD1',
#   'MAP3K14',
#   'MAPK1',
#   'MAPK9',
#   'FASLG',
#   'CTSB',
#   'HTRA2',
#   'BID',
#   'CFLAR',
#   'PIK3CD',
#   'CASP9',
#   'FADD',
#   'PARP1',
#   'TUBA1A',
#   'PIK3R3',
#   'AKT2',
#   'NFKBIA',
#   'RELA',
#   'LMNA',
#   'IL3RA',
#   'CTSO',
#   'EIF2S1',
#   'CASP10',
#   'CASP2',
#   'CASP3',
#   'CTSL',
#   'LMNB2',
#   'TNFRSF10B',
#   'DFFA',
#   'CTSD',
#   'MAP2K2',
#   'ITPR1',
#   'BECN1',
#   'NTRK1',
#   'NGFR',
#   'FAS',
#   'PTPN13',
#   'BCL2L11',
#   'CTSC',
#   'SPTA1',
#   'TUBA1B',
#   'CTSF',
#   'CASP8',
#   'BAX',
#   'TUBA8',
#   'GADD45G',
#   'CASP7',
#   'CAPN1',
#   'CYCS',
#   'MAP3K5',
#   'DAB2IP',
#   'PIK3CA',
#   'ITPR2',
#   'TUBA4A',
#   'ENDOG',
#   'HRK',
#   'NFKB1',
#   'GZMB',
#   'ACTB',
#   'TRAF1',
#   'NRAS',
#   'IL3',
#   'CTSK',
#   'BIRC5',
#   'DDIT3',
#   'APAF1',
#   'TRADD',
#   'KRAS',
#   'XIAP',
#   'PARP4',
#   'BCL2L1',
#   'HRAS',
#   'SPTAN1',
#   'PMAIP1',
#   'CTSV',
#   'BOK',
#   'CASP6',
#   'AIFM1',
#   'BAK1',
#   'TRAF2',
#   'LMNB1',
#   'TUBA3D',
#   'PIK3R2',
#   'RAF1',
#   'IKBKB',
#   'GADD45A',
#   'AKT3',
#   'CTSZ',
#   'TNFSF10',
#   'CTSW',
#   'TNFRSF1A',
#   'PARP3',
#   'RIPK1',
#   'BIRC7',
#   'DIABLO',
#   'BAD',
#   'TP53AIP1',
#   'TUBA1C',
#   'TNFRSF10A',
#   'BCL2',
#   'CTSH',
#   'PIK3R1',
#   'MAPK3',
#   'TUBAL3',
#   'BCL2A1',
#   'TNF',
#   'GADD45B',
#   'CAPN2',
#   'MAP2K1',
#   'MAPK10',
#   'CHUK',
#   'ACTG1',
#   'BIRC2',
#   'JUN',
#   'DAXX',
#   'MCL1',
#   'PIK3CB',
#   'PDPK1',
#   'TP53',
#   'ATM',
#   'DFFB',
#   'CSF2RB',
#   'IKBKG',
#   'PRF1',
#   'AKT1'],
#  'Arachidonic acid metabolism': ['HPGDS',
#   'PTGES',
#   'PTGS2',
#   'PLB1',
#   'PLA2G4D',
#   'CYP2C8',
#   'PTGIS',
#   'CYP4F8',
#   'GPX3',
#   'PLA2G12B',
#   'LTA4H',
#   'PLA2G4C',
#   'PLA2G2C',
#   'GPX2',
#   'PTGS1',
#   'TBXAS1',
#   'CYP2E1',
#   'PLA2G3',
#   'PLA2G2D',
#   'GPX7',
#   'CYP2U1',
#   'EPHX2',
#   'CYP2C9',
#   'GPX8',
#   'ALOX5',
#   'CBR3',
#   'CYP2J2',
#   'CYP2C19',
#   'PTGES2',
#   'ALOX15',
#   'PLA2G10',
#   'PLA2G4A',
#   'PLA2G12A',
#   'PLA2G2F',
#   'PTGES3',
#   'CYP2B6',
#   'GGT1',
#   'PLA2G5',
#   'ALOX12B',
#   'PLA2G2A',
#   'GGT5',
#   'ALOX15B',
#   'CYP4F3',
#   'PLA2G4E',
#   'PLA2G4B',
#   'PLA2G6',
#   'LTC4S',
#   'JMJD7-PLA2G4B',
#   'CBR1',
#   'AKR1C3',
#   'PLA2G1B',
#   'ALOX12',
#   'PTGDS',
#   'PLA2G4F'],
#  'Arginine and proline metabolism': ['AGMAT',
#   'PYCR1',
#   'ODC1',
#   'ALDH2',
#   'GAMT',
#   'LAP3',
#   'AOC1',
#   'MAOA',
#   'NOS1',
#   'L3HYPDH',
#   'CKM',
#   'ALDH4A1',
#   'HOGA1',
#   'ALDH3A2',
#   'SMS',
#   'NOS2',
#   'ALDH7A1',
#   'CNDP2',
#   'ALDH1B1',
#   'PYCR2',
#   'CKMT1B',
#   'P4HA1',
#   'ALDH9A1',
#   'SAT2',
#   'P4HA2',
#   'GOT2',
#   'ARG2',
#   'GOT1',
#   'SAT1',
#   'DAO',
#   'PYCR3',
#   'CKB',
#   'PRODH',
#   'CARNS1',
#   'GATM',
#   'AMD1',
#   'SRM',
#   'OAT',
#   'NOS3',
#   'ALDH18A1',
#   'CKMT1A',
#   'P4HA3',
#   'SMOX',
#   'ARG1',
#   'CNDP1',
#   'MAOB',
#   'AZIN2',
#   'CKMT2'],
#  'Arginine biosynthesis': ['NAGS',
#   'ASL',
#   'GPT',
#   'NOS1',
#   'NOS2',
#   'GLS',
#   'GLUD1',
#   'ABHD14A-ACY1',
#   'GOT2',
#   'ARG2',
#   'GOT1',
#   'GLUD2',
#   'NOS3',
#   'CPS1',
#   'ACY1',
#   'GLUL',
#   'ARG1',
#   'GLS2',
#   'GPT2',
#   'ASS1'],
#  'Arrhythmogenic right ventricular cardiomyopathy': ['CACNG8',
#   'SGCD',
#   'ITGB8',
#   'ITGA10',
#   'ITGA11',
#   'LMNA',
#   'JUP',
#   'CACNG4',
#   'SGCB',
#   'CACNG3',
#   'SLC8A3',
#   'ITGA4',
#   'ACTN2',
#   'ACTB',
#   'CACNA2D3',
#   'ITGA3',
#   'CDH2',
#   'CACNB4',
#   'ITGA8',
#   'ITGA5',
#   'CTNNB1',
#   'CACNB1',
#   'ITGA1',
#   'CTNNA1',
#   'CTNNA2',
#   'RYR2',
#   'CACNA1C',
#   'ITGA2B',
#   'ITGA2',
#   'CACNA1D',
#   'CACNA2D1',
#   'ACTN3',
#   'DES',
#   'DSP',
#   'ITGB7',
#   'DMD',
#   'DAG1',
#   'SGCG',
#   'CACNA2D4',
#   'SLC8A1',
#   'ITGAV',
#   'LEF1',
#   'ATP2A1',
#   'TCF7L2',
#   'ITGB4',
#   'DSG2',
#   'ACTG1',
#   'PKP2',
#   'EMD',
#   'ITGB1',
#   'ITGB3',
#   'CTNNA3',
#   'GJA1',
#   'DSC2',
#   'ITGA7',
#   'LAMA1',
#   'ITGB6',
#   'ITGB5',
#   'LAMA2',
#   'CACNA2D2',
#   'ITGA9',
#   'CACNG6',
#   'CACNB3',
#   'CACNB2',
#   'CACNA1F',
#   'SLC8A2',
#   'ITGA6',
#   'ATP2A3',
#   'TCF7',
#   'TCF7L1',
#   'CACNG2',
#   'SGCA',
#   'ATP2A2'],
#  'Ascorbate and aldarate metabolism': ['RGN',
#   'ALDH2',
#   'GUSB',
#   'ALDH3A2',
#   'ALDH7A1',
#   'UGT2B11',
#   'UGT1A6',
#   'UGT2B7',
#   'ALDH1B1',
#   'UGT2B28',
#   'ALDH9A1',
#   'UGT2B4',
#   'UGT1A1',
#   'UGT2B15',
#   'MIOX',
#   'AKR1A1',
#   'KL',
#   'UGT2A1',
#   'UGT1A7',
#   'UGDH'],
#  'Asthma': ['CD40',
#   'CD40LG',
#   'FCER1A',
#   'HLA-DRA',
#   'HLA-DRB1',
#   'HLA-DQB1',
#   'HLA-DQA1',
#   'RNASE3',
#   'IL3',
#   'HLA-DOB',
#   'HLA-DMA',
#   'HLA-DRB5',
#   'HLA-DQA2',
#   'IL4',
#   'IL13',
#   'IL10',
#   'TNF',
#   'IL5',
#   'HLA-DPA1',
#   'MS4A2',
#   'HLA-DPB1',
#   'PRG2',
#   'HLA-DOA',
#   'FCER1G',
#   'HLA-DMB'],
#  'Autoimmune thyroid disease': ['HLA-G',
#   'CD40',
#   'CD40LG',
#   'HLA-B',
#   'IFNA14',
#   'HLA-DRA',
#   'TG',
#   'HLA-DRB1',
#   'HLA-DQB1',
#   'IFNA21',
#   'CGA',
#   'GZMB',
#   'HLA-DQA1',
#   'CD86',
#   'HLA-C',
#   'TSHR',
#   'HLA-DOB',
#   'HLA-DMA',
#   'HLA-DRB5',
#   'HLA-DQA2',
#   'IL4',
#   'IFNA17',
#   'IL2',
#   'IL10',
#   'IFNA13',
#   'IL5',
#   'IFNA2',
#   'IFNA8',
#   'FASLG',
#   'HLA-F',
#   'FAS',
#   'CTLA4',
#   'HLA-DPA1',
#   'CD80',
#   'IFNA1',
#   'IFNA16',
#   'TPO',
#   'CD28',
#   'IFNA7',
#   'HLA-DPB1',
#   'HLA-DOA',
#   'HLA-A',
#   'PRF1',
#   'HLA-E',
#   'IFNA10',
#   'HLA-DMB'],
#  'Autophagy': ['SH3GLB1',
#   'NRBF2',
#   'ATG14',
#   'HMGB1',
#   'TSC2',
#   'PRAP1',
#   'DAPK2',
#   'EIF2AK3',
#   'RRAGC',
#   'MAPK8',
#   'BNIP3',
#   'IRS1',
#   'IGBP1',
#   'MAP3K7',
#   'ERN1',
#   'MTMR14',
#   'SUPT20H',
#   'ATG4B',
#   'RAB1A',
#   'MAPK1',
#   'MAPK9',
#   'CTSB',
#   'HIF1A',
#   'CFLAR',
#   'PIK3CD',
#   'PRKACB',
#   'MTMR3',
#   'ATG2A',
#   'DEPTOR',
#   'SQSTM1',
#   'RAB7B',
#   'PIK3R3',
#   'AKT2',
#   'ATG13',
#   'ATG16L1',
#   'TRAF6',
#   'EIF2S1',
#   'ATG5',
#   'ATG10',
#   'ATG101',
#   'PIK3C3',
#   'ATG9A',
#   'CTSL',
#   'TP53INP2',
#   'DAPK1',
#   'CTSD',
#   'MAP2K2',
#   'ITPR1',
#   'BECN1',
#   'GABARAPL2',
#   'PIK3R4',
#   'RB1CC1',
#   'RAB8A',
#   'RRAGA',
#   'GABARAP',
#   'PPP2CA',
#   'EIF2AK4',
#   'VMP1',
#   'ATG16L2',
#   'ATG4D',
#   'DAPK3',
#   'LAMP1',
#   'IGF1R',
#   'ATG2B',
#   'RAB33B',
#   'GABARAPL1',
#   'RRAGB',
#   'ULK2',
#   'TANK',
#   'AKT1',
#   'CAMKK2',
#   'RRAGD',
#   'IRS2',
#   'PIK3CA',
#   'MTOR',
#   'AMBRA1',
#   'RPS6KB2',
#   'UVRAG',
#   'NRAS',
#   'PRKAA2',
#   'WIPI2',
#   'KRAS',
#   'PRKAA1',
#   'PRKACA',
#   'BCL2L1',
#   'HRAS',
#   'MTMR4',
#   'TSC1',
#   'ATG9B',
#   'STK11',
#   'ATG4C',
#   'RRAS',
#   'PIK3R2',
#   'RAF1',
#   'PPP2CB',
#   'RPTOR',
#   'VAMP8',
#   'RRAS2',
#   'AKT3',
#   'ATG7',
#   'SNAP29',
#   'STX17',
#   'WIPI1',
#   'TBK1',
#   'RPS6KB1',
#   'PRKCQ',
#   'BAD',
#   'MLST8',
#   'MRAS',
#   'BCL2',
#   'ULK1',
#   'LAMP2',
#   'PIK3R1',
#   'MAPK3',
#   'PRKCD',
#   'WDR41',
#   'MAP2K1',
#   'MAPK10',
#   'ATG12',
#   'DDIT4',
#   'AKT1S1',
#   'ZFYVE1',
#   'PTEN',
#   'PIK3CB',
#   'ATG3',
#   'PDPK1',
#   'RUBCN',
#   'RAB39B',
#   'ATG4A',
#   'SMCR8',
#   'RAB7A',
#   'RHEB'],
#  'Axon guidance': ['EPHB2',
#   'ENAH',
#   'BMPR2',
#   'SLIT1',
#   'EPHB1',
#   'FES',
#   'BMPR1B',
#   'NTNG1',
#   'RAC3',
#   'ARHGEF12',
#   'CAMK2D',
#   'ABLIM3',
#   'EPHA3',
#   'ROBO3',
#   'SEMA5B',
#   'SEMA4A',
#   'UNC5C',
#   'PLXNA2',
#   'PARD3',
#   'ROCK2',
#   'PLXNA3',
#   'RND1',
#   'SEMA4C',
#   'LRIG2',
#   'LIMK1',
#   'MET',
#   'MAPK1',
#   'SEMA3D',
#   'CXCL12',
#   'CAMK2A',
#   'PAK5',
#   'SRGAP1',
#   'PLXNA1',
#   'FZD3',
#   'SEMA6D',
#   'PIK3CD',
#   'EPHA1',
#   'MYL9',
#   'DPYSL5',
#   'TRPC1',
#   'TRPC3',
#   'LRRC4C',
#   'NTN1',
#   'PIK3R3',
#   'TRPC5',
#   'BOC',
#   'CFL1',
#   'NEO1',
#   'RHOA',
#   'RGMA',
#   'SEMA4B',
#   'SEMA7A',
#   'SEMA3C',
#   'SHH',
#   'RHOD',
#   'PLXNB2',
#   'CFL2',
#   'PRKCA',
#   'EPHB3',
#   'SEMA6C',
#   'SRGAP2',
#   'EPHA7',
#   'UNC5D',
#   'NTN3',
#   'SEMA4D',
#   'SRC',
#   'EFNA4',
#   'SLIT3',
#   'NTNG2',
#   'WNT4',
#   'PARD6A',
#   'SSH1',
#   'EFNA2',
#   'L1CAM',
#   'PLXNA4',
#   'PPP3CA',
#   'ITGB1',
#   'PTK2',
#   'SEMA3F',
#   'SEMA3G',
#   'EFNA5',
#   'CAMK2B',
#   'GSK3B',
#   'RASA1',
#   'EFNB2',
#   'PTCH1',
#   'EFNA1',
#   'PAK3',
#   'NRP1',
#   'NFATC4',
#   'SEMA3A',
#   'PARD6G',
#   'ROBO1',
#   'PIK3CA',
#   'SLIT2',
#   'EPHB4',
#   'PAK1',
#   'FYN',
#   'SEMA6B',
#   'NFATC3',
#   'PPP3R2',
#   'WNT5A',
#   'NRAS',
#   'LRRC4',
#   'MYL12A',
#   'GDF7',
#   'NCK1',
#   'GNAI1',
#   'BMP7',
#   'SEMA5A',
#   'ILK',
#   'NCK2',
#   'SEMA6A',
#   'GNAI2',
#   'KRAS',
#   'HRAS',
#   'EPHA2',
#   'PRKCZ',
#   'PLXNC1',
#   'CXCR4',
#   'CAMK2G',
#   'PPP3CC',
#   'RAC2',
#   'DPYSL2',
#   'TRPC6',
#   'SRGAP3',
#   'RRAS',
#   'ABLIM2',
#   'PIK3R2',
#   'RAF1',
#   'PAK2',
#   'UNC5A',
#   'DCC',
#   'ABL1',
#   'EPHA4',
#   'PLXNB1',
#   'SSH3',
#   'CDC42',
#   'PARD6B',
#   'SMO',
#   'WNT5B',
#   'PPP3R1',
#   'EFNB1',
#   'SEMA4G',
#   'EPHB6',
#   'PIK3R1',
#   'MAPK3',
#   'NGEF',
#   'EFNB3',
#   'SSH2',
#   'UNC5B',
#   'GNAI3',
#   'RYK',
#   'SEMA4F',
#   'ABLIM1',
#   'RGS3',
#   'RAC1',
#   'PAK6',
#   'PLCG1',
#   'PTPN11',
#   'MYL5',
#   'LIMK2',
#   'ROCK1',
#   'PPP3CB',
#   'PAK4',
#   'NFATC2',
#   'EFNA3',
#   'SEMA3E',
#   'SEMA3B',
#   'PLCG2',
#   'PIK3CB',
#   'PDPK1',
#   'EPHA5',
#   'PLXNB3',
#   'CDK5',
#   'NTN4',
#   'MYL12B',
#   'ROBO2',
#   'BUB1B-PAK6'],
#  'B cell receptor signaling pathway': ['LYN',
#   'CD22',
#   'FOS',
#   'LILRA6',
#   'CD72',
#   'RAC3',
#   'BTK',
#   'LILRB1',
#   'VAV1',
#   'MAPK1',
#   'LILRB4',
#   'PIK3CD',
#   'IFITM1',
#   'SOS1',
#   'CD79B',
#   'PIK3R3',
#   'AKT2',
#   'NFKBIA',
#   'BLNK',
#   'RELA',
#   'DAPP1',
#   'NFATC1',
#   'MALT1',
#   'LILRA2',
#   'MAP2K2',
#   'FCGR2B',
#   'LILRB2',
#   'LILRA1',
#   'PPP3CA',
#   'GSK3B',
#   'NFKBIE',
#   'PIK3CA',
#   'NFKB1',
#   'SYK',
#   'NFATC3',
#   'PPP3R2',
#   'NRAS',
#   'LILRA4',
#   'CD79A',
#   'CD81',
#   'KRAS',
#   'HRAS',
#   'VAV2',
#   'SOS2',
#   'PPP3CC',
#   'RAC2',
#   'PIK3AP1',
#   'INPPL1',
#   'PIK3R2',
#   'RAF1',
#   'CD19',
#   'INPP5D',
#   'IKBKB',
#   'AKT3',
#   'LILRB5',
#   'PPP3R1',
#   'PIK3R1',
#   'MAPK3',
#   'VAV3',
#   'BCL10',
#   'RAC1',
#   'MAP2K1',
#   'PTPN6',
#   'LILRB3',
#   'PPP3CB',
#   'CHUK',
#   'GRB2',
#   'JUN',
#   'NFATC2',
#   'NFKBIB',
#   'CARD11',
#   'PIK3CB',
#   'PLCG2',
#   'RASGRP3',
#   'CR2',
#   'IKBKG',
#   'PRKCB',
#   'LILRA5',
#   'AKT1'],
#  'Bacterial invasion of epithelial cells': ['CDC42',
#   'ARPC4',
#   'RHOA',
#   'CAV2',
#   'PIK3CA',
#   'CRK',
#   'SHC2',
#   'ACTR2',
#   'ACTR3B',
#   'ARHGAP10',
#   'ACTB',
#   'ARHGEF26',
#   'CRKL',
#   'CDH1',
#   'ARPC1B',
#   'RHOG',
#   'ITGA5',
#   'VCL',
#   'PIK3R1',
#   'ELMO2',
#   'CTNNB1',
#   'PXN',
#   'ILK',
#   'CTNNA1',
#   'CTNNA2',
#   'BCAR1',
#   'ARPC5',
#   'DNM3',
#   'ELMO3',
#   'MET',
#   'WASF1',
#   'RAC1',
#   'SRC',
#   'SHC4',
#   'ARPC3',
#   'ARPC2',
#   'SHC1',
#   'CLTA',
#   'ACTR3',
#   'GAB1',
#   'MAD2L2',
#   'CD2AP',
#   'ACTG1',
#   'CAV1',
#   'PIK3CD',
#   'ITGB1',
#   'CLTB',
#   'CTNNA3',
#   'SHC3',
#   'PIK3R2',
#   'ELMO1',
#   'PTK2',
#   'DNM1',
#   'CTTN',
#   'ARPC1A',
#   'PIK3CB',
#   'CLTC',
#   'WASL',
#   'FN1',
#   'DOCK1',
#   'WASF2',
#   'CLTCL1',
#   'DNM2',
#   'ACTR3C',
#   'CBL',
#   'PIK3R3',
#   'HCLS1',
#   'ARPC5L'],
#  'Basal cell carcinoma': ['WNT3',
#   'FZD9',
#   'SMO',
#   'BMP2',
#   'WNT5B',
#   'APC',
#   'WNT3A',
#   'GLI1',
#   'FZD1',
#   'WNT7B',
#   'AXIN1',
#   'WNT2B',
#   'SHH',
#   'FZD7',
#   'FZD10',
#   'FZD5',
#   'AXIN2',
#   'WNT5A',
#   'GLI3',
#   'WNT1',
#   'WNT8B',
#   'CTNNB1',
#   'CDKN1A',
#   'DVL3',
#   'DVL2',
#   'DVL1',
#   'PTCH2',
#   'WNT11',
#   'GADD45B',
#   'WNT7A',
#   'WNT9A',
#   'DDB2',
#   'WNT9B',
#   'TCF7L2',
#   'FZD6',
#   'LEF1',
#   'FZD8',
#   'WNT4',
#   'WNT10A',
#   'WNT10B',
#   'FZD3',
#   'SUFU',
#   'POLK',
#   'BAK1',
#   'APC2',
#   'WNT16',
#   'TP53',
#   'KIF7',
#   'BAX',
#   'GSK3B',
#   'FZD2',
#   'GADD45A',
#   'PTCH1',
#   'TCF7',
#   'GADD45G',
#   'TCF7L1',
#   'BMP4',
#   'FZD4',
#   'HHIP',
#   'GLI2',
#   'WNT6'],
#  'Basal transcription factors': ['GTF2H2',
#   'ERCC2',
#   'GTF2F1',
#   'TAF1L',
#   'TAF12',
#   'GTF2F2',
#   'GTF2H5',
#   'TAF6',
#   'GTF2H3',
#   'TAF1',
#   'TAF13',
#   'TBPL2',
#   'TAF15',
#   'TAF4B',
#   'TAF11',
#   'GTF2A2',
#   'GTF2B',
#   'TAF7L',
#   'TAF9B',
#   'TBP',
#   'TAF2',
#   'GTF2I',
#   'CCNH',
#   'TAF3',
#   'GTF2H1',
#   'MNAT1',
#   'TAF10',
#   'TAF9',
#   'TAF7',
#   'GTF2E1',
#   'GTF2IRD1',
#   'TAF5L',
#   'GTF2E2',
#   'GTF2H4',
#   'TAF8',
#   'CDK7',
#   'ERCC3',
#   'TAF6L',
#   'GTF2H2C',
#   'TAF4',
#   'TBPL1',
#   'GTF2A1',
#   'TAF5'],
#  'Base excision repair': ['PARP3',
#   'NEIL1',
#   'PARP2',
#   'APEX2',
#   'SMUG1',
#   'HMGB1',
#   'POLD1',
#   'POLD3',
#   'PCNA',
#   'NEIL3',
#   'UNG',
#   'TDG',
#   'NTHL1',
#   'APEX1',
#   'NEIL2',
#   'POLE3',
#   'OGG1',
#   'PARP4',
#   'POLE2',
#   'FEN1',
#   'LIG3',
#   'POLD2',
#   'POLE',
#   'XRCC1',
#   'POLB',
#   'MBD4',
#   'MUTYH',
#   'PARP1',
#   'POLD4',
#   'MPG',
#   'POLE4',
#   'POLL',
#   'LIG1'],
#  'Bile secretion': ['SCARB1',
#   'SLCO1B3',
#   'ABCG8',
#   'SLC9A3',
#   'SLC51A',
#   'ABCG2',
#   'ATP1B2',
#   'AQP4',
#   'ADCY5',
#   'RXRA',
#   'SLC51B',
#   'GNAS',
#   'BAAT',
#   'SLC27A5',
#   'ABCB11',
#   'ATP1A4',
#   'UGT2B11',
#   'ABCB1',
#   'HMGCR',
#   'SCT',
#   'UGT1A6',
#   'AQP1',
#   'SLCO1A2',
#   'CYP7A1',
#   'UGT2B7',
#   'UGT2B28',
#   'ATP1B1',
#   'SLC10A1',
#   'ADCY2',
#   'PRKACA',
#   'UGT2B4',
#   'ATP1B4',
#   'SLC22A1',
#   'UGT1A1',
#   'ADCY4',
#   'SLC10A2',
#   'FXYD2',
#   'ABCC2',
#   'AQP8',
#   'SLC4A4',
#   'ABCB4',
#   'UGT2B15',
#   'ATP1A2',
#   'ATP1A1',
#   'CFTR',
#   'ATP1A3',
#   'SLC4A2',
#   'NCEH1',
#   'KCNN2',
#   'AQP9',
#   'SLC5A1',
#   'UGT2A1',
#   'ADCY9',
#   'ABCC3',
#   'SLC2A1',
#   'ADCY6',
#   'UGT1A7',
#   'PRKACB',
#   'SCTR',
#   'CA2',
#   'SLC4A5',
#   'SULT2A1',
#   'ABCG5',
#   'ATP1B3',
#   'SLC9A1',
#   'ABCC4',
#   'EPHX1',
#   'ADCY1',
#   'ADCY7',
#   'CYP3A4',
#   'ADCY3',
#   'LDLR'],
#  'Biosynthesis of unsaturated fatty acids': ['ELOVL1',
#   'ELOVL5',
#   'HACD1',
#   'BAAT',
#   'SCD',
#   'HACD2',
#   'ELOVL6',
#   'SCD5',
#   'ELOVL3',
#   'TECR',
#   'ACAA1',
#   'ACOX1',
#   'FADS1',
#   'HSD17B4',
#   'ACOX3',
#   'SCP2',
#   'ACOT4',
#   'HSD17B12',
#   'ACOT1',
#   'HACD3',
#   'ELOVL7',
#   'FADS2',
#   'HACD4',
#   'ELOVL4',
#   'ACOT2',
#   'ACOT7'],
#  'Bladder cancer': ['THBS1',
#   'UPK3A',
#   'ARAF',
#   'VEGFA',
#   'RPS6KA5',
#   'RASSF1',
#   'E2F1',
#   'EGF',
#   'CDK4',
#   'CDKN2A',
#   'DAPK2',
#   'FGFR3',
#   'E2F3',
#   'CCND1',
#   'CDH1',
#   'NRAS',
#   'MMP9',
#   'MAPK3',
#   'DAPK1',
#   'CDKN1A',
#   'E2F2',
#   'MAP2K2',
#   'KRAS',
#   'EGFR',
#   'HRAS',
#   'RB1',
#   'MAPK1',
#   'MMP2',
#   'SRC',
#   'MAP2K1',
#   'TYMP',
#   'BRAF',
#   'MYC',
#   'HBEGF',
#   'DAPK3',
#   'RAF1',
#   'CXCL8',
#   'TP53',
#   'ERBB2',
#   'MDM2',
#   'MMP1'],
#  'Breast cancer': ['FGF22',
#   'SHC2',
#   'NOTCH3',
#   'EGF',
#   'FOS',
#   'AXIN1',
#   'FZD7',
#   'FZD10',
#   'FZD5',
#   'FGF23',
#   'CTNNB1',
#   'E2F2',
#   'JAG2',
#   'DVL3',
#   'WNT9A',
#   'MAPK1',
#   'SP1',
#   'SHC1',
#   'MYC',
#   'FZD3',
#   'FGF5',
#   'PIK3CD',
#   'APC2',
#   'FGF18',
#   'SOS1',
#   'FZD2',
#   'FGF1',
#   'FZD4',
#   'WNT3A',
#   'PIK3R3',
#   'AKT2',
#   'FGF10',
#   'LRP5',
#   'FRAT2',
#   'APC',
#   'CDK6',
#   'PGR',
#   'DLL1',
#   'FZD1',
#   'ESR1',
#   'WNT2B',
#   'CDK4',
#   'CCND1',
#   'WNT1',
#   'WNT8B',
#   'CDKN1A',
#   'MAP2K2',
#   'WNT11',
#   'HEYL',
#   'DDB2',
#   'KIT',
#   'FZD8',
#   'FLT4',
#   'WNT4',
#   'POLK',
#   'SHC3',
#   'FRAT1',
#   'IGF1R',
#   'BAX',
#   'NFKB2',
#   'GSK3B',
#   'GADD45G',
#   'LEF1',
#   'WNT6',
#   'TNFSF11',
#   'FZD9',
#   'BRCA1',
#   'NCOA1',
#   'ARAF',
#   'PIK3CA',
#   'DLL3',
#   'JAG1',
#   'WNT7B',
#   'NOTCH1',
#   'MTOR',
#   'RPS6KB2',
#   'WNT5A',
#   'NRAS',
#   'BRCA2',
#   'NCOA3',
#   'NOTCH4',
#   'DVL2',
#   'KRAS',
#   'HRAS',
#   'SOS2',
#   'FGF2',
#   'CSNK1A1L',
#   'WNT10A',
#   'WNT10B',
#   'BAK1',
#   'PIK3R2',
#   'RAF1',
#   'HES5',
#   'ERBB2',
#   'FGF17',
#   'FGF7',
#   'GADD45A',
#   'TCF7',
#   'AKT3',
#   'TCF7L1',
#   'WNT3',
#   'DLL4',
#   'WNT5B',
#   'HES1',
#   'E2F1',
#   'FGF8',
#   'CSNK1A1',
#   'RPS6KB1',
#   'E2F3',
#   'FGFR1',
#   'AXIN2',
#   'PIK3R1',
#   'HEY1',
#   'MAPK3',
#   'IGF1',
#   'NOTCH2',
#   'FGF20',
#   'DVL1',
#   'EGFR',
#   'GADD45B',
#   'WNT7A',
#   'RB1',
#   'SHC4',
#   'MAP2K1',
#   'WNT9B',
#   'FZD6',
#   'FGF9',
#   'LRP6',
#   'BRAF',
#   'TCF7L2',
#   'GRB2',
#   'HEY2',
#   'ESR2',
#   'JUN',
#   'PTEN',
#   'PIK3CB',
#   'WNT16',
#   'TP53',
#   'AKT1'],
#  'Butanoate metabolism': ['ACAT2',
#   'ACSM1',
#   'OXCT2',
#   'ALDH5A1',
#   'ACSM3',
#   'AACS',
#   'GAD2',
#   'EHHADH',
#   'BDH1',
#   'ABAT',
#   'L2HGDH',
#   'OXCT1',
#   'BDH2',
#   'ACSM4',
#   'ACSM5',
#   'HADH',
#   'HMGCS1',
#   'GAD1',
#   'ACSM2B',
#   'HADHA',
#   'ACSM2A',
#   'HMGCL',
#   'ACSM6',
#   'ECHS1',
#   'ACAT1',
#   'ACADS'],
#  'C-type lectin receptor signaling pathway': ['MAPK8',
#   'ARHGEF12',
#   'IKBKE',
#   'EGR3',
#   'ITPR3',
#   'LSP1',
#   'CBLB',
#   'CALML5',
#   'MAP3K14',
#   'MAPK1',
#   'MAPK9',
#   'CLEC7A',
#   'BCL3',
#   'MAPK13',
#   'PIK3CD',
#   'MAPKAPK2',
#   'PYCARD',
#   'CALML3',
#   'CYLD',
#   'CLEC4M',
#   'FCER1G',
#   'PIK3R3',
#   'AKT2',
#   'NFKBIA',
#   'RELA',
#   'RHOA',
#   'PTGS2',
#   'NFATC1',
#   'MALT1',
#   'CD209',
#   'CALM3',
#   'NLRP3',
#   'IRF1',
#   'ITPR1',
#   'SRC',
#   'EGR2',
#   'CLEC4D',
#   'IRF9',
#   'KSR1',
#   'PLK3',
#   'IL1B',
#   'PPP3CA',
#   'CASP8',
#   'NFKB2',
#   'MDM2',
#   'CALML4',
#   'CALM1',
#   'NFATC4',
#   'RELB',
#   'CCL22',
#   'PIK3CA',
#   'ITPR2',
#   'CASP1',
#   'PAK1',
#   'NFKB1',
#   'SYK',
#   'NFATC3',
#   'PPP3R2',
#   'NRAS',
#   'IL23A',
#   'IL2',
#   'MAPK12',
#   'KRAS',
#   'IL6',
#   'HRAS',
#   'PPP3CC',
#   'RRAS',
#   'CALM2',
#   'PIK3R2',
#   'RAF1',
#   'STAT1',
#   'IKBKB',
#   'CCL17',
#   'CALML6',
#   'RRAS2',
#   'AKT3',
#   'IL12B',
#   'PPP3R1',
#   'MRAS',
#   'MAPK11',
#   'PIK3R1',
#   'MAPK3',
#   'IL10',
#   'TNF',
#   'MAPK14',
#   'PRKCD',
#   'CLEC4E',
#   'BCL10',
#   'PTPN11',
#   'MAPK10',
#   'PPP3CB',
#   'CHUK',
#   'IL12A',
#   'JUN',
#   'NFATC2',
#   'PLCG2',
#   'CLEC6A',
#   'CARD9',
#   'PIK3CB',
#   'IKBKG',
#   'IL17D',
#   'STAT2',
#   'CLEC1B',
#   'AKT1'],
#  'Caffeine metabolism': ['CYP2A7', 'XDH', 'CYP1A2', 'NAT1', 'CYP2A6', 'NAT2'],
#  'Calcium signaling pathway': ['TNNC1',
#   'ASPH',
#   'ADRB2',
#   'DRD5',
#   'MST1',
#   'HRC',
#   'FGF22',
#   'CHRM2',
#   'NOS1',
#   'EGF',
#   'PDGFD',
#   'PLCB4',
#   'PLCD4',
#   'F2R',
#   'FGFR4',
#   'VEGFB',
#   'FGF23',
#   'ITPR3',
#   'CAMK2D',
#   'RYR2',
#   'CACNA1C',
#   'CALML5',
#   'P2RX6',
#   'ADCY2',
#   'HTR6',
#   'HTR4',
#   'CACNA1I',
#   'TBXA2R',
#   'NTSR1',
#   'PDGFRB',
#   'ADCY4',
#   'ATP2B1',
#   'SLC8A1',
#   'MET',
#   'CAMK2A',
#   'FGFR2',
#   'FGF5',
#   'FGF18',
#   'PRKACB',
#   'PLCD1',
#   'CALML3',
#   'VDAC3',
#   'PTK2B',
#   'P2RX5',
#   'STIM1',
#   'FGF1',
#   'ADORA2B',
#   'MCOLN1',
#   'ADCY3',
#   'BDKRB2',
#   'FGF10',
#   'CHRM5',
#   'RYR1',
#   'BDKRB1',
#   'ORAI1',
#   'GNAS',
#   'ADRB3',
#   'PHKA2',
#   'FGFR3',
#   'CACNA1H',
#   'VDAC1',
#   'PTGER1',
#   'PDGFB',
#   'NOS2',
#   'P2RX7',
#   'PHKA1',
#   'PDGFC',
#   'PHKG2',
#   'CACNA1E',
#   'PRKCA',
#   'HRH1',
#   'CALM3',
#   'CACNA1D',
#   'ITPR1',
#   'PLN',
#   'GRM1',
#   'NTRK1',
#   'PLCZ1',
#   'NTRK2',
#   'ERBB3',
#   'PRKCG',
#   'CAMK1',
#   'RET',
#   'FLT4',
#   'PPP3CA',
#   'ADCY9',
#   'TACR1',
#   'ITPKA',
#   'CASQ1',
#   'KDR',
#   'ADRB1',
#   'CHRNA7',
#   'RYR3',
#   'HRH2',
#   'CACNA1F',
#   'HTR2A',
#   'CAMK2B',
#   'CALML4',
#   'PDE1C',
#   'P2RX2',
#   'SPHK1',
#   'ATP2A3',
#   'TPCN2',
#   'ADCY1',
#   'ADCY7',
#   'GRM5',
#   'CALM1',
#   'ATP2A2',
#   'GRIN2C',
#   'PDE1B',
#   'VEGFA',
#   'ITPR2',
#   'EDNRA',
#   'STIM2',
#   'CASQ2',
#   'NTRK3',
#   'PLCB3',
#   'PPP3R2',
#   'ORAI2',
#   'PTGER3',
#   'ITPKB',
#   'VEGFC',
#   'TNNC2',
#   'MST1R',
#   'PRKACA',
#   'FLT1',
#   'TACR2',
#   'CXCR4',
#   'MYLK',
#   'CAMK2G',
#   'ITPKC',
#   'PPP3CC',
#   'FGF2',
#   'LTB4R2',
#   'ATP2B4',
#   'P2RX1',
#   'PHKG1',
#   'GNA14',
#   'SLC25A5',
#   'MYLK3',
#   'PLCB2',
#   'CALM2',
#   'SPHK2',
#   'GRIN1',
#   'GNA15',
#   'GDNF',
#   'CHRM3',
#   'SLC8A2',
#   'ERBB2',
#   'FGF17',
#   'FGF7',
#   'CALML6',
#   'HTR2B',
#   'MCOLN2',
#   'GRIN2D',
#   'PHKB',
#   'PTAFR',
#   'CAMK4',
#   'PDE1A',
#   'OXTR',
#   'SLC25A31',
#   'PPIF',
#   'PPP3R1',
#   'PDGFRA',
#   'SLC25A4',
#   'SLC8A3',
#   'MCOLN3',
#   'MYLK2',
#   'MYLK4',
#   'CACNA1G',
#   'FGF8',
#   'CAMK1D',
#   'P2RX3',
#   'FGFR1',
#   'PDGFA',
#   'PTGFR',
#   'VEGFD',
#   'AVPR1A',
#   'SLC25A6',
#   'ADRA1B',
#   'CCKBR',
#   'CYSLTR1',
#   'GNAQ',
#   'ATP2B3',
#   'GRIN2A',
#   'FGF20',
#   'ORAI3',
#   'EGFR',
#   'PLCB1',
#   'ADORA2A',
#   'HGF',
#   'GNA11',
#   'TPCN1',
#   'GNAL',
#   'CD38',
#   'PLCD3',
#   'GRPR',
#   'PLCG1',
#   'MCU',
#   'PPP3CB',
#   'PLCE1',
#   'FGF9',
#   'ATP2A1',
#   'EDNRB',
#   'ERBB4',
#   'P2RX4',
#   'PLCG2',
#   'HTR7',
#   'CYSLTR2',
#   'NOS3',
#   'VDAC2',
#   'CAMK1G',
#   'CACNA1B',
#   'PRKCB',
#   'CACNA1A',
#   'ADRA1A',
#   'ATP2B2'],
#  'Carbohydrate digestion and absorption': ['PIK3R3',
#   'MGAM2',
#   'AMY2B',
#   'HK2',
#   'PIK3CA',
#   'TAS1R3',
#   'ATP1B2',
#   'AMY2A',
#   'PLCB4',
#   'PLCB3',
#   'ATP1A4',
#   'PIK3R1',
#   'AMY1A',
#   'HK1',
#   'ATP1B1',
#   'CACNA1D',
#   'PLCB1',
#   'AMY1B',
#   'ATP1B4',
#   'HKDC1',
#   'FXYD2',
#   'MGAM',
#   'ATP1A2',
#   'ATP1A1',
#   'ATP1A3',
#   'PLCB2',
#   'PIK3CD',
#   'G6PC2',
#   'SLC5A1',
#   'SLC37A4',
#   'PIK3R2',
#   'PIK3CB',
#   'HK3',
#   'LCT',
#   'ATP1B3',
#   'AKT3',
#   'PRKCB',
#   'G6PC3',
#   'SLC2A5',
#   'AKT1',
#   'AKT2'],
#  'Cardiac muscle contraction': ['TNNC1',
#   'CACNG8',
#   'ASPH',
#   'COX7A1',
#   'HRC',
#   'TPM1',
#   'COX6A1',
#   'CACNG4',
#   'ATP1B2',
#   'COX6B2',
#   'CACNG3',
#   'COX6C',
#   'COX7C',
#   'UQCRC1',
#   'CASQ2',
#   'SLC8A3',
#   'COX5A',
#   'UQCRC2',
#   'UQCRQ',
#   'CACNA2D3',
#   'CACNB4',
#   'UQCRHL',
#   'MYL2',
#   'ATP1A4',
#   'COX7B2',
#   'TNNI3',
#   'CACNB1',
#   'MYH6',
#   'RYR2',
#   'CACNA1C',
#   'ATP1B1',
#   'CACNA1D',
#   'CACNA2D1',
#   'UQCRFS1',
#   'CYC1',
#   'COX7A2L',
#   'COX6A2',
#   'ATP1B4',
#   'TPM2',
#   'TPM4',
#   'CACNA2D4',
#   'SLC8A1',
#   'TNNT2',
#   'FXYD2',
#   'COX6B1',
#   'ATP2A1',
#   'ATP1A2',
#   'ATP1A1',
#   'ATP1A3',
#   'UQCR11',
#   'SLC9A6',
#   'COX5B',
#   'UQCRH',
#   'COX7B',
#   'MYL4',
#   'CACNA2D2',
#   'SLC9A7',
#   'UQCR10',
#   'COX4I1',
#   'CACNG6',
#   'TPM3',
#   'CACNB3',
#   'COX7A2',
#   'CACNB2',
#   'CACNA1F',
#   'SLC8A2',
#   'COX8A',
#   'ATP1B3',
#   'ATP2A3',
#   'ACTC1',
#   'COX4I2',
#   'SLC9A1',
#   'CACNG2',
#   'ATP2A2',
#   'UQCRB'],
#  'Cell adhesion molecules': ['ICAM1',
#   'CNTN2',
#   'CDH15',
#   'SDC1',
#   'CLDN8',
#   'CD22',
#   'CD4',
#   'HLA-DQB1',
#   'JAM2',
#   'NTNG1',
#   'SPN',
#   'NRXN1',
#   'SELP',
#   'TIGIT',
#   'NCAM1',
#   'VSIR',
#   'SIGLEC1',
#   'HLA-DPA1',
#   'CLDN14',
#   'PTPRF',
#   'CDH3',
#   'CD226',
#   'VCAN',
#   'ALCAM',
#   'ITGA9',
#   'CLDN2',
#   'NLGN4Y',
#   'LRRC4C',
#   'JAM3',
#   'HLA-A',
#   'HLA-E',
#   'CADM3',
#   'CD8B2',
#   'NRXN3',
#   'ITGB8',
#   'NEO1',
#   'CLDN3',
#   'ICOS',
#   'CLDN6',
#   'HLA-DRA',
#   'HLA-DQA1',
#   'CNTNAP2',
#   'CDH1',
#   'HLA-DRB5',
#   'NLGN4X',
#   'MADCAM1',
#   'VTCN1',
#   'SDC4',
#   'F11R',
#   'NLGN3',
#   'CD99',
#   'HLA-F',
#   'NECTIN3',
#   'NTNG2',
#   'CADM1',
#   'NEGR1',
#   'ITGB1',
#   'L1CAM',
#   'CLDN20',
#   'CD28',
#   'CD6',
#   'CLDN7',
#   'CLDN11',
#   'ITGA6',
#   'NCAM2',
#   'CD2',
#   'PDCD1',
#   'CD34',
#   'ESAM',
#   'CD40LG',
#   'PVR',
#   'MAG',
#   'ICAM3',
#   'CDH2',
#   'OCLN',
#   'SELPLG',
#   'LRRC4',
#   'HLA-DMA',
#   'CNTNAP1',
#   'NLGN2',
#   'ITGB7',
#   'NECTIN2',
#   'CLDN9',
#   'NECTIN1',
#   'ITGAV',
#   'ITGAM',
#   'CDH5',
#   'IGSF11',
#   'LRRC4B',
#   'ITGAL',
#   'CDH4',
#   'CD80',
#   'CLDN18',
#   'PTPRC',
#   'SDC2',
#   'CLDN1',
#   'HLA-DPB1',
#   'CD274',
#   'PTPRM',
#   'HLA-DOA',
#   'CD8A',
#   'ITGA4',
#   'VCAM1',
#   'CLDN10',
#   'HLA-DMB',
#   'HLA-G',
#   'CLDN15',
#   'CD40',
#   'CLDN5',
#   'NLGN1',
#   'HLA-B',
#   'CLDN16',
#   'HLA-DRB1',
#   'SELL',
#   'CD86',
#   'MPZ',
#   'HLA-C',
#   'ITGA8',
#   'GLG1',
#   'CLDN23',
#   'CD99L2',
#   'HLA-DOB',
#   'ITGB2',
#   'HLA-DQA2',
#   'ICAM2',
#   'CLDN4',
#   'PDCD1LG2',
#   'CD8B',
#   'CTLA4',
#   'CD276',
#   'CNTN1',
#   'NRCAM',
#   'ICOSLG',
#   'NFASC',
#   'MPZL1',
#   'SDC3',
#   'PECAM1',
#   'NRXN2',
#   'CD58',
#   'CLDN19'],
#  'Cell cycle': ['STAG1',
#   'ANAPC2',
#   'CDC16',
#   'CDKN2A',
#   'YWHAE',
#   'E2F4',
#   'ANAPC11',
#   'TGFB1',
#   'CDC25B',
#   'CDKN1C',
#   'E2F2',
#   'HDAC1',
#   'RBL1',
#   'CCNB2',
#   'CCNE2',
#   'MYC',
#   'MCM5',
#   'ORC2',
#   'TTK',
#   'CDC27',
#   'SKP2',
#   'BUB1B',
#   'BUB1',
#   'CDK2',
#   'PTTG1',
#   'ANAPC1',
#   'TGFB2',
#   'CDKN2D',
#   'CDK6',
#   'ANAPC13',
#   'CDKN2B',
#   'CDK4',
#   'SMC1A',
#   'MCM2',
#   'WEE2',
#   'DBF4',
#   'CCND3',
#   'CCND1',
#   'MCM7',
#   'YWHAB',
#   'CDKN1A',
#   'EP300',
#   'MCM6',
#   'E2F5',
#   'CCNH',
#   'CUL1',
#   'CDKN2C',
#   'CDC26',
#   'SFN',
#   'STAG2',
#   'CCNA2',
#   'GSK3B',
#   'MDM2',
#   'RBX1',
#   'YWHAH',
#   'GADD45G',
#   'ANAPC5',
#   'ESPL1',
#   'ORC4',
#   'PRKDC',
#   'YWHAQ',
#   'PLK1',
#   'CCNB1',
#   'FZR1',
#   'YWHAZ',
#   'PKMYT1',
#   'PCNA',
#   'MAD2L1',
#   'SMAD4',
#   'CREBBP',
#   'HDAC2',
#   'CDC20',
#   'CDC25A',
#   'ANAPC7',
#   'SMAD2',
#   'CDC14B',
#   'CCNE1',
#   'CHEK1',
#   'MAD2L2',
#   'SKP1',
#   'CDKN1B',
#   'CCNA1',
#   'CDC23',
#   'ABL1',
#   'CDC6',
#   'MAD1L1',
#   'GADD45A',
#   'ANAPC4',
#   'CCNB3',
#   'SMAD3',
#   'TFDP1',
#   'CCND2',
#   'E2F1',
#   'CHEK2',
#   'CDC45',
#   'E2F3',
#   'ORC6',
#   'WEE1',
#   'ORC5',
#   'ANAPC10',
#   'RAD21',
#   'PTTG2',
#   'ATR',
#   'ORC1',
#   'GADD45B',
#   'RB1',
#   'TFDP2',
#   'RBL2',
#   'ZBTB17',
#   'BUB3',
#   'CDK1',
#   'CDC7',
#   'SMC3',
#   'TGFB3',
#   'CDC25C',
#   'MCM4',
#   'MCM3',
#   'ORC3',
#   'YWHAG',
#   'SMC1B',
#   'TP53',
#   'CDK7',
#   'ATM',
#   'CDC14A'],
#  'Cellular senescence': ['SIRT1',
#   'TSC2',
#   'CDKN2A',
#   'E2F4',
#   'TGFB1',
#   'ITPR3',
#   'LIN9',
#   'E2F2',
#   'CALML5',
#   'RBL1',
#   'CCNB2',
#   'CCNE2',
#   'PPP1CA',
#   'MAPK1',
#   'MRE11',
#   'IL1A',
#   'MAPK13',
#   'IGFBP3',
#   'MYC',
#   'PIK3CD',
#   'MAPKAPK2',
#   'ZFP36L2',
#   'MAP2K3',
#   'CDK2',
#   'CALML3',
#   'SQSTM1',
#   'VDAC3',
#   'TGFB2',
#   'SERPINE1',
#   'HLA-A',
#   'HUS1',
#   'HLA-E',
#   'FOXO1',
#   'PIK3R3',
#   'AKT2',
#   'RELA',
#   'CDK6',
#   'CDKN2B',
#   'CDK4',
#   'CCND3',
#   'CCND1',
#   'VDAC1',
#   'NFATC1',
#   'TGFBR2',
#   'CDKN1A',
#   'CALM3',
#   'MAP2K2',
#   'CACNA1D',
#   'ITPR1',
#   'LIN37',
#   'E2F5',
#   'HIPK2',
#   'RAD9B',
#   'HLA-F',
#   'MAP2K6',
#   'BTRC',
#   'LIN54',
#   'HIPK1',
#   'TGFBR1',
#   'CCNA2',
#   'PPP3CA',
#   'RAD50',
#   'TRAF3IP2',
#   'PPID',
#   'MDM2',
#   'CALML4',
#   'NBN',
#   'GADD45G',
#   'CAPN1',
#   'CALM1',
#   'NFATC4',
#   'AKT1',
#   'ZFP36L1',
#   'RAD9A',
#   'PIK3CA',
#   'ITPR2',
#   'CCNB1',
#   'NFKB1',
#   'KIR2DL4',
#   'MTOR',
#   'NFATC3',
#   'PPP3R2',
#   'NRAS',
#   'FOXO3',
#   'PPP1CB',
#   'RBBP4',
#   'MAPK12',
#   'RASSF5',
#   'CDC25A',
#   'KRAS',
#   'IL6',
#   'HRAS',
#   'SMAD2',
#   'TSC1',
#   'CCNE1',
#   'CHEK1',
#   'FOXM1',
#   'PPP3CC',
#   'SLC25A5',
#   'ETS1',
#   'RRAS',
#   'CALM2',
#   'PIK3R2',
#   'HIPK4',
#   'CCNA1',
# ...
#   'KDELR3',
#   'GNAS',
#   'TCIRG1',
#   'ACTB',
#   'ATP6V1E1',
#   'SLC12A2',
#   'ATP6AP1',
#   'SEC61A2',
#   'KDELR1',
#   'PRKCA',
#   'ATP6V1E2',
#   'ATP6V1B1',
#   'ARF1',
#   'ATP6V0E1',
#   'ATP6V0A4',
#   'PRKACA',
#   'ATP6V0B',
#   'KCNQ1',
#   'SEC61A1',
#   'ATP6V1D',
#   'PLCG1',
#   'ATP6V1F',
#   'SEC61B',
#   'ATP6V0D1',
#   'ATP6V0E2',
#   'ATP6V1G3',
#   'CFTR',
#   'ACTG1',
#   'TJP1',
#   'ADCY9',
#   'ATP6V1C1',
#   'PRKACB',
#   'PLCG2',
#   'ATP6V1C2',
#   'ATP6V0D2',
#   'ATP6V0A1',
#   'ATP6V1A',
#   'ATP6V1G2',
#   'ATP6V1B2',
#   'ATP6V1H',
#   'PDIA4',
#   'ADCY3',
#   'ATP6V1G1'],
#  'Viral carcinogenesis': ['GTF2H2',
#   'HDAC11',
#   'LYN',
#   'CDKN2A',
#   'YWHAE',
#   'GTF2H3',
#   'EGR3',
#   'ATF4',
#   'HDAC1',
#   'CREB3L4',
#   'LTBR',
#   'RBL1',
#   'CCNE2',
#   'MAPK1',
#   'CREB1',
#   'STAT5A',
#   'KAT2B',
#   'ATP6V0D1',
#   'EIF2AK2',
#   'ACTN1',
#   'PKM',
#   'DNAJA3',
#   'PIK3CD',
#   'GTF2E1',
#   'HDAC9',
#   'MAPKAPK2',
#   'PRKACB',
#   'SKP2',
#   'CDK2',
#   'UBR4',
#   'VDAC3',
#   'HLA-A',
#   'HLA-E',
#   'PIK3R3',
#   'STAT3',
#   'NFKBIA',
#   'CCR5',
#   'CREB3',
#   'DLG1',
#   'VAC14',
#   'RELA',
#   'RHOA',
#   'CDK6',
#   'CDKN2B',
#   'CDK4',
#   'RBPJ',
#   'CCND3',
#   'CCND1',
#   'SCRIB',
#   'DDX3X',
#   'YWHAB',
#   'GTF2B',
#   'CASP3',
#   'HDAC6',
#   'CDKN1A',
#   'SCIN',
#   'EP300',
#   'SND1',
#   'SRC',
#   'HLA-F',
#   'EGR2',
#   'CCNA2',
#   'IRF9',
#   'DDB1',
#   'TRAF5',
#   'ACTN4',
#   'CREB3L1',
#   'CASP8',
#   'GTF2E2',
#   'GTF2H4',
#   'CCR4',
#   'BAX',
#   'PSMC1',
#   'NFKB2',
#   'MDM2',
#   'TBPL1',
#   'YWHAH',
#   'YWHAQ',
#   'JAK3',
#   'PIK3CA',
#   'CCR8',
#   'YWHAZ',
#   'NFKB1',
#   'CCR3',
#   'SYK',
#   'TRAF1',
#   'USP7',
#   'HDAC7',
#   'C3',
#   'NRAS',
#   'HDAC3',
#   'SRF',
#   'TBPL2',
#   'CREBBP',
#   'HDAC2',
#   'CDC20',
#   'HDAC5',
#   'TBP',
#   'TRADD',
#   'UBE3A',
#   'KRAS',
#   'PRKACA',
#   'HRAS',
#   'RANBP1',
#   'CCNE1',
#   'CHEK1',
#   'PMAIP1',
#   'CREB3L3',
#   'BAK1',
#   'KAT2A',
#   'TRAF2',
#   'PIK3R2',
#   'CDKN1B',
#   'CCNA1',
#   'POLB',
#   'ATP6V0D2',
#   'REL',
#   'MAD1L1',
#   'CREB5',
#   'SNW1',
#   'GTF2A1',
#   'HNRNPK',
#   'STAT5B',
#   'CREB3L2',
#   'HLA-G',
#   'RASA2',
#   'IRF7',
#   'CDC42',
#   'HLA-B',
#   'CCND2',
#   'HDAC8',
#   'HPN',
#   'CHD4',
#   'BAD',
#   'HLA-C',
#   'ATF6B',
#   'ATF2',
#   'TRAF3',
#   'GTF2A2',
#   'PIK3R1',
#   'HDAC4',
#   'MAPK3',
#   'PXN',
#   'HDAC10',
#   'SP100',
#   'RB1',
#   'RAC1',
#   'RBL2',
#   'JAK1',
#   'GTF2H1',
#   'CDK1',
#   'GRB2',
#   'JUN',
#   'IL6ST',
#   'YWHAG',
#   'PIK3CB',
#   'TP53',
#   'MRPS18B',
#   'GSN',
#   'IRF3',
#   'GTF2H2C',
#   'IKBKG'],
#  'Viral myocarditis': ['CYCS',
#   'ICAM1',
#   'HLA-G',
#   'CD40',
#   'SGCD',
#   'CD40LG',
#   'HLA-B',
#   'HLA-DRA',
#   'SGCB',
#   'HLA-DRB1',
#   'FYN',
#   'HLA-DQB1',
#   'ACTB',
#   'HLA-DQA1',
#   'CD86',
#   'RAC3',
#   'HLA-C',
#   'CCND1',
#   'CASP3',
#   'HLA-DOB',
#   'ITGB2',
#   'HLA-DRB5',
#   'HLA-DMA',
#   'HLA-DQA2',
#   'EIF4G2',
#   'EIF4G3',
#   'MYH6',
#   'CD55',
#   'ABL2',
#   'RAC1',
#   'EIF4G1',
#   'DMD',
#   'DAG1',
#   'SGCG',
#   'HLA-F',
#   'CXADR',
#   'RAC2',
#   'BID',
#   'HLA-DPA1',
#   'ACTG1',
#   'CAV1',
#   'ITGAL',
#   'CD80',
#   'LAMA1',
#   'CD28',
#   'LAMA2',
#   'CASP8',
#   'HLA-DPB1',
#   'ABL1',
#   'CASP9',
#   'HLA-DOA',
#   'HLA-A',
#   'PRF1',
#   'HLA-E',
#   'SGCA',
#   'HLA-DMB'],
#  'Viral protein interaction with cytokine and cytokine receptor': ['CCR7',
#   'CX3CR1',
#   'CXCR1',
#   'IL2RA',
#   'CCL14',
#   'CCR10',
#   'LTBR',
#   'CXCR3',
#   'CCR6',
#   'CXCL13',
#   'IL18',
#   'CXCL12',
#   'CCR2',
#   'CXCL2',
#   'CCL2',
#   'TNFRSF1B',
#   'CCL24',
#   'CSF1R',
#   'IL2RG',
#   'IL20RB',
#   'IL19',
#   'CCL13',
#   'IL10RA',
#   'IL34',
#   'CCL3',
#   'CCR5',
#   'PF4',
#   'PF4V1',
#   'PPBP',
#   'CCL4',
#   'IL24',
#   'CCL1',
#   'CXCL6',
#   'CCL19',
#   'TNFRSF10B',
#   'CCL3L1',
#   'TNFSF14',
#   'CCL18',
#   'XCL1',
#   'CCL16',
#   'CCR4',
#   'CCL25',
#   'CCL8',
#   'ACKR3',
#   'CCL22',
#   'TNFRSF14',
#   'CCR8',
#   'CXCL11',
#   'CCL26',
#   'CCR3',
#   'CXCL14',
#   'TNFRSF10D',
#   'TNFRSF10C',
#   'IL2',
#   'CCL27',
#   'IL18R1',
#   'IL6',
#   'CXCR4',
#   'CCL23',
#   'CXCR5',
#   'IL6R',
#   'CCL28',
#   'CXCL9',
#   'IL20RA',
#   'LTA',
#   'IL20',
#   'CCR9',
#   'CXCR2',
#   'CXCL10',
#   'CXCL8',
#   'IL2RB',
#   'CCL17',
#   'CCL7',
#   'TNFSF10',
#   'XCL2',
#   'TNFRSF1A',
#   'CXCL5',
#   'CSF1',
#   'XCR1',
#   'IL37',
#   'CXCL3',
#   'TNFRSF10A',
#   'IL10RB',
#   'IL10',
#   'TNF',
#   'IL22RA1',
#   'ACKR4',
#   'CCL5',
#   'IL18RAP',
#   'CX3CL1',
#   'CCL20',
#   'CCL4L2',
#   'IL6ST',
#   'CCR1',
#   'CCL15',
#   'CXCL1'],
#  'Vitamin B6 metabolism': ['PSAT1',
#   'PNPO',
#   'PDXP',
#   'PDXK',
#   'AOX1',
#   'PHOSPHO2'],
#  'Vitamin digestion and absorption': ['SCARB1',
#   'BTD',
#   'PLB1',
#   'LRAT',
#   'ABCC1',
#   'SLC5A6',
#   'FOLH1',
#   'SLC19A1',
#   'SLC23A1',
#   'AWAT2',
#   'LMBRD1',
#   'SLC19A3',
#   'SLC19A2',
#   'SLC52A3',
#   'MMACHC',
#   'RBP2',
#   'SLC46A1',
#   'APOB',
#   'CUBN',
#   'TCN2',
#   'APOA1'],
#  'Wnt signaling pathway': ['LGR6',
#   'PORCN',
#   'AXIN1',
#   'PLCB4',
#   'FZD10',
#   'FZD7',
#   'SFRP2',
#   'MAPK8',
#   'DKK4',
#   'TBL1XR1',
#   'RAC3',
#   'FZD5',
#   'MAP3K7',
#   'CAMK2D',
#   'CTNNB1',
#   'RSPO3',
#   'PRICKLE1',
#   'DVL3',
#   'ROCK2',
#   'NKD1',
#   'WNT9A',
#   'MAPK9',
#   'CAMK2A',
#   'MYC',
#   'NKD2',
#   'SERPINF1',
#   'FZD3',
#   'APC2',
#   'NOTUM',
#   'PRKACB',
#   'CXXC4',
#   'SFRP4',
#   'FZD2',
#   'SENP2',
#   'FZD4',
#   'WNT3A',
#   'TBL1X',
#   'CTBP1',
#   'LRP5',
#   'FRAT2',
#   'PPARD',
#   'RHOA',
#   'APC',
#   'FZD1',
#   'ROR1',
#   'WNT2B',
#   'SOST',
#   'DKK1',
#   'CCND3',
#   'CCND1',
#   'NFATC1',
#   'TLE4',
#   'WNT1',
#   'PRKCA',
#   'WNT8B',
#   'PRICKLE4',
#   'EP300',
#   'WNT11',
#   'INVS',
#   'CSNK2A2',
#   'CUL1',
#   'CSNK2B',
#   'BTRC',
#   'ZNRF3',
#   'PRKCG',
#   'FZD8',
#   'WNT4',
#   'PPP3CA',
#   'FRAT1',
#   'VANGL2',
#   'CAMK2B',
#   'WIF1',
#   'GSK3B',
#   'RBX1',
#   'LEF1',
#   'PRICKLE2',
#   'NFATC4',
#   'WNT6',
#   'TLE1',
#   'FZD9',
#   'SIAH1',
#   'WNT7B',
#   'MMP7',
#   'CSNK2A1',
#   'NFATC3',
#   'PLCB3',
#   'PPP3R2',
#   'WNT5A',
#   'FOSL1',
#   'BAMBI',
#   'SMAD4',
#   'CREBBP',
#   'RNF43',
#   'PRICKLE3',
#   'DVL2',
#   'CBY1',
#   'TLE2',
#   'PRKACA',
#   'NLK',
#   'CAMK2G',
#   'PPP3CC',
#   'RAC2',
#   'TBL1Y',
#   'CSNK1A1L',
#   'PSEN1',
#   'WNT10A',
#   'WNT10B',
#   'PLCB2',
#   'SKP1',
#   'VANGL1',
#   'DKK2',
#   'CACYBP',
#   'LGR4',
#   'DAAM2',
#   'RUVBL1',
#   'TLE6',
#   'CTNND2',
#   'TCF7',
#   'TCF7L1',
#   'DAAM1',
#   'TPTEP2-CSNK1E',
#   'SMAD3',
#   'WNT3',
#   'CTNNBIP1',
#   'WNT5B',
#   'CCND2',
#   'PPP3R1',
#   'CSNK1A1',
#   'TLE3',
#   'AXIN2',
#   'FBXW11',
#   'RYK',
#   'DVL1',
#   'PLCB1',
#   'CSNK1E',
#   'CTBP2',
#   'WNT7A',
#   'RAC1',
#   'ROR2',
#   'MAPK10',
#   'WNT9B',
#   'PPP3CB',
#   'FZD6',
#   'TCF7L2',
#   'LRP6',
#   'JUN',
#   'NFATC2',
#   'WNT16',
#   'TP53',
#   'CHD8',
#   'PRKCB',
#   'GPC4'],
#  'Yersinia infection': ['FOS',
#   'CD4',
#   'MAPK8',
#   'RAC3',
#   'ARHGEF12',
#   'ITGA5',
#   'TICAM1',
#   'MAP3K7',
#   'LCK',
#   'ELMO2',
#   'WIPF1',
#   'TLR4',
#   'ARF6',
#   'ROCK2',
#   'VAV1',
#   'ARPC5',
#   'LIMK1',
#   'MAPK1',
#   'MAPK9',
#   'ARPC2',
#   'IRAK4',
#   'IL18',
#   'ACTR3',
#   'MAPK13',
#   'CCL2',
#   'PIK3CD',
#   'ELMO1',
#   'MAP2K3',
#   'MYD88',
#   'WIPF2',
#   'PYCARD',
#   'BAIAP2',
#   'MEFV',
#   'PTK2B',
#   'WASL',
#   'PKN1',
#   'PIK3R3',
#   'AKT2',
#   'CD8B2',
#   'NFKBIA',
#   'RELA',
#   'RHOA',
#   'ACTR2',
#   'TRAF6',
#   'ARPC1B',
#   'NFATC1',
#   'TAB1',
#   'IRAK1',
#   'BCAR1',
#   'NLRP3',
#   'MAP2K2',
#   'SRC',
#   'MAP2K6',
#   'FCGR2A',
#   'ITGB1',
#   'IL1B',
#   'PTK2',
#   'ARHGEF28',
#   'GSK3B',
#   'WAS',
#   'MAP2K4',
#   'PIK3CA',
#   'PKN2',
#   'ARHGEF7',
#   'CASP1',
#   'ACTR3B',
#   'NFKB1',
#   'ACTB',
#   'NFATC3',
#   'CRKL',
#   'IL2',
#   'MAPK12',
#   'RPS6KA1',
#   'IL6',
#   'VAV2',
#   'RPS6KA6',
#   'RPS6KA2',
#   'RAC2',
#   'ZAP70',
#   'PIP5K1A',
#   'TRAF2',
#   'PIK3R2',
#   'MAP2K7',
#   'ARPC1A',
#   'CXCL8',
#   'IKBKB',
#   'NLRC4',
#   'FN1',
#   'WIPF3',
#   'DOCK1',
#   'CD8A',
#   'PIP5K1B',
#   'AKT3',
#   'WASF2',
#   'ITGA4',
#   'TAB2',
#   'ARPC5L',
#   'LCP2',
#   'SKAP2',
#   'CDC42',
#   'ARPC4',
#   'CRK',
#   'GIT2',
#   'TBK1',
#   'FYB1',
#   'MAPK11',
#   'RHOG',
#   'PIK3R1',
#   'MAPK3',
#   'PXN',
#   'GNAQ',
#   'IL10',
#   'TNF',
#   'MAPK14',
#   'RPS6KA3',
#   'VAV3',
#   'CD8B',
#   'RAC1',
#   'MAP2K1',
#   'MAPK10',
#   'PLCG1',
#   'ROCK1',
#   'CHUK',
#   'ACTG1',
#   'LAT',
#   'ARHGEF1',
#   'JUN',
#   'NFATC2',
#   'PIK3CB',
#   'IFNB1',
#   'IRF3',
#   'IKBKG',
#   'PIP5K1C',
#   'ACTR3C',
#   'AKT1',
#   'ARPC3'],
#  'alpha-Linolenic acid metabolism': ['PLA2G4D',
#   'PLB1',
#   'PLA2G12B',
#   'PLA2G4C',
#   'PLA2G2C',
#   'PLA2G3',
#   'PLA2G2D',
#   'ACAA1',
#   'ACOX1',
#   'PLA2G10',
#   'PLA2G4A',
#   'ACOX3',
#   'PLA2G12A',
#   'PLA2G2F',
#   'PLA2G5',
#   'PLA2G2A',
#   'PLA2G4E',
#   'PLA2G4B',
#   'PLA2G6',
#   'JMJD7-PLA2G4B',
#   'FADS2',
#   'PLA2G1B',
#   'PLA2G4F'],
#  'beta-Alanine metabolism': ['GADL1',
#   'ALDH6A1',
#   'ALDH2',
#   'HIBCH',
#   'AOC3',
#   'ALDH3A2',
#   'GAD2',
#   'ALDH7A1',
#   'EHHADH',
#   'ABAT',
#   'UPB1',
#   'CNDP2',
#   'ALDH1B1',
#   'ALDH3B1',
#   'ACOX1',
#   'ALDH9A1',
#   'ACOX3',
#   'CARNS1',
#   'ALDH3B2',
#   'ALDH3A1',
#   'DPYD',
#   'MLYCD',
#   'AOC2',
#   'GAD1',
#   'SMOX',
#   'DPYS',
#   'HADHA',
#   'CNDP1',
#   'ECHS1',
#   'ACADS'],
#  'cAMP signaling pathway': ['ADRB2',
#   'DRD5',
#   'OXT',
#   'CHRM2',
#   'ATP1B2',
#   'FOS',
#   'ADCY5',
#   'NPY1R',
#   'MAPK8',
#   'RAC3',
#   'FFAR2',
#   'TSHR',
#   'EDN1',
#   'F2R',
#   'CAMK2D',
#   'CREB3L4',
#   'RYR2',
#   'CACNA1C',
#   'CALML5',
#   'GHRL',
#   'ADCY2',
#   'ROCK2',
#   'HTR6',
#   'VAV1',
#   'HTR4',
#   'PPP1CA',
#   'MAPK9',
#   'MAPK1',
#   'ADCY4',
#   'CREB1',
#   'PDE4A',
#   'ATP2B1',
#   'HCN4',
#   'CAMK2A',
#   'GABBR1',
#   'ATP1A3',
#   'PIK3CD',
#   'ARAP3',
#   'LIPE',
#   'RAP1B',
#   'MYL9',
#   'HTR1D',
#   'PRKACB',
#   'GABBR2',
#   'CALML3',
#   'ADCY3',
#   'PIK3R3',
#   'AKT2',
#   'NFKBIA',
#   'BDNF',
#   'CREB3',
#   'NPY',
#   'RELA',
#   'RHOA',
#   'PDE4C',
#   'GLI1',
#   'ORAI1',
#   'GNAS',
#   'ADCYAP1',
#   'VIP',
#   'PPP1R12A',
#   'NFATC1',
#   'HCAR3',
#   'GLI3',
#   'MC2R',
#   'CALM3',
#   'EP300',
#   'ATP1B1',
#   'MAP2K2',
#   'CACNA1D',
#   'PDE4B',
#   'ACOX1',
#   'PLN',
#   'ATP1B4',
#   'ADCYAP1R1',
#   'FXYD2',
#   'CFTR',
#   'ATP1A2',
#   'ATP1A1',
#   'ADCY9',
#   'ADCY6',
#   'PLD2',
#   'GIPR',
#   'CREB3L1',
#   'ADRB1',
#   'HTR1F',
#   'PPP1R1B',
#   'GRIA4',
#   'CAMK2B',
#   'CACNA1F',
#   'CALML4',
#   'PTCH1',
#   'ATP2A3',
#   'ADCY1',
#   'ADCY7',
#   'CALM1',
#   'ATP2A2',
#   'GRIN2C',
#   'GRIN2B',
#   'SUCNR1',
#   'CNGA1',
#   'PTGER2',
#   'PIK3CA',
#   'EDNRA',
#   'PAK1',
#   'SSTR2',
#   'NFKB1',
#   'CGA',
#   'PTGER3',
#   'PPP1CB',
#   'CREBBP',
#   'EDN3',
#   'GNAI1',
#   'POMC',
#   'GNAI2',
#   'HCAR1',
#   'PRKACA',
#   'NPR1',
#   'CNGB1',
#   'CNGB3',
#   'VAV2',
#   'CAMK2G',
#   'LHB',
#   'RAC2',
#   'ATP2B4',
#   'PDE4D',
#   'CREB3L3',
#   'TIAM1',
#   'RRAS',
#   'VIPR2',
#   'CALM2',
#   'HCAR2',
#   'SOX9',
#   'PIK3R2',
#   'PLD1',
#   'RAF1',
#   'FXYD1',
#   'AMH',
#   'GRIN1',
#   'CREB5',
#   'CALML6',
#   'CNGA4',
#   'GRIN2D',
#   'RRAS2',
#   'AKT3',
#   'CAMK4',
#   'HHIP',
#   'PDE3A',
#   'OXTR',
#   'CREB3L2',
#   'ADORA1',
#   'RAPGEF3',
#   'AFDN',
#   'BAD',
#   'PDE10A',
#   'GRIN3A',
#   'ATP1A4',
#   'PIK3R1',
#   'TNNI3',
#   'PDE3B',
#   'RAP1A',
#   'MAPK3',
#   'GRIA3',
#   'ATP2B3',
#   'GNAI3',
#   'GRIN2A',
#   'NPPA',
#   'VAV3',
#   'ADORA2A',
#   'PPP1CC',
#   'RAC1',
#   'EDN2',
#   'CNGA3',
#   'ADCY10',
#   'MAP2K1',
#   'MAPK10',
#   'ROCK1',
#   'ACOX3',
#   'PLCE1',
#   'ATP2A1',
#   'BRAF',
#   'GRIN3B',
#   'HCN2',
#   'DRD2',
#   'JUN',
#   'PIK3CB',
#   'GRIA1',
#   'PPARA',
#   'ATP1B3',
#   'SLC9A1',
#   'ABCC4',
#   'RAPGEF4',
#   'AKT1',
#   'ATP2B2'],
#  'cGMP-PKG signaling pathway': ['MEF2C',
#   'PDE2A',
#   'KCNMB2',
#   'ADRB2',
#   'KCNMB4',
#   'INSR',
#   'ATP1B2',
#   'ADCY5',
#   'PLCB4',
#   'IRS1',
#   'ATF4',
#   'PIK3CG',
#   'ITPR3',
#   'GNA12',
#   'CREB3L4',
#   'CACNA1C',
#   'CALML5',
#   'OPRD1',
#   'GTF2I',
#   'ROCK2',
#   'ADCY2',
#   'PPP1CA',
#   'MAPK1',
#   'ADCY4',
#   'CREB1',
#   'ATP2B1',
#   'SLC8A1',
#   'ATP1A3',
#   'MYL9',
#   'GUCY1B1',
#   'CALML3',
#   'ADORA3',
#   'VDAC3',
#   'MEF2D',
#   'ADCY3',
#   'BDKRB2',
#   'AKT2',
#   'CREB3',
#   'RHOA',
#   'ADRB3',
#   'KCNMB1',
#   'KCNMB3',
#   'PPP1R12A',
#   'VDAC1',
#   'NFATC1',
#   'PDE5A',
#   'KCNMA1',
#   'MYH6',
#   'CALM3',
#   'ATP1B1',
#   'MAP2K2',
#   'CACNA1D',
#   'ITPR1',
#   'PLN',
#   'ATP1B4',
#   'FXYD2',
#   'ATP1A2',
#   'ATP1A1',
#   'PPP3CA',
#   'ADCY9',
#   'GTF2IRD1',
#   'ADCY6',
#   'MEF2B',
#   'CREB3L1',
#   'RGS2',
#   'ADRB1',
#   'CACNA1F',
#   'CALML4',
#   'ATP2A3',
#   'ADCY1',
#   'ADCY7',
#   'CALM1',
#   'NFATC4',
#   'ATP2A2',
#   'PIK3R5',
#   'GNA13',
#   'CNGA1',
#   'IRS2',
#   'ITPR2',
#   'EDNRA',
#   'NFATC3',
#   'PLCB3',
#   'PPP3R2',
#   'SRF',
#   'PPP1CB',
#   'GNAI1',
#   'GNAI2',
#   'NPR1',
#   'CNGB1',
#   'MYLK',
#   'PPP3CC',
#   'ATP2B4',
#   'TRPC6',
#   'CREB3L3',
#   'ADRA2B',
#   'SLC25A5',
#   'MYLK3',
#   'PLCB2',
#   'BORCS8-MEF2B',
#   'CALM2',
#   'RAF1',
#   'SLC8A2',
#   'CREB5',
#   'CALML6',
#   'VASP',
#   'AKT3',
#   'GUCY1A2',
#   'PDE3A',
#   'KNG1',
#   'GUCY1A1',
#   'CREB3L2',
#   'SLC25A31',
#   'PPIF',
#   'ADRA2A',
#   'PPP3R1',
#   'MYLK2',
#   'ADORA1',
#   'SLC25A4',
#   'SLC8A3',
#   'MYLK4',
#   'BAD',
#   'PRKG1',
#   'ATF6B',
#   'ATF2',
#   'ATP1A4',
#   'SLC25A6',
#   'ADRA1B',
#   'PDE3B',
#   'MAPK3',
#   'GNAQ',
#   'ATP2B3',
#   'GNAI3',
#   'NPR2',
#   'NPPA',
#   'PRKG2',
#   'PLCB1',
#   'GNA11',
#   'PPP1CC',
#   'MAP2K1',
#   'ROCK1',
#   'PPP3CB',
#   'ATP2A1',
#   'EDNRB',
#   'NFATC2',
#   'NPPC',
#   'VDAC2',
#   'NOS3',
#   'ATP1B3',
#   'PRKCE',
#   'MEF2A',
#   'PIK3R6',
#   'AKT1',
#   'ADRA1A',
#   'ATP2B2'],
#  'mRNA surveillance pathway': ['CPSF3',
#   'PPP2R5E',
#   'FIP1L1',
#   'PPP2R2C',
#   'PABPN1',
#   'MAGOH',
#   'CSTF2',
#   'RNMT',
#   'PNN',
#   'PPP2R2B',
#   'CPSF7',
#   'MSI2',
#   'PABPC1L2A',
#   'CSTF3',
#   'PPP1CA',
#   'CPSF2',
#   'UPF2',
#   'MSI1',
#   'HBS1L',
#   'PPP2R2A',
#   'UPF3A',
#   'CASC3',
#   'EIF4A3',
#   'PPP2R5A',
#   'PABPC3',
#   'RNGTT',
#   'PPP2R2D',
#   'CPSF4',
#   'SMG7',
#   'GLE1',
#   'PPP2R3A',
#   'CLP1',
#   'PABPC1',
#   'PPP2R5C',
#   'ALYREF',
#   'UPF1',
#   'DDX39B',
#   'PPP2R1A',
#   'NXT2',
#   'PPP2CA',
#   'CPSF6',
#   'DAZAP1',
#   'CSTF1',
#   'PAPOLA',
#   'SYMPK',
#   'PCF11',
#   'CPSF4L',
#   'PABPC4',
#   'RNPS1',
#   'PABPN1L',
#   'NXF3',
#   'SMG6',
#   'PPP1CB',
#   'GSPT2',
#   'NXT1',
#   'SSU72',
#   'NXF1',
#   'PPP2R5B',
#   'MAGOHB',
#   'FUS',
#   'NUDT21',
#   'TARDBP',
#   'SMG5',
#   'PPP2R3B',
#   'PPP2R1B',
#   'NCBP2L',
#   'PPP2CB',
#   'SMG1',
#   'NCBP2',
#   'ETF1',
#   'SRRM1',
#   'PPP2R5D',
#   'WDR82',
#   'CSTF2T',
#   'CPSF1',
#   'DDX19B',
#   'PYM1',
#   'PAPOLG',
#   'RBM8A',
#   'PPP2R3C',
#   'SAP18',
#   'PPP1CC',
#   'PELO',
#   'PABPC1L',
#   'WDR33',
#   'GSPT1',
#   'PAPOLB',
#   'ACIN1',
#   'BCL2L2-PABPN1',
#   'NCBP1',
#   'UPF3B',
#   'DDX19A'],
#  'mTOR signaling pathway': ['STRADA',
#   'NPRL3',
#   'INSR',
#   'SLC38A9',
#   'TSC2',
#   'NPRL2',
#   'RRAGC',
#   'FNIP1',
#   'FZD7',
#   'FZD10',
#   'FZD5',
#   'IRS1',
#   'CAB39',
#   'ATP6V1E1',
#   'DVL3',
#   'WNT9A',
#   'MAPK1',
#   'FZD3',
#   'PIK3CD',
#   'ATP6V1C1',
#   'SKP2',
#   'SLC7A5',
#   'GRB10',
#   'DEPTOR',
#   'SOS1',
#   'LAMTOR1',
#   'FZD2',
#   'ATP6V1H',
#   'FZD4',
#   'WNT3A',
#   'PIK3R3',
#   'AKT2',
#   'LPIN3',
#   'LRP5',
#   'WDR59',
#   'RHOA',
#   'FZD1',
#   'LAMTOR4',
#   'WNT2B',
#   'WNT1',
#   'PRKCA',
#   'WNT8B',
#   'ATP6V1E2',
#   'MAP2K2',
#   'WNT11',
#   'ATP6V1G3',
#   'RRAGA',
#   'PRKCG',
#   'FZD8',
#   'WNT4',
#   'MIOS',
#   'TBC1D7',
#   'ATP6V1C2',
#   'IGF1R',
#   'FNIP2',
#   'EIF4B',
#   'RRAGB',
#   'GSK3B',
#   'ULK2',
#   'LAMTOR5',
#   'WNT6',
#   'ATP6V1G1',
#   'FZD9',
#   'SGK1',
#   'RRAGD',
#   'PIK3CA',
#   'WNT7B',
#   'CASTOR1',
#   'RICTOR',
#   'MTOR',
#   'LPIN2',
#   'RPS6KB2',
#   'WNT5A',
#   'NRAS',
#   'EIF4E',
#   'ATP6V1B1',
#   'SEC13',
#   'DVL2',
#   'PRKAA2',
#   'KRAS',
#   'RPS6KA1',
#   'PRKAA1',
#   'HRAS',
#   'TSC1',
#   'ATP6V1D',
#   'RPS6KA6',
#   'SOS2',
#   'RPS6KA2',
#   'STK11',
#   'WNT10A',
#   'WNT10B',
#   'DEPDC5',
#   'PIK3R2',
#   'MAPKAP1',
#   'PRR5',
#   'RAF1',
#   'SEH1L',
#   'EIF4E2',
#   'IKBKB',
#   'LAMTOR2',
#   'RPTOR',
#   'ATP6V1A',
#   'AKT3',
#   'ATP6V1B2',
#   'CASTOR2',
#   'ATP6V1G2',
#   'WNT3',
#   'TNFRSF1A',
#   'WNT5B',
#   'RPS6',
#   'TELO2',
#   'LPIN1',
#   'WDR24',
#   'RPS6KB1',
#   'MLST8',
#   'CAB39L',
#   'FLCN',
#   'ULK1',
#   'PIK3R1',
#   'MAPK3',
#   'IGF1',
#   'TNF',
#   'RPS6KA3',
#   'DVL1',
#   'TTI1',
#   'EIF4EBP1',
#   'WNT7A',
#   'LAMTOR3',
#   'RHEB',
#   'MAP2K1',
#   'WNT9B',
#   'ATP6V1F',
#   'CHUK',
#   'FZD6',
#   'LRP6',
#   'BRAF',
#   'DDIT4',
#   'GRB2',
#   'AKT1S1',
#   'CLIP1',
#   'RNF152',
#   'PTEN',
#   'PIK3CB',
#   'STRADB',
#   'WNT16',
#   'PDPK1',
#   'SLC3A2',
#   'PRKCB',
#   'SESN2',
#   'AKT1'],
#  'p53 signaling pathway': ['CYCS',
#   'ADGRB1',
#   'THBS1',
#   'SHISA5',
#   'CCND2',
#   'CDK6',
#   'RPRM',
#   'BBC3',
#   'SIAH1',
#   'RRM2',
#   'CCNB1',
#   'TSC2',
#   'ZMAT3',
#   'CDK4',
#   'CHEK2',
#   'CDKN2A',
#   'AIFM2',
#   'PPM1D',
#   'STEAP3',
#   'TP53AIP1',
#   'CCND3',
#   'CCND1',
#   'BCL2',
#   'TNFRSF10A',
#   'CASP3',
#   'CCNG1',
#   'IGF1',
#   'RRM2B',
#   'CDKN1A',
#   'APAF1',
#   'ATR',
#   'PERP',
#   'TNFRSF10B',
#   'SESN3',
#   'PIDD1',
#   'TP73',
#   'CCNE2',
#   'GADD45B',
#   'BCL2L1',
#   'CCNB2',
#   'CCNE1',
#   'CHEK1',
#   'DDB2',
#   'SESN1',
#   'RCHY1',
#   'FAS',
#   'CDK1',
#   'GORAB',
#   'COP1',
#   'PMAIP1',
#   'BID',
#   'SFN',
#   'IGFBP3',
#   'PTEN',
#   'CD82',
#   'MDM4',
#   'CASP8',
#   'GTSE1',
#   'TP53I3',
#   'CDK2',
#   'TP53',
#   'ATM',
#   'BAX',
#   'CASP9',
#   'SERPINB5',
#   'MDM2',
#   'GADD45A',
#   'SERPINE1',
#   'EI24',
#   'CCNG2',
#   'GADD45G',
#   'SESN2',
#   'SIVA1']}

# %% [markdown]
# PCC-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_severe_0.6.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="pcc_knd_binary_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="pcc_knd_linear_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)


list_to_txt(path="pcc_knd_nlog_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="pcc_knd_reciprocal_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_severe_10.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="pcc_knn_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# Binary-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_severe_0.7.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="binary_knd_binary_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_ctrl_0.3.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_mild_0.3.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_severe_0.3.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="binary_knd_linear_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_ctrl_0.3.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_mild_0.3.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_severe_0.3.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="binary_knd_nlog_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="binary_knd_reciprocal_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_severe_10.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="binary_knn_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# Linear-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_severe_0.7.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="linear_knd_binary_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="linear_knd_linear_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_severe_0.4.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="linear_knd_nlog_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_ctrl_0.5.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_mild_0.5.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_severe_0.5.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="linear_knd_reciprocal_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_severe_10.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="linear_knn_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# nlog

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_severe_0.7.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="nlog_knd_binary_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_severe_0.4.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="nlog_knd_linear_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="nlog_knd_nlog_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_severe_0.7.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="nlog_knd_reciprocal_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_severe_10.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="nlog_knn_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# Reciprocal-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_ctrl_0.8.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_mild_0.8.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_severe_0.8.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="reciprocal_knd_binary_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_severe_0.4.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="reciprocal_knd_linear_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_severe_0.6.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="reciprocal_knd_nlog_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_severe_0.6.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="reciprocal_knd_reciprocal_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_severe_10.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="reciprocal_knn_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# pcc_leiden

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_severe_0.35.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="pcc_leiden_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# hdWGCNA ### NOT YET ###

# %%
module_ctrl = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_ctrl_2.5.json")
module_mild = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_mild_2.5.json")
module_severe = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_severe_2.5.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)

list_to_txt(path="hdWGCNA_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe])

# %% [markdown]
# TOM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_ctrl_0.1.json")
module_mild = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_mild_0.1.json")
module_severe = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_severe_0.1.json")
module_mildV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_mildV_0.1.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)
relevance_mildV = relevance(my_modules=module_mildV, curated_modules=KEGG_2021_Human)

list_to_txt(path="TOM_Leiden_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe, relevance_mildV])

# %% [markdown]
# Hotspot

# %%
module_ctrl = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_ctrl_50.json")
module_mild = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_mild_50.json")
module_severe = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_severe_50.json")
module_mildV = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_mildV_50.json")

relevance_ctrl = relevance(my_modules=module_ctrl, curated_modules=KEGG_2021_Human)
relevance_mild = relevance(my_modules=module_mild, curated_modules=KEGG_2021_Human)
relevance_severe = relevance(my_modules=module_severe, curated_modules=KEGG_2021_Human)
relevance_mildV = relevance(my_modules=module_mildV, curated_modules=KEGG_2021_Human)

list_to_txt(path="Hotspot_KEGG_relevance.txt", number_list=[relevance_ctrl, relevance_mild, relevance_severe, relevance_mildV])
