# %% [markdown]
# pairwise t-test for all module detection methods, based on enrichment ratio

# %%
import numpy as np
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from algorithm_comparison import file_to_float, ttest

# %%
my_enrichment_ratio_1 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method1_enrichment_ratio.txt")
my_enrichment_ratio_2 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method2_enrichment_ratio.txt")
my_enrichment_ratio_3 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method3_enrichment_ratio.txt")
my_enrichment_ratio_4 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method4_enrichment_ratio.txt")
my_enrichment_ratio_5 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method5_enrichment_ratio.txt")
my_enrichment_ratio_6 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/my_method6_enrichment_ratio.txt")

# %%
enrichment_ratio_1 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method1_enrichment_ratio.txt")
enrichment_ratio_2 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method2_enrichment_ratio.txt")
enrichment_ratio_3 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method3_enrichment_ratio.txt")
enrichment_ratio_4 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method4_enrichment_ratio.txt")
enrichment_ratio_5 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method5_enrichment_ratio.txt")
enrichment_ratio_6 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method6_enrichment_ratio.txt")
enrichment_ratio_7 = file_to_float(path="/home/jovyan/work/module_detection_algorithm_comparison/method7_enrichment_ratio.txt")

# %%
print(np.mean(my_enrichment_ratio_1))
print(np.mean(my_enrichment_ratio_2))
print(np.mean(my_enrichment_ratio_3))  # best, few modules
print(np.mean(my_enrichment_ratio_4))  # good, slightly better
print(np.mean(my_enrichment_ratio_5))  # good
print(np.mean(my_enrichment_ratio_6))  # bad, few modules
# Out:
# 0.8333333333333333
# 0.3866666666666666
# 0.48277537790262504
# 0.41376044405225815
# 0.4000968890785518
# 0.2954297676938682

# %%
print(np.mean(enrichment_ratio_1))
print(np.mean(enrichment_ratio_2))
print(np.mean(enrichment_ratio_3))  # best
print(np.mean(enrichment_ratio_4))
print(np.mean(enrichment_ratio_5))
print(np.mean(enrichment_ratio_6))
print(np.mean(enrichment_ratio_7))  # best, few clusters
# Out:
# 0.17324920916310096
# 0.2071343791417318
# 0.38207219698907313
# 0.2575550875592995
# 0.2598028610184282
# 0.23391296751287377
# 0.5673270697167755

# %%
my_enrichment_ratio = [my_enrichment_ratio_1, my_enrichment_ratio_2, my_enrichment_ratio_3, 
                      my_enrichment_ratio_4, my_enrichment_ratio_5, my_enrichment_ratio_6]

for i in range(len(my_enrichment_ratio)):
    for j in range(i+1, len(my_enrichment_ratio)):
        ttest(list1=my_enrichment_ratio[i], list2=my_enrichment_ratio[j])
# Out:
# The difference is statistically significant.
# p_value = 0.017285200675714516
# The difference is statistically significant.
# p_value = 0.0118509632056754
# The difference is statistically significant.
# p_value = 0.004742663597546699
# The difference is statistically significant.
# p_value = 0.003652534917159679
# The difference is statistically significant.
# p_value = 0.0016085096820368666
# There is no significant difference.
# p_value = 0.401380708746915
# There is no significant difference.
# p_value = 0.8094956443469351
# There is no significant difference.
# p_value = 0.903319273029343
# There is no significant difference.
# p_value = 0.452505725309745
# There is no significant difference.
# p_value = 0.08451040136296709
# The difference is statistically significant.
# p_value = 0.023747329952834142
# The difference is statistically significant.
# p_value = 0.007314559281316979
# There is no significant difference.
# p_value = 0.6678384823282866
# ...

# %%
enrichment_ratio = [enrichment_ratio_1, enrichment_ratio_2, enrichment_ratio_3, 
                      enrichment_ratio_4, enrichment_ratio_5, enrichment_ratio_6, 
                   enrichment_ratio_7]

for i in range(len(enrichment_ratio)):
    for j in range(i+1, len(enrichment_ratio)):
        ttest(list1=enrichment_ratio[i], list2=enrichment_ratio[j])
# Out:
# There is no significant difference.
# p_value = 0.38132412066333154
# The difference is statistically significant.
# p_value = 0.0001025430513551567
# The difference is statistically significant.
# p_value = 0.014933596885065056
# The difference is statistically significant.
# p_value = 0.013487933192020391
# The difference is statistically significant.
# p_value = 0.042222213742606235
# The difference is statistically significant.
# p_value = 6.385830355673457e-05
# The difference is statistically significant.
# p_value = 0.0005872605796289083
# There is no significant difference.
# p_value = 0.1309465017588355
# There is no significant difference.
# p_value = 0.11809813054065174
# There is no significant difference.
# p_value = 0.36686750009729724
# The difference is statistically significant.
# p_value = 0.00014565604780722788
# The difference is statistically significant.
# p_value = 0.00031293760094847946
# The difference is statistically significant.
# ...

# %%
ttest(list1=my_enrichment_ratio_3, list2=my_enrichment_ratio_4)
# Out:
# There is no significant difference.
# p_value = 0.08451040136296709

# %%
ttest(list1=my_enrichment_ratio_3, list2=my_enrichment_ratio_5)
# Out:
# The difference is statistically significant.
# p_value = 0.023747329952834142

# %%
ttest(list1=my_enrichment_ratio_4, list2=my_enrichment_ratio_5)
# Out:
# There is no significant difference.
# p_value = 0.6678384823282866

# %%
ttest(list1=enrichment_ratio_1, list2=enrichment_ratio_4)
# Out:
# The difference is statistically significant.
# p_value = 0.030159858179290365
