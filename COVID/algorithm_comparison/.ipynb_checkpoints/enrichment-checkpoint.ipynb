# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import module_to_dict
from algorithm_comparison import enrichment, list_to_txt, enrich_single_module

# %%
# !pwd
# %cd /home/jovyan/work/COVID/algorithm_comparison/Cell
# !pwd
# Out:
# /home/jovyan/work/COVID/algorithm_comparison
# /home/jovyan/work/COVID/algorithm_comparison/Cell
# /home/jovyan/work/COVID/algorithm_comparison/Cell

# %% [markdown]
# Cell: create the background gene (12939) list

# %%
# import pandas as pd
# pcc_ctrl = pd.read_csv("/home/jovyan/work/COVID/results/pcc_control.csv", index_col=0)
# print(pcc_ctrl.shape)
# with open("background.txt", "w") as file:
#     for i in pcc_ctrl.index:
#         file.write(i + "\n")

# %%
total_genes = 26571

# %% [markdown]
# PCC-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_binary/Cell/module_severe_0.6.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 85, total modules: 155, enrichment_ratio: 0.5483870967741935
# correctly_assigned_genes: 11221, total genes: 26571, correctly_assigned_ratio: 0.4223025102555418
# pathways: 88, total modules: 159, enrichment_ratio: 0.5534591194968553
# correctly_assigned_genes: 13553, total genes: 26571, correctly_assigned_ratio: 0.5100673666779572
# pathways: 284, total modules: 492, enrichment_ratio: 0.5772357723577236
# correctly_assigned_genes: 14968, total genes: 26571, correctly_assigned_ratio: 0.5633209137781792

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 88, total modules: 155, enrichment_ratio: 0.567741935483871
# correctly_assigned_genes: 12909, total genes: 26571, correctly_assigned_ratio: 0.4858304166196229
# pathways: 101, total modules: 159, enrichment_ratio: 0.6352201257861635
# correctly_assigned_genes: 15770, total genes: 26571, correctly_assigned_ratio: 0.5935041963042414
# pathways: 341, total modules: 492, enrichment_ratio: 0.693089430894309
# correctly_assigned_genes: 17706, total genes: 26571, correctly_assigned_ratio: 0.6663655865417184

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 106, total modules: 155, enrichment_ratio: 0.6838709677419355
# correctly_assigned_genes: 6609, total genes: 26571, correctly_assigned_ratio: 0.24872981822287457
# pathways: 122, total modules: 159, enrichment_ratio: 0.7672955974842768
# correctly_assigned_genes: 9508, total genes: 26571, correctly_assigned_ratio: 0.3578337285009973
# pathways: 439, total modules: 492, enrichment_ratio: 0.8922764227642277
# correctly_assigned_genes: 11634, total genes: 26571, correctly_assigned_ratio: 0.43784577170599526

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 95, total modules: 155, enrichment_ratio: 0.6129032258064516
# correctly_assigned_genes: 9885, total genes: 26571, correctly_assigned_ratio: 0.3720221293891837
# pathways: 115, total modules: 159, enrichment_ratio: 0.7232704402515723
# correctly_assigned_genes: 9447, total genes: 26571, correctly_assigned_ratio: 0.3555379925482669
# pathways: 396, total modules: 492, enrichment_ratio: 0.8048780487804879
# correctly_assigned_genes: 11690, total genes: 26571, correctly_assigned_ratio: 0.439953332580633

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_linear/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 103, total modules: 214, enrichment_ratio: 0.48130841121495327
# correctly_assigned_genes: 9436, total genes: 26571, correctly_assigned_ratio: 0.35512400737646305
# pathways: 94, total modules: 167, enrichment_ratio: 0.562874251497006
# correctly_assigned_genes: 13082, total genes: 26571, correctly_assigned_ratio: 0.49234127432162883
# pathways: 334, total modules: 556, enrichment_ratio: 0.6007194244604317
# correctly_assigned_genes: 13670, total genes: 26571, correctly_assigned_ratio: 0.5144706635053253

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 113, total modules: 214, enrichment_ratio: 0.5280373831775701
# correctly_assigned_genes: 11899, total genes: 26571, correctly_assigned_ratio: 0.4478190508449061
# pathways: 113, total modules: 167, enrichment_ratio: 0.6766467065868264
# correctly_assigned_genes: 17929, total genes: 26571, correctly_assigned_ratio: 0.674758195024651
# pathways: 385, total modules: 556, enrichment_ratio: 0.6924460431654677
# correctly_assigned_genes: 17283, total genes: 26571, correctly_assigned_ratio: 0.6504459749350796

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 158, total modules: 214, enrichment_ratio: 0.7383177570093458
# correctly_assigned_genes: 10181, total genes: 26571, correctly_assigned_ratio: 0.383162094012269
# pathways: 136, total modules: 167, enrichment_ratio: 0.8143712574850299
# correctly_assigned_genes: 9489, total genes: 26571, correctly_assigned_ratio: 0.35711866320424523
# pathways: 502, total modules: 556, enrichment_ratio: 0.9028776978417267
# correctly_assigned_genes: 9033, total genes: 26571, correctly_assigned_ratio: 0.3399570960821949

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 124, total modules: 214, enrichment_ratio: 0.5794392523364486
# correctly_assigned_genes: 8799, total genes: 26571, correctly_assigned_ratio: 0.3311505024274585
# pathways: 117, total modules: 167, enrichment_ratio: 0.7005988023952096
# correctly_assigned_genes: 9286, total genes: 26571, correctly_assigned_ratio: 0.34947875503368336
# pathways: 430, total modules: 556, enrichment_ratio: 0.7733812949640287
# correctly_assigned_genes: 10500, total genes: 26571, correctly_assigned_ratio: 0.39516766399458053

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_nlog/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 94, total modules: 198, enrichment_ratio: 0.47474747474747475
# correctly_assigned_genes: 9741, total genes: 26571, correctly_assigned_ratio: 0.3666026871401152
# pathways: 98, total modules: 165, enrichment_ratio: 0.593939393939394
# correctly_assigned_genes: 13506, total genes: 26571, correctly_assigned_ratio: 0.5082985209438862
# pathways: 345, total modules: 595, enrichment_ratio: 0.5798319327731093
# correctly_assigned_genes: 13697, total genes: 26571, correctly_assigned_ratio: 0.5154868089270257

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 112, total modules: 198, enrichment_ratio: 0.5656565656565656
# correctly_assigned_genes: 12598, total genes: 26571, correctly_assigned_ratio: 0.4741259267622596
# pathways: 108, total modules: 165, enrichment_ratio: 0.6545454545454545
# correctly_assigned_genes: 17396, total genes: 26571, correctly_assigned_ratio: 0.6546987316999736
# pathways: 413, total modules: 595, enrichment_ratio: 0.6941176470588235
# correctly_assigned_genes: 17123, total genes: 26571, correctly_assigned_ratio: 0.6444243724361146

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 146, total modules: 198, enrichment_ratio: 0.7373737373737373
# correctly_assigned_genes: 7722, total genes: 26571, correctly_assigned_ratio: 0.2906175906063001
# pathways: 129, total modules: 165, enrichment_ratio: 0.7818181818181819
# correctly_assigned_genes: 9488, total genes: 26571, correctly_assigned_ratio: 0.3570810281886267
# pathways: 541, total modules: 595, enrichment_ratio: 0.9092436974789916
# correctly_assigned_genes: 9235, total genes: 26571, correctly_assigned_ratio: 0.34755936923713826

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 111, total modules: 198, enrichment_ratio: 0.5606060606060606
# correctly_assigned_genes: 8607, total genes: 26571, correctly_assigned_ratio: 0.32392457942870045
# pathways: 109, total modules: 165, enrichment_ratio: 0.6606060606060606
# correctly_assigned_genes: 9007, total genes: 26571, correctly_assigned_ratio: 0.33897858567611305
# pathways: 451, total modules: 595, enrichment_ratio: 0.7579831932773109
# correctly_assigned_genes: 10719, total genes: 26571, correctly_assigned_ratio: 0.40340973241503897

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knd_reciprocal/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 86, total modules: 177, enrichment_ratio: 0.4858757062146893
# correctly_assigned_genes: 8667, total genes: 26571, correctly_assigned_ratio: 0.3261826803658123
# pathways: 88, total modules: 157, enrichment_ratio: 0.5605095541401274
# correctly_assigned_genes: 12985, total genes: 26571, correctly_assigned_ratio: 0.4886906778066313
# pathways: 342, total modules: 585, enrichment_ratio: 0.5846153846153846
# correctly_assigned_genes: 13523, total genes: 26571, correctly_assigned_ratio: 0.5089383162094012

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 93, total modules: 177, enrichment_ratio: 0.5254237288135594
# correctly_assigned_genes: 11697, total genes: 26571, correctly_assigned_ratio: 0.44021677768996276
# pathways: 109, total modules: 157, enrichment_ratio: 0.6942675159235668
# correctly_assigned_genes: 18135, total genes: 26571, correctly_assigned_ratio: 0.6825110082420685
# pathways: 400, total modules: 585, enrichment_ratio: 0.6837606837606838
# correctly_assigned_genes: 17125, total genes: 26571, correctly_assigned_ratio: 0.6444996424673516

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 131, total modules: 177, enrichment_ratio: 0.7401129943502824
# correctly_assigned_genes: 7503, total genes: 26571, correctly_assigned_ratio: 0.2823755221858417
# pathways: 126, total modules: 157, enrichment_ratio: 0.802547770700637
# correctly_assigned_genes: 9525, total genes: 26571, correctly_assigned_ratio: 0.35847352376651237
# pathways: 534, total modules: 585, enrichment_ratio: 0.9128205128205128
# correctly_assigned_genes: 9935, total genes: 26571, correctly_assigned_ratio: 0.3739038801701103

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 108, total modules: 177, enrichment_ratio: 0.6101694915254238
# correctly_assigned_genes: 10358, total genes: 26571, correctly_assigned_ratio: 0.3898234917767491
# pathways: 108, total modules: 157, enrichment_ratio: 0.6878980891719745
# correctly_assigned_genes: 9623, total genes: 26571, correctly_assigned_ratio: 0.36216175529712846
# pathways: 457, total modules: 585, enrichment_ratio: 0.7811965811965812
# correctly_assigned_genes: 15428, total genes: 26571, correctly_assigned_ratio: 0.5806330209627037

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/pcc/knn/Cell/module_severe_10.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 40, total modules: 146, enrichment_ratio: 0.273972602739726
# correctly_assigned_genes: 7553, total genes: 26571, correctly_assigned_ratio: 0.2842572729667683
# pathways: 49, total modules: 147, enrichment_ratio: 0.3333333333333333
# correctly_assigned_genes: 9243, total genes: 26571, correctly_assigned_ratio: 0.3478604493620865
# pathways: 49, total modules: 142, enrichment_ratio: 0.34507042253521125
# correctly_assigned_genes: 10351, total genes: 26571, correctly_assigned_ratio: 0.3895600466674194

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 45, total modules: 146, enrichment_ratio: 0.3082191780821918
# correctly_assigned_genes: 8235, total genes: 26571, correctly_assigned_ratio: 0.30992435361860676
# pathways: 61, total modules: 147, enrichment_ratio: 0.41496598639455784
# correctly_assigned_genes: 11333, total genes: 26571, correctly_assigned_ratio: 0.4265176320048173
# pathways: 58, total modules: 142, enrichment_ratio: 0.4084507042253521
# correctly_assigned_genes: 11978, total genes: 26571, correctly_assigned_ratio: 0.4507922170787701

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 43, total modules: 146, enrichment_ratio: 0.2945205479452055
# correctly_assigned_genes: 7685, total genes: 26571, correctly_assigned_ratio: 0.2892250950284144
# pathways: 53, total modules: 147, enrichment_ratio: 0.36054421768707484
# correctly_assigned_genes: 9314, total genes: 26571, correctly_assigned_ratio: 0.3505325354710022
# pathways: 49, total modules: 142, enrichment_ratio: 0.34507042253521125
# correctly_assigned_genes: 9278, total genes: 26571, correctly_assigned_ratio: 0.3491776749087351

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 48, total modules: 146, enrichment_ratio: 0.3287671232876712
# correctly_assigned_genes: 8671, total genes: 26571, correctly_assigned_ratio: 0.3263332204282865
# pathways: 51, total modules: 147, enrichment_ratio: 0.3469387755102041
# correctly_assigned_genes: 9288, total genes: 26571, correctly_assigned_ratio: 0.3495540250649204
# pathways: 53, total modules: 142, enrichment_ratio: 0.3732394366197183
# correctly_assigned_genes: 10089, total genes: 26571, correctly_assigned_ratio: 0.37969967257536413

# %% [markdown]
# Binary-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_binary/Cell/module_severe_0.7.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 41, total modules: 101, enrichment_ratio: 0.40594059405940597
# correctly_assigned_genes: 11284, total genes: 26571, correctly_assigned_ratio: 0.4246735162395092
# pathways: 39, total modules: 108, enrichment_ratio: 0.3611111111111111
# correctly_assigned_genes: 9778, total genes: 26571, correctly_assigned_ratio: 0.3679951827180008
# pathways: 40, total modules: 75, enrichment_ratio: 0.5333333333333333
# correctly_assigned_genes: 4272, total genes: 26571, correctly_assigned_ratio: 0.16077678672236648

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 51, total modules: 101, enrichment_ratio: 0.504950495049505
# correctly_assigned_genes: 15658, total genes: 26571, correctly_assigned_ratio: 0.5892890745549659
# pathways: 48, total modules: 108, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 14543, total genes: 26571, correctly_assigned_ratio: 0.5473260321403033
# pathways: 48, total modules: 75, enrichment_ratio: 0.64
# correctly_assigned_genes: 6485, total genes: 26571, correctly_assigned_ratio: 0.24406307628617666

# %%
o_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 61, total modules: 101, enrichment_ratio: 0.6039603960396039
# correctly_assigned_genes: 9607, total genes: 26571, correctly_assigned_ratio: 0.36155959504723195
# pathways: 74, total modules: 108, enrichment_ratio: 0.6851851851851852
# correctly_assigned_genes: 8042, total genes: 26571, correctly_assigned_ratio: 0.30266079560423015
# pathways: 58, total modules: 75, enrichment_ratio: 0.7733333333333333
# correctly_assigned_genes: 2837, total genes: 26571, correctly_assigned_ratio: 0.10677053930977382

# %%
o_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 52, total modules: 101, enrichment_ratio: 0.5148514851485149
# correctly_assigned_genes: 9534, total genes: 26571, correctly_assigned_ratio: 0.35881223890707914
# pathways: 55, total modules: 108, enrichment_ratio: 0.5092592592592593
# correctly_assigned_genes: 10271, total genes: 26571, correctly_assigned_ratio: 0.38654924541793684
# pathways: 51, total modules: 75, enrichment_ratio: 0.68
# correctly_assigned_genes: 4525, total genes: 26571, correctly_assigned_ratio: 0.17029844567385496

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_ctrl_0.3.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_mild_0.3.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_linear/Cell/module_severe_0.3.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 39, total modules: 93, enrichment_ratio: 0.41935483870967744
# correctly_assigned_genes: 12820, total genes: 26571, correctly_assigned_ratio: 0.4824809002295736
# 2025-04-23 10:29:15,134 [ERROR] Error fetching enrichment results: KEGG_2021_Human
# pathways: 25, total modules: 64, enrichment_ratio: 0.390625
# correctly_assigned_genes: 15565, total genes: 26571, correctly_assigned_ratio: 0.5857890181024425
# pathways: 5, total modules: 9, enrichment_ratio: 0.5555555555555556
# correctly_assigned_genes: 4830, total genes: 26571, correctly_assigned_ratio: 0.18177712543750707

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 39, total modules: 93, enrichment_ratio: 0.41935483870967744
# correctly_assigned_genes: 16952, total genes: 26571, correctly_assigned_ratio: 0.6379887847653457
# pathways: 28, total modules: 64, enrichment_ratio: 0.4375
# correctly_assigned_genes: 15853, total genes: 26571, correctly_assigned_ratio: 0.5966279026005796
# pathways: 6, total modules: 9, enrichment_ratio: 0.6666666666666666
# correctly_assigned_genes: 5087, total genes: 26571, correctly_assigned_ratio: 0.19144932445146964

# %%
ratio_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 51, total modules: 93, enrichment_ratio: 0.5483870967741935
# correctly_assigned_genes: 8760, total genes: 26571, correctly_assigned_ratio: 0.32968273681833576
# pathways: 39, total modules: 64, enrichment_ratio: 0.609375
# correctly_assigned_genes: 7623, total genes: 26571, correctly_assigned_ratio: 0.28689172406006547
# pathways: 4, total modules: 9, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 2344, total genes: 26571, correctly_assigned_ratio: 0.0882164766098378

# %%
ratio_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 50, total modules: 93, enrichment_ratio: 0.5376344086021505
# correctly_assigned_genes: 10069, total genes: 26571, correctly_assigned_ratio: 0.3789469722629935
# pathways: 29, total modules: 64, enrichment_ratio: 0.453125
# correctly_assigned_genes: 8067, total genes: 26571, correctly_assigned_ratio: 0.3036016709946935
# pathways: 4, total modules: 9, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 2593, total genes: 26571, correctly_assigned_ratio: 0.09758759549885213

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_ctrl_0.3.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_mild_0.3.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_nlog/Cell/module_severe_0.3.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 50, total modules: 119, enrichment_ratio: 0.42016806722689076
# correctly_assigned_genes: 11017, total genes: 26571, correctly_assigned_ratio: 0.41462496706936136
# pathways: 32, total modules: 88, enrichment_ratio: 0.36363636363636365
# correctly_assigned_genes: 9856, total genes: 26571, correctly_assigned_ratio: 0.37093071393624627
# pathways: 9, total modules: 17, enrichment_ratio: 0.5294117647058824
# correctly_assigned_genes: 4705, total genes: 26571, correctly_assigned_ratio: 0.1770727484851906

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 59, total modules: 119, enrichment_ratio: 0.4957983193277311
# correctly_assigned_genes: 15423, total genes: 26571, correctly_assigned_ratio: 0.5804448458846111
# pathways: 42, total modules: 88, enrichment_ratio: 0.4772727272727273
# correctly_assigned_genes: 15232, total genes: 26571, correctly_assigned_ratio: 0.5732565579014716
# pathways: 13, total modules: 17, enrichment_ratio: 0.7647058823529411
# correctly_assigned_genes: 5233, total genes: 26571, correctly_assigned_ratio: 0.19694403673177524

# %%
atio_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 74, total modules: 119, enrichment_ratio: 0.6218487394957983
# correctly_assigned_genes: 8372, total genes: 26571, correctly_assigned_ratio: 0.31508035075834556
# pathways: 59, total modules: 88, enrichment_ratio: 0.6704545454545454
# correctly_assigned_genes: 8231, total genes: 26571, correctly_assigned_ratio: 0.30977381355613265
# pathways: 10, total modules: 17, enrichment_ratio: 0.5882352941176471
# correctly_assigned_genes: 2639, total genes: 26571, correctly_assigned_ratio: 0.09931880621730459

# %%
atio_4S, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 55, total modules: 119, enrichment_ratio: 0.46218487394957986
# correctly_assigned_genes: 10015, total genes: 26571, correctly_assigned_ratio: 0.3769146814195928
# pathways: 50, total modules: 88, enrichment_ratio: 0.5681818181818182
# correctly_assigned_genes: 10890, total genes: 26571, correctly_assigned_ratio: 0.4098453200858078
# pathways: 13, total modules: 17, enrichment_ratio: 0.7647058823529411
# correctly_assigned_genes: 4884, total genes: 26571, correctly_assigned_ratio: 0.18380941628090774

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knd_reciprocal/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 22, total modules: 57, enrichment_ratio: 0.38596491228070173
# correctly_assigned_genes: 12600, total genes: 26571, correctly_assigned_ratio: 0.47420119679349665
# pathways: 21, total modules: 45, enrichment_ratio: 0.4666666666666667
# correctly_assigned_genes: 16149, total genes: 26571, correctly_assigned_ratio: 0.6077678672236649
# pathways: 5, total modules: 9, enrichment_ratio: 0.5555555555555556
# correctly_assigned_genes: 4846, total genes: 26571, correctly_assigned_ratio: 0.18237928568740355

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 22, total modules: 57, enrichment_ratio: 0.38596491228070173
# correctly_assigned_genes: 16111, total genes: 26571, correctly_assigned_ratio: 0.6063377366301607
# pathways: 20, total modules: 45, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 16691, total genes: 26571, correctly_assigned_ratio: 0.628166045688909
# pathways: 6, total modules: 9, enrichment_ratio: 0.6666666666666666
# correctly_assigned_genes: 4873, total genes: 26571, correctly_assigned_ratio: 0.18339543110910392

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 30, total modules: 57, enrichment_ratio: 0.5263157894736842
# correctly_assigned_genes: 8351, total genes: 26571, correctly_assigned_ratio: 0.3142900154303564
# pathways: 25, total modules: 45, enrichment_ratio: 0.5555555555555556
# correctly_assigned_genes: 7607, total genes: 26571, correctly_assigned_ratio: 0.28628956381016896
# pathways: 4, total modules: 9, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 2503, total genes: 26571, correctly_assigned_ratio: 0.0942004440931843

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 28, total modules: 57, enrichment_ratio: 0.49122807017543857
# correctly_assigned_genes: 12003, total genes: 26571, correctly_assigned_ratio: 0.4517330924692334
# pathways: 20, total modules: 45, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 8741, total genes: 26571, correctly_assigned_ratio: 0.3289676715215837
# pathways: 5, total modules: 9, enrichment_ratio: 0.5555555555555556
# correctly_assigned_genes: 2624, total genes: 26571, correctly_assigned_ratio: 0.0987542809830266

# %%
module_ctrl = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/binary/knn/Cell/module_severe_10.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 43, total modules: 135, enrichment_ratio: 0.31851851851851853
# correctly_assigned_genes: 7031, total genes: 26571, correctly_assigned_ratio: 0.26461179481389485
# pathways: 53, total modules: 131, enrichment_ratio: 0.40458015267175573
# correctly_assigned_genes: 8560, total genes: 26571, correctly_assigned_ratio: 0.32215573369462946
# pathways: 42, total modules: 127, enrichment_ratio: 0.33070866141732286
# correctly_assigned_genes: 2735, total genes: 26571, correctly_assigned_ratio: 0.10293176771668361

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 47, total modules: 135, enrichment_ratio: 0.34814814814814815
# correctly_assigned_genes: 7332, total genes: 26571, correctly_assigned_ratio: 0.2759399345150728
# pathways: 58, total modules: 131, enrichment_ratio: 0.44274809160305345
# correctly_assigned_genes: 9332, total genes: 26571, correctly_assigned_ratio: 0.3512099657521358
# pathways: 44, total modules: 127, enrichment_ratio: 0.3464566929133858
# correctly_assigned_genes: 2856, total genes: 26571, correctly_assigned_ratio: 0.10748560460652591

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 35, total modules: 135, enrichment_ratio: 0.25925925925925924
# correctly_assigned_genes: 5755, total genes: 26571, correctly_assigned_ratio: 0.21658951488464867
# pathways: 44, total modules: 131, enrichment_ratio: 0.33587786259541985
# correctly_assigned_genes: 6435, total genes: 26571, correctly_assigned_ratio: 0.2421813255052501
# pathways: 66, total modules: 127, enrichment_ratio: 0.5196850393700787
# correctly_assigned_genes: 3754, total genes: 26571, correctly_assigned_ratio: 0.1412818486319672

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="binary_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="binary_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 43, total modules: 135, enrichment_ratio: 0.31851851851851853
# correctly_assigned_genes: 6366, total genes: 26571, correctly_assigned_ratio: 0.23958450942757142
# pathways: 44, total modules: 131, enrichment_ratio: 0.33587786259541985
# correctly_assigned_genes: 7161, total genes: 26571, correctly_assigned_ratio: 0.26950434684430397
# pathways: 45, total modules: 127, enrichment_ratio: 0.3543307086614173
# correctly_assigned_genes: 2823, total genes: 26571, correctly_assigned_ratio: 0.10624364909111438

# %% [markdown]
# Linear-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_binary/Cell/module_severe_0.7.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 34, total modules: 87, enrichment_ratio: 0.39080459770114945
# correctly_assigned_genes: 12341, total genes: 26571, correctly_assigned_ratio: 0.464453727748297
# pathways: 40, total modules: 96, enrichment_ratio: 0.4166666666666667
# correctly_assigned_genes: 10797, total genes: 26571, correctly_assigned_ratio: 0.4063452636332844
# pathways: 34, total modules: 60, enrichment_ratio: 0.5666666666666667
# correctly_assigned_genes: 4259, total genes: 26571, correctly_assigned_ratio: 0.1602875315193256

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 41, total modules: 87, enrichment_ratio: 0.47126436781609193
# correctly_assigned_genes: 15470, total genes: 26571, correctly_assigned_ratio: 0.582213691618682
# pathways: 52, total modules: 96, enrichment_ratio: 0.5416666666666666
# correctly_assigned_genes: 15516, total genes: 26571, correctly_assigned_ratio: 0.5839449023371345
# pathways: 39, total modules: 60, enrichment_ratio: 0.65
# correctly_assigned_genes: 6462, total genes: 26571, correctly_assigned_ratio: 0.24319747092695043

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 52, total modules: 87, enrichment_ratio: 0.5977011494252874
# correctly_assigned_genes: 9613, total genes: 26571, correctly_assigned_ratio: 0.36178540514094315
# pathways: 61, total modules: 96, enrichment_ratio: 0.6354166666666666
# correctly_assigned_genes: 7283, total genes: 26571, correctly_assigned_ratio: 0.2740958187497648
# pathways: 46, total modules: 60, enrichment_ratio: 0.7666666666666667
# correctly_assigned_genes: 2719, total genes: 26571, correctly_assigned_ratio: 0.1023296074667871

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 48, total modules: 87, enrichment_ratio: 0.5517241379310345
# correctly_assigned_genes: 11745, total genes: 26571, correctly_assigned_ratio: 0.44202325843965223
# pathways: 50, total modules: 96, enrichment_ratio: 0.5208333333333334
# correctly_assigned_genes: 8067, total genes: 26571, correctly_assigned_ratio: 0.3036016709946935
# pathways: 39, total modules: 60, enrichment_ratio: 0.65
# correctly_assigned_genes: 4302, total genes: 26571, correctly_assigned_ratio: 0.16190583719092244

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_linear/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 28, total modules: 72, enrichment_ratio: 0.3888888888888889
# correctly_assigned_genes: 13580, total genes: 26571, correctly_assigned_ratio: 0.5110835120996575
# pathways: 27, total modules: 61, enrichment_ratio: 0.4426229508196721
# correctly_assigned_genes: 15639, total genes: 26571, correctly_assigned_ratio: 0.5885740092582138
# pathways: 8, total modules: 13, enrichment_ratio: 0.6153846153846154
# correctly_assigned_genes: 4824, total genes: 26571, correctly_assigned_ratio: 0.18155131534379587

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 34, total modules: 72, enrichment_ratio: 0.4722222222222222
# correctly_assigned_genes: 16722, total genes: 26571, correctly_assigned_ratio: 0.6293327311730834
# pathways: 26, total modules: 61, enrichment_ratio: 0.4262295081967213
# correctly_assigned_genes: 15856, total genes: 26571, correctly_assigned_ratio: 0.5967408076474352
# pathways: 9, total modules: 13, enrichment_ratio: 0.6923076923076923
# correctly_assigned_genes: 5162, total genes: 26571, correctly_assigned_ratio: 0.1942719506228595

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 37, total modules: 72, enrichment_ratio: 0.5138888888888888
# correctly_assigned_genes: 9147, total genes: 26571, correctly_assigned_ratio: 0.3442474878627075
# pathways: 39, total modules: 61, enrichment_ratio: 0.639344262295082
# correctly_assigned_genes: 7586, total genes: 26571, correctly_assigned_ratio: 0.28549922848217985
# pathways: 9, total modules: 13, enrichment_ratio: 0.6923076923076923
# correctly_assigned_genes: 2648, total genes: 26571, correctly_assigned_ratio: 0.09965752135787137

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 34, total modules: 72, enrichment_ratio: 0.4722222222222222
# correctly_assigned_genes: 11216, total genes: 26571, correctly_assigned_ratio: 0.4221143351774491
# pathways: 33, total modules: 61, enrichment_ratio: 0.5409836065573771
# correctly_assigned_genes: 8743, total genes: 26571, correctly_assigned_ratio: 0.32904294155282077
# pathways: 8, total modules: 13, enrichment_ratio: 0.6153846153846154
# correctly_assigned_genes: 2606, total genes: 26571, correctly_assigned_ratio: 0.09807685070189304

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_nlog/Cell/module_severe_0.4.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 22, total modules: 60, enrichment_ratio: 0.36666666666666664
# correctly_assigned_genes: 14112, total genes: 26571, correctly_assigned_ratio: 0.5311053404087163
# pathways: 19, total modules: 51, enrichment_ratio: 0.37254901960784315
# correctly_assigned_genes: 16461, total genes: 26571, correctly_assigned_ratio: 0.6195099920966467
# pathways: 7, total modules: 10, enrichment_ratio: 0.7
# correctly_assigned_genes: 5100, total genes: 26571, correctly_assigned_ratio: 0.19193857965451055

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 27, total modules: 60, enrichment_ratio: 0.45
# correctly_assigned_genes: 17305, total genes: 26571, correctly_assigned_ratio: 0.6512739452786873
# pathways: 23, total modules: 51, enrichment_ratio: 0.45098039215686275
# correctly_assigned_genes: 17595, total genes: 26571, correctly_assigned_ratio: 0.6621880998080614
# pathways: 7, total modules: 10, enrichment_ratio: 0.7
# correctly_assigned_genes: 5100, total genes: 26571, correctly_assigned_ratio: 0.19193857965451055

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 35, total modules: 60, enrichment_ratio: 0.5833333333333334
# correctly_assigned_genes: 10056, total genes: 26571, correctly_assigned_ratio: 0.37845771705995257
# pathways: 31, total modules: 51, enrichment_ratio: 0.6078431372549019
# correctly_assigned_genes: 7613, total genes: 26571, correctly_assigned_ratio: 0.28651537390388016
# pathways: 6, total modules: 10, enrichment_ratio: 0.6
# correctly_assigned_genes: 2636, total genes: 26571, correctly_assigned_ratio: 0.09920590117044899

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 30, total modules: 60, enrichment_ratio: 0.5
# correctly_assigned_genes: 11718, total genes: 26571, correctly_assigned_ratio: 0.4410071130179519
# pathways: 27, total modules: 51, enrichment_ratio: 0.5294117647058824
# correctly_assigned_genes: 8820, total genes: 26571, correctly_assigned_ratio: 0.3319408377554477
# pathways: 5, total modules: 10, enrichment_ratio: 0.5
# correctly_assigned_genes: 2598, total genes: 26571, correctly_assigned_ratio: 0.0977757705769448

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_ctrl_0.5.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_mild_0.5.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knd_reciprocal/Cell/module_severe_0.5.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 21, total modules: 56, enrichment_ratio: 0.375
# correctly_assigned_genes: 13880, total genes: 26571, correctly_assigned_ratio: 0.522374016785217
# pathways: 17, total modules: 47, enrichment_ratio: 0.3617021276595745
# correctly_assigned_genes: 16492, total genes: 26571, correctly_assigned_ratio: 0.6206766775808212
# pathways: 5, total modules: 9, enrichment_ratio: 0.5555555555555556
# correctly_assigned_genes: 4831, total genes: 26571, correctly_assigned_ratio: 0.18181476045312558

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 23, total modules: 56, enrichment_ratio: 0.4107142857142857
# correctly_assigned_genes: 16896, total genes: 26571, correctly_assigned_ratio: 0.6358812238907079
# pathways: 22, total modules: 47, enrichment_ratio: 0.46808510638297873
# correctly_assigned_genes: 17727, total genes: 26571, correctly_assigned_ratio: 0.6671559218697076
# pathways: 7, total modules: 9, enrichment_ratio: 0.7777777777777778
# correctly_assigned_genes: 5075, total genes: 26571, correctly_assigned_ratio: 0.19099770426404727

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 29, total modules: 56, enrichment_ratio: 0.5178571428571429
# correctly_assigned_genes: 9634, total genes: 26571, correctly_assigned_ratio: 0.3625757404689323
# pathways: 26, total modules: 47, enrichment_ratio: 0.5531914893617021
# correctly_assigned_genes: 7321, total genes: 26571, correctly_assigned_ratio: 0.27552594934326896
# pathways: 4, total modules: 9, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 2460, total genes: 26571, correctly_assigned_ratio: 0.09258213842158744

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 26, total modules: 56, enrichment_ratio: 0.4642857142857143
# correctly_assigned_genes: 11955, total genes: 26571, correctly_assigned_ratio: 0.44992661171954385
# pathways: 30, total modules: 47, enrichment_ratio: 0.6382978723404256
# correctly_assigned_genes: 9416, total genes: 26571, correctly_assigned_ratio: 0.3543713070640924
# pathways: 4, total modules: 9, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 2596, total genes: 26571, correctly_assigned_ratio: 0.09770050054570772

# %%
module_ctrl = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/linear/knn/Cell/module_severe_10.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 39, total modules: 139, enrichment_ratio: 0.2805755395683453
# correctly_assigned_genes: 6180, total genes: 26571, correctly_assigned_ratio: 0.23258439652252455
# pathways: 40, total modules: 133, enrichment_ratio: 0.3007518796992481
# correctly_assigned_genes: 6388, total genes: 26571, correctly_assigned_ratio: 0.2404124797711791
# pathways: 45, total modules: 114, enrichment_ratio: 0.39473684210526316
# correctly_assigned_genes: 3320, total genes: 26571, correctly_assigned_ratio: 0.12494825185352453

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 54, total modules: 139, enrichment_ratio: 0.38848920863309355
# correctly_assigned_genes: 8311, total genes: 26571, correctly_assigned_ratio: 0.31278461480561515
# pathways: 60, total modules: 133, enrichment_ratio: 0.45112781954887216
# correctly_assigned_genes: 9234, total genes: 26571, correctly_assigned_ratio: 0.3475217342215197
# pathways: 43, total modules: 114, enrichment_ratio: 0.37719298245614036
# correctly_assigned_genes: 3258, total genes: 26571, correctly_assigned_ratio: 0.12261488088517557

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 42, total modules: 139, enrichment_ratio: 0.302158273381295
# correctly_assigned_genes: 6445, total genes: 26571, correctly_assigned_ratio: 0.2425576756614354
# pathways: 41, total modules: 133, enrichment_ratio: 0.3082706766917293
# correctly_assigned_genes: 6209, total genes: 26571, correctly_assigned_ratio: 0.23367581197546197
# pathways: 48, total modules: 114, enrichment_ratio: 0.42105263157894735
# correctly_assigned_genes: 3139, total genes: 26571, correctly_assigned_ratio: 0.11813631402657032

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="linear_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="linear_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 39, total modules: 139, enrichment_ratio: 0.2805755395683453
# correctly_assigned_genes: 6033, total genes: 26571, correctly_assigned_ratio: 0.22705204922660044
# pathways: 52, total modules: 133, enrichment_ratio: 0.39097744360902253
# correctly_assigned_genes: 8003, total genes: 26571, correctly_assigned_ratio: 0.30119302999510744
# pathways: 36, total modules: 114, enrichment_ratio: 0.3157894736842105
# correctly_assigned_genes: 2723, total genes: 26571, correctly_assigned_ratio: 0.10248014752926123

# %% [markdown]
# log

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_binary/Cell/module_severe_0.7.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 40, total modules: 82, enrichment_ratio: 0.4878048780487805
# correctly_assigned_genes: 14953, total genes: 26571, correctly_assigned_ratio: 0.5627563885439012
# pathways: 36, total modules: 99, enrichment_ratio: 0.36363636363636365
# correctly_assigned_genes: 14898, total genes: 26571, correctly_assigned_ratio: 0.560686462684882
# pathways: 24, total modules: 48, enrichment_ratio: 0.5
# correctly_assigned_genes: 3888, total genes: 26571, correctly_assigned_ratio: 0.1463249407248504

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 32, total modules: 82, enrichment_ratio: 0.3902439024390244
# correctly_assigned_genes: 15032, total genes: 26571, correctly_assigned_ratio: 0.5657295547777652
# pathways: 49, total modules: 99, enrichment_ratio: 0.494949494949495
# correctly_assigned_genes: 15326, total genes: 26571, correctly_assigned_ratio: 0.5767942493696135
# pathways: 29, total modules: 48, enrichment_ratio: 0.6041666666666666
# correctly_assigned_genes: 6737, total genes: 26571, correctly_assigned_ratio: 0.2535471002220466

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 48, total modules: 82, enrichment_ratio: 0.5853658536585366
# correctly_assigned_genes: 9741, total genes: 26571, correctly_assigned_ratio: 0.3666026871401152
# pathways: 67, total modules: 99, enrichment_ratio: 0.6767676767676768
# correctly_assigned_genes: 7846, total genes: 26571, correctly_assigned_ratio: 0.295284332542998
# pathways: 35, total modules: 48, enrichment_ratio: 0.7291666666666666
# correctly_assigned_genes: 2534, total genes: 26571, correctly_assigned_ratio: 0.09536712957735878

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 37, total modules: 82, enrichment_ratio: 0.45121951219512196
# correctly_assigned_genes: 10503, total genes: 26571, correctly_assigned_ratio: 0.39528056904143616
# pathways: 47, total modules: 99, enrichment_ratio: 0.47474747474747475
# correctly_assigned_genes: 7460, total genes: 26571, correctly_assigned_ratio: 0.28075721651424485
# pathways: 32, total modules: 48, enrichment_ratio: 0.6666666666666666
# correctly_assigned_genes: 2541, total genes: 26571, correctly_assigned_ratio: 0.0956305746866885

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_linear/Cell/module_severe_0.4.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 24, total modules: 52, enrichment_ratio: 0.46153846153846156
# correctly_assigned_genes: 16504, total genes: 26571, correctly_assigned_ratio: 0.6211282977682435
# pathways: 22, total modules: 69, enrichment_ratio: 0.3188405797101449
# correctly_assigned_genes: 15864, total genes: 26571, correctly_assigned_ratio: 0.5970418877723834
# pathways: 6, total modules: 15, enrichment_ratio: 0.4
# correctly_assigned_genes: 4581, total genes: 26571, correctly_assigned_ratio: 0.17240600654849272

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 25, total modules: 52, enrichment_ratio: 0.4807692307692308
# correctly_assigned_genes: 12855, total genes: 26571, correctly_assigned_ratio: 0.4837981257762222
# pathways: 35, total modules: 69, enrichment_ratio: 0.5072463768115942
# correctly_assigned_genes: 17753, total genes: 26571, correctly_assigned_ratio: 0.6681344322757894
# pathways: 8, total modules: 15, enrichment_ratio: 0.5333333333333333
# correctly_assigned_genes: 4676, total genes: 26571, correctly_assigned_ratio: 0.17598133303225322

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 29, total modules: 52, enrichment_ratio: 0.5576923076923077
# correctly_assigned_genes: 10224, total genes: 26571, correctly_assigned_ratio: 0.38478039968386585
# pathways: 47, total modules: 69, enrichment_ratio: 0.6811594202898551
# correctly_assigned_genes: 9121, total genes: 26571, correctly_assigned_ratio: 0.34326897745662566
# pathways: 11, total modules: 15, enrichment_ratio: 0.7333333333333333
# correctly_assigned_genes: 2682, total genes: 26571, correctly_assigned_ratio: 0.10093711188890143

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 27, total modules: 52, enrichment_ratio: 0.5192307692307693
# correctly_assigned_genes: 10396, total genes: 26571, correctly_assigned_ratio: 0.3912536223702533
# pathways: 34, total modules: 69, enrichment_ratio: 0.4927536231884058
# correctly_assigned_genes: 8783, total genes: 26571, correctly_assigned_ratio: 0.330548342177562
# pathways: 12, total modules: 15, enrichment_ratio: 0.8
# correctly_assigned_genes: 4765, total genes: 26571, correctly_assigned_ratio: 0.1793308494223025

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_nlog/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 23, total modules: 59, enrichment_ratio: 0.3898305084745763
# correctly_assigned_genes: 16227, total genes: 26571, correctly_assigned_ratio: 0.6107033984419104
# pathways: 27, total modules: 70, enrichment_ratio: 0.38571428571428573
# correctly_assigned_genes: 17146, total genes: 26571, correctly_assigned_ratio: 0.6452899777953408
# pathways: 7, total modules: 16, enrichment_ratio: 0.4375
# correctly_assigned_genes: 7602, total genes: 26571, correctly_assigned_ratio: 0.2861013887320763

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 26, total modules: 59, enrichment_ratio: 0.4406779661016949
# correctly_assigned_genes: 12121, total genes: 26571, correctly_assigned_ratio: 0.4561740243122201
# pathways: 34, total modules: 70, enrichment_ratio: 0.4857142857142857
# correctly_assigned_genes: 17093, total genes: 26571, correctly_assigned_ratio: 0.6432953219675586
# pathways: 8, total modules: 16, enrichment_ratio: 0.5
# correctly_assigned_genes: 4644, total genes: 26571, correctly_assigned_ratio: 0.1747770125324602

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 30, total modules: 59, enrichment_ratio: 0.5084745762711864
# correctly_assigned_genes: 9433, total genes: 26571, correctly_assigned_ratio: 0.3550111023296075
# pathways: 46, total modules: 70, enrichment_ratio: 0.6571428571428571
# correctly_assigned_genes: 8387, total genes: 26571, correctly_assigned_ratio: 0.31564487599262353
# pathways: 11, total modules: 16, enrichment_ratio: 0.6875
# correctly_assigned_genes: 2669, total genes: 26571, correctly_assigned_ratio: 0.10044785668586052

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 27, total modules: 59, enrichment_ratio: 0.4576271186440678
# correctly_assigned_genes: 10187, total genes: 26571, correctly_assigned_ratio: 0.3833879041059802
# pathways: 33, total modules: 70, enrichment_ratio: 0.4714285714285714
# correctly_assigned_genes: 8558, total genes: 26571, correctly_assigned_ratio: 0.32208046366339244
# pathways: 9, total modules: 16, enrichment_ratio: 0.5625
# correctly_assigned_genes: 4665, total genes: 26571, correctly_assigned_ratio: 0.17556734786044936

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_mild_0.7.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knd_reciprocal/Cell/module_severe_0.7.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 27, total modules: 69, enrichment_ratio: 0.391304347826087
# correctly_assigned_genes: 15633, total genes: 26571, correctly_assigned_ratio: 0.5883481991645026
# pathways: 27, total modules: 75, enrichment_ratio: 0.36
# correctly_assigned_genes: 11948, total genes: 26571, correctly_assigned_ratio: 0.44966316661021416
# pathways: 6, total modules: 14, enrichment_ratio: 0.42857142857142855
# correctly_assigned_genes: 4724, total genes: 26571, correctly_assigned_ratio: 0.17778781378194272

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 28, total modules: 69, enrichment_ratio: 0.4057971014492754
# correctly_assigned_genes: 11402, total genes: 26571, correctly_assigned_ratio: 0.42911444808249594
# pathways: 35, total modules: 75, enrichment_ratio: 0.4666666666666667
# correctly_assigned_genes: 16687, total genes: 26571, correctly_assigned_ratio: 0.6280155056264348
# pathways: 9, total modules: 14, enrichment_ratio: 0.6428571428571429
# correctly_assigned_genes: 4764, total genes: 26571, correctly_assigned_ratio: 0.17929321440668397

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 38, total modules: 69, enrichment_ratio: 0.5507246376811594
# correctly_assigned_genes: 9826, total genes: 26571, correctly_assigned_ratio: 0.36980166346769033
# pathways: 48, total modules: 75, enrichment_ratio: 0.64
# correctly_assigned_genes: 8353, total genes: 26571, correctly_assigned_ratio: 0.3143652854615935
# pathways: 10, total modules: 14, enrichment_ratio: 0.7142857142857143
# correctly_assigned_genes: 2668, total genes: 26571, correctly_assigned_ratio: 0.100410221670242

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 29, total modules: 69, enrichment_ratio: 0.42028985507246375
# correctly_assigned_genes: 8929, total genes: 26571, correctly_assigned_ratio: 0.3360430544578676
# pathways: 36, total modules: 75, enrichment_ratio: 0.48
# correctly_assigned_genes: 8698, total genes: 26571, correctly_assigned_ratio: 0.3273493658499868
# pathways: 10, total modules: 14, enrichment_ratio: 0.7142857142857143
# correctly_assigned_genes: 4772, total genes: 26571, correctly_assigned_ratio: 0.17959429453163223

# %%
module_ctrl = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/nlog/knn/Cell/module_severe_10.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 33, total modules: 138, enrichment_ratio: 0.2391304347826087
# correctly_assigned_genes: 5695, total genes: 26571, correctly_assigned_ratio: 0.2143314139475368
# pathways: 50, total modules: 144, enrichment_ratio: 0.3472222222222222
# correctly_assigned_genes: 6976, total genes: 26571, correctly_assigned_ratio: 0.26254186895487563
# pathways: 41, total modules: 117, enrichment_ratio: 0.3504273504273504
# correctly_assigned_genes: 2979, total genes: 26571, correctly_assigned_ratio: 0.11211471152760528

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 48, total modules: 138, enrichment_ratio: 0.34782608695652173
# correctly_assigned_genes: 8343, total genes: 26571, correctly_assigned_ratio: 0.31398893530540817
# pathways: 63, total modules: 144, enrichment_ratio: 0.4375
# correctly_assigned_genes: 9185, total genes: 26571, correctly_assigned_ratio: 0.34567761845621164
# pathways: 48, total modules: 117, enrichment_ratio: 0.41025641025641024
# correctly_assigned_genes: 3558, total genes: 26571, correctly_assigned_ratio: 0.133905385570735

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 40, total modules: 138, enrichment_ratio: 0.2898550724637681
# correctly_assigned_genes: 6666, total genes: 26571, correctly_assigned_ratio: 0.25087501411313085
# pathways: 44, total modules: 144, enrichment_ratio: 0.3055555555555556
# correctly_assigned_genes: 6187, total genes: 26571, correctly_assigned_ratio: 0.2328478416318543
# pathways: 49, total modules: 117, enrichment_ratio: 0.4188034188034188
# correctly_assigned_genes: 3166, total genes: 26571, correctly_assigned_ratio: 0.11915245944827067

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="nlog_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="nlog_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 33, total modules: 138, enrichment_ratio: 0.2391304347826087
# correctly_assigned_genes: 5369, total genes: 26571, correctly_assigned_ratio: 0.20206239885589553
# pathways: 48, total modules: 144, enrichment_ratio: 0.3333333333333333
# correctly_assigned_genes: 6366, total genes: 26571, correctly_assigned_ratio: 0.23958450942757142
# pathways: 41, total modules: 117, enrichment_ratio: 0.3504273504273504
# correctly_assigned_genes: 2786, total genes: 26571, correctly_assigned_ratio: 0.10485115351322871

# %% [markdown]
# Reciprocal-SWIM

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_ctrl_0.8.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_mild_0.8.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_binary/Cell/module_severe_0.8.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 44, total modules: 97, enrichment_ratio: 0.4536082474226804
# correctly_assigned_genes: 15492, total genes: 26571, correctly_assigned_ratio: 0.5830416619622897
# pathways: 59, total modules: 120, enrichment_ratio: 0.49166666666666664
# correctly_assigned_genes: 15616, total genes: 26571, correctly_assigned_ratio: 0.5877084038989876
# pathways: 26, total modules: 58, enrichment_ratio: 0.4482758620689655
# correctly_assigned_genes: 4075, total genes: 26571, correctly_assigned_ratio: 0.15336268864551578

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 46, total modules: 97, enrichment_ratio: 0.4742268041237113
# correctly_assigned_genes: 11174, total genes: 26571, correctly_assigned_ratio: 0.4205336645214708
# pathways: 61, total modules: 120, enrichment_ratio: 0.5083333333333333
# correctly_assigned_genes: 15957, total genes: 26571, correctly_assigned_ratio: 0.6005419442249068
# pathways: 31, total modules: 58, enrichment_ratio: 0.5344827586206896
# correctly_assigned_genes: 4161, total genes: 26571, correctly_assigned_ratio: 0.1565992999887095

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 57, total modules: 97, enrichment_ratio: 0.5876288659793815
# correctly_assigned_genes: 7111, total genes: 26571, correctly_assigned_ratio: 0.26762259606337735
# pathways: 88, total modules: 120, enrichment_ratio: 0.7333333333333333
# correctly_assigned_genes: 7677, total genes: 26571, correctly_assigned_ratio: 0.2889240149034662
# pathways: 38, total modules: 58, enrichment_ratio: 0.6551724137931034
# correctly_assigned_genes: 2714, total genes: 26571, correctly_assigned_ratio: 0.10214143238869444

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 51, total modules: 97, enrichment_ratio: 0.5257731958762887
# correctly_assigned_genes: 12054, total genes: 26571, correctly_assigned_ratio: 0.4536524782657785
# pathways: 65, total modules: 120, enrichment_ratio: 0.5416666666666666
# correctly_assigned_genes: 7302, total genes: 26571, correctly_assigned_ratio: 0.2748108840465169
# pathways: 38, total modules: 58, enrichment_ratio: 0.6551724137931034
# correctly_assigned_genes: 2665, total genes: 26571, correctly_assigned_ratio: 0.1002973166233864

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_ctrl_0.4.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_mild_0.4.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_linear/Cell/module_severe_0.4.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 49, total modules: 113, enrichment_ratio: 0.4336283185840708
# correctly_assigned_genes: 15509, total genes: 26571, correctly_assigned_ratio: 0.5836814572278047
# pathways: 48, total modules: 108, enrichment_ratio: 0.4444444444444444
# correctly_assigned_genes: 15236, total genes: 26571, correctly_assigned_ratio: 0.5734070979639456
# pathways: 20, total modules: 41, enrichment_ratio: 0.4878048780487805
# correctly_assigned_genes: 7406, total genes: 26571, correctly_assigned_ratio: 0.27872492567084417

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 54, total modules: 113, enrichment_ratio: 0.4778761061946903
# correctly_assigned_genes: 11963, total genes: 26571, correctly_assigned_ratio: 0.45022769184449213
# pathways: 61, total modules: 108, enrichment_ratio: 0.5648148148148148
# correctly_assigned_genes: 16200, total genes: 26571, correctly_assigned_ratio: 0.60968725302021
# pathways: 22, total modules: 41, enrichment_ratio: 0.5365853658536586
# correctly_assigned_genes: 4404, total genes: 26571, correctly_assigned_ratio: 0.16574460878401265

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 74, total modules: 113, enrichment_ratio: 0.6548672566371682
# correctly_assigned_genes: 10244, total genes: 26571, correctly_assigned_ratio: 0.3855330999962365
# pathways: 77, total modules: 108, enrichment_ratio: 0.7129629629629629
# correctly_assigned_genes: 7659, total genes: 26571, correctly_assigned_ratio: 0.2882465846223326
# pathways: 27, total modules: 41, enrichment_ratio: 0.6585365853658537
# correctly_assigned_genes: 2668, total genes: 26571, correctly_assigned_ratio: 0.100410221670242

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 61, total modules: 113, enrichment_ratio: 0.5398230088495575
# correctly_assigned_genes: 11290, total genes: 26571, correctly_assigned_ratio: 0.4248993263332204
# pathways: 64, total modules: 108, enrichment_ratio: 0.5925925925925926
# correctly_assigned_genes: 7580, total genes: 26571, correctly_assigned_ratio: 0.28527341838846865
# pathways: 25, total modules: 41, enrichment_ratio: 0.6097560975609756
# correctly_assigned_genes: 4434, total genes: 26571, correctly_assigned_ratio: 0.16687365925256858

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_nlog/Cell/module_severe_0.6.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 35, total modules: 85, enrichment_ratio: 0.4117647058823529
# correctly_assigned_genes: 16372, total genes: 26571, correctly_assigned_ratio: 0.6161604757065974
# pathways: 48, total modules: 103, enrichment_ratio: 0.46601941747572817
# correctly_assigned_genes: 14177, total genes: 26571, correctly_assigned_ratio: 0.5335516164239208
# pathways: 19, total modules: 40, enrichment_ratio: 0.475
# correctly_assigned_genes: 7419, total genes: 26571, correctly_assigned_ratio: 0.27921418087388505

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratios_I, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 36, total modules: 85, enrichment_ratio: 0.4235294117647059
# correctly_assigned_genes: 16611, total genes: 26571, correctly_assigned_ratio: 0.6251552444394265
# pathways: 62, total modules: 103, enrichment_ratio: 0.6019417475728155
# correctly_assigned_genes: 16845, total genes: 26571, correctly_assigned_ratio: 0.6339618380941628
# pathways: 20, total modules: 40, enrichment_ratio: 0.5
# correctly_assigned_genes: 4400, total genes: 26571, correctly_assigned_ratio: 0.1655940687215385

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 55, total modules: 85, enrichment_ratio: 0.6470588235294118
# correctly_assigned_genes: 8295, total genes: 26571, correctly_assigned_ratio: 0.31218245455571864
# pathways: 76, total modules: 103, enrichment_ratio: 0.7378640776699029
# correctly_assigned_genes: 7095, total genes: 26571, correctly_assigned_ratio: 0.26702043581348084
# pathways: 27, total modules: 40, enrichment_ratio: 0.675
# correctly_assigned_genes: 2679, total genes: 26571, correctly_assigned_ratio: 0.10082420684204584

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 44, total modules: 85, enrichment_ratio: 0.5176470588235295
# correctly_assigned_genes: 15088, total genes: 26571, correctly_assigned_ratio: 0.567837115652403
# pathways: 58, total modules: 103, enrichment_ratio: 0.5631067961165048
# correctly_assigned_genes: 9001, total genes: 26571, correctly_assigned_ratio: 0.33875277558240185
# pathways: 25, total modules: 40, enrichment_ratio: 0.625
# correctly_assigned_genes: 4453, total genes: 26571, correctly_assigned_ratio: 0.1675887245493207

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_ctrl_0.6.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_mild_0.6.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knd_reciprocal/Cell/module_severe_0.6.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 34, total modules: 86, enrichment_ratio: 0.3953488372093023
# correctly_assigned_genes: 16548, total genes: 26571, correctly_assigned_ratio: 0.6227842384554589
# pathways: 40, total modules: 93, enrichment_ratio: 0.43010752688172044
# correctly_assigned_genes: 15792, total genes: 26571, correctly_assigned_ratio: 0.5943321666478492
# pathways: 13, total modules: 34, enrichment_ratio: 0.38235294117647056
# correctly_assigned_genes: 7448, total genes: 26571, correctly_assigned_ratio: 0.28030559632682245

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 38, total modules: 86, enrichment_ratio: 0.4418604651162791
# correctly_assigned_genes: 16533, total genes: 26571, correctly_assigned_ratio: 0.622219713221181
# pathways: 55, total modules: 93, enrichment_ratio: 0.5913978494623656
# correctly_assigned_genes: 15941, total genes: 26571, correctly_assigned_ratio: 0.5999397839750104
# pathways: 20, total modules: 34, enrichment_ratio: 0.5882352941176471
# correctly_assigned_genes: 4568, total genes: 26571, correctly_assigned_ratio: 0.1719167513454518

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 56, total modules: 86, enrichment_ratio: 0.6511627906976745
# correctly_assigned_genes: 10832, total genes: 26571, correctly_assigned_ratio: 0.40766248917993303
# pathways: 68, total modules: 93, enrichment_ratio: 0.7311827956989247
# correctly_assigned_genes: 8594, total genes: 26571, correctly_assigned_ratio: 0.32343532422565957
# pathways: 22, total modules: 34, enrichment_ratio: 0.6470588235294118
# correctly_assigned_genes: 2651, total genes: 26571, correctly_assigned_ratio: 0.09977042640472696

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 46, total modules: 86, enrichment_ratio: 0.5348837209302325
# correctly_assigned_genes: 14705, total genes: 26571, correctly_assigned_ratio: 0.5534229046705055
# pathways: 51, total modules: 93, enrichment_ratio: 0.5483870967741935
# correctly_assigned_genes: 7741, total genes: 26571, correctly_assigned_ratio: 0.2913326559030522
# pathways: 18, total modules: 34, enrichment_ratio: 0.5294117647058824
# correctly_assigned_genes: 2633, total genes: 26571, correctly_assigned_ratio: 0.09909299612359339

# %%
module_ctrl = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_ctrl_10.json")
module_mild = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_mild_10.json")
module_severe = module_to_dict("../../parameter_tuning/reciprocal/knn/Cell/module_severe_10.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 34, total modules: 147, enrichment_ratio: 0.23129251700680273
# correctly_assigned_genes: 5738, total genes: 26571, correctly_assigned_ratio: 0.21594971961913365
# pathways: 45, total modules: 148, enrichment_ratio: 0.30405405405405406
# correctly_assigned_genes: 6723, total genes: 26571, correctly_assigned_ratio: 0.25302021000338715
# pathways: 40, total modules: 117, enrichment_ratio: 0.3418803418803419
# correctly_assigned_genes: 2987, total genes: 26571, correctly_assigned_ratio: 0.11241579165255354

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 51, total modules: 147, enrichment_ratio: 0.3469387755102041
# correctly_assigned_genes: 8257, total genes: 26571, correctly_assigned_ratio: 0.31075232396221447
# pathways: 53, total modules: 148, enrichment_ratio: 0.3581081081081081
# correctly_assigned_genes: 8134, total genes: 26571, correctly_assigned_ratio: 0.3061232170411351
# pathways: 47, total modules: 117, enrichment_ratio: 0.4017094017094017
# correctly_assigned_genes: 3354, total genes: 26571, correctly_assigned_ratio: 0.1262278423845546

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 37, total modules: 147, enrichment_ratio: 0.25170068027210885
# correctly_assigned_genes: 5656, total genes: 26571, correctly_assigned_ratio: 0.21286364833841406
# pathways: 44, total modules: 148, enrichment_ratio: 0.2972972972972973
# correctly_assigned_genes: 6638, total genes: 26571, correctly_assigned_ratio: 0.24982123367581197
# pathways: 48, total modules: 117, enrichment_ratio: 0.41025641025641024
# correctly_assigned_genes: 3300, total genes: 26571, correctly_assigned_ratio: 0.12419555154115389

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="reciprocal_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="reciprocal_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 35, total modules: 147, enrichment_ratio: 0.23809523809523808
# correctly_assigned_genes: 5743, total genes: 26571, correctly_assigned_ratio: 0.2161378946972263
# pathways: 43, total modules: 148, enrichment_ratio: 0.2905405405405405
# correctly_assigned_genes: 6223, total genes: 26571, correctly_assigned_ratio: 0.2342027021941214
# pathways: 40, total modules: 117, enrichment_ratio: 0.3418803418803419
# correctly_assigned_genes: 3001, total genes: 26571, correctly_assigned_ratio: 0.11294268187121298

# %% [markdown]
# pcc_leiden

# %%
module_ctrl = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_ctrl_0.35.json")
module_mild = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_mild_0.35.json")
module_severe = module_to_dict("../../parameter_tuning/pcc_leiden/Cell/module_severe_0.35.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_leiden_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_leiden_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 644, total modules: 1180, enrichment_ratio: 0.5457627118644067
# correctly_assigned_genes: 9942, total genes: 26571, correctly_assigned_ratio: 0.37416732527943997
# pathways: 269, total modules: 526, enrichment_ratio: 0.5114068441064639
# correctly_assigned_genes: 17415, total genes: 26571, correctly_assigned_ratio: 0.6554137969967258
# pathways: 670, total modules: 1215, enrichment_ratio: 0.551440329218107
# correctly_assigned_genes: 12738, total genes: 26571, correctly_assigned_ratio: 0.479394828948854

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_leiden_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_leiden_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 765, total modules: 1180, enrichment_ratio: 0.6483050847457628
# correctly_assigned_genes: 15186, total genes: 26571, correctly_assigned_ratio: 0.5715253471830191
# pathways: 319, total modules: 526, enrichment_ratio: 0.6064638783269962
# correctly_assigned_genes: 18713, total genes: 26571, correctly_assigned_ratio: 0.7042640472695796
# pathways: 794, total modules: 1215, enrichment_ratio: 0.6534979423868312
# correctly_assigned_genes: 16701, total genes: 26571, correctly_assigned_ratio: 0.6285423958450943

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_leiden_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_leiden_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 988, total modules: 1180, enrichment_ratio: 0.8372881355932204
# correctly_assigned_genes: 14368, total genes: 26571, correctly_assigned_ratio: 0.5407399044070603
# pathways: 447, total modules: 526, enrichment_ratio: 0.8498098859315589
# correctly_assigned_genes: 12814, total genes: 26571, correctly_assigned_ratio: 0.48225509013586243
# pathways: 985, total modules: 1215, enrichment_ratio: 0.8106995884773662
# correctly_assigned_genes: 12521, total genes: 26571, correctly_assigned_ratio: 0.4712280305596327

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="pcc_leiden_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="pcc_leiden_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
# Out:
# pathways: 836, total modules: 1180, enrichment_ratio: 0.7084745762711865
# correctly_assigned_genes: 11898, total genes: 26571, correctly_assigned_ratio: 0.44778141582928754
# pathways: 380, total modules: 526, enrichment_ratio: 0.7224334600760456
# correctly_assigned_genes: 12134, total genes: 26571, correctly_assigned_ratio: 0.456663279515261
# pathways: 870, total modules: 1215, enrichment_ratio: 0.7160493827160493
# correctly_assigned_genes: 10857, total genes: 26571, correctly_assigned_ratio: 0.4086033645703963

# %% [markdown]
# hdWGCNA

# %%
module_ctrl = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_ctrl_25.json")
module_mild = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_mild_25.json")
module_severe = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/module_severe_25.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="hdWGCNA_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="hdWGCNA_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="hdWGCNA_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="hdWGCNA_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %% [markdown]
# TOM_Leiden

# %%
module_ctrl = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_ctrl_0.1.json")
module_mild = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_mild_0.1.json")
module_severe = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_severe_0.1.json")
module_mildV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_mildV_0.1.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mildV, correctly_assigned_ratio_mildV = enrichment(modules=module_mildV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="TOM_Leiden_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mildV, correctly_assigned_ratio_mildV = enrichment(modules=module_mildV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="TOM_Leiden_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mildV, correctly_assigned_ratio_mildV = enrichment(modules=module_mildV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="TOM_Leiden_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mildV, correctly_assigned_ratio_mildV = enrichment(modules=module_mildV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="TOM_Leiden_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %% [markdown]
# Hotspot

# %%
module_ctrl = module_to_dict("../../parameter_tuning/hotspot/Cell/module_ctrl_50.json")
module_mild = module_to_dict("../../parameter_tuning/hotspot/Cell/module_mild_50.json")
module_severe = module_to_dict("../../parameter_tuning/hotspot/Cell/module_severe_50.json")

enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="Hotspot_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="Hotspot_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="Hotspot_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])

# %%
enrichment_ratio_ctrl, correctly_assigned_ratio_ctrl = enrichment(modules=module_ctrl, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_mild, correctly_assigned_ratio_mild = enrichment(modules=module_mild, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_severe, correctly_assigned_ratio_severe = enrichment(modules=module_severe, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_ctrl, enrichment_ratio_mild, enrichment_ratio_severe])
list_to_txt(path="Hotspot_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_ctrl, correctly_assigned_ratio_mild, correctly_assigned_ratio_severe])
