# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from algorithm_comparison import number_of_modules, number_of_modules_to_txt

# %% [markdown]
# METHOD2

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD2_leiden/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD2_leiden/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD2_leiden/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD2_leiden/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD2_leiden/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method2_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])

# %% [markdown]
# METHOD3

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD3_PCC_distance/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD3_PCC_distance/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD3_PCC_distance/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD3_PCC_distance/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD3_PCC_distance/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method3_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])

# %% [markdown]
# METHOD4

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD4_connection_distance/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD4_connection_distance/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD4_connection_distance/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD4_connection_distance/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD4_connection_distance/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method4_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])

# %% [markdown]
# METHOD5

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD5_PCC_linear_transformed_weighted_distance/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD5_PCC_linear_transformed_weighted_distance/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD5_PCC_linear_transformed_weighted_distance/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD5_PCC_linear_transformed_weighted_distance/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD5_PCC_linear_transformed_weighted_distance/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method5_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])

# %% [markdown]
# METHOD6

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD6_PCC_exponential_transformed_weighted_distance/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD6_PCC_exponential_transformed_weighted_distance/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD6_PCC_exponential_transformed_weighted_distance/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD6_PCC_exponential_transformed_weighted_distance/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD6_PCC_exponential_transformed_weighted_distance/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method6_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])

# %% [markdown]
# METHOD7

# %%
modules_4S = module_to_dict("/home/jovyan/work/METHOD7_PCC_graph/module_4S.json")
modules_I = module_to_dict("/home/jovyan/work/METHOD7_PCC_graph/module_I.json")
modules_III = module_to_dict("/home/jovyan/work/METHOD7_PCC_graph/module_III.json")
modules_IV = module_to_dict("/home/jovyan/work/METHOD7_PCC_graph/module_IV.json")
modules_NA = module_to_dict("/home/jovyan/work/METHOD7_PCC_graph/module_NA.json")
number_of_modules_4S = number_of_modules(modules_4S, min_module_size=10)
number_of_modules_I = number_of_modules(modules_I, min_module_size=10)
number_of_modules_III = number_of_modules(modules_III, min_module_size=10)
number_of_modules_IV = number_of_modules(modules_IV, min_module_size=10)
number_of_modules_NA = number_of_modules(modules_NA, min_module_size=10)
number_of_modules_to_txt(path="method7_number_of_modules.txt", number_of_modules_list=[number_of_modules_4S, number_of_modules_I, number_of_modules_III, number_of_modules_IV, number_of_modules_NA])
