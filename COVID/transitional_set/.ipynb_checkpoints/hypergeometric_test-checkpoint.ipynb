# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS')
from methods import module_to_dict
from transitional_set import module_relation_bipartite

# %%
# !pwd
# %cd /home/jovyan/work/COVID/transitional_set/Cell/Reciprocal_reciprocal
# !pwd
# Out:
# /home/jovyan/work/COVID/transitional_set
# /home/jovyan/work/COVID/transitional_set/Cell/Reciprocal_reciprocal
# /home/jovyan/work/COVID/transitional_set/Cell/Reciprocal_reciprocal

# %%
module_ctrl = module_to_dict("/home/jovyan/work/COVID/parameter_tuning/reciprocal/knd_reciprocal/Cell/module_ctrl_0.7.json")
module_mild = module_to_dict("/home/jovyan/work/COVID/parameter_tuning/reciprocal/knd_reciprocal/Cell/module_mild_0.7.json")
module_severe = module_to_dict("/home/jovyan/work/COVID/parameter_tuning/reciprocal/knd_reciprocal/Cell/module_severe_0.7.json")

# %%
print(len(module_ctrl))
print(len(module_mild))
print(len(module_severe))
# Out:
# 108
# 107
# 36

# %% [markdown]
# write function

# %%
module_relation_bipartite(q_value=0.001, first_module=module_ctrl, second_module=module_mild, first_module_stage="ctrl", second_module_stage="mild", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_ctrl, second_module=module_severe, first_module_stage="ctrl", second_module_stage="severe", save=True)

# %%
module_relation_bipartite(q_value=0.001, first_module=module_mild, second_module=module_severe, first_module_stage="mild", second_module_stage="severe", save=True)
