# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/hdWGCNA/Cell
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/hdWGCNA/Cell
# '/home/jovyan/work/COVID/parameter_tuning/hdWGCNA/Cell'

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import hdWGCNA_to_module, module_to_json

# %%
deepSplit_values = [0,5,1,15,2,25,3,35,4]
for deepSplit in deepSplit_values:
    module_ctrl = hdWGCNA_to_module(stage="ctrl", path=f"results/module_ctrl_{deepSplit}.csv")
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{deepSplit}.json")
# Out:
# 321
# 369
# 432
# 502
# 568
# 680
# 724
# 762
# 807

# %%
for deepSplit in deepSplit_values:
    module_mild = hdWGCNA_to_module(stage="mild", path=f"results/module_mild_{deepSplit}.csv")
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{deepSplit}.json")
# Out:
# 363
# 424
# 476
# 541
# 616
# 731
# 759
# 781
# 811

# %%
for deepSplit in deepSplit_values:
    module_severe = hdWGCNA_to_module(stage="severe", path=f"results/module_severe_{deepSplit}.csv")
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{deepSplit}.json")
# Out:
# 268
# 292
# 325
# 385
# 430
# 534
# 581
# 619
# 672
