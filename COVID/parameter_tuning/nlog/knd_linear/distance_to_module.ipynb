# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/nlog/Cell
# '/home/jovyan/work/COVID/parameter_tuning/nlog/Cell'

# %%
# import the distance data
distance_ctrl = pd.read_csv("distance_ctrl.csv", index_col=0)

# Set the name of the DataFrame
distance_ctrl.name = "distance_ctrl"

distance_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1    0.000000    3.778899    4.972045    3.924102    4.430515
# AL627309.4    3.778899    0.000000    4.865977    3.652759    3.100637
# AL732372.1    4.972045    4.865977    0.000000    4.524850    5.272541
# AL669831.2    3.924102    3.652759    4.524850    0.000000    4.201934
# AL669831.5    4.430515    3.100637    5.272541    4.201934    0.000000
# ...                ...         ...         ...         ...         ...
# AC023491.2    7.664906    7.457042    5.023237    6.171850    7.995776
# AC004556.1   13.628827   13.027796   11.402998   11.769381   13.412530
# AC233755.2    4.904769    4.541583    1.839327    4.369376    4.851666
# AC233755.1    5.490331    5.179744    2.573518    5.281402    5.657581
# AC240274.1    7.524041    5.803603    5.413452    6.881986    6.152076
#
#             LINC00115     FAM41C  AL645608.7  AL645608.3  AL645608.5  ...  \
# ...

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_linear, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/knd_linear/Cell/
# %pwd

# %% [markdown]
# Cell: resolution = 0.4

# %%
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 30%: 50~ modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 35%: 35~ modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 20~245 modules
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 45%: 15~205 modules

for resolution_parameter in resolution_values:
    module_ctrl = distance_to_module_linear(distance_coordinate=distance_ctrl, fig_path1=f"./figures/degree_distribution_ctrl_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_ctrl_{resolution_parameter}.png", threshold_percentile=45, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")

# %%
del distance_ctrl
del module_ctrl

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/Cell/
# %pwd

# import the distance data
distance_mild = pd.read_csv("distance_mild.csv", index_col=0)

# Set the name of the DataFrame
distance_mild.name = "distance_mild"

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/knd_linear/Cell/
# %pwd

# %%
for resolution_parameter in resolution_values:
    module_mild = distance_to_module_linear(distance_coordinate=distance_mild, fig_path1=f"./figures/degree_distribution_mild_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_mild_{resolution_parameter}.png", threshold_percentile=45, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")

# %%
del distance_mild
del module_mild

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/Cell/
# %pwd

# import the distance data
distance_severe = pd.read_csv("distance_severe.csv", index_col=0)

# Set the name of the DataFrame
distance_severe.name = "distance_severe"

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/nlog/knd_linear/Cell/
# %pwd

# %%
for resolution_parameter in resolution_values:
    module_severe = distance_to_module_linear(distance_coordinate=distance_severe, fig_path1=f"./figures/degree_distribution_severe_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_severe_{resolution_parameter}.png", threshold_percentile=45, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")

# %%
del distance_severe
del module_severe
