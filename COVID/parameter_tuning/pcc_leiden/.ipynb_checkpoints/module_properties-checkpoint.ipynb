# %% [markdown]
# look at the properties of modules

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from method1_7 import module_to_dict, module_info, get_distribution, module_size_distribution

# %% [markdown]
# resolution = 0.35

# %%
module_I = module_to_dict("module_I.json")
module_IV = module_to_dict("module_IV.json")
module_info(module=module_I)
module_info(module=module_IV)
module_size_distribution(module_dict=module_I)
module_size_distribution(module_dict=module_IV)
# Out:
# total modules = 1016, modules <= 3 = 952, modules >= 1000 = 1
# modules <= 3 ratio = 0.937007874015748, modules >= 1000 ratio = 0.000984251968503937, other modules ratio = 0.06200787401574803
# total genes = 12850, genes <= 3 = 1400, genes >= 1000 = 10611
# genes <= 3 ratio = 0.10894941634241245, genes >= 1000 ratio = 0.8257587548638132, other genes ratio = 0.06529182879377432
#
# total modules = 288, modules <= 3 = 273, modules >= 1000 = 1
# modules <= 3 ratio = 0.9479166666666666, modules >= 1000 ratio = 0.003472222222222222, other modules ratio = 0.04861111111111111
# total genes = 12850, genes <= 3 = 337, genes >= 1000 = 11976
# genes <= 3 ratio = 0.02622568093385214, genes >= 1000 ratio = 0.9319844357976653, other genes ratio = 0.04178988326848249
# weibull_min: KS Statistic = 0.6457, p-value = 0.0000, Params = (0.4661920714901876, 0.9999999999999999, 7.104421882689223)
# ...
