# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
# Out:
# /home/jovyan/work/COVID/results
# '/home/jovyan/work/COVID/results'

# %%
# import the PCC data
pcc_ctrl = pd.read_csv("pcc_control.csv", index_col=0)
pcc_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1    1.000000    0.355817    0.228245    0.445432    0.383732
# AL627309.4    0.355817    1.000000   -0.020470    0.560937    0.581096
# AL732372.1    0.228245   -0.020470    1.000000    0.074559    0.122271
# AL669831.2    0.445432    0.560937    0.074559    1.000000    0.342962
# AL669831.5    0.383732    0.581096    0.122271    0.342962    1.000000
# ...                ...         ...         ...         ...         ...
# AC023491.2   -0.049202   -0.091704    0.136197    0.151045    0.014234
# AC004556.1   -0.164801   -0.032674    0.064839   -0.056025    0.078203
# AC233755.2    0.182791    0.054308    0.529239    0.008447    0.192516
# AC233755.1    0.104667    0.144107    0.321262    0.011003    0.205644
# AC240274.1   -0.109492    0.010559   -0.244606    0.040818    0.267993
#
#               FAM87B  LINC00115    FAM41C  AL645608.7  AL645608.3  ...  \
# AL627309.1  0.251694   0.398397 -0.180755    0.211937    0.506467  ...
# AL627309.4  0.312776   0.630832 -0.019241    0.363555    0.714848  ...
# AL732372.1  0.018383   0.211597  0.053498    0.472034    0.054544  ...
# AL669831.2  0.114597   0.372664 -0.112743    0.512556    0.649911  ...
# AL669831.5  0.273196   0.748895  0.091072    0.314765    0.647219  ...
# ...              ...        ...       ...         ...         ...  ...
# AC023491.2 -0.069917   0.019486 -0.033949    0.158318    0.049841  ...
# AC004556.1 -0.128880  -0.011038  0.372018    0.270079   -0.002586  ...
# AC233755.2  0.080272   0.211016 -0.149634    0.215407    0.047768  ...
# AC233755.1  0.118125   0.207483 -0.106997    0.124246    0.076481  ...
# AC240274.1 -0.151401  -0.044060  0.404624    0.091268    0.102978  ...
#
#             AL592183.1  AC007325.1  AC007325.4  AC007325.2  AL354822.1  \
# AL627309.1   -0.219447    0.089707   -0.075948    0.367428    0.444251
# AL627309.4   -0.258779    0.110143   -0.136197   -0.158947    0.505242
# AL732372.1   -0.174837    0.118689    0.040996    0.618964    0.250344
# AL669831.2   -0.050993    0.207640    0.117096    0.047820    0.563173
# AL669831.5   -0.206828    0.171393   -0.163116   -0.092695    0.395888
# ...                ...         ...         ...         ...         ...
# AC023491.2   -0.021710    0.667373    0.029373    0.267866    0.015188
# AC004556.1   -0.198202   -0.091038   -0.335324   -0.101195   -0.354331
# AC233755.2   -0.226518    0.060870    0.063155    0.153132    0.390805
# AC233755.1   -0.163637    0.004468    0.016443    0.038674    0.253158
# AC240274.1    0.192119   -0.157074   -0.184677   -0.261587   -0.218895
#
#             AC023491.2  AC004556.1  AC233755.2  AC233755.1  AC240274.1
# AL627309.1   -0.049202   -0.164801    0.182791    0.104667   -0.109492
# AL627309.4   -0.091704   -0.032674    0.054308    0.144107    0.010559
# AL732372.1    0.136197    0.064839    0.529239    0.321262   -0.244606
# AL669831.2    0.151045   -0.056025    0.008447    0.011003    0.040818
# AL669831.5    0.014234    0.078203    0.192516    0.205644    0.267993
# ...                ...         ...         ...         ...         ...
# AC023491.2    1.000000    0.053339   -0.085043   -0.091648   -0.038598
# AC004556.1    0.053339    1.000000   -0.141557   -0.107665    0.348891
# AC233755.2   -0.085043   -0.141557    1.000000    0.672246   -0.300307
# AC233755.1   -0.091648   -0.107665    0.672246    1.000000   -0.207532
# AC240274.1   -0.038598    0.348891   -0.300307   -0.207532    1.000000
#
# [26571 rows x 26571 columns]

# %%
# Set the name of the DataFrame
pcc_ctrl.name = "pcc_ctrl"

# %% [markdown]
# construct a weighted graph of edges based on 1-abs(PCC-value)

# %% [markdown]
# delete rows and columns with Inf entries, since those genes are deleted from the module. (already ensured the genes won't contribute to potential modules candidates by assuring only 1 connected component is >= 3 in the previous graph)

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import Leiden_pcc_to_module, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/pcc_leiden/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/pcc_leiden/Cell
# '/home/jovyan/work/COVID/parameter_tuning/pcc_leiden/Cell'

# %% [markdown]
# Cell: resolution = 0.35
# PCC_thres = 0.5

# %%
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for pcc_threshold = 0.3: 20~330 modules

for resolution_parameter in resolution_values:
    module_ctrl = Leiden_pcc_to_module(pcc_matrix=pcc_ctrl, fig_path1=f"../figures/degree_distribution_ctrl_{resolution_parameter}.png", fig_path2=f"../figures/distance_distribution_ctrl_{resolution_parameter}.png", fig_path3=f"../figures/weight_distribution_ctrl_{resolution_parameter}.png", pcc_threshold=0.7, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
# Out:
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 872
# Number of modules: 576
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 1193
# Number of modules: 714
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 1475
# Number of modules: 832
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 1713
# Number of modules: 964
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 2130
# Number of modules: 1052
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 2356
# Number of modules: 1180
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# Number of clusters: 2625
# Number of modules: 1304
# IGRAPH UNW- 26571 20778982 --
# + attr: name (v), weight (e)
# Number of connected components: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for pcc_threshold = 0.3: 20~330 modules
#       3 for resolution_parameter in resolution_values:
# ----> 4     module_ctrl = Leiden_pcc_to_module(pcc_matrix=pcc_ctrl, fig_path1=f"../figures/degree_distribution_ctrl_{resolution_parameter}.png", fig_path2=f"../figures/distance_distribution_ctrl_{resolution_parameter}.png", fig_path3=f"../figures/weight_distribution_ctrl_{resolution_parameter}.png", pcc_threshold=0.5, resolution_parameter=resolution_parameter, seed=123456)
#       5     module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
#
# File ~/work/FUNCTIONS/methods.py:1926, in Leiden_pcc_to_module(pcc_matrix, fig_path1, fig_path2, fig_path3, pcc_threshold, resolution_parameter, min_module_size, seed)
#    1922 plt.show()
#    1924 # plot the shortest_distances' distribution
#    1925 # Get all pairs of nodes' distances
# -> 1926 distances = graph.distances()
#    1928 # Flatten the distances matrix
#    1929 all_distances = [
#    1930     distance for distances_row in distances for distance in distances_row if distance != float('inf')]
#
# KeyboardInterrupt:

# %%
del module_ctrl
del pcc_ctrl

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
pcc_mild = pd.read_csv("pcc_mild.csv", index_col=0)
pcc_mild.name = "pcc_mild"

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/pcc_leiden/Cell/
# %pwd
for resolution_parameter in resolution_values:
    module_mild = Leiden_pcc_to_module(pcc_matrix=pcc_mild, fig_path1=f"../figures/degree_distribution_mild_{resolution_parameter}.png", fig_path2=f"../figures/distance_distribution_mild_{resolution_parameter}.png", fig_path3=f"../figures/weight_distribution_mild_{resolution_parameter}.png", pcc_threshold=0.7, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")

# %%
del module_mild
del pcc_mild

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
pcc_severe = pd.read_csv("pcc_severe.csv", index_col=0)
pcc_severe.name = "pcc_severe"

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/pcc_leiden/Cell/
# %pwd
for resolution_parameter in resolution_values:
    module_severe = Leiden_pcc_to_module(pcc_matrix=pcc_severe, fig_path1=f"../figures/degree_distribution_severe_{resolution_parameter}.png", fig_path2=f"../figures/distance_distribution_severe_{resolution_parameter}.png", fig_path3=f"../figures/weight_distribution_severe_{resolution_parameter}.png", pcc_threshold=0.7, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")

# %%
del module_severe
del pcc_severe
