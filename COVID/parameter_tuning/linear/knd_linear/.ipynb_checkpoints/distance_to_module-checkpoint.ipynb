# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Linear_SWIM/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Linear_SWIM/Cell
# '/home/jovyan/work/parameter_tuning/Linear_SWIM/Cell'

# %%
# import the distance data
distance_4S = pd.read_csv("distance_4S.csv", index_col=0)
distance_I = pd.read_csv("distance_I.csv", index_col=0)
distance_III = pd.read_csv("distance_III.csv", index_col=0)
distance_IV = pd.read_csv("distance_IV.csv", index_col=0)
# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_4S
# Out:
#              TSPAN6      DPM1     SCYL3  C1orf112       FGR     FUCA2  \
# Symbol
# TSPAN6     0.000000  0.773897  0.703237  0.680294  0.641601  0.932403
# DPM1       0.773897  0.000000  0.766109  0.590894  0.824524  0.948819
# SCYL3      0.703237  0.766109  0.000000  0.729685  0.839800  0.855578
# C1orf112   0.680294  0.590894  0.729685  0.000000  0.784112  0.677189
# FGR        0.641601  0.824524  0.839800  0.784112  0.000000  0.949113
# ...             ...       ...       ...       ...       ...       ...
# LINC01481  0.670417  0.549146  0.799766  0.672784  0.875168  0.719538
# CYB561D2   0.677001  0.831691  0.862807  0.651520  0.760975  0.747418
# CCDC7      0.717391  0.800076  0.639342  0.627736  0.916372  0.538260
# MATR3      0.949935  0.800544  1.055671  0.938310  0.686201  0.985063
# RGS5       0.278521  0.604077  0.662947  0.482961  0.724755  0.826673
#
#                GCLC      NFYA     STPG1    NIPAL3  ...  LINC01176  \
# Symbol                                             ...
# TSPAN6     0.642840  0.871225  0.526939  0.545899  ...   0.738398
# DPM1       0.590362  0.753948  0.924640  0.816038  ...   0.725012
# SCYL3      0.920618  0.836668  0.764158  0.907570  ...   0.797875
# C1orf112   0.634887  0.702711  0.964767  0.812670  ...   0.425192
# FGR        0.880398  1.116074  0.631834  0.672725  ...   0.780782
# ...             ...       ...       ...       ...  ...        ...
# LINC01481  0.663468  0.846457  0.916438  0.795607  ...   0.546080
# CYB561D2   0.673582  0.841441  0.852502  0.691066  ...   0.575123
# CCDC7      0.664552  0.717312  0.901846  0.847528  ...   0.523721
# MATR3      0.928994  1.111983  0.799736  1.014488  ...   0.848503
# RGS5       0.540197  0.759855  0.720565  0.756931  ...   0.625633
#
#            SEPSECS-AS1    ADORA3     BISPR    PRNCR1  LINC01481  CYB561D2  \
# Symbol
# TSPAN6        1.021534  0.593825  0.744499  0.778509   0.670417  0.677001
# DPM1          1.145491  0.783683  0.891021  0.929501   0.549146  0.831691
# SCYL3         0.829310  0.952175  1.058118  0.832073   0.799766  0.862807
# C1orf112      1.159817  0.756361  0.932474  0.743247   0.672784  0.651520
# FGR           1.143568  0.356712  0.288029  0.741138   0.875168  0.760975
# ...                ...       ...       ...       ...        ...       ...
# LINC01481     1.093692  0.866292  0.923138  0.928838   0.000000  0.439779
# CYB561D2      1.224633  0.841054  0.900323  0.907297   0.439779  0.000000
# CCDC7         0.801145  0.982249  1.012634  0.907546   0.549174  0.548301
# MATR3         1.353973  0.776750  0.919423  1.214153   0.450581  0.730473
# RGS5          0.983924  0.643589  0.791872  0.776638   0.527497  0.665477
#
#               CCDC7     MATR3      RGS5
# Symbol
# TSPAN6     0.717391  0.949935  0.278521
# DPM1       0.800076  0.800544  0.604077
# SCYL3      0.639342  1.055671  0.662947
# C1orf112   0.627736  0.938310  0.482961
# FGR        0.916372  0.686201  0.724755
# ...             ...       ...       ...
# LINC01481  0.549174  0.450581  0.527497
# CYB561D2   0.548301  0.730473  0.665477
# CCDC7      0.000000  0.814700  0.706725
# MATR3      0.814700  0.000000  0.855623
# RGS5       0.706725  0.855623  0.000000
#
# [12390 rows x 12390 columns]

# %%
# Set the name of the DataFrame
distance_4S.name = "distance_4S"
distance_I.name = "distance_I"
distance_III.name = "distance_III"
distance_IV.name = "distance_IV"
# distance_NA.name = "distance_NA"

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_linear, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/parameter_tuning/Linear_SWIM/knd_linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/parameter_tuning/Linear_SWIM/knd_linear/Cell
# '/home/jovyan/work/parameter_tuning/Linear_SWIM/knd_linear/Cell'

# %% [markdown]
# Cell: resolution = 0.35

# %%
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 30%: 50~ modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 35%: 35~ modules
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 20~355 modules

for resolution_parameter in resolution_values:
    module_4S = distance_to_module_linear(distance_coordinate=distance_4S, fig_path1=f"./figures/degree_distribution_4S_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_4S_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_4S, file_path=f"module_4S_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 26
# Cluster assignments: [0, 0, 1, 0, 4, 2, 0, 2, 4, 4, 0, 2, 0, 0, 1, 0, 1, 2, 2, 1]
# Number of modules: 19
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 38
# Cluster assignments: [1, 5, 1, 0, 4, 2, 0, 2, 8, 4, 0, 2, 0, 0, 1, 0, 1, 5, 4, 2]
# Number of modules: 31
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 64
# Cluster assignments: [1, 3, 7, 0, 5, 2, 0, 2, 8, 5, 0, 2, 2, 2, 7, 0, 19, 3, 30, 7]
# Number of modules: 45
# IOStream.flush timed out
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 90
# Cluster assignments: [1, 3, 7, 0, 5, 2, 0, 6, 11, 11, 3, 6, 2, 2, 7, 0, 44, 12, 6, 7]
# Number of modules: 65
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 134
# Cluster assignments: [1, 2, 9, 2, 5, 10, 0, 13, 16, 16, 6, 8, 3, 3, 9, 3, 16, 12, 8, 9]
# Number of modules: 94
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# IOStream.flush timed out
# Number of clusters: 222
# Cluster assignments: [1, 2, 6, 8, 5, 12, 2, 10, 17, 17, 4, 16, 3, 3, 13, 3, 17, 22, 16, 24]
# Number of modules: 135
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# IOStream.flush timed out
# Number of clusters: 340
# Cluster assignments: [2, 9, 16, 7, 6, 19, 1, 19, 25, 25, 5, 338, 3, 3, 14, 3, 46, 24, 21, 17]
# Number of modules: 185
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 538
# Cluster assignments: [49, 9, 12, 7, 6, 37, 1, 70, 66, 31, 8, 70, 11, 2, 26, 7, 76, 44, 29, 33]
# Number of modules: 268
# threshold_percentile = 40%: threshold_distance = 24.764014687708436
# Number of connected components: 3
# Number of clusters: 882
# Cluster assignments: [22, 8, 60, 6, 5, 61, 9, 87, 54, 73, 9, 565, 11, 11, 42, 17, 99, 63, 45, 118]
# Number of modules: 356

# %%
for resolution_parameter in resolution_values:
    module_I = distance_to_module_linear(distance_coordinate=distance_I, fig_path1=f"./figures/degree_distribution_I_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_I_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_I, file_path=f"module_I_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 34
# Cluster assignments: [12, 2, 0, 0, 4, 0, 0, 0, 1, 2, 0, 1, 0, 0, 0, 0, 9, 0, 1, 6]
# Number of modules: 26
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 54
# Cluster assignments: [17, 2, 0, 2, 4, 1, 0, 0, 1, 2, 0, 1, 0, 0, 0, 3, 14, 2, 1, 7]
# Number of modules: 45
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 85
# Cluster assignments: [19, 7, 5, 1, 4, 2, 1, 0, 6, 6, 0, 5, 0, 0, 0, 5, 20, 1, 8, 10]
# Number of modules: 62
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 136
# Cluster assignments: [19, 3, 6, 3, 5, 2, 1, 0, 4, 32, 0, 6, 0, 0, 0, 6, 53, 3, 8, 14]
# IOStream.flush timed out
# Number of modules: 91
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 232
# Cluster assignments: [83, 13, 6, 3, 4, 2, 1, 1, 5, 18, 0, 6, 0, 0, 0, 6, 84, 27, 8, 16]
# Number of modules: 143
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 375
# Cluster assignments: [107, 20, 6, 3, 4, 2, 11, 11, 7, 14, 0, 10, 0, 0, 0, 6, 219, 14, 9, 16]
# Number of modules: 202
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 595
# Cluster assignments: [248, 78, 9, 3, 4, 2, 9, 9, 10, 35, 9, 11, 0, 0, 0, 19, 455, 13, 165, 17]
# Number of modules: 284
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 922
# Cluster assignments: [881, 63, 22, 3, 4, 7, 59, 9, 90, 49, 9, 13, 0, 0, 0, 22, 644, 54, 86, 20]
# Number of modules: 375
# threshold_percentile = 40%: threshold_distance = 23.760763517932496
# Number of connected components: 2
# Number of clusters: 1440
# Cluster assignments: [908, 75, 28, 3, 60, 146, 26, 26, 283, 67, 9, 86, 0, 0, 0, 28, 909, 45, 1111, 56]
# Number of modules: 478

# %%
for resolution_parameter in resolution_values:
    module_III = distance_to_module_linear(distance_coordinate=distance_III, fig_path1=f"./figures/degree_distribution_III_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_III_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_III, file_path=f"module_III_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 28
# Cluster assignments: [0, 3, 0, 1, 2, 1, 1, 1, 1, 1, 2, 0, 0, 0, 1, 3, 5, 2, 0, 0]
# Number of modules: 21
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 44
# Cluster assignments: [0, 7, 0, 5, 9, 1, 1, 3, 3, 3, 2, 0, 0, 0, 1, 4, 7, 2, 0, 0]
# Number of modules: 35
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 72
# Cluster assignments: [3, 9, 0, 5, 7, 6, 1, 3, 3, 3, 25, 0, 0, 1, 1, 4, 40, 2, 0, 0]
# Number of modules: 54
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 117
# Cluster assignments: [6, 12, 0, 4, 13, 7, 1, 6, 6, 6, 27, 0, 1, 1, 1, 2, 21, 5, 0, 0]
# Number of modules: 75
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 174
# Cluster assignments: [7, 42, 0, 3, 16, 8, 6, 7, 7, 7, 29, 1, 1, 1, 6, 4, 22, 5, 0, 0]
# Number of modules: 112
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 275
# Cluster assignments: [11, 63, 0, 9, 20, 18, 7, 10, 12, 10, 38, 2, 2, 1, 7, 3, 119, 4, 2, 0]
# Number of modules: 154
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 424
# Cluster assignments: [9, 86, 0, 11, 23, 204, 7, 12, 16, 12, 33, 2, 2, 1, 7, 18, 181, 5, 2, 0]
# Number of modules: 224
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# Number of clusters: 660
# Cluster assignments: [14, 366, 2, 10, 25, 34, 9, 21, 18, 14, 110, 2, 8, 1, 9, 27, 263, 5, 2, 0]
# Number of modules: 306
# threshold_percentile = 40%: threshold_distance = 23.05365369194659
# Number of connected components: 2
# IOStream.flush timed out
# Number of clusters: 1021
# Cluster assignments: [76, 683, 1, 11, 78, 170, 5, 36, 23, 17, 151, 1, 3, 2, 71, 42, 612, 34, 1, 0]
# Number of modules: 396

# %%
for resolution_parameter in resolution_values:
    module_IV = distance_to_module_linear(distance_coordinate=distance_IV, fig_path1=f"./figures/degree_distribution_IV_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_IV_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_IV, file_path=f"module_IV_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 28
# Cluster assignments: [1, 2, 0, 0, 5, 0, 0, 0, 4, 0, 0, 0, 0, 0, 0, 1, 0, 3, 0, 1]
# Number of modules: 22
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 42
# Cluster assignments: [1, 2, 0, 0, 5, 0, 0, 0, 7, 0, 0, 0, 0, 0, 3, 1, 0, 14, 0, 1]
# Number of modules: 29
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 55
# Cluster assignments: [1, 7, 0, 0, 6, 4, 0, 0, 8, 0, 0, 3, 0, 0, 4, 1, 0, 14, 12, 1]
# Number of modules: 43
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 87
# Cluster assignments: [9, 5, 0, 0, 7, 4, 0, 0, 15, 0, 0, 3, 2, 0, 4, 1, 0, 10, 9, 1]
# Number of modules: 63
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 128
# Cluster assignments: [2, 7, 0, 0, 8, 4, 0, 0, 12, 0, 0, 5, 3, 0, 4, 2, 0, 18, 29, 1]
# Number of modules: 91
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 191
# Cluster assignments: [69, 7, 0, 0, 71, 2, 0, 0, 47, 0, 0, 5, 1, 0, 2, 3, 0, 18, 16, 33]
# Number of modules: 122
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 290
# Cluster assignments: [76, 26, 0, 0, 75, 2, 1, 0, 70, 0, 6, 5, 1, 0, 14, 3, 0, 42, 6, 23]
# Number of modules: 173
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 450
# Cluster assignments: [148, 78, 0, 3, 101, 2, 1, 0, 114, 0, 1, 6, 6, 0, 15, 11, 0, 57, 7, 35]
# Number of modules: 256
# threshold_percentile = 40%: threshold_distance = 23.931557775333765
# Number of connected components: 2
# Number of clusters: 752
# Cluster assignments: [174, 200, 1, 2, 128, 17, 4, 1, 254, 0, 7, 16, 14, 0, 456, 12, 0, 61, 42, 29]
# Number of modules: 352
