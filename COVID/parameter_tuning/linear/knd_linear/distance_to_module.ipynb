# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/Cell'

# %%
# import the distance data
distance_ctrl = pd.read_csv("distance_ctrl.csv", index_col=0)

# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1    0.000000    0.657115    0.755880    0.655672    0.743854
# AL627309.4    0.657115    0.000000    0.908747    0.513504    0.489982
# AL732372.1    0.755880    0.908747    0.000000    0.872752    0.909304
# AL669831.2    0.655672    0.513504    0.872752    0.000000    0.692827
# AL669831.5    0.743854    0.489982    0.909304    0.692827    0.000000
# ...                ...         ...         ...         ...         ...
# AC023491.2    1.097004    1.155263    0.858126    1.100192    1.137698
# AC004556.1    1.588252    1.388156    1.381288    1.510132    1.434723
# AC233755.2    0.846691    0.821105    0.410235    0.870087    0.841570
# AC233755.1    0.970765    0.908607    0.485108    0.916722    0.995265
# AC240274.1    1.121568    0.928856    0.857833    1.099538    0.763911
#
#             LINC00115    FAM41C  AL645608.7  AL645608.3  AL645608.5  ...  \
# ...

# %%
# Set the name of the DataFrame
distance_ctrl.name = "distance_ctrl"

# distance_NA.name = "distance_NA"

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_linear, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell'

# %% [markdown]
# Cell: resolution = 0.35

# %%
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 30%: 50~ modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 35%: 35~ modules
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 20~355 modules

for resolution_parameter in resolution_values:
    module_ctrl = distance_to_module_linear(distance_coordinate=distance_ctrl, fig_path1=f"./figures/degree_distribution_ctrl_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_ctrl_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 42.57596298363782
# Number of connected components: 1
# Number of clusters: 16
# Cluster assignments: [0, 0, 1, 0, 0, 0, 2, 1, 0, 0, 1, 2, 0, 0, 1, 4, 0, 3, 0, 4]
# Number of modules: 13
# threshold_percentile = 40%: threshold_distance = 42.57596298363782
# Number of connected components: 1
# Number of clusters: 23
# Cluster assignments: [0, 0, 1, 0, 0, 0, 3, 1, 0, 0, 1, 3, 0, 0, 4, 4, 0, 6, 0, 4]
# Number of modules: 19
# threshold_percentile = 40%: threshold_distance = 42.57596298363782
# Number of connected components: 1
# Number of clusters: 30
# Cluster assignments: [0, 0, 1, 0, 0, 0, 3, 1, 0, 0, 1, 3, 0, 0, 4, 4, 2, 6, 0, 4]
# Number of modules: 25
# threshold_percentile = 40%: threshold_distance = 42.57596298363782
# Number of connected components: 1
# Number of clusters: 45
# Cluster assignments: [0, 0, 2, 0, 0, 0, 7, 1, 0, 0, 1, 4, 0, 0, 2, 6, 3, 9, 0, 6]
# Number of modules: 35
# ...

# %%
del distance_ctrl
del module_ctrl

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd

distance_mild = pd.read_csv("distance_mild.csv", index_col=0)
distance_mild.name = "distance_mild"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell'

# %%
for resolution_parameter in resolution_values:
    module_mild = distance_to_module_linear(distance_coordinate=distance_mild, fig_path1=f"./figures/degree_distribution_mild_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_mild_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 44.43633581134683
# Number of connected components: 1
# Number of clusters: 19
# Cluster assignments: [1, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0, 4, 3, 3, 1, 2, 1, 1, 1, 1]
# Number of modules: 14
# threshold_percentile = 40%: threshold_distance = 44.43633581134683
# Number of connected components: 1
# Number of clusters: 28
# Cluster assignments: [1, 0, 4, 0, 0, 2, 2, 0, 0, 0, 4, 4, 3, 3, 1, 4, 1, 1, 1, 1]
# Number of modules: 21
# threshold_percentile = 40%: threshold_distance = 44.43633581134683
# Number of connected components: 1
# Number of clusters: 37
# Cluster assignments: [7, 0, 4, 0, 0, 2, 2, 0, 0, 0, 4, 4, 3, 3, 1, 4, 3, 1, 3, 1]
# Number of modules: 30
# threshold_percentile = 40%: threshold_distance = 44.43633581134683
# Number of connected components: 1
# Number of clusters: 48
# Cluster assignments: [7, 2, 5, 0, 0, 2, 4, 0, 0, 0, 5, 5, 6, 16, 3, 8, 3, 1, 3, 1]
# Number of modules: 38
# ...

# %%
del distance_mild
del module_mild

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd

distance_severe = pd.read_csv("distance_severe.csv", index_col=0)
distance_severe.name = "distance_severe"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knd_linear/Cell'

# %%
for resolution_parameter in resolution_values:
    module_severe = distance_to_module_linear(distance_coordinate=distance_severe, fig_path1=f"./figures/degree_distribution_severe_{resolution_parameter}.svg", fig_path2=f"./figures/weight_distribution_severe_{resolution_parameter}.svg", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 69.01825499282928
# Number of connected components: 1
# Number of clusters: 8
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 7
# threshold_percentile = 40%: threshold_distance = 69.01825499282928
# Number of connected components: 1
# Number of clusters: 10
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 8
# threshold_percentile = 40%: threshold_distance = 69.01825499282928
# Number of connected components: 1
# Number of clusters: 11
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 9
# threshold_percentile = 40%: threshold_distance = 69.01825499282928
# Number of connected components: 1
# Number of clusters: 12
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 9
# ...

# %%
del distance_severe
del module_severe
