# %%
import scanpy as sc
import anndata as ad
import pandas as pd

# %%
sc.settings.verbosity = 3

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/Cell'

# %%
# import the distance data
distance_ctrl = pd.read_csv("distance_ctrl.csv", index_col=0)

# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
distance_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1    0.000000    0.657115    0.755880    0.655672    0.743854
# AL627309.4    0.657115    0.000000    0.908747    0.513504    0.489982
# AL732372.1    0.755880    0.908747    0.000000    0.872752    0.909304
# AL669831.2    0.655672    0.513504    0.872752    0.000000    0.692827
# AL669831.5    0.743854    0.489982    0.909304    0.692827    0.000000
# ...                ...         ...         ...         ...         ...
# AC023491.2    1.097004    1.155263    0.858126    1.100192    1.137698
# AC004556.1    1.588252    1.388156    1.381288    1.510132    1.434723
# AC233755.2    0.846691    0.821105    0.410235    0.870087    0.841570
# AC233755.1    0.970765    0.908607    0.485108    0.916722    0.995265
# AC240274.1    1.121568    0.928856    0.857833    1.099538    0.763911
#
#             LINC00115    FAM41C  AL645608.7  AL645608.3  AL645608.5  ...  \
# AL627309.1   0.688396  1.413018    0.822428    0.483287    0.451495  ...
# AL627309.4   0.422250  1.226445    0.723070    0.285152    0.257531  ...
# AL732372.1   0.829491  1.059949    0.499035    0.797381    0.775332  ...
# AL669831.2   0.635874  1.156220    0.602271    0.391414    0.366679  ...
# AL669831.5   0.251105  1.320983    0.817859    0.409056    0.445124  ...
# ...               ...       ...         ...         ...         ...  ...
# AC023491.2   1.006842  1.259052    0.748405    0.938631    0.983194  ...
# AC004556.1   1.277477  1.144729    1.156811    1.396095    1.348100  ...
# AC233755.2   0.750246  1.157157    0.551321    0.758933    0.747305  ...
# AC233755.1   0.899709  1.268132    0.650527    0.770191    0.769849  ...
# AC240274.1   0.877906  0.741353    0.787517    0.931929    0.977041  ...
#
#             AL592183.1  AC007325.1  AC007325.4  AC007325.2  AL354822.1  \
# AL627309.1    1.187831    1.056839    1.262503    0.767839    0.702020
# AL627309.4    0.959146    1.020837    1.130319    0.914378    0.531606
# AL732372.1    0.972535    0.901488    0.913564    0.401565    0.694548
# AL669831.2    1.103663    1.090349    1.002296    0.918007    0.516461
# AL669831.5    1.059674    1.007094    1.209692    0.985544    0.654455
# ...                ...         ...         ...         ...         ...
# AC023491.2    1.186761    0.791556    1.092604    0.794264    1.074304
# AC004556.1    1.561147    1.484098    1.476974    1.413291    1.298008
# AC233755.2    1.013519    0.952944    0.862705    0.589267    0.645777
# AC233755.1    1.141365    1.148068    1.011480    0.785977    0.801838
# AC240274.1    0.964472    1.143400    1.068726    0.856848    0.885126
#
#             AC023491.2  AC004556.1  AC233755.2  AC233755.1  AC240274.1
# AL627309.1    1.097004    1.588252    0.846691    0.970765    1.121568
# AL627309.4    1.155263    1.388156    0.821105    0.908607    0.928856
# AL732372.1    0.858126    1.381288    0.410235    0.485108    0.857833
# AL669831.2    1.100192    1.510132    0.870087    0.916722    1.099538
# AL669831.5    1.137698    1.434723    0.841570    0.995265    0.763911
# ...                ...         ...         ...         ...         ...
# AC023491.2    0.000000    1.577872    0.994281    1.152593    1.236813
# AC004556.1    1.577872    0.000000    1.500339    1.641818    1.039413
# AC233755.2    0.994281    1.500339    0.000000    0.307075    0.805993
# AC233755.1    1.152593    1.641818    0.307075    0.000000    1.081061
# AC240274.1    1.236813    1.039413    0.805993    1.081061    0.000000
#
# [22129 rows x 22129 columns]

# %%
distance_ctrl = ad.AnnData(X=distance_ctrl)

# %%
# Set the name of the DataFrame
distance_ctrl.name = "distance_ctrl"

# distance_NA.name = "distance_NA"

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_leiden, leiden_to_module, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell'

# %% [markdown]
# 4S

# %%
resolution_values = [1,2,3,4,5,10,15,20,25]  # for n_neighbors=30: 15~280 clusters
# n_Neighbors doesn't affect the number of clusters at all, so don't need to use a large value

for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_ctrl, data_name="distance_ctrl", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_ctrl_{resolution_parameter}.svg")
    module_ctrl = leiden_to_module(distance_ctrl)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:02:10)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
# /home/jovyan/work/FUNCTIONS/methods.py:505: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(data, resolution=resolution)
#     finished: found 22 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:27)
# Number of modules: 22
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:23)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 32 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:18)
# Number of modules: 32
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:23)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 48 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:15)
# Number of modules: 48
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:25)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 64 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:29)
# Number of modules: 64
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:26)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 79 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:39)
# Number of modules: 79
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:25)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 139 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:25)
# Number of modules: 139
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:24)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 191 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:18)
# Number of modules: 191
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:02:08)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 246 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:26)
# Number of modules: 246
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:22)
# IGRAPH U-W- 22129 435490 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 303 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:16)
# Number of modules: 303

# %% [markdown]
# I

# %%
del distance_ctrl
del module_ctrl

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd

distance_mild = pd.read_csv("distance_mild.csv", index_col=0)
distance_mild = ad.AnnData(X=distance_mild)
distance_mild.name = "distance_mild"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell'

# %%
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_mild, data_name="distance_mild", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_mild_{resolution_parameter}.svg")
    module_mild = leiden_to_module(distance_mild)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:25)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 21 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:18)
# Number of modules: 21
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:53)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 40 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:14)
# Number of modules: 40
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:27)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 55 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:16)
# Number of modules: 55
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:28)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 67 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:16)
# Number of modules: 67
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:26)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 80 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:19)
# Number of modules: 80
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:26)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 133 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:28)
# Number of modules: 133
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:26)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 188 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:27)
# Number of modules: 188
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:26)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 245 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:22)
# Number of modules: 245
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:25)
# IGRAPH U-W- 20819 406783 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 298 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:23)
# Number of modules: 298

# %%
del distance_mild
del module_mild

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/Cell/
# %pwd

distance_severe = pd.read_csv("distance_severe.csv", index_col=0)
distance_severe = ad.AnnData(X=distance_severe)
distance_severe.name = "distance_severe"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell
# '/home/jovyan/work/COVID/parameter_tuning/linear/knn/Cell'

# %%
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_severe, data_name="distance_severe", n_neighbors=30, resolution=resolution_parameter, fig_path=f"./figures/degree_distribution_severe_{resolution_parameter}.svg")
    module_severe = leiden_to_module(distance_severe)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:12)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)
# Number of modules: 20
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 35 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)
# Number of modules: 35
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 49 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)
# Number of modules: 49
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:12)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 60 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)
# Number of modules: 60
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 66 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:04)
# Number of modules: 66
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:12)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 114 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:05)
# Number of modules: 114
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:12)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 156 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:05)
# Number of modules: 156
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:42)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 187 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)
# Number of modules: 187
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:14)
# IGRAPH U-W- 8519 165619 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 219 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:03)
# Number of modules: 219

# %%
del distance_severe
del module_severe
