# %%
import hotspot
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplscience
import pickle

# %%
# !pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/hotspot/Cell
# !pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/hotspot
# /home/jovyan/work/COVID/parameter_tuning/hotspot/Cell
# /home/jovyan/work/COVID/parameter_tuning/hotspot/Cell

# %%
adata = sc.read_h5ad("../../../COVID_macrophage_scVI.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 56861 × 26571
#     obs: 'PatientID', 'Sample type', 'CoVID-19 severity', 'datasets', 'batch', 'celltype', 'majorType', 'sampleID', 'City', 'Age', 'Sex', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'leiden', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0-0', 'genome-1-0', 'genome-10-0', 'genome-11-0', 'genome-2-0', 'genome-3-0', 'genome-4-0', 'genome-5-0', 'genome-6-0', 'genome-7-0', 'genome-8-0', 'genome-9-0', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std', 'highly_variable_rank', 'variances', 'variances_norm'
#     uns: 'CoVID-19 severity_colors', 'PatientID_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cell_type_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'scrublet', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     varm: 'PCs'
#     layers: 'counts', 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# Ctrl

# %%
adata_ctrl = adata[adata.obs["CoVID-19 severity"] == "control"]
adata_ctrl

# %%
adata_mild = adata[adata.obs["CoVID-19 severity"] == "mild/moderate"]
adata_mild

# %%
adata_severe = adata[adata.obs["CoVID-19 severity"] == "severe/critical"]
adata_severe
# Out:
# View of AnnData object with n_obs × n_vars = 50866 × 26571
#     obs: 'PatientID', 'Sample type', 'CoVID-19 severity', 'datasets', 'batch', 'celltype', 'majorType', 'sampleID', 'City', 'Age', 'Sex', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'leiden', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0-0', 'genome-1-0', 'genome-10-0', 'genome-11-0', 'genome-2-0', 'genome-3-0', 'genome-4-0', 'genome-5-0', 'genome-6-0', 'genome-7-0', 'genome-8-0', 'genome-9-0', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std', 'highly_variable_rank', 'variances', 'variances_norm'
#     uns: 'CoVID-19 severity_colors', 'PatientID_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cell_type_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'scrublet', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     varm: 'PCs'
#     layers: 'counts', 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
del adata

# %%
hs = hotspot.Hotspot(
    adata_ctrl,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)

# %%
hs_results = hs.compute_autocorrelations()
hs_results.head(15)

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=15)

# %%
# Save the Hotspot object to a file
with open("hotspot_object_ctrl.pkl", "wb") as f:
    pickle.dump(hs, f)

# %%
del hs
del adata_ctrl

# %% [markdown]
# Mild

# %%
hs = hotspot.Hotspot(
    adata_mild,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)

# %%
hs_results = hs.compute_autocorrelations()

# %%
# Select the genes with significant lineage autocorrelation
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=15)

# %%
# Save the Hotspot object to a file
with open("hotspot_object_mild.pkl", "wb") as f:
    pickle.dump(hs, f)

# %%
del hs
del adata_mild

# %% [markdown]
# Severe

# %%
len(adata_severe)*0.5
# Out:
# 25433.0

# %%
adata_severe_20 = sc.pp.subsample(adata_severe, n_obs=25433, copy=True, random_state=1234)

# %%
adata_severe_20
# Out:
# AnnData object with n_obs × n_vars = 25433 × 26571
#     obs: 'PatientID', 'Sample type', 'CoVID-19 severity', 'datasets', 'batch', 'celltype', 'majorType', 'sampleID', 'City', 'Age', 'Sex', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'leiden', 'cell_type', '_scvi_batch', '_scvi_labels', 'leiden_scVI'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0-0', 'genome-1-0', 'genome-10-0', 'genome-11-0', 'genome-2-0', 'genome-3-0', 'genome-4-0', 'genome-5-0', 'genome-6-0', 'genome-7-0', 'genome-8-0', 'genome-9-0', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std', 'highly_variable_rank', 'variances', 'variances_norm'
#     uns: 'CoVID-19 severity_colors', 'PatientID_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cell_type_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_scVI', 'leiden_scVI_colors', 'leiden_scVI_sizes', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'scrublet', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_scVI', 'X_umap', '_scvi_extra_continuous_covs'
#     varm: 'PCs'
#     layers: 'counts', 'scvi_log', 'scvi_normalized', 'scvi_scale'
#     obsp: 'connectivities', 'distances'

# %%
import gc
del adata_severe
gc.collect()
# Out:
# 2146

# %%
hs = hotspot.Hotspot(
    adata_severe_20,
    layer_key="scvi_log",
    model='normal',
    latent_obsm_key="X_scVI",
    # umi_counts_obs_key="total_counts"
)

# %%
hs.create_knn_graph(weighted_graph=False, n_neighbors=30)

# %%
hs_results = hs.compute_autocorrelations()
# Out:
# 100% 26571/26571 [02:10<00:00, 203.39it/s]

# %%
# Select the genes with significant lineage autocorrelation/
hs_genes = hs_results.index

# Compute pair-wise local correlations between these genes
lcz = hs.compute_local_correlations(hs_genes, jobs=15)
# Out:
# Computing pair-wise local correlation on 26571 features...
# 100% 26571/26571 [00:17<00:00, 1483.97it/s]
#   3% 10841818/352995735 [46:04<23:46:28, 3997.68it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  10% 34434649/352995735 [2:26:13<22:03:12, 4012.49it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  16% 55466712/352995735 [3:55:28<21:17:27, 3881.79it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  16% 57828376/352995735 [4:05:29<20:32:29, 3991.46it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  22% 78863337/352995735 [5:34:44<19:00:43, 4005.25it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  23% 79932218/352995735 [5:39:20<19:31:52, 3883.57it/s]

# %%
# Save the Hotspot object to a file
with open("hotspot_object_severe.pkl", "wb") as f:
    pickle.dump(hs, f)

# %%
del hs
del adata_severe_20
