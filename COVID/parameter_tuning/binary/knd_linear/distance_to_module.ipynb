# %%
import pandas as pd

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell
# '/home/jovyan/work/COVID/parameter_tuning/binary/Cell'

# %%
# import the distance data
distance_ctrl = pd.read_csv("distance_ctrl.csv", index_col=0)
distance_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1         0.0         3.0         3.0         3.0         3.0
# AL627309.4         3.0         0.0         4.0         2.0         2.0
# AL732372.1         3.0         4.0         0.0         4.0         4.0
# AL669831.2         3.0         2.0         4.0         0.0         3.0
# AL669831.5         3.0         2.0         4.0         3.0         0.0
# ...                ...         ...         ...         ...         ...
# AC023491.2         4.0         5.0         4.0         5.0         5.0
# AC004556.1         6.0         5.0         6.0         6.0         6.0
# AC233755.2         4.0         4.0         2.0         4.0         4.0
# AC233755.1         4.0         4.0         2.0         4.0         4.0
# AC240274.1         5.0         4.0         4.0         5.0         3.0
#
#             LINC00115  FAM41C  AL645608.7  AL645608.3  AL645608.5  ...  \
# AL627309.1        3.0     6.0         4.0         2.0         2.0  ...
# AL627309.4        2.0     5.0         3.0         1.0         1.0  ...
# AL732372.1        4.0     4.0         2.0         4.0         3.0  ...
# AL669831.2        3.0     5.0         3.0         2.0         2.0  ...
# AL669831.5        1.0     5.0         3.0         2.0         2.0  ...
# ...               ...     ...         ...         ...         ...  ...
# AC023491.2        4.0     5.0         4.0         4.0         4.0  ...
# AC004556.1        5.0     4.0         5.0         5.0         5.0  ...
# AC233755.2        3.0     5.0         3.0         3.0         3.0  ...
# AC233755.1        4.0     5.0         3.0         4.0         4.0  ...
# AC240274.1        4.0     3.0         3.0         4.0         4.0  ...
#
#             AL592183.1  AC007325.1  AC007325.4  AC007325.2  AL354822.1  \
# AL627309.1         5.0         4.0         5.0         3.0         3.0
# AL627309.4         4.0         4.0         5.0         4.0         2.0
# AL732372.1         4.0         4.0         4.0         2.0         3.0
# AL669831.2         5.0         4.0         4.0         4.0         2.0
# AL669831.5         4.0         4.0         5.0         4.0         3.0
# ...                ...         ...         ...         ...         ...
# AC023491.2         5.0         3.0         5.0         4.0         4.0
# AC004556.1         6.0         6.0         6.0         5.0         5.0
# AC233755.2         4.0         4.0         4.0         3.0         3.0
# AC233755.1         5.0         5.0         4.0         3.0         3.0
# AC240274.1         4.0         5.0         4.0         3.0         4.0
#
#             AC023491.2  AC004556.1  AC233755.2  AC233755.1  AC240274.1
# AL627309.1         4.0         6.0         4.0         4.0         5.0
# AL627309.4         5.0         5.0         4.0         4.0         4.0
# AL732372.1         4.0         6.0         2.0         2.0         4.0
# AL669831.2         5.0         6.0         4.0         4.0         5.0
# AL669831.5         5.0         6.0         4.0         4.0         3.0
# ...                ...         ...         ...         ...         ...
# AC023491.2         0.0         7.0         5.0         5.0         5.0
# AC004556.1         7.0         0.0         6.0         7.0         4.0
# AC233755.2         5.0         6.0         0.0         2.0         3.0
# AC233755.1         5.0         7.0         2.0         0.0         4.0
# AC240274.1         5.0         4.0         3.0         4.0         0.0
#
# [22129 rows x 22129 columns]

# %%
# Set the name of the DataFrame
distance_ctrl.name = "distance_ctrl"
# distance_NA.name = "distance_NA"

# %% [markdown]
# construct a weighted graph as leiden's input from the 50-PC distance space. Using Euclidean distance in the space, selecting top k% shortest distance as edges, normalize the distance to between 0-1, and then take the reciprocal to make smaller distances larger weights and vice versa

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_module_linear, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell
# '/home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell'

# %% [markdown]
# Cell: resolution = 0.3

# %%
resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 40%: 25~690 modules
# resolution_values = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5]  # for 50%: 15~650 modules

# cannot calculate distance since it takes too long for a denser graph
for resolution_parameter in resolution_values:
    module_ctrl = distance_to_module_linear(distance_coordinate=distance_ctrl, fig_path1=f"./figures/degree_distribution_ctrl_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_ctrl_{resolution_parameter}.png", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
# Out:
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 20
# Cluster assignments: [0, 0, 1, 0, 0, 0, 3, 1, 0, 0, 1, 3, 0, 0, 4, 4, 2, 2, 0, 4]
# Number of modules: 17
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 34
# Cluster assignments: [0, 0, 1, 0, 0, 0, 4, 1, 0, 0, 1, 4, 0, 0, 2, 6, 3, 9, 0, 6]
# Number of modules: 27
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 50
# Cluster assignments: [0, 0, 2, 0, 0, 0, 10, 1, 0, 0, 1, 4, 0, 0, 2, 5, 5, 7, 0, 6]
# Number of modules: 39
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 84
# Cluster assignments: [7, 0, 2, 0, 0, 0, 11, 1, 0, 0, 1, 4, 0, 0, 2, 5, 3, 28, 0, 6]
# Number of modules: 63
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 124
# Cluster assignments: [21, 0, 2, 4, 0, 0, 14, 1, 0, 0, 1, 6, 0, 0, 7, 54, 3, 42, 0, 7]
# Number of modules: 93
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 223
# Cluster assignments: [30, 0, 2, 3, 0, 0, 17, 1, 3, 0, 27, 15, 0, 0, 7, 61, 41, 58, 0, 7]
# Number of modules: 144
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 420
# Cluster assignments: [125, 2, 6, 2, 4, 0, 26, 1, 2, 2, 19, 23, 0, 0, 9, 124, 168, 76, 0, 12]
# Number of modules: 245
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 792
# Cluster assignments: [148, 2, 6, 2, 3, 0, 30, 1, 2, 2, 24, 26, 0, 0, 14, 140, 283, 214, 0, 23]
# Number of modules: 418
# threshold_percentile = 40%: threshold_distance = 175.05427729707148
# Number of connected components: 1
# Number of clusters: 1621
# Cluster assignments: [260, 2, 29, 19, 3, 1, 37, 0, 2, 2, 29, 82, 3, 11, 25, 228, 898, 915, 3, 185]
# Number of modules: 719

# %%
del module_ctrl
del distance_ctrl

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
distance_mild = pd.read_csv("distance_mild.csv", index_col=0)
distance_mild.name = "distance_mild"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell/
# %pwd

for resolution_parameter in resolution_values:
    module_mild = distance_to_module_linear(distance_coordinate=distance_mild, fig_path1=f"./figures/degree_distribution_mild_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_mild_{resolution_parameter}.png", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 25
# Cluster assignments: [1, 0, 0, 0, 0, 2, 2, 0, 0, 0, 4, 4, 3, 3, 1, 2, 1, 1, 1, 1]
# Number of modules: 18
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 34
# Cluster assignments: [5, 0, 4, 0, 0, 2, 2, 0, 0, 0, 4, 4, 3, 3, 1, 4, 3, 1, 3, 1]
# Number of modules: 27
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 51
# Cluster assignments: [5, 0, 4, 0, 0, 2, 22, 0, 0, 0, 4, 8, 3, 3, 3, 8, 3, 1, 3, 1]
# Number of modules: 37
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 71
# Cluster assignments: [6, 3, 5, 0, 0, 4, 18, 0, 0, 0, 5, 8, 7, 15, 2, 8, 2, 1, 2, 1]
# Number of modules: 47
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 99
# Cluster assignments: [7, 2, 5, 2, 19, 4, 14, 0, 2, 2, 7, 8, 6, 15, 3, 8, 3, 1, 3, 1]
# Number of modules: 64
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 150
# Cluster assignments: [9, 2, 6, 2, 24, 4, 15, 0, 2, 2, 8, 20, 18, 19, 3, 10, 3, 1, 3, 1]
# Number of modules: 98
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 231
# Cluster assignments: [10, 1, 25, 1, 27, 4, 20, 0, 1, 1, 25, 23, 19, 53, 11, 16, 11, 3, 11, 2]
# Number of modules: 140
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 389
# Cluster assignments: [12, 10, 23, 66, 31, 5, 36, 0, 1, 1, 23, 53, 49, 63, 11, 44, 11, 3, 11, 2]
# Number of modules: 228
# threshold_percentile = 40%: threshold_distance = 181.31464364468746
# Number of connected components: 1
# Number of clusters: 712
# Cluster assignments: [16, 17, 43, 10, 40, 7, 38, 0, 2, 2, 88, 73, 95, 627, 15, 61, 15, 5, 15, 3]
# Number of modules: 367

# %%
del module_mild
del distance_mild

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
distance_severe = pd.read_csv("distance_severe.csv", index_col=0)
distance_severe.name = "distance_severe"
# distance_NA = pd.read_csv("distance_NA.csv", index_col=0)
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell/
# %pwd
for resolution_parameter in resolution_values:
    module_severe = distance_to_module_linear(distance_coordinate=distance_severe, fig_path1=f"./figures/degree_distribution_severe_{resolution_parameter}.png", fig_path2=f"./figures/weight_distribution_severe_{resolution_parameter}.png", threshold_percentile=40, resolution_parameter=resolution_parameter, seed=123456)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knd_linear/Cell
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 8
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 8
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 10
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 8
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 11
# Cluster assignments: [2, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 8
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 12
# Cluster assignments: [2, 2, 3, 2, 1, 1, 1, 0, 1, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 2]
# Number of modules: 9
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 13
# Cluster assignments: [1, 1, 4, 1, 3, 2, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 0, 1]
# Number of modules: 9
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 15
# Cluster assignments: [1, 1, 4, 1, 3, 2, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 0, 1]
# Number of modules: 13
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 17
# Cluster assignments: [1, 1, 3, 1, 4, 2, 2, 3, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 0, 1]
# Number of modules: 15
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 23
# Cluster assignments: [1, 1, 4, 1, 3, 2, 2, 4, 2, 3, 2, 2, 0, 0, 3, 3, 3, 2, 0, 1]
# Number of modules: 17
# threshold_percentile = 40%: threshold_distance = 265.29794571387094
# Number of connected components: 1
# Number of clusters: 26
# Cluster assignments: [1, 1, 3, 1, 5, 2, 4, 3, 2, 2, 2, 2, 0, 0, 2, 2, 2, 4, 0, 1]
# Number of modules: 20

# %%
del module_severe
del distance_severe
