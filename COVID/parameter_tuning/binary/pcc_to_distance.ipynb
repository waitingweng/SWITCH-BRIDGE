# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
# Out:
# /home/jovyan/work/COVID/results
# '/home/jovyan/work/COVID/results'

# %%
# import the PCC data
pcc_ctrl = pd.read_csv("pcc_control.csv", index_col=0)

# %%
# Melt the DataFrame to long format
df_melted = pcc_ctrl.melt()
del pcc_ctrl

# %%
df_melted
# Out:
#              variable     value
# 0          AL627309.1  1.000000
# 1          AL627309.1  0.355817
# 2          AL627309.1  0.228245
# 3          AL627309.1  0.445432
# 4          AL627309.1  0.383732
# ...               ...       ...
# 706018036  AC240274.1 -0.038598
# 706018037  AC240274.1  0.348891
# 706018038  AC240274.1 -0.300307
# 706018039  AC240274.1 -0.207532
# 706018040  AC240274.1  1.000000
#
# [706018041 rows x 2 columns]

# %%
# Set font sizes using rcParams
plt.rcParams.update({
    'axes.titlesize': 28,
    'axes.labelsize': 25,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20,
    'legend.fontsize': 20
})

# Plot using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df_melted['value'], bins=30, kde=True)
plt.title('PCC control')
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')

# Save the plot to a file
plt.savefig('../figures/pcc_control.svg')

plt.show()

# %%
del df_melted

# %%
# import the PCC data
pcc_mild = pd.read_csv("pcc_mild.csv", index_col=0)

# %%
# Melt the DataFrame to long format
df_melted = pcc_mild.melt()
del pcc_mild

# %%
# Set font sizes using rcParams
plt.rcParams.update({
    'axes.titlesize': 28,
    'axes.labelsize': 25,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20,
    'legend.fontsize': 20
})

# Plot using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df_melted['value'], bins=30, kde=True)
plt.title('PCC Mild/Moderate')
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')

# Save the plot to a file
plt.savefig('../figures/pcc_mild.svg')

plt.show()

# %%
del df_melted
# import the PCC data
pcc_severe = pd.read_csv("pcc_severe.csv", index_col=0)
# Melt the DataFrame to long format
df_melted = pcc_severe.melt()
del pcc_severe

# %%
# Set font sizes using rcParams
plt.rcParams.update({
    'axes.titlesize': 28,
    'axes.labelsize': 25,
    'xtick.labelsize': 20,
    'ytick.labelsize': 20,
    'legend.fontsize': 20
})

# Plot using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(df_melted['value'], bins=30, kde=True)
plt.title('PCC Severe')
plt.xlabel('Pearson Correlation')
plt.ylabel('Frequency')

# Save the plot to a file
plt.savefig('../figures/pcc_severe.png')

plt.show()

# %%
# import the PCC data
pcc_ctrl = pd.read_csv("pcc_control.csv", index_col=0)
pcc_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1    1.000000    0.355817    0.228245    0.445432    0.383732
# AL627309.4    0.355817    1.000000   -0.020470    0.560937    0.581096
# AL732372.1    0.228245   -0.020470    1.000000    0.074559    0.122271
# AL669831.2    0.445432    0.560937    0.074559    1.000000    0.342962
# AL669831.5    0.383732    0.581096    0.122271    0.342962    1.000000
# ...                ...         ...         ...         ...         ...
# AC023491.2   -0.049202   -0.091704    0.136197    0.151045    0.014234
# AC004556.1   -0.164801   -0.032674    0.064839   -0.056025    0.078203
# AC233755.2    0.182791    0.054308    0.529239    0.008447    0.192516
# AC233755.1    0.104667    0.144107    0.321262    0.011003    0.205644
# AC240274.1   -0.109492    0.010559   -0.244606    0.040818    0.267993
#
#               FAM87B  LINC00115    FAM41C  AL645608.7  AL645608.3  ...  \
# ...

# %% [markdown]
# construct an unweighted graph of edges based on whether the PCC exceeds the theshold.

# %% [markdown]
# delete rows and columns with Inf entries, since those genes are deleted from the module. (already ensured the genes won't contribute to potential modules candidates by assuring only 1 connected component is >= 3 in the previous graph)

# %% [markdown]
# write the function that convertes PCC matrix to distance matrix

# %%
# take a look what values should be set as thresholds
sum = 0
for colname in pcc_ctrl:
    for value in pcc_ctrl[colname]:
        if value > 0.7:
            sum += 1
print(sum/(pcc_ctrl.shape[0]**2))
# Out:
# 0.0066947481870367675

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import Binary_SWIM_pcc_to_distance

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell
# '/home/jovyan/work/COVID/parameter_tuning/binary/Cell'

# %%
distance_ctrl = Binary_SWIM_pcc_to_distance(pcc_matrix=pcc_ctrl, fig_path1="../figures/degree_distribution_ctrl.png", fig_path2="../figures/distance_distribution_ctrl.png", pcc_threshold=0.7)
distance_ctrl.to_csv("distance_ctrl.csv")
distance_ctrl
del distance_ctrl
del pcc_ctrl
# Out:
# IGRAPH UN-- 26571 2589516 --
# + attr: name (v)
# graph is connected: False
# All Pairs Distances:
# <class 'list'>
# 26571X26571
# Number of vertices in largest connected component: 22129
# Number of edges in largest connected component: 2589426

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
pcc_mild = pd.read_csv("pcc_mild.csv", index_col=0)
# Out:
# /home/jovyan/work/COVID/results

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd

# pcc_NA = pd.read_csv("pcc_NA.csv", index_col=0)
distance_mild = Binary_SWIM_pcc_to_distance(pcc_matrix=pcc_mild, fig_path1="../figures/degree_distribution_mild.png", fig_path2="../figures/distance_distribution_mild.png", pcc_threshold=0.7)
distance_mild.to_csv("distance_mild.csv")
distance_mild

del distance_mild
del pcc_mild
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell
# IGRAPH UN-- 26571 3343117 --
# + attr: name (v)
# graph is connected: False
# All Pairs Distances:
# <class 'list'>
# 26571X26571
# Number of vertices in largest connected component: 20819
# Number of edges in largest connected component: 3343010

# %%
# %pwd
# %cd /home/jovyan/work/COVID/results/
# %pwd
pcc_severe = pd.read_csv("pcc_severe.csv", index_col=0)
# Out:
# /home/jovyan/work/COVID/results

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd

distance_severe = Binary_SWIM_pcc_to_distance(pcc_matrix=pcc_severe, fig_path1="../figures/degree_distribution_severe.png", fig_path2="../figures/distance_distribution_severe.png", pcc_threshold=0.7)
distance_severe.to_csv("distance_severe.csv")
distance_severe

del distance_severe
del pcc_severe
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell
# IGRAPH UN-- 26571 1143059 --
# + attr: name (v)
# graph is connected: False
# All Pairs Distances:
# <class 'list'>
# 26571X26571
# Number of vertices in largest connected component: 8519
# Number of edges in largest connected component: 1141157
