# %%
import scanpy as sc
import anndata as ad
import pandas as pd

# %%
sc.settings.verbosity = 3

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell
# '/home/jovyan/work/COVID/parameter_tuning/binary/Cell'

# %%
# import the distance data
distance_ctrl = pd.read_csv("distance_ctrl.csv", index_col=0)

distance_ctrl
# Out:
#             AL627309.1  AL627309.4  AL732372.1  AL669831.2  AL669831.5  \
# AL627309.1         0.0         3.0         3.0         3.0         3.0
# AL627309.4         3.0         0.0         4.0         2.0         2.0
# AL732372.1         3.0         4.0         0.0         4.0         4.0
# AL669831.2         3.0         2.0         4.0         0.0         3.0
# AL669831.5         3.0         2.0         4.0         3.0         0.0
# ...                ...         ...         ...         ...         ...
# AC023491.2         4.0         5.0         4.0         5.0         5.0
# AC004556.1         6.0         5.0         6.0         6.0         6.0
# AC233755.2         4.0         4.0         2.0         4.0         4.0
# AC233755.1         4.0         4.0         2.0         4.0         4.0
# AC240274.1         5.0         4.0         4.0         5.0         3.0
#
#             LINC00115  FAM41C  AL645608.7  AL645608.3  AL645608.5  ...  \
# ...

# %%
distance_ctrl = ad.AnnData(X=distance_ctrl)
# distance_NA = ad.AnnData(X=distance_NA)

# %%
# Set the name of the DataFrame
distance_ctrl.name = "distance_ctrl"

# %%
import sys
sys.path.append('/home/jovyan/work/FUNCTIONS/')
from methods import distance_to_leiden, leiden_to_module, module_to_json

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell/
# %pwd
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell
# '/home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell'

# %% [markdown]
# Cell: resolution = 10

# %% [markdown]
# 4S

# %%
resolution_values = [1,2,3,4,5,10,15,20,25]  # for n_neighbors=30: 15~260 clusters
# n_Neighbors doesn't affect the number of clusters at all, so don't need to use a large value

for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_ctrl, data_name="distance_ctrl", n_neighbors=30, resolution=resolution_parameter, fig_path=f"../figures/degree_distribution_ctrl_{resolution_parameter}.png")
    module_ctrl = leiden_to_module(distance_ctrl)
    module_to_json(module_dict=module_ctrl, file_path=f"module_ctrl_{resolution_parameter}.json")
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:50)
# IGRAPH U-W- 22129 431992 --
# + attr: weight (e)
# running Leiden clustering
# /home/jovyan/work/FUNCTIONS/methods.py:505: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(data, resolution=resolution)
#     finished: found 19 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:19)
# Number of modules: 19
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:25)
# IGRAPH U-W- 22129 431992 --
# ...

# %%
del module_ctrl
del distance_ctrl

# %% [markdown]
# I

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
distance_mild = pd.read_csv("distance_mild.csv", index_col=0)
distance_mild = ad.AnnData(X=distance_mild)
distance_mild.name = "distance_mild"
# distance_NA.name = "distance_NA"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell/
# %pwd

for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_mild, data_name="distance_mild", n_neighbors=30, resolution=resolution_parameter, fig_path=f"../figures/degree_distribution_mild_{resolution_parameter}.png")
    module_mild = leiden_to_module(distance_mild)
    module_to_json(module_dict=module_mild, file_path=f"module_mild_{resolution_parameter}.json")
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:13)
# IGRAPH U-W- 20819 406690 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 22 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:13)
# Number of modules: 22
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:12)
# IGRAPH U-W- 20819 406690 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 39 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:23)
# Number of modules: 39
# computing neighbors
#     finished: added to `.uns['neighbors']`
# ...

# %%
del module_mild
del distance_mild

# %% [markdown]
# III

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/Cell/
# %pwd
distance_severe = pd.read_csv("distance_severe.csv", index_col=0)
distance_severe = ad.AnnData(X=distance_severe)
distance_severe.name = "distance_severe"
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/Cell

# %%
# %pwd
# %cd /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell/
# %pwd
for resolution_parameter in resolution_values: 
    distance_to_leiden(distance_severe, data_name="distance_severe", n_neighbors=30, resolution=resolution_parameter, fig_path=f"../figures/degree_distribution_severe_{resolution_parameter}.png")
    module_severe = leiden_to_module(distance_severe)
    module_to_json(module_dict=module_severe, file_path=f"module_severe_{resolution_parameter}.json")
# Out:
# /home/jovyan/work/COVID/parameter_tuning/binary/knn/Cell
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# IGRAPH U-W- 8519 167355 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 37 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)
# Number of modules: 37
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:14)
# IGRAPH U-W- 8519 167355 --
# + attr: weight (e)
# running Leiden clustering
#     finished: found 52 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)
# Number of modules: 52
# computing neighbors
#     finished: added to `.uns['neighbors']`
# ...

# %%
del module_severe
del distance_severe

# %% [markdown]
# IV
