# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
# sys.path.append('./utils/')

import scanpy as sc
import anndata as ad
import scvi
import seaborn as sns
import torch
import gc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 import pandas as pd
# ----> 2 import pytables
#       3 import matplotlib.pyplot as plt
#       4 import os
#
# ModuleNotFoundError: No module named 'pytables'

# %% [markdown]
# ### First, we load the files from GSE158055 including 9 severe samples, 3 mild samples

# %%
GSE158055 = sc.read_h5ad("GSE158055_freshBALF.h5ad")

# %%
GSE158055
# Out:
# AnnData object with n_obs × n_vars = 42723 × 27943
#     obs: 'celltype', 'majorType', 'sampleID', 'PatientID', 'datasets', 'City', 'Age', 'Sex', 'Sample type', 'CoVID-19 severity', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished'
#     uns: 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'har_emb'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### Second, we load the files from GSE145926/ including 6 severe samples, 3 moderate samples and 3 control samples and we assign the "PatientID", "Sample type", "CoVID-19 severity", and "Datasets (accession number)" to anndata.obs

# %%
C141 = sc.read_10x_h5("GSE145926/GSM4339769_C141_filtered_feature_bc_matrix.h5")
C141.var_names_make_unique()
C141.obs['PatientID'] = "C141"
C141.obs["Sample type"] = "fresh BALF"
C141.obs['CoVID-19 severity'] = "mild/moderate"
C141.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C142 = sc.read_10x_h5("GSE145926/GSM4339770_C142_filtered_feature_bc_matrix.h5")
C142.var_names_make_unique()
C142.obs['PatientID'] = "C142"
C142.obs["Sample type"] = "fresh BALF"
C142.obs['CoVID-19 severity'] = "mild/moderate"
C142.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C144 = sc.read_10x_h5("GSE145926/GSM4339772_C144_filtered_feature_bc_matrix.h5")
C144.var_names_make_unique()
C144.obs['PatientID'] = "C144"
C144.obs["Sample type"] = "fresh BALF"
C144.obs['CoVID-19 severity'] = "mild/moderate"
C144.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C143 = sc.read_10x_h5("GSE145926/GSM4339771_C143_filtered_feature_bc_matrix.h5")
C143.var_names_make_unique()
C143.obs['PatientID'] = "C143"
C143.obs["Sample type"] = "fresh BALF"
C143.obs['CoVID-19 severity'] = "severe/critical"
C143.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C145 = sc.read_10x_h5("GSE145926/GSM4339773_C145_filtered_feature_bc_matrix.h5")
C145.var_names_make_unique()
C145.obs['PatientID'] = "C145"
C145.obs["Sample type"] = "fresh BALF"
C145.obs['CoVID-19 severity'] = "severe/critical"
C145.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C146 = sc.read_10x_h5("GSE145926/GSM4339774_C146_filtered_feature_bc_matrix.h5")
C146.var_names_make_unique()
C146.obs['PatientID'] = "C146"
C146.obs["Sample type"] = "fresh BALF"
C146.obs['CoVID-19 severity'] = "severe/critical"
C146.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C148 = sc.read_10x_h5("GSE145926/GSM4475051_C148_filtered_feature_bc_matrix.h5")
C148.var_names_make_unique()
C148.obs['PatientID'] = "C148"
C148.obs["Sample type"] = "fresh BALF"
C148.obs['CoVID-19 severity'] = "severe/critical"
C148.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C149 = sc.read_10x_h5("GSE145926/GSM4475052_C149_filtered_feature_bc_matrix.h5")
C149.var_names_make_unique()
C149.obs['PatientID'] = "C149"
C149.obs["Sample type"] = "fresh BALF"
C149.obs['CoVID-19 severity'] = "severe/critical"
C149.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C152 = sc.read_10x_h5("GSE145926/GSM4475053_C152_filtered_feature_bc_matrix.h5")
C152.var_names_make_unique()
C152.obs['PatientID'] = "C152"
C152.obs["Sample type"] = "fresh BALF"
C152.obs['CoVID-19 severity'] = "severe/critical"
C152.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C51 = sc.read_10x_h5("GSE145926/GSM4475048_C51_filtered_feature_bc_matrix.h5")
C51.var_names_make_unique()
C51.obs['PatientID'] = "C51"
C51.obs["Sample type"] = "fresh BALF"
C51.obs['CoVID-19 severity'] = "control"
C51.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C52 = sc.read_10x_h5("GSE145926/GSM4475049_C52_filtered_feature_bc_matrix.h5")
C52.var_names_make_unique()
C52.obs['PatientID'] = "C52"
C52.obs["Sample type"] = "fresh BALF"
C52.obs['CoVID-19 severity'] = "control"
C52.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
C100 = sc.read_10x_h5("GSE145926/GSM4475050_C100_filtered_feature_bc_matrix.h5")
C100.var_names_make_unique()
C100.obs['PatientID'] = "C100"
C100.obs["Sample type"] = "fresh BALF"
C100.obs['CoVID-19 severity'] = "control"
C100.obs['datasets'] = 'GSE145926'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %% [markdown]
# ### Combine 12 h5 files from GSE145926

# %%
GSE145926 = C51.concatenate(C52, C100, C141, C142, C144, C143, C145, C146, C148, C149, C152)
# Out:
# /tmp/ipykernel_14714/3700328020.py:1: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   GSE145926 = C51.concatenate(C52, C100, C141, C142, C144, C143, C145, C146, C148, C149, C152)

# %%
GSE145926
# Out:
# AnnData object with n_obs × n_vars = 108230 × 33538
#     obs: 'PatientID', 'Sample type', 'CoVID-19 severity', 'datasets', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome-0', 'genome-1', 'genome-10', 'genome-11', 'genome-2', 'genome-3', 'genome-4', 'genome-5', 'genome-6', 'genome-7', 'genome-8', 'genome-9'

# %%
GSE145926.write_h5ad("GSE145926_freshBALF.h5ad")

# %% [markdown]
# ### Third, we load the files from GSE263817/ including 5 R-PASC samples, 4 Non-R-PASC samples and 2 control samples. We also assign the "PatientID", "Sample type", "CoVID-19 severity", and "Datasets (accession number)" to anndata.obs

# %%
CON3 = sc.read_10x_h5("PASC_GSE263817/control/GSM8199614.h5")
CON3.var_names_make_unique()
CON3.obs['PatientID'] = "CON3"
CON3.obs["Sample type"] = "fresh BALF"
CON3.obs['CoVID-19 severity'] = "control"
CON3.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CON4 = sc.read_10x_h5("PASC_GSE263817/control/GSM8199616.h5")
CON4.var_names_make_unique()
CON4.obs['PatientID'] = "CON4"
CON4.obs["Sample type"] = "fresh BALF"
CON4.obs['CoVID-19 severity'] = "control"
CON4.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD1 = sc.read_10x_h5("PASC_GSE263817/R_PASC/GSM8199617.h5")
CVD1.var_names_make_unique()
CVD1.obs['PatientID'] = "CVD1"
CVD1.obs["Sample type"] = "fresh BALF"
CVD1.obs['CoVID-19 severity'] = "R-PASC"
CVD1.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD2 = sc.read_10x_h5("PASC_GSE263817/R_PASC/GSM8199619.h5")
CVD2.var_names_make_unique()
CVD2.obs['PatientID'] = "CVD2"
CVD2.obs["Sample type"] = "fresh BALF"
CVD2.obs['CoVID-19 severity'] = "R-PASC"
CVD2.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD3 = sc.read_10x_h5("PASC_GSE263817/R_PASC/GSM8199621.h5")
CVD3.var_names_make_unique()
CVD3.obs['PatientID'] = "CVD3"
CVD3.obs["Sample type"] = "fresh BALF"
CVD3.obs['CoVID-19 severity'] = "R-PASC"
CVD3.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD8 = sc.read_10x_h5("PASC_GSE263817/R_PASC/GSM8199627.h5")
CVD8.var_names_make_unique()
CVD8.obs['PatientID'] = "CVD8"
CVD8.obs["Sample type"] = "fresh BALF"
CVD8.obs['CoVID-19 severity'] = "R-PASC"
CVD8.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD9 = sc.read_10x_h5("PASC_GSE263817/R_PASC/GSM8199629.h5")
CVD9.var_names_make_unique()
CVD9.obs['PatientID'] = "CVD9"
CVD9.obs["Sample type"] = "fresh BALF"
CVD9.obs['CoVID-19 severity'] = "R-PASC"
CVD9.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD6 = sc.read_10x_h5("PASC_GSE263817/Non_R_PASC/GSM8199623.h5")
CVD6.var_names_make_unique()
CVD6.obs['PatientID'] = "CVD6"
CVD6.obs["Sample type"] = "fresh BALF"
CVD6.obs['CoVID-19 severity'] = "Non-R-PASC"
CVD6.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD7 = sc.read_10x_h5("PASC_GSE263817/Non_R_PASC/GSM8199625.h5")
CVD7.var_names_make_unique()
CVD7.obs['PatientID'] = "CVD7"
CVD7.obs["Sample type"] = "fresh BALF"
CVD7.obs['CoVID-19 severity'] = "Non-R-PASC"
CVD7.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD10 = sc.read_10x_h5("PASC_GSE263817/Non_R_PASC/GSM8199631.h5")
CVD10.var_names_make_unique()
CVD10.obs['PatientID'] = "CVD10"
CVD10.obs["Sample type"] = "fresh BALF"
CVD10.obs['CoVID-19 severity'] = "Non-R-PASC"
CVD10.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CVD11 = sc.read_10x_h5("PASC_GSE263817/Non_R_PASC/GSM8199633.h5")
CVD11.var_names_make_unique()
CVD11.obs['PatientID'] = "CVD11"
CVD11.obs["Sample type"] = "fresh BALF"
CVD11.obs['CoVID-19 severity'] = "Non-R-PASC"
CVD11.obs['datasets'] = 'GSE263817'
# Out:
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/envs/the-project/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
GSE263817 = CON3.concatenate(CON4,CVD1,CVD2,CVD3,CVD8,CVD9,CVD6,CVD7,CVD10,CVD11)
# Out:
# /tmp/ipykernel_14714/1708088754.py:1: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   GSE263817 = CON3.concatenate(CON4,CVD1,CVD2,CVD3,CVD8,CVD9,CVD6,CVD7,CVD10,CVD11)

# %%
GSE263817
# Out:
# AnnData object with n_obs × n_vars = 73038 × 36601
#     obs: 'PatientID', 'Sample type', 'CoVID-19 severity', 'datasets', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
GSE263817.write_h5ad("GSE263817_freshBALF.h5ad")
