# %%
# %pwd
# %cd /home/jovyan/work/results/Cell/
# %pwd
# Out:
# /home/jovyan/work/results/Cell
# '/home/jovyan/work/results/Cell'

# %%
import pandas as pd
import numpy as np

# %%
deg_4S_I = pd.read_csv("deg_4S_I.csv", index_col=0)
deg_4S_III = pd.read_csv("deg_4S_III.csv", index_col=0)
deg_4S_IV = pd.read_csv("deg_4S_IV.csv", index_col=0)
deg_I_III = pd.read_csv("deg_I_III.csv", index_col=0)
deg_I_IV = pd.read_csv("deg_I_IV.csv", index_col=0)
deg_III_IV = pd.read_csv("deg_III_IV.csv", index_col=0)
deg_4S_I
# Out:
#          names      scores  logfoldchanges  pvals  pvals_adj
# 0      C5orf15  122.069374        0.987562    0.0        0.0
# 1        KCTD5  121.783590        1.083719    0.0        0.0
# 2      ATP6V1H  119.688840        0.772117    0.0        0.0
# 3       CHMP1B  116.934650        1.129777    0.0        0.0
# 4       NAP1L3  116.731514        1.156047    0.0        0.0
# ...        ...         ...             ...    ...        ...
# 12934     JUND -114.298230       -2.801515    0.0        0.0
# 12935     AVEN -115.296486       -1.543200    0.0        0.0
# 12936   SPTAN1 -115.965340       -1.196288    0.0        0.0
# 12937   DOPEY2 -116.143005       -1.135941    0.0        0.0
# 12938      CIC -117.197260       -0.959119    0.0        0.0
#
# [12939 rows x 5 columns]

# %%
up_deg_I_4S = deg_4S_I[(deg_4S_I['logfoldchanges'] < -1) & (deg_4S_I['pvals_adj'] < 0.05)]['names']
up_deg_I_4S.to_csv('up_deg_I_4S.txt', header=False, index=False)
up_deg_I_4S
# Out:
# 6332      CDC45
# 6353     COL9A1
# 6390     SLC7A8
# 7336      ESPL1
# 7974       E2F2
#           ...
# 12932     FOCAD
# 12934      JUND
# 12935      AVEN
# 12936    SPTAN1
# 12937    DOPEY2
# Name: names, Length: 437, dtype: object

# %%
up_deg_III_4S = deg_4S_III[(deg_4S_III['logfoldchanges'] < -1) & (deg_4S_III['pvals_adj'] < 0.05)]['names']
up_deg_III_4S.to_csv('up_deg_III_4S.txt', header=False, index=False)
up_deg_III_4S
# Out:
# 4516       PLK1
# 5171      CDCA3
# 5687     FAM83D
# 5912      CCNA2
# 6194      NDC80
#           ...
# 12934      COA4
# 12935      CHML
# 12936      SSR3
# 12937    CTHRC1
# 12938      NME2
# Name: names, Length: 928, dtype: object

# %%
up_deg_IV_4S = deg_4S_IV[(deg_4S_IV['logfoldchanges'] < -1) & (deg_4S_IV['pvals_adj'] < 0.05)]['names']
up_deg_IV_4S.to_csv('up_deg_IV_4S.txt', header=False, index=False)
up_deg_IV_4S
# Out:
# 6718       NYAP2
# 6915        NBAS
# 6986       KIF23
# 7329        MATK
# 7419      NUSAP1
#           ...
# 12930     ADGRL1
# 12932     ATP11C
# 12934       SBK1
# 12936    TMSB15A
# 12937    SLC27A5
# Name: names, Length: 468, dtype: object

# %%
up_deg_III_I = deg_I_III[(deg_I_III['logfoldchanges'] < -1) & (deg_I_III['pvals_adj'] < 0.05)]['names']
up_deg_III_I.to_csv('up_deg_III_I.txt', header=False, index=False)
up_deg_III_I
# Out:
# 5894        AURKA
# 6098        IFIT3
# 6647         PLK1
# 6658        IFIT1
# 6834         NEK2
#            ...
# 12934      CTHRC1
# 12935    SERPINF1
# 12936     SLC38A5
# 12937       DIMT1
# 12938       PTRH2
# Name: names, Length: 394, dtype: object

# %%
up_deg_IV_I = deg_I_IV[(deg_I_IV['logfoldchanges'] < -1) & (deg_I_IV['pvals_adj'] < 0.05)]['names']
up_deg_IV_I.to_csv('up_deg_IV_I.txt', header=False, index=False)
up_deg_IV_I
# Out:
# 6025       NYAP2
# 7727      PTGER2
# 8808      B3GNT4
# 9041       SYTL2
# 9119        MATK
#           ...
# 12933    ANAPC11
# 12935       NARF
# 12936      RPL39
# 12937    TMSB15A
# 12938      COX7B
# Name: names, Length: 335, dtype: object

# %%
up_deg_IV_III = deg_III_IV[(deg_III_IV['logfoldchanges'] < -1) & (deg_III_IV['pvals_adj'] < 0.05)]['names']
up_deg_IV_III.to_csv('up_deg_IV_III.txt', header=False, index=False)
up_deg_IV_III
# Out:
# 4524       NYAP2
# 5124      SLFN11
# 7247       BCL9L
# 7577       NTRK2
# 8052      IGFBP7
#           ...
# 12934      CEND1
# 12935     STRADB
# 12936     PGPEP1
# 12937     SYCE1L
# 12938    CCDC184
# Name: names, Length: 481, dtype: object
