# %%
import anndata 
import scanpy

# %%
adata = scanpy.read_h5ad('/home/yang2tseng/R/COVID19_ALL.h5ad')

# %%
BALF = adata[adata.obs["Sample type"] == "fresh BALF"]

# %%
BALF.write_h5ad("/hdd/edward/the-project/COVID/GSE158055_freshBALF.h5ad")
