# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS/')
from algorithm_comparison import file_to_float

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /hdd/edward/the-project/algorithm_comparison
# /hdd/edward/the-project/algorithm_comparison/Cell
# /hdd/edward/the-project/algorithm_comparison/Cell

# %% [markdown]
# KEGG

# %%
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_KEGG_correctly_assigned_ratio.txt")
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_KEGG_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = Binary_SWIM_knd_binary_correctly_assigned_ratio
data2 = Reciprocal_SWIM_knd_binary_correctly_assigned_ratio
data3 = Nlog_SWIM_knd_linear_correctly_assigned_ratio
data4 = Reciprocal_SWIM_knd_linear_correctly_assigned_ratio
data5 = Nlog_SWIM_knd_nlog_correctly_assigned_ratio
data6 = Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio
data7 = Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio
data8 = Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio
data9 = Binary_SWIM_knn_correctly_assigned_ratio
data10 = Reciprocal_SWIM_knn_correctly_assigned_ratio
data11 = hdWGCNA_correctly_assigned_ratio
data12 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('KEGG Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

plt.savefig("./figures/KEGG_correctly_assigned_genes_ratio_comparison_partial.svg")
# Show the plot
plt.show()

# %%
PCC_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Linear_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Linear_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Linear_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Linear_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knn_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
Linear_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
Nlog_SWIM_knn_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knn_KEGG_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_KEGG_correctly_assigned_ratio.txt")

# %%
PCC_Leiden_correctly_assigned_ratio = file_to_float(path="PCC_Leiden_KEGG_correctly_assigned_ratio.txt")

# %%
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_KEGG_correctly_assigned_ratio.txt")

# %%
# TOM_Leiden_correctly_assigned_ratio = file_to_float(path="TOM_Leiden_KEGG_correctly_assigned_ratio.txt")

# %%
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_KEGG_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_correctly_assigned_ratio, Binary_SWIM_knd_binary_correctly_assigned_ratio, Linear_SWIM_knd_binary_correctly_assigned_ratio, Nlog_SWIM_knd_binary_correctly_assigned_ratio, Reciprocal_SWIM_knd_binary_correctly_assigned_ratio]
data2 = [PCC_SWIM_knd_linear_correctly_assigned_ratio, Binary_SWIM_knd_linear_correctly_assigned_ratio, Linear_SWIM_knd_linear_correctly_assigned_ratio, Nlog_SWIM_knd_linear_correctly_assigned_ratio, Reciprocal_SWIM_knd_linear_correctly_assigned_ratio]
data3 = [PCC_SWIM_knd_nlog_correctly_assigned_ratio, Binary_SWIM_knd_nlog_correctly_assigned_ratio, Linear_SWIM_knd_nlog_correctly_assigned_ratio, Nlog_SWIM_knd_nlog_correctly_assigned_ratio, Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio]
data4 = [PCC_SWIM_knd_reciprocal_correctly_assigned_ratio, Binary_SWIM_knd_reciprocal_correctly_assigned_ratio, Linear_SWIM_knd_reciprocal_correctly_assigned_ratio, Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio, Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio]
data5 = [PCC_SWIM_knn_correctly_assigned_ratio, Binary_SWIM_knn_correctly_assigned_ratio, Linear_SWIM_knn_correctly_assigned_ratio, Nlog_SWIM_knn_correctly_assigned_ratio, Reciprocal_SWIM_knn_correctly_assigned_ratio]
data6 = PCC_Leiden_correctly_assigned_ratio
data7 = hdWGCNA_correctly_assigned_ratio
data8 = Hotspot_correctly_assigned_ratio
# data9 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('KEGG Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/KEGG_correctly_assigned_genes_ratio_comparison.svg")
# Show the plot
plt.show()

# %%
# Create a new figure for the legend
fig_legend = plt.figure(figsize=(4, 2))
plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]],
           ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn'], fontsize=12, loc='center')
plt.axis('off')  # Hide axes in the legend-only plot

# Save the legend as a separate image
plt.savefig('./figures/correctly_assigned_genes_ratio_comparison_legend.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# Reactome

# %%
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_Reactome_correctly_assigned_ratio.txt")
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_Reactome_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = Binary_SWIM_knd_binary_correctly_assigned_ratio
data2 = Reciprocal_SWIM_knd_binary_correctly_assigned_ratio
data3 = Nlog_SWIM_knd_linear_correctly_assigned_ratio
data4 = Reciprocal_SWIM_knd_linear_correctly_assigned_ratio
data5 = Nlog_SWIM_knd_nlog_correctly_assigned_ratio
data6 = Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio
data7 = Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio
data8 = Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio
data9 = Binary_SWIM_knn_correctly_assigned_ratio
data10 = Reciprocal_SWIM_knn_correctly_assigned_ratio
data11 = hdWGCNA_correctly_assigned_ratio
data12 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Reactome Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

plt.savefig("./figures/Reactome_correctly_assigned_genes_ratio_comparison_partial.svg")
# Show the plot
plt.show()

# %%
PCC_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Linear_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Linear_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Linear_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Linear_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knn_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
Linear_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
Nlog_SWIM_knn_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knn_Reactome_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_Reactome_correctly_assigned_ratio.txt")

# %%
PCC_Leiden_correctly_assigned_ratio = file_to_float(path="PCC_Leiden_Reactome_correctly_assigned_ratio.txt")

# %%
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_Reactome_correctly_assigned_ratio.txt")

# %%
# TOM_Leiden_correctly_assigned_ratio = file_to_float(path="TOM_Leiden_Reactome_correctly_assigned_ratio.txt")

# %%
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_Reactome_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_correctly_assigned_ratio, Binary_SWIM_knd_binary_correctly_assigned_ratio, Linear_SWIM_knd_binary_correctly_assigned_ratio, Nlog_SWIM_knd_binary_correctly_assigned_ratio, Reciprocal_SWIM_knd_binary_correctly_assigned_ratio]
data2 = [PCC_SWIM_knd_linear_correctly_assigned_ratio, Binary_SWIM_knd_linear_correctly_assigned_ratio, Linear_SWIM_knd_linear_correctly_assigned_ratio, Nlog_SWIM_knd_linear_correctly_assigned_ratio, Reciprocal_SWIM_knd_linear_correctly_assigned_ratio]
data3 = [PCC_SWIM_knd_nlog_correctly_assigned_ratio, Binary_SWIM_knd_nlog_correctly_assigned_ratio, Linear_SWIM_knd_nlog_correctly_assigned_ratio, Nlog_SWIM_knd_nlog_correctly_assigned_ratio, Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio]
data4 = [PCC_SWIM_knd_reciprocal_correctly_assigned_ratio, Binary_SWIM_knd_reciprocal_correctly_assigned_ratio, Linear_SWIM_knd_reciprocal_correctly_assigned_ratio, Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio, Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio]
data5 = [PCC_SWIM_knn_correctly_assigned_ratio, Binary_SWIM_knn_correctly_assigned_ratio, Linear_SWIM_knn_correctly_assigned_ratio, Nlog_SWIM_knn_correctly_assigned_ratio, Reciprocal_SWIM_knn_correctly_assigned_ratio]
data6 = PCC_Leiden_correctly_assigned_ratio
data7 = hdWGCNA_correctly_assigned_ratio
data8 = Hotspot_correctly_assigned_ratio
# data9 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('Reactome Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/Reactome_correctly_assigned_genes_ratio_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# BioPlex

# %%
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_BioPlex_correctly_assigned_ratio.txt")
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_BioPlex_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = Binary_SWIM_knd_binary_correctly_assigned_ratio
data2 = Reciprocal_SWIM_knd_binary_correctly_assigned_ratio
data3 = Nlog_SWIM_knd_linear_correctly_assigned_ratio
data4 = Reciprocal_SWIM_knd_linear_correctly_assigned_ratio
data5 = Nlog_SWIM_knd_nlog_correctly_assigned_ratio
data6 = Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio
data7 = Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio
data8 = Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio
data9 = Binary_SWIM_knn_correctly_assigned_ratio
data10 = Reciprocal_SWIM_knn_correctly_assigned_ratio
data11 = hdWGCNA_correctly_assigned_ratio
data12 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('BioPlex Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

plt.savefig("./figures/BioPlex_correctly_assigned_genes_ratio_comparison_partial.svg")
# Show the plot
plt.show()

# %%
PCC_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Linear_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Linear_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Linear_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Linear_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knn_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
Linear_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
Nlog_SWIM_knn_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_BioPlex_correctly_assigned_ratio.txt")

# %%
PCC_Leiden_correctly_assigned_ratio = file_to_float(path="PCC_Leiden_BioPlex_correctly_assigned_ratio.txt")

# %%
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_BioPlex_correctly_assigned_ratio.txt")

# %%
# TOM_Leiden_correctly_assigned_ratio = file_to_float(path="TOM_Leiden_BioPlex_correctly_assigned_ratio.txt")

# %%
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_BioPlex_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_correctly_assigned_ratio, Binary_SWIM_knd_binary_correctly_assigned_ratio, Linear_SWIM_knd_binary_correctly_assigned_ratio, Nlog_SWIM_knd_binary_correctly_assigned_ratio, Reciprocal_SWIM_knd_binary_correctly_assigned_ratio]
data2 = [PCC_SWIM_knd_linear_correctly_assigned_ratio, Binary_SWIM_knd_linear_correctly_assigned_ratio, Linear_SWIM_knd_linear_correctly_assigned_ratio, Nlog_SWIM_knd_linear_correctly_assigned_ratio, Reciprocal_SWIM_knd_linear_correctly_assigned_ratio]
data3 = [PCC_SWIM_knd_nlog_correctly_assigned_ratio, Binary_SWIM_knd_nlog_correctly_assigned_ratio, Linear_SWIM_knd_nlog_correctly_assigned_ratio, Nlog_SWIM_knd_nlog_correctly_assigned_ratio, Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio]
data4 = [PCC_SWIM_knd_reciprocal_correctly_assigned_ratio, Binary_SWIM_knd_reciprocal_correctly_assigned_ratio, Linear_SWIM_knd_reciprocal_correctly_assigned_ratio, Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio, Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio]
data5 = [PCC_SWIM_knn_correctly_assigned_ratio, Binary_SWIM_knn_correctly_assigned_ratio, Linear_SWIM_knn_correctly_assigned_ratio, Nlog_SWIM_knn_correctly_assigned_ratio, Reciprocal_SWIM_knn_correctly_assigned_ratio]
data6 = PCC_Leiden_correctly_assigned_ratio
data7 = hdWGCNA_correctly_assigned_ratio
data8 = Hotspot_correctly_assigned_ratio
# data9 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('BioPlex Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/BioPlex_correctly_assigned_genes_ratio_comparison.svg")
# Show the plot
plt.show()

# %% [markdown]
# WikiPathway

# %%
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_WikiPathway_correctly_assigned_ratio.txt")
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_WikiPathway_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = Binary_SWIM_knd_binary_correctly_assigned_ratio
data2 = Reciprocal_SWIM_knd_binary_correctly_assigned_ratio
data3 = Nlog_SWIM_knd_linear_correctly_assigned_ratio
data4 = Reciprocal_SWIM_knd_linear_correctly_assigned_ratio
data5 = Nlog_SWIM_knd_nlog_correctly_assigned_ratio
data6 = Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio
data7 = Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio
data8 = Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio
data9 = Binary_SWIM_knn_correctly_assigned_ratio
data10 = Reciprocal_SWIM_knn_correctly_assigned_ratio
data11 = hdWGCNA_correctly_assigned_ratio
data12 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.5, positions=[1], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.5, positions=[2], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.5, positions=[3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.5, positions=[4], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.5, positions=[5], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp6 = ax.boxplot(data6, widths=0.5, positions=[6], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.5, positions=[7], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.5, positions=[8], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp9 = ax.boxplot(data9, widths=0.5, positions=[9], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp10 = ax.boxplot(data10, widths=0.5, positions=[10], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp11 = ax.boxplot(data11, widths=0.5, positions=[11], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp12 = ax.boxplot(data12, widths=0.5, positions=[12], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['Binary_binary', 'Reciprocal_binary', 'Nlog_linear', 'Reciprocal_linear', 'Nlog_nlog', 'Reciprocal_nlog', 'Nlog_reciprocal', 'Reciprocal_reciprocal', 'Binary_knn', 'Reciprocal_knn', 'hdWGCNA', 'Hotspot']
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45, ha='right')  # ha='right' ensures the labels are aligned properly

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('WikiPathway Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

plt.savefig("./figures/WikiPathway_correctly_assigned_genes_ratio_comparison_partial.svg")
# Show the plot
plt.show()

# %%
PCC_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Linear_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_binary_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Linear_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_linear_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Linear_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Linear_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt")

# %%
PCC_SWIM_knn_correctly_assigned_ratio = file_to_float(path="PCC_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
Binary_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Binary_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
Linear_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Linear_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
Nlog_SWIM_knn_correctly_assigned_ratio = file_to_float(path="NLog_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")
Reciprocal_SWIM_knn_correctly_assigned_ratio = file_to_float(path="Reciprocal_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt")

# %%
PCC_Leiden_correctly_assigned_ratio = file_to_float(path="PCC_Leiden_WikiPathway_correctly_assigned_ratio.txt")

# %%
hdWGCNA_correctly_assigned_ratio = file_to_float(path="hdWGCNA_WikiPathway_correctly_assigned_ratio.txt")

# %%
# TOM_Leiden_correctly_assigned_ratio = file_to_float(path="TOM_Leiden_WikiPathway_correctly_assigned_ratio.txt")

# %%
Hotspot_correctly_assigned_ratio = file_to_float(path="Hotspot_WikiPathway_correctly_assigned_ratio.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = [PCC_SWIM_knd_binary_correctly_assigned_ratio, Binary_SWIM_knd_binary_correctly_assigned_ratio, Linear_SWIM_knd_binary_correctly_assigned_ratio, Nlog_SWIM_knd_binary_correctly_assigned_ratio, Reciprocal_SWIM_knd_binary_correctly_assigned_ratio]
data2 = [PCC_SWIM_knd_linear_correctly_assigned_ratio, Binary_SWIM_knd_linear_correctly_assigned_ratio, Linear_SWIM_knd_linear_correctly_assigned_ratio, Nlog_SWIM_knd_linear_correctly_assigned_ratio, Reciprocal_SWIM_knd_linear_correctly_assigned_ratio]
data3 = [PCC_SWIM_knd_nlog_correctly_assigned_ratio, Binary_SWIM_knd_nlog_correctly_assigned_ratio, Linear_SWIM_knd_nlog_correctly_assigned_ratio, Nlog_SWIM_knd_nlog_correctly_assigned_ratio, Reciprocal_SWIM_knd_nlog_correctly_assigned_ratio]
data4 = [PCC_SWIM_knd_reciprocal_correctly_assigned_ratio, Binary_SWIM_knd_reciprocal_correctly_assigned_ratio, Linear_SWIM_knd_reciprocal_correctly_assigned_ratio, Nlog_SWIM_knd_reciprocal_correctly_assigned_ratio, Reciprocal_SWIM_knd_reciprocal_correctly_assigned_ratio]
data5 = [PCC_SWIM_knn_correctly_assigned_ratio, Binary_SWIM_knn_correctly_assigned_ratio, Linear_SWIM_knn_correctly_assigned_ratio, Nlog_SWIM_knn_correctly_assigned_ratio, Reciprocal_SWIM_knn_correctly_assigned_ratio]
data6 = PCC_Leiden_correctly_assigned_ratio
data7 = hdWGCNA_correctly_assigned_ratio
data8 = Hotspot_correctly_assigned_ratio
# data9 = Hotspot_correctly_assigned_ratio

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Draw the first box plot
bp1 = ax.boxplot(data1, widths=0.15, positions=[1,3,5,7,9], patch_artist=True, boxprops={"facecolor": "red"}, medianprops={"color": "white"})
bp2 = ax.boxplot(data2, widths=0.15, positions=[1.3,3.3,5.3,7.3,9.3], patch_artist=True, boxprops={"facecolor": "green"}, medianprops={"color": "white"})
bp3 = ax.boxplot(data3, widths=0.15, positions=[1.6,3.6,5.6,7.6,9.6], patch_artist=True, boxprops={"facecolor": "orange"}, medianprops={"color": "white"})
bp4 = ax.boxplot(data4, widths=0.15, positions=[1.9,3.9,5.9,7.9,9.9], patch_artist=True, boxprops={"facecolor": "blue"}, medianprops={"color": "white"})
bp5 = ax.boxplot(data5, widths=0.15, positions=[2.2,4.2,6.2,8.2,10.2], patch_artist=True, boxprops={"facecolor": "yellow"}, medianprops={"color": "white"})
# Draw the second box plot
bp6 = ax.boxplot(data6, widths=0.15, positions=[11.6], patch_artist=True, boxprops={"facecolor": "purple"}, medianprops={"color": "white"})
bp7 = ax.boxplot(data7, widths=0.15, positions=[13.6], patch_artist=True, boxprops={"facecolor": "black"}, medianprops={"color": "white"})
bp8 = ax.boxplot(data8, widths=0.15, positions=[15.6], patch_artist=True, boxprops={"facecolor": "brown"}, medianprops={"color": "white"})
# bp9 = ax.boxplot(data9, widths=0.15, positions=[17.6], patch_artist=True, boxprops={"facecolor": "grey"}, medianprops={"color": "white"})

# Set custom text labels for the major ticks on the x-axis
custom_labels = ['PCC', 'Binary', 'Linear', 'Nlog', 'Reciprocal', 'Leiden', 'hdWGCNA', 'Hotspot']
ax.set_xticks([1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6])  # Set the positions of major ticks
ax.set_xticklabels(custom_labels)  # Set the labels for major ticks

# Increase font size of major tick labels
ax.tick_params(axis='both', which='major', labelsize=12)

ax.yaxis.grid(True)

# Add labels and title
ax.set_xlabel('Methods', fontsize=18)
ax.set_ylabel('WikiPathway Gene Hits Ratio', fontsize=18)
ax.set_title('Correctly Assigned Genes Ratio Comparison', fontsize=20)

# Add legend for categories
# plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], bp5["boxes"][0]], ['knd_binary', 'knd_linear', 'knd_nlog', 'knd_reciprocal', 'knn', 'PCC_Leiden', 'hdWGCNA'], fontsize=15)

plt.savefig("./figures/WikiPathway_correctly_assigned_genes_ratio_comparison.svg")
# Show the plot
plt.show()
