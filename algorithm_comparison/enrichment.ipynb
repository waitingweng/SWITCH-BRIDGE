# %%
import sys
sys.path.append('/hdd/edward/the-project/FUNCTIONS')
from methods import module_to_dict
from algorithm_comparison import enrichment, list_to_txt

# %%
# !pwd
# %cd Cell/
# !pwd
# Out:
# /hdd/edward/the-project/algorithm_comparison
# /hdd/edward/the-project/algorithm_comparison/Cell
# /hdd/edward/the-project/algorithm_comparison/Cell

# %% [markdown]
# Cell: create the background gene (12939) list

# %%
# import pandas as pd
# pcc_4S = pd.read_csv("/home/jovyan/work/results/Cell/pcc_4S.csv", index_col=0)
# # print(pcc_4S.shape)
# with open("background.txt", "w") as file:
#     for i in pcc_4S.index:
#         file.write(i + "\n")

# %%
# results = gseapy.enrichr(gene_list=module_4S["module_4S_175"], gene_sets="KEGG_2021_Human", background="background.txt", outdir=None)
# results.res2d['Adjusted P-value']

# %%
# import gseapy as gp
# # default: Human
# names = gp.get_library_name()
# print(len(names))
# names

# %%
total_genes = 12939

# %% [markdown]
# PCC-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_binary/Cell/module_IV_0.6.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 58, total modules: 132, enrichment_ratio: 0.4393939393939394
# correctly_assigned_genes: 7663, total genes: 12939, correctly_assigned_ratio: 0.5922405131772162
# pathways: 51, total modules: 111, enrichment_ratio: 0.4594594594594595
# correctly_assigned_genes: 7383, total genes: 12939, correctly_assigned_ratio: 0.5706005100857872
# pathways: 47, total modules: 95, enrichment_ratio: 0.49473684210526314
# correctly_assigned_genes: 8243, total genes: 12939, correctly_assigned_ratio: 0.6370662338666049
# pathways: 40, total modules: 105, enrichment_ratio: 0.38095238095238093
# correctly_assigned_genes: 6345, total genes: 12939, correctly_assigned_ratio: 0.49037792719684675

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 81, total modules: 132, enrichment_ratio: 0.6136363636363636
# correctly_assigned_genes: 5488, total genes: 12939, correctly_assigned_ratio: 0.42414406059200865
# pathways: 61, total modules: 111, enrichment_ratio: 0.5495495495495496
# correctly_assigned_genes: 5986, total genes: 12939, correctly_assigned_ratio: 0.4626323518046217
# pathways: 56, total modules: 95, enrichment_ratio: 0.5894736842105263
# correctly_assigned_genes: 5393, total genes: 12939, correctly_assigned_ratio: 0.4168019166859881
# pathways: 53, total modules: 105, enrichment_ratio: 0.5047619047619047
# correctly_assigned_genes: 5353, total genes: 12939, correctly_assigned_ratio: 0.4137104876729268

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 59, total modules: 132, enrichment_ratio: 0.44696969696969696
# correctly_assigned_genes: 5106, total genes: 12939, correctly_assigned_ratio: 0.39462091351727335
# pathways: 49, total modules: 111, enrichment_ratio: 0.44144144144144143
# correctly_assigned_genes: 5756, total genes: 12939, correctly_assigned_ratio: 0.44485663497951927
# pathways: 51, total modules: 95, enrichment_ratio: 0.5368421052631579
# correctly_assigned_genes: 6959, total genes: 12939, correctly_assigned_ratio: 0.5378313625473375
# pathways: 51, total modules: 105, enrichment_ratio: 0.4857142857142857
# correctly_assigned_genes: 5792, total genes: 12939, correctly_assigned_ratio: 0.44763892109127446

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_linear/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 51, total modules: 116, enrichment_ratio: 0.4396551724137931
# correctly_assigned_genes: 6486, total genes: 12939, correctly_assigned_ratio: 0.5012752144678878
# pathways: 49, total modules: 123, enrichment_ratio: 0.3983739837398374
# correctly_assigned_genes: 7281, total genes: 12939, correctly_assigned_ratio: 0.5627173661024809
# pathways: 46, total modules: 84, enrichment_ratio: 0.5476190476190477
# correctly_assigned_genes: 9156, total genes: 12939, correctly_assigned_ratio: 0.7076281010897287
# pathways: 27, total modules: 82, enrichment_ratio: 0.32926829268292684
# correctly_assigned_genes: 5666, total genes: 12939, correctly_assigned_ratio: 0.4379009197001314

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 71, total modules: 116, enrichment_ratio: 0.6120689655172413
# correctly_assigned_genes: 6178, total genes: 12939, correctly_assigned_ratio: 0.4774712110673159
# pathways: 67, total modules: 123, enrichment_ratio: 0.5447154471544715
# correctly_assigned_genes: 5576, total genes: 12939, correctly_assigned_ratio: 0.43094520442074347
# pathways: 46, total modules: 84, enrichment_ratio: 0.5476190476190477
# correctly_assigned_genes: 6226, total genes: 12939, correctly_assigned_ratio: 0.4811809258829894
# pathways: 45, total modules: 82, enrichment_ratio: 0.5487804878048781
# correctly_assigned_genes: 4455, total genes: 12939, correctly_assigned_ratio: 0.34430790632970093

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 52, total modules: 116, enrichment_ratio: 0.4482758620689655
# correctly_assigned_genes: 6254, total genes: 12939, correctly_assigned_ratio: 0.4833449261921323
# pathways: 52, total modules: 123, enrichment_ratio: 0.42276422764227645
# correctly_assigned_genes: 3890, total genes: 12939, correctly_assigned_ratio: 0.3006414715202102
# pathways: 40, total modules: 84, enrichment_ratio: 0.47619047619047616
# correctly_assigned_genes: 6065, total genes: 12939, correctly_assigned_ratio: 0.4687379241054177
# pathways: 43, total modules: 82, enrichment_ratio: 0.524390243902439
# correctly_assigned_genes: 6211, total genes: 12939, correctly_assigned_ratio: 0.48002164000309144

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_nlog/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 61, total modules: 128, enrichment_ratio: 0.4765625
# correctly_assigned_genes: 7623, total genes: 12939, correctly_assigned_ratio: 0.5891490841641549
# pathways: 46, total modules: 120, enrichment_ratio: 0.38333333333333336
# correctly_assigned_genes: 7518, total genes: 12939, correctly_assigned_ratio: 0.581034083004869
# pathways: 44, total modules: 84, enrichment_ratio: 0.5238095238095238
# correctly_assigned_genes: 7175, total genes: 12939, correctly_assigned_ratio: 0.5545250792178684
# pathways: 43, total modules: 98, enrichment_ratio: 0.4387755102040816
# correctly_assigned_genes: 6697, total genes: 12939, correctly_assigned_ratio: 0.5175825025117861

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 79, total modules: 128, enrichment_ratio: 0.6171875
# correctly_assigned_genes: 5858, total genes: 12939, correctly_assigned_ratio: 0.4527397789628256
# pathways: 60, total modules: 120, enrichment_ratio: 0.5
# correctly_assigned_genes: 5823, total genes: 12939, correctly_assigned_ratio: 0.45003477857639695
# pathways: 48, total modules: 84, enrichment_ratio: 0.5714285714285714
# correctly_assigned_genes: 7417, total genes: 12939, correctly_assigned_ratio: 0.5732282247468893
# pathways: 57, total modules: 98, enrichment_ratio: 0.5816326530612245
# correctly_assigned_genes: 4351, total genes: 12939, correctly_assigned_ratio: 0.33627019089574156

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 57, total modules: 128, enrichment_ratio: 0.4453125
# correctly_assigned_genes: 4695, total genes: 12939, correctly_assigned_ratio: 0.3628564804080686
# pathways: 44, total modules: 120, enrichment_ratio: 0.36666666666666664
# correctly_assigned_genes: 6348, total genes: 12939, correctly_assigned_ratio: 0.4906097843728263
# pathways: 43, total modules: 84, enrichment_ratio: 0.5119047619047619
# correctly_assigned_genes: 6321, total genes: 12939, correctly_assigned_ratio: 0.48852306978900994
# pathways: 50, total modules: 98, enrichment_ratio: 0.5102040816326531
# correctly_assigned_genes: 4226, total genes: 12939, correctly_assigned_ratio: 0.326609475229925

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 59, total modules: 124, enrichment_ratio: 0.47580645161290325
# correctly_assigned_genes: 7533, total genes: 12939, correctly_assigned_ratio: 0.582193368884767
# pathways: 42, total modules: 112, enrichment_ratio: 0.375
# correctly_assigned_genes: 7451, total genes: 12939, correctly_assigned_ratio: 0.5758559394079913
# pathways: 50, total modules: 84, enrichment_ratio: 0.5952380952380952
# correctly_assigned_genes: 9900, total genes: 12939, correctly_assigned_ratio: 0.7651286807326687
# pathways: 36, total modules: 85, enrichment_ratio: 0.4235294117647059
# correctly_assigned_genes: 6875, total genes: 12939, correctly_assigned_ratio: 0.5313393616199088

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 77, total modules: 124, enrichment_ratio: 0.6209677419354839
# correctly_assigned_genes: 6056, total genes: 12939, correctly_assigned_ratio: 0.46804235257747895
# pathways: 53, total modules: 112, enrichment_ratio: 0.4732142857142857
# correctly_assigned_genes: 5867, total genes: 12939, correctly_assigned_ratio: 0.45343535049076433
# pathways: 53, total modules: 84, enrichment_ratio: 0.6309523809523809
# correctly_assigned_genes: 8455, total genes: 12939, correctly_assigned_ratio: 0.6534508076358296
# pathways: 47, total modules: 85, enrichment_ratio: 0.5529411764705883
# correctly_assigned_genes: 5722, total genes: 12939, correctly_assigned_ratio: 0.4422289203184172

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 58, total modules: 124, enrichment_ratio: 0.46774193548387094
# correctly_assigned_genes: 5236, total genes: 12939, correctly_assigned_ratio: 0.40466805780972254
# pathways: 48, total modules: 112, enrichment_ratio: 0.42857142857142855
# correctly_assigned_genes: 6870, total genes: 12939, correctly_assigned_ratio: 0.5309529329932762
# pathways: 47, total modules: 84, enrichment_ratio: 0.5595238095238095
# correctly_assigned_genes: 7871, total genes: 12939, correctly_assigned_ratio: 0.6083159440451349
# pathways: 38, total modules: 85, enrichment_ratio: 0.4470588235294118
# correctly_assigned_genes: 7157, total genes: 12939, correctly_assigned_ratio: 0.5531339361619909

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_SWIM/knn/Cell/module_IV_10.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 56, total modules: 134, enrichment_ratio: 0.417910447761194
# correctly_assigned_genes: 5663, total genes: 12939, correctly_assigned_ratio: 0.4376690625241518
# pathways: 48, total modules: 138, enrichment_ratio: 0.34782608695652173
# correctly_assigned_genes: 4612, total genes: 12939, correctly_assigned_ratio: 0.35644176520596643
# pathways: 50, total modules: 131, enrichment_ratio: 0.3816793893129771
# correctly_assigned_genes: 5394, total genes: 12939, correctly_assigned_ratio: 0.41687920241131465
# pathways: 42, total modules: 135, enrichment_ratio: 0.3111111111111111
# correctly_assigned_genes: 4200, total genes: 12939, correctly_assigned_ratio: 0.3246000463714352

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 41, total modules: 134, enrichment_ratio: 0.30597014925373134
# correctly_assigned_genes: 3940, total genes: 12939, correctly_assigned_ratio: 0.3045057577865368
# pathways: 45, total modules: 138, enrichment_ratio: 0.32608695652173914
# correctly_assigned_genes: 4314, total genes: 12939, correctly_assigned_ratio: 0.3334106190586599
# pathways: 36, total modules: 131, enrichment_ratio: 0.2748091603053435
# correctly_assigned_genes: 3694, total genes: 12939, correctly_assigned_ratio: 0.2854934693562099
# pathways: 42, total modules: 135, enrichment_ratio: 0.3111111111111111
# correctly_assigned_genes: 4033, total genes: 12939, correctly_assigned_ratio: 0.3116933302419043

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_SWIM_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 40, total modules: 134, enrichment_ratio: 0.29850746268656714
# correctly_assigned_genes: 3836, total genes: 12939, correctly_assigned_ratio: 0.29646804235257745
# pathways: 45, total modules: 138, enrichment_ratio: 0.32608695652173914
# correctly_assigned_genes: 4469, total genes: 12939, correctly_assigned_ratio: 0.34538990648427237
# pathways: 41, total modules: 131, enrichment_ratio: 0.31297709923664124
# correctly_assigned_genes: 4310, total genes: 12939, correctly_assigned_ratio: 0.33310147615735375
# pathways: 43, total modules: 135, enrichment_ratio: 0.31851851851851853
# correctly_assigned_genes: 4318, total genes: 12939, correctly_assigned_ratio: 0.333719761959966

# %% [markdown]
# Binary-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_binary/Cell/module_IV_0.7.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 54, total modules: 119, enrichment_ratio: 0.453781512605042
# correctly_assigned_genes: 8576, total genes: 12939, correctly_assigned_ratio: 0.66280238040034
# pathways: 59, total modules: 137, enrichment_ratio: 0.4306569343065693
# correctly_assigned_genes: 7487, total genes: 12939, correctly_assigned_ratio: 0.5786382255197465
# pathways: 43, total modules: 119, enrichment_ratio: 0.36134453781512604
# correctly_assigned_genes: 9043, total genes: 12939, correctly_assigned_ratio: 0.6988948141278306
# pathways: 62, total modules: 134, enrichment_ratio: 0.4626865671641791
# correctly_assigned_genes: 7711, total genes: 12939, correctly_assigned_ratio: 0.5959502279928897

# %%
o_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 83, total modules: 119, enrichment_ratio: 0.6974789915966386
# correctly_assigned_genes: 5902, total genes: 12939, correctly_assigned_ratio: 0.45614035087719296
# pathways: 87, total modules: 137, enrichment_ratio: 0.635036496350365
# correctly_assigned_genes: 6342, total genes: 12939, correctly_assigned_ratio: 0.49014607002086713
# pathways: 82, total modules: 119, enrichment_ratio: 0.6890756302521008
# correctly_assigned_genes: 5587, total genes: 12939, correctly_assigned_ratio: 0.43179534739933534
# pathways: 91, total modules: 134, enrichment_ratio: 0.6791044776119403
# correctly_assigned_genes: 6444, total genes: 12939, correctly_assigned_ratio: 0.49802921400417344

# %%
o_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 70, total modules: 119, enrichment_ratio: 0.5882352941176471
# correctly_assigned_genes: 7263, total genes: 12939, correctly_assigned_ratio: 0.5613262230466033
# pathways: 78, total modules: 137, enrichment_ratio: 0.5693430656934306
# correctly_assigned_genes: 7223, total genes: 12939, correctly_assigned_ratio: 0.558234794033542
# pathways: 57, total modules: 119, enrichment_ratio: 0.4789915966386555
# correctly_assigned_genes: 8346, total genes: 12939, correctly_assigned_ratio: 0.6450266635752376
# pathways: 75, total modules: 134, enrichment_ratio: 0.5597014925373134
# correctly_assigned_genes: 7712, total genes: 12939, correctly_assigned_ratio: 0.5960275137182163

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_linear/Cell/module_IV_0.3.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 57, total modules: 128, enrichment_ratio: 0.4453125
# correctly_assigned_genes: 6876, total genes: 12939, correctly_assigned_ratio: 0.5314166473452353
# pathways: 86, total modules: 202, enrichment_ratio: 0.42574257425742573
# correctly_assigned_genes: 8169, total genes: 12939, correctly_assigned_ratio: 0.6313470901924415
# pathways: 78, total modules: 168, enrichment_ratio: 0.4642857142857143
# correctly_assigned_genes: 9487, total genes: 12939, correctly_assigned_ratio: 0.7332096761728109
# pathways: 53, total modules: 117, enrichment_ratio: 0.452991452991453
# correctly_assigned_genes: 7894, total genes: 12939, correctly_assigned_ratio: 0.6100935157276451

# %%
ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 91, total modules: 128, enrichment_ratio: 0.7109375
# correctly_assigned_genes: 7479, total genes: 12939, correctly_assigned_ratio: 0.5780199397171343
# pathways: 149, total modules: 202, enrichment_ratio: 0.7376237623762376
# correctly_assigned_genes: 7289, total genes: 12939, correctly_assigned_ratio: 0.5633356519050932
# pathways: 115, total modules: 168, enrichment_ratio: 0.6845238095238095
# correctly_assigned_genes: 5396, total genes: 12939, correctly_assigned_ratio: 0.4170337738619677
# pathways: 78, total modules: 117, enrichment_ratio: 0.6666666666666666
# correctly_assigned_genes: 6392, total genes: 12939, correctly_assigned_ratio: 0.49401035628719375

# %%
ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 69, total modules: 128, enrichment_ratio: 0.5390625
# correctly_assigned_genes: 6576, total genes: 12939, correctly_assigned_ratio: 0.5082309297472757
# pathways: 112, total modules: 202, enrichment_ratio: 0.5544554455445545
# correctly_assigned_genes: 7492, total genes: 12939, correctly_assigned_ratio: 0.5790246541463792
# pathways: 92, total modules: 168, enrichment_ratio: 0.5476190476190477
# correctly_assigned_genes: 8489, total genes: 12939, correctly_assigned_ratio: 0.6560785222969318
# pathways: 63, total modules: 117, enrichment_ratio: 0.5384615384615384
# correctly_assigned_genes: 7150, total genes: 12939, correctly_assigned_ratio: 0.5525929360847052

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_4S_0.3.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_I_0.3.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_III_0.3.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_nlog/Cell/module_IV_0.3.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 43, total modules: 101, enrichment_ratio: 0.42574257425742573
# correctly_assigned_genes: 8359, total genes: 12939, correctly_assigned_ratio: 0.6460313780044826
# pathways: 84, total modules: 177, enrichment_ratio: 0.4745762711864407
# correctly_assigned_genes: 7557, total genes: 12939, correctly_assigned_ratio: 0.5840482262926038
# pathways: 58, total modules: 136, enrichment_ratio: 0.4264705882352941
# correctly_assigned_genes: 9458, total genes: 12939, correctly_assigned_ratio: 0.7309683901383415
# pathways: 46, total modules: 92, enrichment_ratio: 0.5
# correctly_assigned_genes: 8822, total genes: 12939, correctly_assigned_ratio: 0.681814668830667

# %%
atio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 71, total modules: 101, enrichment_ratio: 0.7029702970297029
# correctly_assigned_genes: 7327, total genes: 12939, correctly_assigned_ratio: 0.5662725094675014
# pathways: 129, total modules: 177, enrichment_ratio: 0.7288135593220338
# correctly_assigned_genes: 8039, total genes: 12939, correctly_assigned_ratio: 0.6212999458999923
# pathways: 92, total modules: 136, enrichment_ratio: 0.6764705882352942
# correctly_assigned_genes: 5780, total genes: 12939, correctly_assigned_ratio: 0.4467114923873561
# pathways: 58, total modules: 92, enrichment_ratio: 0.6304347826086957
# correctly_assigned_genes: 5725, total genes: 12939, correctly_assigned_ratio: 0.4424607774943968

# %%
atio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 48, total modules: 101, enrichment_ratio: 0.4752475247524752
# correctly_assigned_genes: 5218, total genes: 12939, correctly_assigned_ratio: 0.403276914753845
# pathways: 95, total modules: 177, enrichment_ratio: 0.536723163841808
# correctly_assigned_genes: 7557, total genes: 12939, correctly_assigned_ratio: 0.5840482262926038
# pathways: 68, total modules: 136, enrichment_ratio: 0.5
# correctly_assigned_genes: 8098, total genes: 12939, correctly_assigned_ratio: 0.6258598036942576
# pathways: 48, total modules: 92, enrichment_ratio: 0.5217391304347826
# correctly_assigned_genes: 7766, total genes: 12939, correctly_assigned_ratio: 0.600200942885849

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knd_reciprocal/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 50, total modules: 123, enrichment_ratio: 0.4065040650406504
# correctly_assigned_genes: 7548, total genes: 12939, correctly_assigned_ratio: 0.5833526547646649
# pathways: 91, total modules: 209, enrichment_ratio: 0.4354066985645933
# correctly_assigned_genes: 7954, total genes: 12939, correctly_assigned_ratio: 0.614730659247237
# pathways: 82, total modules: 171, enrichment_ratio: 0.47953216374269003
# correctly_assigned_genes: 9295, total genes: 12939, correctly_assigned_ratio: 0.7183708169101167
# pathways: 55, total modules: 120, enrichment_ratio: 0.4583333333333333
# correctly_assigned_genes: 8024, total genes: 12939, correctly_assigned_ratio: 0.6201406600200943

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 88, total modules: 123, enrichment_ratio: 0.7154471544715447
# correctly_assigned_genes: 6118, total genes: 12939, correctly_assigned_ratio: 0.47283406754772395
# pathways: 160, total modules: 209, enrichment_ratio: 0.7655502392344498
# correctly_assigned_genes: 7616, total genes: 12939, correctly_assigned_ratio: 0.5886080840868692
# pathways: 122, total modules: 171, enrichment_ratio: 0.7134502923976608
# correctly_assigned_genes: 5691, total genes: 12939, correctly_assigned_ratio: 0.4398330628332947
# pathways: 79, total modules: 120, enrichment_ratio: 0.6583333333333333
# correctly_assigned_genes: 6805, total genes: 12939, correctly_assigned_ratio: 0.5259293608470516

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 66, total modules: 123, enrichment_ratio: 0.5365853658536586
# correctly_assigned_genes: 5316, total genes: 12939, correctly_assigned_ratio: 0.4108509158358451
# pathways: 114, total modules: 209, enrichment_ratio: 0.5454545454545454
# correctly_assigned_genes: 7478, total genes: 12939, correctly_assigned_ratio: 0.5779426539918077
# pathways: 91, total modules: 171, enrichment_ratio: 0.5321637426900585
# correctly_assigned_genes: 8519, total genes: 12939, correctly_assigned_ratio: 0.6583970940567277
# pathways: 73, total modules: 120, enrichment_ratio: 0.6083333333333333
# correctly_assigned_genes: 7693, total genes: 12939, correctly_assigned_ratio: 0.5945590849370122

# %%
module_4S = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Binary_SWIM/knn/Cell/module_IV_10.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 44, total modules: 124, enrichment_ratio: 0.3548387096774194
# correctly_assigned_genes: 4546, total genes: 12939, correctly_assigned_ratio: 0.3513409073344153
# pathways: 48, total modules: 124, enrichment_ratio: 0.3870967741935484
# correctly_assigned_genes: 5131, total genes: 12939, correctly_assigned_ratio: 0.39655305665043666
# pathways: 49, total modules: 129, enrichment_ratio: 0.3798449612403101
# correctly_assigned_genes: 5141, total genes: 12939, correctly_assigned_ratio: 0.397325913903702
# pathways: 47, total modules: 128, enrichment_ratio: 0.3671875
# correctly_assigned_genes: 4787, total genes: 12939, correctly_assigned_ratio: 0.3699667671381096

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 31, total modules: 124, enrichment_ratio: 0.25
# correctly_assigned_genes: 2948, total genes: 12939, correctly_assigned_ratio: 0.22783831826261688
# pathways: 42, total modules: 124, enrichment_ratio: 0.3387096774193548
# correctly_assigned_genes: 4256, total genes: 12939, correctly_assigned_ratio: 0.328928046989721
# pathways: 33, total modules: 129, enrichment_ratio: 0.2558139534883721
# correctly_assigned_genes: 3487, total genes: 12939, correctly_assigned_ratio: 0.26949532421361777
# pathways: 48, total modules: 128, enrichment_ratio: 0.375
# correctly_assigned_genes: 4561, total genes: 12939, correctly_assigned_ratio: 0.3525001932143133

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Binary_SWIM_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Binary_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 33, total modules: 124, enrichment_ratio: 0.2661290322580645
# correctly_assigned_genes: 3097, total genes: 12939, correctly_assigned_ratio: 0.2393538913362702
# pathways: 39, total modules: 124, enrichment_ratio: 0.31451612903225806
# correctly_assigned_genes: 4201, total genes: 12939, correctly_assigned_ratio: 0.32467733209676175
# pathways: 42, total modules: 129, enrichment_ratio: 0.32558139534883723
# correctly_assigned_genes: 4536, total genes: 12939, correctly_assigned_ratio: 0.35056805008115
# pathways: 40, total modules: 128, enrichment_ratio: 0.3125
# correctly_assigned_genes: 4066, total genes: 12939, correctly_assigned_ratio: 0.3142437591776799

# %% [markdown]
# Linear-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_binary/Cell/module_IV_0.7.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 46, total modules: 114, enrichment_ratio: 0.40350877192982454
# correctly_assigned_genes: 8225, total genes: 12939, correctly_assigned_ratio: 0.6356750908107273
# pathways: 57, total modules: 128, enrichment_ratio: 0.4453125
# correctly_assigned_genes: 7314, total genes: 12939, correctly_assigned_ratio: 0.5652677950382564
# pathways: 39, total modules: 113, enrichment_ratio: 0.34513274336283184
# correctly_assigned_genes: 8328, total genes: 12939, correctly_assigned_ratio: 0.6436355205193601
# pathways: 58, total modules: 120, enrichment_ratio: 0.48333333333333334
# correctly_assigned_genes: 8734, total genes: 12939, correctly_assigned_ratio: 0.6750135250019321

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 80, total modules: 114, enrichment_ratio: 0.7017543859649122
# correctly_assigned_genes: 7586, total genes: 12939, correctly_assigned_ratio: 0.5862895123270732
# pathways: 80, total modules: 128, enrichment_ratio: 0.625
# correctly_assigned_genes: 7226, total genes: 12939, correctly_assigned_ratio: 0.5584666512095215
# pathways: 69, total modules: 113, enrichment_ratio: 0.6106194690265486
# correctly_assigned_genes: 3960, total genes: 12939, correctly_assigned_ratio: 0.30605147229306745
# pathways: 73, total modules: 120, enrichment_ratio: 0.6083333333333333
# correctly_assigned_genes: 6440, total genes: 12939, correctly_assigned_ratio: 0.4977200711028673

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 53, total modules: 114, enrichment_ratio: 0.4649122807017544
# correctly_assigned_genes: 6178, total genes: 12939, correctly_assigned_ratio: 0.4774712110673159
# pathways: 68, total modules: 128, enrichment_ratio: 0.53125
# correctly_assigned_genes: 6151, total genes: 12939, correctly_assigned_ratio: 0.4753844964834995
# pathways: 57, total modules: 113, enrichment_ratio: 0.504424778761062
# correctly_assigned_genes: 7910, total genes: 12939, correctly_assigned_ratio: 0.6113300873328696
# pathways: 67, total modules: 120, enrichment_ratio: 0.5583333333333333
# correctly_assigned_genes: 7616, total genes: 12939, correctly_assigned_ratio: 0.5886080840868692

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_linear/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 65, total modules: 135, enrichment_ratio: 0.48148148148148145
# correctly_assigned_genes: 7824, total genes: 12939, correctly_assigned_ratio: 0.6046835149547879
# pathways: 92, total modules: 202, enrichment_ratio: 0.45544554455445546
# correctly_assigned_genes: 8232, total genes: 12939, correctly_assigned_ratio: 0.636216090888013
# pathways: 62, total modules: 154, enrichment_ratio: 0.4025974025974026
# correctly_assigned_genes: 8689, total genes: 12939, correctly_assigned_ratio: 0.6715356673622382
# pathways: 55, total modules: 122, enrichment_ratio: 0.45081967213114754
# correctly_assigned_genes: 7740, total genes: 12939, correctly_assigned_ratio: 0.5981915140273592

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 96, total modules: 135, enrichment_ratio: 0.7111111111111111
# correctly_assigned_genes: 5195, total genes: 12939, correctly_assigned_ratio: 0.4014993430713347
# pathways: 150, total modules: 202, enrichment_ratio: 0.7425742574257426
# correctly_assigned_genes: 6957, total genes: 12939, correctly_assigned_ratio: 0.5376767910966844
# pathways: 110, total modules: 154, enrichment_ratio: 0.7142857142857143
# correctly_assigned_genes: 5540, total genes: 12939, correctly_assigned_ratio: 0.42816291830898834
# pathways: 78, total modules: 122, enrichment_ratio: 0.639344262295082
# correctly_assigned_genes: 7528, total genes: 12939, correctly_assigned_ratio: 0.5818069402581343

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 72, total modules: 135, enrichment_ratio: 0.5333333333333333
# correctly_assigned_genes: 5998, total genes: 12939, correctly_assigned_ratio: 0.4635597805085401
# pathways: 114, total modules: 202, enrichment_ratio: 0.5643564356435643
# correctly_assigned_genes: 6734, total genes: 12939, correctly_assigned_ratio: 0.5204420743488678
# pathways: 88, total modules: 154, enrichment_ratio: 0.5714285714285714
# correctly_assigned_genes: 8286, total genes: 12939, correctly_assigned_ratio: 0.6403895200556458
# pathways: 64, total modules: 122, enrichment_ratio: 0.5245901639344263
# correctly_assigned_genes: 7600, total genes: 12939, correctly_assigned_ratio: 0.5873715124816447

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_nlog/Cell/module_IV_0.4.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 48, total modules: 109, enrichment_ratio: 0.44036697247706424
# correctly_assigned_genes: 7846, total genes: 12939, correctly_assigned_ratio: 0.6063838009119715
# pathways: 76, total modules: 178, enrichment_ratio: 0.42696629213483145
# correctly_assigned_genes: 8308, total genes: 12939, correctly_assigned_ratio: 0.6420898060128294
# pathways: 48, total modules: 131, enrichment_ratio: 0.366412213740458
# correctly_assigned_genes: 8737, total genes: 12939, correctly_assigned_ratio: 0.6752453821779117
# pathways: 56, total modules: 108, enrichment_ratio: 0.5185185185185185
# correctly_assigned_genes: 8329, total genes: 12939, correctly_assigned_ratio: 0.6437128062446866

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 75, total modules: 109, enrichment_ratio: 0.6880733944954128
# correctly_assigned_genes: 5671, total genes: 12939, correctly_assigned_ratio: 0.438287348326764
# pathways: 129, total modules: 178, enrichment_ratio: 0.7247191011235955
# correctly_assigned_genes: 7162, total genes: 12939, correctly_assigned_ratio: 0.5535203647886235
# pathways: 82, total modules: 131, enrichment_ratio: 0.6259541984732825
# correctly_assigned_genes: 4892, total genes: 12939, correctly_assigned_ratio: 0.3780817682973955
# pathways: 73, total modules: 108, enrichment_ratio: 0.6759259259259259
# correctly_assigned_genes: 7191, total genes: 12939, correctly_assigned_ratio: 0.5557616508230929

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 58, total modules: 109, enrichment_ratio: 0.5321100917431193
# correctly_assigned_genes: 5339, total genes: 12939, correctly_assigned_ratio: 0.41262848751835535
# pathways: 100, total modules: 178, enrichment_ratio: 0.5617977528089888
# correctly_assigned_genes: 7528, total genes: 12939, correctly_assigned_ratio: 0.5818069402581343
# pathways: 71, total modules: 131, enrichment_ratio: 0.5419847328244275
# correctly_assigned_genes: 8091, total genes: 12939, correctly_assigned_ratio: 0.6253188036169719
# pathways: 64, total modules: 108, enrichment_ratio: 0.5925925925925926
# correctly_assigned_genes: 7510, total genes: 12939, correctly_assigned_ratio: 0.5804157972022568

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_4S_0.5.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_I_0.5.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_III_0.5.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knd_reciprocal/Cell/module_IV_0.5.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 58, total modules: 112, enrichment_ratio: 0.5178571428571429
# correctly_assigned_genes: 8590, total genes: 12939, correctly_assigned_ratio: 0.6638843805549115
# pathways: 65, total modules: 167, enrichment_ratio: 0.38922155688622756
# correctly_assigned_genes: 7700, total genes: 12939, correctly_assigned_ratio: 0.5951000850142979
# pathways: 55, total modules: 130, enrichment_ratio: 0.4230769230769231
# correctly_assigned_genes: 8325, total genes: 12939, correctly_assigned_ratio: 0.6434036633433805
# pathways: 49, total modules: 104, enrichment_ratio: 0.47115384615384615
# correctly_assigned_genes: 8569, total genes: 12939, correctly_assigned_ratio: 0.6622613803230544

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 82, total modules: 112, enrichment_ratio: 0.7321428571428571
# correctly_assigned_genes: 7193, total genes: 12939, correctly_assigned_ratio: 0.555916222273746
# pathways: 127, total modules: 167, enrichment_ratio: 0.7604790419161677
# correctly_assigned_genes: 7243, total genes: 12939, correctly_assigned_ratio: 0.5597805085400727
# pathways: 82, total modules: 130, enrichment_ratio: 0.6307692307692307
# correctly_assigned_genes: 4178, total genes: 12939, correctly_assigned_ratio: 0.3228997604142515
# pathways: 67, total modules: 104, enrichment_ratio: 0.6442307692307693
# correctly_assigned_genes: 5669, total genes: 12939, correctly_assigned_ratio: 0.43813277687611096

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 59, total modules: 112, enrichment_ratio: 0.5267857142857143
# correctly_assigned_genes: 6765, total genes: 12939, correctly_assigned_ratio: 0.5228379318339903
# pathways: 95, total modules: 167, enrichment_ratio: 0.5688622754491018
# correctly_assigned_genes: 7602, total genes: 12939, correctly_assigned_ratio: 0.5875260839322977
# pathways: 70, total modules: 130, enrichment_ratio: 0.5384615384615384
# correctly_assigned_genes: 8257, total genes: 12939, correctly_assigned_ratio: 0.6381482340211763
# pathways: 56, total modules: 104, enrichment_ratio: 0.5384615384615384
# correctly_assigned_genes: 7643, total genes: 12939, correctly_assigned_ratio: 0.5906947986706855

# %%
module_4S = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Linear_SWIM/knn/Cell/module_IV_10.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 39, total modules: 125, enrichment_ratio: 0.312
# correctly_assigned_genes: 4154, total genes: 12939, correctly_assigned_ratio: 0.3210449030064147
# pathways: 55, total modules: 126, enrichment_ratio: 0.4365079365079365
# correctly_assigned_genes: 5502, total genes: 12939, correctly_assigned_ratio: 0.4252260607465801
# pathways: 49, total modules: 127, enrichment_ratio: 0.3858267716535433
# correctly_assigned_genes: 5371, total genes: 12939, correctly_assigned_ratio: 0.4151016307288044
# pathways: 47, total modules: 137, enrichment_ratio: 0.34306569343065696
# correctly_assigned_genes: 4405, total genes: 12939, correctly_assigned_ratio: 0.3404436200633743

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 40, total modules: 125, enrichment_ratio: 0.32
# correctly_assigned_genes: 4015, total genes: 12939, correctly_assigned_ratio: 0.31030218718602676
# pathways: 38, total modules: 126, enrichment_ratio: 0.30158730158730157
# correctly_assigned_genes: 4049, total genes: 12939, correctly_assigned_ratio: 0.3129299018471288
# pathways: 42, total modules: 127, enrichment_ratio: 0.33070866141732286
# correctly_assigned_genes: 4467, total genes: 12939, correctly_assigned_ratio: 0.3452353350336193
# pathways: 40, total modules: 137, enrichment_ratio: 0.291970802919708
# correctly_assigned_genes: 3514, total genes: 12939, correctly_assigned_ratio: 0.2715820387974341

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Linear_SWIM_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Linear_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 34, total modules: 125, enrichment_ratio: 0.272
# correctly_assigned_genes: 3714, total genes: 12939, correctly_assigned_ratio: 0.2870391838627406
# pathways: 51, total modules: 126, enrichment_ratio: 0.40476190476190477
# correctly_assigned_genes: 5185, total genes: 12939, correctly_assigned_ratio: 0.4007264858180694
# pathways: 44, total modules: 127, enrichment_ratio: 0.3464566929133858
# correctly_assigned_genes: 4632, total genes: 12939, correctly_assigned_ratio: 0.3579874797124971
# pathways: 47, total modules: 137, enrichment_ratio: 0.34306569343065696
# correctly_assigned_genes: 4471, total genes: 12939, correctly_assigned_ratio: 0.34554447793492543

# %% [markdown]
# Nlog_SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_binary/Cell/module_IV_0.7.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 51, total modules: 121, enrichment_ratio: 0.4214876033057851
# correctly_assigned_genes: 8088, total genes: 12939, correctly_assigned_ratio: 0.6250869464409924
# pathways: 65, total modules: 151, enrichment_ratio: 0.4304635761589404
# correctly_assigned_genes: 6200, total genes: 12939, correctly_assigned_ratio: 0.47917149702449957
# pathways: 52, total modules: 148, enrichment_ratio: 0.35135135135135137
# correctly_assigned_genes: 7829, total genes: 12939, correctly_assigned_ratio: 0.6050699435814205
# pathways: 64, total modules: 141, enrichment_ratio: 0.45390070921985815
# correctly_assigned_genes: 7109, total genes: 12939, correctly_assigned_ratio: 0.5494242213463173

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 81, total modules: 121, enrichment_ratio: 0.6694214876033058
# correctly_assigned_genes: 6432, total genes: 12939, correctly_assigned_ratio: 0.49710178530025506
# pathways: 109, total modules: 151, enrichment_ratio: 0.7218543046357616
# correctly_assigned_genes: 6352, total genes: 12939, correctly_assigned_ratio: 0.49091892727413244
# pathways: 98, total modules: 148, enrichment_ratio: 0.6621621621621622
# correctly_assigned_genes: 6990, total genes: 12939, correctly_assigned_ratio: 0.54022722003246
# pathways: 87, total modules: 141, enrichment_ratio: 0.6170212765957447
# correctly_assigned_genes: 5626, total genes: 12939, correctly_assigned_ratio: 0.4348094906870701

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 62, total modules: 121, enrichment_ratio: 0.512396694214876
# correctly_assigned_genes: 8276, total genes: 12939, correctly_assigned_ratio: 0.6396166628023804
# pathways: 76, total modules: 151, enrichment_ratio: 0.5033112582781457
# correctly_assigned_genes: 5680, total genes: 12939, correctly_assigned_ratio: 0.43898291985470284
# pathways: 83, total modules: 148, enrichment_ratio: 0.5608108108108109
# correctly_assigned_genes: 7810, total genes: 12939, correctly_assigned_ratio: 0.6036015148002164
# pathways: 72, total modules: 141, enrichment_ratio: 0.5106382978723404
# correctly_assigned_genes: 7662, total genes: 12939, correctly_assigned_ratio: 0.5921632274518897

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_linear/Cell/module_IV_0.4.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 39, total modules: 101, enrichment_ratio: 0.38613861386138615
# correctly_assigned_genes: 8703, total genes: 12939, correctly_assigned_ratio: 0.6726176675168096
# pathways: 50, total modules: 112, enrichment_ratio: 0.44642857142857145
# correctly_assigned_genes: 7727, total genes: 12939, correctly_assigned_ratio: 0.5971867995981143
# pathways: 62, total modules: 151, enrichment_ratio: 0.4105960264900662
# correctly_assigned_genes: 8289, total genes: 12939, correctly_assigned_ratio: 0.6406213772316253
# pathways: 51, total modules: 116, enrichment_ratio: 0.4396551724137931
# correctly_assigned_genes: 8192, total genes: 12939, correctly_assigned_ratio: 0.6331246618749516

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 67, total modules: 101, enrichment_ratio: 0.6633663366336634
# correctly_assigned_genes: 6810, total genes: 12939, correctly_assigned_ratio: 0.5263157894736842
# pathways: 70, total modules: 112, enrichment_ratio: 0.625
# correctly_assigned_genes: 6239, total genes: 12939, correctly_assigned_ratio: 0.4821856403122343
# pathways: 105, total modules: 151, enrichment_ratio: 0.695364238410596
# correctly_assigned_genes: 7803, total genes: 12939, correctly_assigned_ratio: 0.6030605147229307
# pathways: 77, total modules: 116, enrichment_ratio: 0.6637931034482759
# correctly_assigned_genes: 6063, total genes: 12939, correctly_assigned_ratio: 0.46858335265476464

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 51, total modules: 101, enrichment_ratio: 0.504950495049505
# correctly_assigned_genes: 6687, total genes: 12939, correctly_assigned_ratio: 0.5168096452585208
# pathways: 55, total modules: 112, enrichment_ratio: 0.49107142857142855
# correctly_assigned_genes: 6068, total genes: 12939, correctly_assigned_ratio: 0.4689697812813973
# pathways: 89, total modules: 151, enrichment_ratio: 0.5894039735099338
# correctly_assigned_genes: 7033, total genes: 12939, correctly_assigned_ratio: 0.5435505062215009
# pathways: 63, total modules: 116, enrichment_ratio: 0.5431034482758621
# correctly_assigned_genes: 8219, total genes: 12939, correctly_assigned_ratio: 0.635211376458768

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_nlog/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 47, total modules: 112, enrichment_ratio: 0.41964285714285715
# correctly_assigned_genes: 8751, total genes: 12939, correctly_assigned_ratio: 0.6763273823324832
# pathways: 65, total modules: 161, enrichment_ratio: 0.40372670807453415
# correctly_assigned_genes: 5926, total genes: 12939, correctly_assigned_ratio: 0.45799520828502976
# pathways: 60, total modules: 155, enrichment_ratio: 0.3870967741935484
# correctly_assigned_genes: 7559, total genes: 12939, correctly_assigned_ratio: 0.5842027977432568
# pathways: 59, total modules: 123, enrichment_ratio: 0.4796747967479675
# correctly_assigned_genes: 8195, total genes: 12939, correctly_assigned_ratio: 0.6333565190509313

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 76, total modules: 112, enrichment_ratio: 0.6785714285714286
# correctly_assigned_genes: 6866, total genes: 12939, correctly_assigned_ratio: 0.53064379009197
# pathways: 122, total modules: 161, enrichment_ratio: 0.7577639751552795
# correctly_assigned_genes: 6374, total genes: 12939, correctly_assigned_ratio: 0.4926192132313162
# pathways: 107, total modules: 155, enrichment_ratio: 0.6903225806451613
# correctly_assigned_genes: 7559, total genes: 12939, correctly_assigned_ratio: 0.5842027977432568
# pathways: 72, total modules: 123, enrichment_ratio: 0.5853658536585366
# correctly_assigned_genes: 5705, total genes: 12939, correctly_assigned_ratio: 0.44091506298786615

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 64, total modules: 112, enrichment_ratio: 0.5714285714285714
# correctly_assigned_genes: 6866, total genes: 12939, correctly_assigned_ratio: 0.53064379009197
# pathways: 83, total modules: 161, enrichment_ratio: 0.515527950310559
# correctly_assigned_genes: 5986, total genes: 12939, correctly_assigned_ratio: 0.4626323518046217
# pathways: 90, total modules: 155, enrichment_ratio: 0.5806451612903226
# correctly_assigned_genes: 6825, total genes: 12939, correctly_assigned_ratio: 0.5274750753535822
# pathways: 67, total modules: 123, enrichment_ratio: 0.5447154471544715
# correctly_assigned_genes: 8092, total genes: 12939, correctly_assigned_ratio: 0.6253960893422985

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_4S_0.7.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_I_0.7.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_III_0.7.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knd_reciprocal/Cell/module_IV_0.7.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 56, total modules: 125, enrichment_ratio: 0.448
# correctly_assigned_genes: 8598, total genes: 12939, correctly_assigned_ratio: 0.6645026663575238
# pathways: 71, total modules: 173, enrichment_ratio: 0.41040462427745666
# correctly_assigned_genes: 7405, total genes: 12939, correctly_assigned_ratio: 0.5723007960429709
# pathways: 89, total modules: 183, enrichment_ratio: 0.48633879781420764
# correctly_assigned_genes: 7549, total genes: 12939, correctly_assigned_ratio: 0.5834299404899915
# pathways: 68, total modules: 138, enrichment_ratio: 0.4927536231884058
# correctly_assigned_genes: 7489, total genes: 12939, correctly_assigned_ratio: 0.5787927969703995

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 90, total modules: 125, enrichment_ratio: 0.72
# correctly_assigned_genes: 6797, total genes: 12939, correctly_assigned_ratio: 0.5253110750444393
# pathways: 127, total modules: 173, enrichment_ratio: 0.7341040462427746
# correctly_assigned_genes: 6397, total genes: 12939, correctly_assigned_ratio: 0.49439678491382644
# pathways: 130, total modules: 183, enrichment_ratio: 0.7103825136612022
# correctly_assigned_genes: 7148, total genes: 12939, correctly_assigned_ratio: 0.552438364634052
# pathways: 90, total modules: 138, enrichment_ratio: 0.6521739130434783
# correctly_assigned_genes: 5961, total genes: 12939, correctly_assigned_ratio: 0.4607002086714584

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 62, total modules: 125, enrichment_ratio: 0.496
# correctly_assigned_genes: 8185, total genes: 12939, correctly_assigned_ratio: 0.632583661797666
# pathways: 93, total modules: 173, enrichment_ratio: 0.5375722543352601
# correctly_assigned_genes: 6731, total genes: 12939, correctly_assigned_ratio: 0.5202102171728882
# pathways: 109, total modules: 183, enrichment_ratio: 0.5956284153005464
# correctly_assigned_genes: 6164, total genes: 12939, correctly_assigned_ratio: 0.47638921091274444
# pathways: 76, total modules: 138, enrichment_ratio: 0.5507246376811594
# correctly_assigned_genes: 7076, total genes: 12939, correctly_assigned_ratio: 0.5468737924105418

# %%
module_4S = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Nlog_SWIM/knn/Cell/module_IV_10.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 39, total modules: 124, enrichment_ratio: 0.31451612903225806
# correctly_assigned_genes: 3899, total genes: 12939, correctly_assigned_ratio: 0.301337043048149
# pathways: 48, total modules: 127, enrichment_ratio: 0.3779527559055118
# correctly_assigned_genes: 4910, total genes: 12939, correctly_assigned_ratio: 0.37947291135327305
# pathways: 51, total modules: 137, enrichment_ratio: 0.3722627737226277
# correctly_assigned_genes: 4890, total genes: 12939, correctly_assigned_ratio: 0.3779271968467424
# pathways: 50, total modules: 133, enrichment_ratio: 0.37593984962406013
# correctly_assigned_genes: 4814, total genes: 12939, correctly_assigned_ratio: 0.372053481721926

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 44, total modules: 124, enrichment_ratio: 0.3548387096774194
# correctly_assigned_genes: 4192, total genes: 12939, correctly_assigned_ratio: 0.32398176056882294
# pathways: 42, total modules: 127, enrichment_ratio: 0.33070866141732286
# correctly_assigned_genes: 4034, total genes: 12939, correctly_assigned_ratio: 0.3117706159672309
# pathways: 44, total modules: 137, enrichment_ratio: 0.32116788321167883
# correctly_assigned_genes: 4154, total genes: 12939, correctly_assigned_ratio: 0.3210449030064147
# pathways: 44, total modules: 133, enrichment_ratio: 0.3308270676691729
# correctly_assigned_genes: 3947, total genes: 12939, correctly_assigned_ratio: 0.30504675786382257

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Nlog_SWIM_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="NLog_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 39, total modules: 124, enrichment_ratio: 0.31451612903225806
# correctly_assigned_genes: 3594, total genes: 12939, correctly_assigned_ratio: 0.2777648968235567
# pathways: 38, total modules: 127, enrichment_ratio: 0.2992125984251969
# correctly_assigned_genes: 3980, total genes: 12939, correctly_assigned_ratio: 0.30759718679959813
# pathways: 45, total modules: 137, enrichment_ratio: 0.3284671532846715
# correctly_assigned_genes: 4062, total genes: 12939, correctly_assigned_ratio: 0.31393461627637376
# pathways: 36, total modules: 133, enrichment_ratio: 0.2706766917293233
# correctly_assigned_genes: 3711, total genes: 12939, correctly_assigned_ratio: 0.28680732668676095

# %% [markdown]
# Reciprocal-SWIM

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_4S_0.8.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_I_0.8.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_III_0.8.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_binary/Cell/module_IV_0.8.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_binary_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_binary_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_binary_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_binary_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 41, total modules: 104, enrichment_ratio: 0.3942307692307692
# correctly_assigned_genes: 7772, total genes: 12939, correctly_assigned_ratio: 0.6006646572378082
# pathways: 45, total modules: 128, enrichment_ratio: 0.3515625
# correctly_assigned_genes: 6009, total genes: 12939, correctly_assigned_ratio: 0.46440992348713195
# pathways: 48, total modules: 119, enrichment_ratio: 0.40336134453781514
# correctly_assigned_genes: 8030, total genes: 12939, correctly_assigned_ratio: 0.6206043743720535
# pathways: 50, total modules: 120, enrichment_ratio: 0.4166666666666667
# correctly_assigned_genes: 6628, total genes: 12939, correctly_assigned_ratio: 0.5122497874642553

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_binary_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_binary_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 70, total modules: 104, enrichment_ratio: 0.6730769230769231
# correctly_assigned_genes: 6529, total genes: 12939, correctly_assigned_ratio: 0.5045985006569287
# pathways: 88, total modules: 128, enrichment_ratio: 0.6875
# correctly_assigned_genes: 6413, total genes: 12939, correctly_assigned_ratio: 0.49563335651905094
# pathways: 82, total modules: 119, enrichment_ratio: 0.6890756302521008
# correctly_assigned_genes: 7626, total genes: 12939, correctly_assigned_ratio: 0.5893809413401345
# pathways: 83, total modules: 120, enrichment_ratio: 0.6916666666666667
# correctly_assigned_genes: 6227, total genes: 12939, correctly_assigned_ratio: 0.48125821160831594

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_binary_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_binary_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 53, total modules: 104, enrichment_ratio: 0.5096153846153846
# correctly_assigned_genes: 7193, total genes: 12939, correctly_assigned_ratio: 0.555916222273746
# pathways: 55, total modules: 128, enrichment_ratio: 0.4296875
# correctly_assigned_genes: 5956, total genes: 12939, correctly_assigned_ratio: 0.4603137800448257
# pathways: 62, total modules: 119, enrichment_ratio: 0.5210084033613446
# correctly_assigned_genes: 8372, total genes: 12939, correctly_assigned_ratio: 0.6470360924337275
# pathways: 68, total modules: 120, enrichment_ratio: 0.5666666666666667
# correctly_assigned_genes: 7204, total genes: 12939, correctly_assigned_ratio: 0.5567663652523379

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_4S_0.4.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_I_0.4.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_III_0.4.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_linear/Cell/module_IV_0.4.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_linear_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_linear_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_linear_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_linear_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 54, total modules: 134, enrichment_ratio: 0.40298507462686567
# correctly_assigned_genes: 8380, total genes: 12939, correctly_assigned_ratio: 0.6476543782363398
# pathways: 68, total modules: 164, enrichment_ratio: 0.4146341463414634
# correctly_assigned_genes: 6856, total genes: 12939, correctly_assigned_ratio: 0.5298709328387047
# pathways: 85, total modules: 184, enrichment_ratio: 0.46195652173913043
# correctly_assigned_genes: 8266, total genes: 12939, correctly_assigned_ratio: 0.6388438055491151
# pathways: 65, total modules: 145, enrichment_ratio: 0.4482758620689655
# correctly_assigned_genes: 7244, total genes: 12939, correctly_assigned_ratio: 0.5598577942653992

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_linear_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_linear_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 92, total modules: 134, enrichment_ratio: 0.6865671641791045
# correctly_assigned_genes: 6491, total genes: 12939, correctly_assigned_ratio: 0.5016616430945204
# pathways: 120, total modules: 164, enrichment_ratio: 0.7317073170731707
# correctly_assigned_genes: 5948, total genes: 12939, correctly_assigned_ratio: 0.45969549424221345
# pathways: 142, total modules: 184, enrichment_ratio: 0.7717391304347826
# correctly_assigned_genes: 7997, total genes: 12939, correctly_assigned_ratio: 0.6180539454362779
# pathways: 101, total modules: 145, enrichment_ratio: 0.696551724137931
# correctly_assigned_genes: 6437, total genes: 12939, correctly_assigned_ratio: 0.4974882139268877

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_linear_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_linear_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 74, total modules: 134, enrichment_ratio: 0.5522388059701493
# correctly_assigned_genes: 7148, total genes: 12939, correctly_assigned_ratio: 0.552438364634052
# pathways: 83, total modules: 164, enrichment_ratio: 0.5060975609756098
# correctly_assigned_genes: 6338, total genes: 12939, correctly_assigned_ratio: 0.489836927119561
# pathways: 104, total modules: 184, enrichment_ratio: 0.5652173913043478
# correctly_assigned_genes: 7549, total genes: 12939, correctly_assigned_ratio: 0.5834299404899915
# pathways: 87, total modules: 145, enrichment_ratio: 0.6
# correctly_assigned_genes: 7960, total genes: 12939, correctly_assigned_ratio: 0.6151943735991963

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_nlog/Cell/module_IV_0.6.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_nlog_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_nlog_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratios_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_nlog_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_nlog_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 40, total modules: 109, enrichment_ratio: 0.3669724770642202
# correctly_assigned_genes: 8116, total genes: 12939, correctly_assigned_ratio: 0.6272509467501353
# pathways: 49, total modules: 119, enrichment_ratio: 0.4117647058823529
# correctly_assigned_genes: 6616, total genes: 12939, correctly_assigned_ratio: 0.5113223587603369
# pathways: 66, total modules: 160, enrichment_ratio: 0.4125
# correctly_assigned_genes: 7586, total genes: 12939, correctly_assigned_ratio: 0.5862895123270732
# pathways: 56, total modules: 124, enrichment_ratio: 0.45161290322580644
# correctly_assigned_genes: 7713, total genes: 12939, correctly_assigned_ratio: 0.5961047994435428

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_nlog_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_nlog_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 74, total modules: 109, enrichment_ratio: 0.6788990825688074
# correctly_assigned_genes: 6388, total genes: 12939, correctly_assigned_ratio: 0.4937012133858876
# pathways: 82, total modules: 119, enrichment_ratio: 0.6890756302521008
# correctly_assigned_genes: 6773, total genes: 12939, correctly_assigned_ratio: 0.5234562176366025
# pathways: 116, total modules: 160, enrichment_ratio: 0.725
# correctly_assigned_genes: 8260, total genes: 12939, correctly_assigned_ratio: 0.6383800911971559
# pathways: 82, total modules: 124, enrichment_ratio: 0.6612903225806451
# correctly_assigned_genes: 6117, total genes: 12939, correctly_assigned_ratio: 0.4727567818223974

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_nlog_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_nlog_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 61, total modules: 109, enrichment_ratio: 0.5596330275229358
# correctly_assigned_genes: 7625, total genes: 12939, correctly_assigned_ratio: 0.5893036556148079
# pathways: 54, total modules: 119, enrichment_ratio: 0.453781512605042
# correctly_assigned_genes: 6377, total genes: 12939, correctly_assigned_ratio: 0.49285107040729575
# pathways: 94, total modules: 160, enrichment_ratio: 0.5875
# correctly_assigned_genes: 8130, total genes: 12939, correctly_assigned_ratio: 0.6283329469047066
# pathways: 70, total modules: 124, enrichment_ratio: 0.5645161290322581
# correctly_assigned_genes: 7764, total genes: 12939, correctly_assigned_ratio: 0.6000463714351959

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_4S_0.6.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_I_0.6.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_III_0.6.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knd_reciprocal/Cell/module_IV_0.6.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 38, total modules: 102, enrichment_ratio: 0.37254901960784315
# correctly_assigned_genes: 8043, total genes: 12939, correctly_assigned_ratio: 0.6216090888012984
# pathways: 48, total modules: 129, enrichment_ratio: 0.37209302325581395
# correctly_assigned_genes: 6889, total genes: 12939, correctly_assigned_ratio: 0.5324213617744803
# pathways: 64, total modules: 148, enrichment_ratio: 0.43243243243243246
# correctly_assigned_genes: 8544, total genes: 12939, correctly_assigned_ratio: 0.660329237189891
# pathways: 53, total modules: 118, enrichment_ratio: 0.4491525423728814
# correctly_assigned_genes: 7615, total genes: 12939, correctly_assigned_ratio: 0.5885307983615427

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 71, total modules: 102, enrichment_ratio: 0.696078431372549
# correctly_assigned_genes: 8109, total genes: 12939, correctly_assigned_ratio: 0.6267099466728495
# pathways: 88, total modules: 129, enrichment_ratio: 0.6821705426356589
# correctly_assigned_genes: 6972, total genes: 12939, correctly_assigned_ratio: 0.5388360769765824
# pathways: 106, total modules: 148, enrichment_ratio: 0.7162162162162162
# correctly_assigned_genes: 7950, total genes: 12939, correctly_assigned_ratio: 0.6144215163459309
# pathways: 82, total modules: 118, enrichment_ratio: 0.6949152542372882
# correctly_assigned_genes: 6513, total genes: 12939, correctly_assigned_ratio: 0.5033619290517042

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knd_reciprocal_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 46, total modules: 102, enrichment_ratio: 0.45098039215686275
# correctly_assigned_genes: 6783, total genes: 12939, correctly_assigned_ratio: 0.5242290748898678
# pathways: 62, total modules: 129, enrichment_ratio: 0.4806201550387597
# correctly_assigned_genes: 6590, total genes: 12939, correctly_assigned_ratio: 0.5093129299018472
# pathways: 94, total modules: 148, enrichment_ratio: 0.6351351351351351
# correctly_assigned_genes: 7982, total genes: 12939, correctly_assigned_ratio: 0.6168946595563799
# pathways: 69, total modules: 118, enrichment_ratio: 0.5847457627118644
# correctly_assigned_genes: 8502, total genes: 12939, correctly_assigned_ratio: 0.6570832367261766

# %%
module_4S = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_4S_10.json")
module_I = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_I_10.json")
module_III = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_III_10.json")
module_IV = module_to_dict("../../parameter_tuning/Reciprocal_SWIM/knn/Cell/module_IV_10.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knn_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knn_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knn_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knn_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 36, total modules: 125, enrichment_ratio: 0.288
# correctly_assigned_genes: 3633, total genes: 12939, correctly_assigned_ratio: 0.28077904011129146
# pathways: 48, total modules: 131, enrichment_ratio: 0.366412213740458
# correctly_assigned_genes: 4658, total genes: 12939, correctly_assigned_ratio: 0.35999690857098693
# pathways: 50, total modules: 125, enrichment_ratio: 0.4
# correctly_assigned_genes: 5148, total genes: 12939, correctly_assigned_ratio: 0.3978669139809877
# pathways: 45, total modules: 133, enrichment_ratio: 0.3383458646616541
# correctly_assigned_genes: 4701, total genes: 12939, correctly_assigned_ratio: 0.3633201947600278

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knn_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knn_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 34, total modules: 125, enrichment_ratio: 0.272
# correctly_assigned_genes: 3121, total genes: 12939, correctly_assigned_ratio: 0.24120874874410697
# pathways: 43, total modules: 131, enrichment_ratio: 0.3282442748091603
# correctly_assigned_genes: 4350, total genes: 12939, correctly_assigned_ratio: 0.336192905170415
# pathways: 40, total modules: 125, enrichment_ratio: 0.32
# correctly_assigned_genes: 4374, total genes: 12939, correctly_assigned_ratio: 0.3380477625782518
# pathways: 39, total modules: 133, enrichment_ratio: 0.2932330827067669
# correctly_assigned_genes: 3568, total genes: 12939, correctly_assigned_ratio: 0.27575546796506684

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Reciprocal_SWIM_knn_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Reciprocal_SWIM_knn_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 35, total modules: 125, enrichment_ratio: 0.28
# correctly_assigned_genes: 3435, total genes: 12939, correctly_assigned_ratio: 0.2654764664966381
# pathways: 37, total modules: 131, enrichment_ratio: 0.2824427480916031
# correctly_assigned_genes: 3595, total genes: 12939, correctly_assigned_ratio: 0.2778421825488832
# pathways: 38, total modules: 125, enrichment_ratio: 0.304
# correctly_assigned_genes: 3839, total genes: 12939, correctly_assigned_ratio: 0.2966998995285571
# pathways: 47, total modules: 133, enrichment_ratio: 0.3533834586466165
# correctly_assigned_genes: 4710, total genes: 12939, correctly_assigned_ratio: 0.3640157662879666

# %% [markdown]
# PCC_Leiden

# %%
module_4S = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_4S_0.35.json")
module_I = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_I_0.35.json")
module_III = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_III_0.35.json")
module_IV = module_to_dict("../../parameter_tuning/PCC_Leiden/Cell/module_IV_0.35.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_Leiden_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_Leiden_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_Leiden_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_Leiden_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 62, total modules: 131, enrichment_ratio: 0.4732824427480916
# correctly_assigned_genes: 9899, total genes: 12939, correctly_assigned_ratio: 0.7650513950073421
# pathways: 50, total modules: 130, enrichment_ratio: 0.38461538461538464
# correctly_assigned_genes: 7339, total genes: 12939, correctly_assigned_ratio: 0.5671999381714198
# pathways: 46, total modules: 94, enrichment_ratio: 0.48936170212765956
# correctly_assigned_genes: 10497, total genes: 12939, correctly_assigned_ratio: 0.8112682587526084
# pathways: 43, total modules: 82, enrichment_ratio: 0.524390243902439
# correctly_assigned_genes: 10640, total genes: 12939, correctly_assigned_ratio: 0.8223201174743024

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_Leiden_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_Leiden_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 91, total modules: 131, enrichment_ratio: 0.6946564885496184
# correctly_assigned_genes: 6716, total genes: 12939, correctly_assigned_ratio: 0.5190509312929902
# pathways: 88, total modules: 130, enrichment_ratio: 0.676923076923077
# correctly_assigned_genes: 7225, total genes: 12939, correctly_assigned_ratio: 0.558389365484195
# pathways: 68, total modules: 94, enrichment_ratio: 0.723404255319149
# correctly_assigned_genes: 6461, total genes: 12939, correctly_assigned_ratio: 0.4993430713347245
# pathways: 56, total modules: 82, enrichment_ratio: 0.6829268292682927
# correctly_assigned_genes: 9193, total genes: 12939, correctly_assigned_ratio: 0.7104876729268104

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="PCC_Leiden_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="PCC_Leiden_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 70, total modules: 131, enrichment_ratio: 0.5343511450381679
# correctly_assigned_genes: 6477, total genes: 12939, correctly_assigned_ratio: 0.5005796429399489
# pathways: 69, total modules: 130, enrichment_ratio: 0.5307692307692308
# correctly_assigned_genes: 7165, total genes: 12939, correctly_assigned_ratio: 0.5537522219646032
# pathways: 57, total modules: 94, enrichment_ratio: 0.6063829787234043
# correctly_assigned_genes: 9815, total genes: 12939, correctly_assigned_ratio: 0.7585593940799135
# pathways: 52, total modules: 82, enrichment_ratio: 0.6341463414634146
# correctly_assigned_genes: 9509, total genes: 12939, correctly_assigned_ratio: 0.7349099621299946

# %% [markdown]
# hdWGCNA

# %%
module_4S = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_4S_2.5.json")
module_I = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_I_2.5.json")
module_III = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_III_2.5.json")
module_IV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/hdWGCNA/module_IV_2.5.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="hdWGCNA_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="hdWGCNA_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 77, total modules: 129, enrichment_ratio: 0.5968992248062015
# correctly_assigned_genes: 1938, total genes: 12939, correctly_assigned_ratio: 0.14977973568281938
# pathways: 65, total modules: 131, enrichment_ratio: 0.4961832061068702
# correctly_assigned_genes: 2380, total genes: 12939, correctly_assigned_ratio: 0.18394002627714662
# pathways: 39, total modules: 62, enrichment_ratio: 0.6290322580645161
# correctly_assigned_genes: 3032, total genes: 12939, correctly_assigned_ratio: 0.2343303191900456
# pathways: 64, total modules: 128, enrichment_ratio: 0.5
# correctly_assigned_genes: 1879, total genes: 12939, correctly_assigned_ratio: 0.14521987788855398

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="hdWGCNA_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 110, total modules: 129, enrichment_ratio: 0.8527131782945736
# correctly_assigned_genes: 2087, total genes: 12939, correctly_assigned_ratio: 0.1612953087564727
# pathways: 101, total modules: 131, enrichment_ratio: 0.7709923664122137
# correctly_assigned_genes: 2547, total genes: 12939, correctly_assigned_ratio: 0.1968467424066775
# pathways: 41, total modules: 62, enrichment_ratio: 0.6612903225806451
# correctly_assigned_genes: 1661, total genes: 12939, correctly_assigned_ratio: 0.12837158976736995
# pathways: 102, total modules: 128, enrichment_ratio: 0.796875
# correctly_assigned_genes: 2079, total genes: 12939, correctly_assigned_ratio: 0.1606770229538604

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="hdWGCNA_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="hdWGCNA_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 92, total modules: 129, enrichment_ratio: 0.7131782945736435
# correctly_assigned_genes: 2255, total genes: 12939, correctly_assigned_ratio: 0.1742793106113301
# pathways: 78, total modules: 131, enrichment_ratio: 0.5954198473282443
# correctly_assigned_genes: 2543, total genes: 12939, correctly_assigned_ratio: 0.19653759950537136
# pathways: 39, total modules: 62, enrichment_ratio: 0.6290322580645161
# correctly_assigned_genes: 2402, total genes: 12939, correctly_assigned_ratio: 0.1856403122343303
# pathways: 78, total modules: 128, enrichment_ratio: 0.609375
# correctly_assigned_genes: 1784, total genes: 12939, correctly_assigned_ratio: 0.13787773398253342

# %% [markdown]
# TOM_Leiden

# %%
module_4S = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_4S_0.1.json")
module_I = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_I_0.1.json")
module_III = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_III_0.1.json")
module_IV = module_to_dict("../../parameter_tuning/hdWGCNA/Cell/TOM_Leiden/module_IV_0.1.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="TOM_Leiden_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="TOM_Leiden_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 9, total modules: 11, enrichment_ratio: 0.8181818181818182
# correctly_assigned_genes: 318, total genes: 12939, correctly_assigned_ratio: 0.024576860653837237
# pathways: 14, total modules: 21, enrichment_ratio: 0.6666666666666666
# correctly_assigned_genes: 825, total genes: 12939, correctly_assigned_ratio: 0.06376072339438905
# pathways: 21, total modules: 34, enrichment_ratio: 0.6176470588235294
# correctly_assigned_genes: 2911, total genes: 12939, correctly_assigned_ratio: 0.2249787464255352
# pathways: 16, total modules: 18, enrichment_ratio: 0.8888888888888888
# correctly_assigned_genes: 553, total genes: 12939, correctly_assigned_ratio: 0.042739006105572304

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="TOM_Leiden_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 11, total modules: 11, enrichment_ratio: 1.0
# correctly_assigned_genes: 329, total genes: 12939, correctly_assigned_ratio: 0.025427003632429092
# pathways: 20, total modules: 21, enrichment_ratio: 0.9523809523809523
# correctly_assigned_genes: 880, total genes: 12939, correctly_assigned_ratio: 0.06801143828734833
# pathways: 29, total modules: 34, enrichment_ratio: 0.8529411764705882
# correctly_assigned_genes: 2955, total genes: 12939, correctly_assigned_ratio: 0.22837931833990263
# pathways: 15, total modules: 18, enrichment_ratio: 0.8333333333333334
# correctly_assigned_genes: 491, total genes: 12939, correctly_assigned_ratio: 0.037947291135327306

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="TOM_Leiden_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="TOM_Leiden_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 10, total modules: 11, enrichment_ratio: 0.9090909090909091
# correctly_assigned_genes: 324, total genes: 12939, correctly_assigned_ratio: 0.025040575005796428
# pathways: 17, total modules: 21, enrichment_ratio: 0.8095238095238095
# correctly_assigned_genes: 864, total genes: 12939, correctly_assigned_ratio: 0.06677486668212382
# pathways: 25, total modules: 34, enrichment_ratio: 0.7352941176470589
# correctly_assigned_genes: 2920, total genes: 12939, correctly_assigned_ratio: 0.22567431795347398
# pathways: 16, total modules: 18, enrichment_ratio: 0.8888888888888888
# correctly_assigned_genes: 483, total genes: 12939, correctly_assigned_ratio: 0.03732900533271505

# %% [markdown]
# Hotspot

# %%
module_4S = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_4S_50.json")
module_I = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_I_50.json")
module_III = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_III_50.json")
module_IV = module_to_dict("../../parameter_tuning/Hotspot/Cell/module_IV_50.json")

enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="KEGG_2021_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_KEGG_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Hotspot_KEGG_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="Reactome_2022", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_Reactome_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Hotspot_Reactome_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 49, total modules: 103, enrichment_ratio: 0.47572815533980584
# correctly_assigned_genes: 5286, total genes: 12939, correctly_assigned_ratio: 0.40853234407604916
# pathways: 45, total modules: 112, enrichment_ratio: 0.4017857142857143
# correctly_assigned_genes: 4303, total genes: 12939, correctly_assigned_ratio: 0.332560476080068
# pathways: 46, total modules: 113, enrichment_ratio: 0.40707964601769914
# correctly_assigned_genes: 4755, total genes: 12939, correctly_assigned_ratio: 0.36749362392766055
# pathways: 44, total modules: 102, enrichment_ratio: 0.43137254901960786
# correctly_assigned_genes: 4622, total genes: 12939, correctly_assigned_ratio: 0.3572146224592318

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="BioPlex_2017", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_BioPlex_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Hotspot_BioPlex_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 32, total modules: 103, enrichment_ratio: 0.3106796116504854
# correctly_assigned_genes: 3532, total genes: 12939, correctly_assigned_ratio: 0.2729731818533117
# pathways: 39, total modules: 112, enrichment_ratio: 0.3482142857142857
# correctly_assigned_genes: 3559, total genes: 12939, correctly_assigned_ratio: 0.2750598964371281
# pathways: 38, total modules: 113, enrichment_ratio: 0.336283185840708
# correctly_assigned_genes: 4142, total genes: 12939, correctly_assigned_ratio: 0.3201174743024963
# pathways: 34, total modules: 102, enrichment_ratio: 0.3333333333333333
# correctly_assigned_genes: 3529, total genes: 12939, correctly_assigned_ratio: 0.2727413246773321

# %%
enrichment_ratio_4S, correctly_assigned_ratio_4S = enrichment(modules=module_4S, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_I, correctly_assigned_ratio_I = enrichment(modules=module_I, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_III, correctly_assigned_ratio_III = enrichment(modules=module_III, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)
enrichment_ratio_IV, correctly_assigned_ratio_IV = enrichment(modules=module_IV, gene_sets="WikiPathway_2023_Human", min_module_size=4, total_genes=total_genes)

list_to_txt(path="Hotspot_WikiPathway_enrichment_ratio.txt", number_list=[enrichment_ratio_4S, enrichment_ratio_I, enrichment_ratio_III, enrichment_ratio_IV])
list_to_txt(path="Hotspot_WikiPathway_correctly_assigned_ratio.txt", number_list=[correctly_assigned_ratio_4S, correctly_assigned_ratio_I, correctly_assigned_ratio_III, correctly_assigned_ratio_IV])
# Out:
# pathways: 27, total modules: 103, enrichment_ratio: 0.2621359223300971
# correctly_assigned_genes: 3364, total genes: 12939, correctly_assigned_ratio: 0.2599891799984543
# pathways: 40, total modules: 112, enrichment_ratio: 0.35714285714285715
# correctly_assigned_genes: 3702, total genes: 12939, correctly_assigned_ratio: 0.28611175515882215
# pathways: 43, total modules: 113, enrichment_ratio: 0.3805309734513274
# correctly_assigned_genes: 4361, total genes: 12939, correctly_assigned_ratio: 0.3370430481490069
# pathways: 30, total modules: 102, enrichment_ratio: 0.29411764705882354
# correctly_assigned_genes: 3287, total genes: 12939, correctly_assigned_ratio: 0.2540381791483113
